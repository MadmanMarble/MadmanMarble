# %% [markdown]
# <a href="https://colab.research.google.com/github/MadmanMarble/MadmanMarble/blob/main/training_data_organization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook for data exploration - looking at the planet crop data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import shutil
import hashlib

# %%
# !pip install rasterio
import rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.9-cp310-cp310-manylinux2014_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 43.3 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.1)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.9 snuggs-1.4.7

# %%
# !mkdir /content/data
# !mkdir /content/image

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/stacked_data/landsat.zip -d /content/data/
# Out:
# Archive:  /content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/stacked_data/landsat.zip
#    creating: /content/data/content/export/landsat/
#   inflating: /content/data/content/export/landsat/4_stacked.tif
#   inflating: /content/data/content/export/landsat/3_stacked.tif
#   inflating: /content/data/content/export/landsat/5_stacked.tif
#   inflating: /content/data/content/export/landsat/2_stacked.tif
#   inflating: /content/data/content/export/landsat/1_stacked.tif

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/images/"
tif_source = "/content/data/content/export/landsat/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 4_stacked.tif to Google Drive folder.
# Copied 3_stacked.tif to Google Drive folder.
# Copied 5_stacked.tif to Google Drive folder.
# Copied 2_stacked.tif to Google Drive folder.
# Copied 1_stacked.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/naip_128x128data/utm4/dem/"
tif_source = "/content/data/content/exports/dem/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 23020_dem.tif to Google Drive folder.
# Copied 23450_dem.tif to Google Drive folder.
# Copied 23422_dem.tif to Google Drive folder.
# Copied 23213_dem.tif to Google Drive folder.
# Copied 22708_dem.tif to Google Drive folder.
# Copied 23413_dem.tif to Google Drive folder.
# Copied 23373_dem.tif to Google Drive folder.
# Copied 23545_dem.tif to Google Drive folder.
# Copied 23788_dem.tif to Google Drive folder.
# Copied 23226_dem.tif to Google Drive folder.
# Copied 23499_dem.tif to Google Drive folder.
# Copied 23670_dem.tif to Google Drive folder.
# Copied 23946_dem.tif to Google Drive folder.
# Copied 23796_dem.tif to Google Drive folder.
# Copied 23925_dem.tif to Google Drive folder.
# Copied 22755_dem.tif to Google Drive folder.
# Copied 22777_dem.tif to Google Drive folder.
# Copied 22906_dem.tif to Google Drive folder.
# Copied 23791_dem.tif to Google Drive folder.
# Copied 23419_dem.tif to Google Drive folder.
# Copied 23243_dem.tif to Google Drive folder.
# Copied 23569_dem.tif to Google Drive folder.
# Copied 22973_dem.tif to Google Drive folder.
# Copied 23616_dem.tif to Google Drive folder.
# Copied 23388_dem.tif to Google Drive folder.
# Copied 22990_dem.tif to Google Drive folder.
# Copied 22738_dem.tif to Google Drive folder.
# Copied 23904_dem.tif to Google Drive folder.
# Copied 23336_dem.tif to Google Drive folder.
# Copied 22474_dem.tif to Google Drive folder.
# Copied 22306_dem.tif to Google Drive folder.
# Copied 22439_dem.tif to Google Drive folder.
# Copied 22818_dem.tif to Google Drive folder.
# Copied 22658_dem.tif to Google Drive folder.
# Copied 22329_dem.tif to Google Drive folder.
# Copied 23539_dem.tif to Google Drive folder.
# Copied 22388_dem.tif to Google Drive folder.
# Copied 23562_dem.tif to Google Drive folder.
# Copied 22305_dem.tif to Google Drive folder.
# Copied 22882_dem.tif to Google Drive folder.
# Copied 23065_dem.tif to Google Drive folder.
# Copied 23244_dem.tif to Google Drive folder.
# Copied 23383_dem.tif to Google Drive folder.
# Copied 23969_dem.tif to Google Drive folder.
# Copied 23930_dem.tif to Google Drive folder.
# Copied 22627_dem.tif to Google Drive folder.
# Copied 22461_dem.tif to Google Drive folder.
# Copied 23504_dem.tif to Google Drive folder.
# Copied 22710_dem.tif to Google Drive folder.
# Copied 23078_dem.tif to Google Drive folder.
# Copied 22459_dem.tif to Google Drive folder.
# Copied 23769_dem.tif to Google Drive folder.
# Copied 23266_dem.tif to Google Drive folder.
# Copied 23271_dem.tif to Google Drive folder.
# Copied 23807_dem.tif to Google Drive folder.
# Copied 23814_dem.tif to Google Drive folder.
# Copied 23403_dem.tif to Google Drive folder.
# Copied 23053_dem.tif to Google Drive folder.
# Copied 23047_dem.tif to Google Drive folder.
# Copied 23521_dem.tif to Google Drive folder.
# Copied 23527_dem.tif to Google Drive folder.
# Copied 23498_dem.tif to Google Drive folder.
# Copied 23236_dem.tif to Google Drive folder.
# Copied 23509_dem.tif to Google Drive folder.
# Copied 23329_dem.tif to Google Drive folder.
# Copied 23592_dem.tif to Google Drive folder.
# Copied 23468_dem.tif to Google Drive folder.
# Copied 22854_dem.tif to Google Drive folder.
# Copied 23164_dem.tif to Google Drive folder.
# Copied 23649_dem.tif to Google Drive folder.
# Copied 22435_dem.tif to Google Drive folder.
# Copied 23851_dem.tif to Google Drive folder.
# Copied 22531_dem.tif to Google Drive folder.
# Copied 22548_dem.tif to Google Drive folder.
# Copied 22390_dem.tif to Google Drive folder.
# Copied 23369_dem.tif to Google Drive folder.
# Copied 22811_dem.tif to Google Drive folder.
# Copied 23774_dem.tif to Google Drive folder.
# Copied 22602_dem.tif to Google Drive folder.
# Copied 23640_dem.tif to Google Drive folder.
# Copied 22327_dem.tif to Google Drive folder.
# Copied 23767_dem.tif to Google Drive folder.
# Copied 23354_dem.tif to Google Drive folder.
# Copied 23532_dem.tif to Google Drive folder.
# Copied 22795_dem.tif to Google Drive folder.
# Copied 23567_dem.tif to Google Drive folder.
# Copied 23283_dem.tif to Google Drive folder.
# Copied 22804_dem.tif to Google Drive folder.
# Copied 23401_dem.tif to Google Drive folder.
# Copied 23722_dem.tif to Google Drive folder.
# Copied 22989_dem.tif to Google Drive folder.
# Copied 23321_dem.tif to Google Drive folder.
# Copied 23227_dem.tif to Google Drive folder.
# Copied 23834_dem.tif to Google Drive folder.
# Copied 23725_dem.tif to Google Drive folder.
# Copied 22526_dem.tif to Google Drive folder.
# Copied 23251_dem.tif to Google Drive folder.
# Copied 23377_dem.tif to Google Drive folder.
# Copied 22457_dem.tif to Google Drive folder.
# Copied 23869_dem.tif to Google Drive folder.
# Copied 23690_dem.tif to Google Drive folder.
# Copied 23550_dem.tif to Google Drive folder.
# Copied 23929_dem.tif to Google Drive folder.
# Copied 23974_dem.tif to Google Drive folder.
# Copied 22588_dem.tif to Google Drive folder.
# Copied 22490_dem.tif to Google Drive folder.
# Copied 22711_dem.tif to Google Drive folder.
# Copied 23310_dem.tif to Google Drive folder.
# Copied 23882_dem.tif to Google Drive folder.
# Copied 23628_dem.tif to Google Drive folder.
# Copied 23296_dem.tif to Google Drive folder.
# Copied 22524_dem.tif to Google Drive folder.
# Copied 23147_dem.tif to Google Drive folder.
# Copied 22798_dem.tif to Google Drive folder.
# Copied 23515_dem.tif to Google Drive folder.
# Copied 22664_dem.tif to Google Drive folder.
# Copied 23104_dem.tif to Google Drive folder.
# Copied 23712_dem.tif to Google Drive folder.
# Copied 23209_dem.tif to Google Drive folder.
# Copied 23810_dem.tif to Google Drive folder.
# Copied 23789_dem.tif to Google Drive folder.
# Copied 23956_dem.tif to Google Drive folder.
# Copied 23305_dem.tif to Google Drive folder.
# Copied 23816_dem.tif to Google Drive folder.
# Copied 22417_dem.tif to Google Drive folder.
# Copied 23576_dem.tif to Google Drive folder.
# Copied 22412_dem.tif to Google Drive folder.
# Copied 22581_dem.tif to Google Drive folder.
# Copied 22438_dem.tif to Google Drive folder.
# Copied 23694_dem.tif to Google Drive folder.
# Copied 23589_dem.tif to Google Drive folder.
# Copied 23911_dem.tif to Google Drive folder.
# Copied 22667_dem.tif to Google Drive folder.
# Copied 23040_dem.tif to Google Drive folder.
# Copied 22344_dem.tif to Google Drive folder.
# Copied 23697_dem.tif to Google Drive folder.
# Copied 22472_dem.tif to Google Drive folder.
# Copied 22712_dem.tif to Google Drive folder.
# Copied 22987_dem.tif to Google Drive folder.
# Copied 23752_dem.tif to Google Drive folder.
# Copied 23447_dem.tif to Google Drive folder.
# Copied 23879_dem.tif to Google Drive folder.
# Copied 22655_dem.tif to Google Drive folder.
# Copied 22885_dem.tif to Google Drive folder.
# Copied 23612_dem.tif to Google Drive folder.
# Copied 23716_dem.tif to Google Drive folder.
# Copied 22303_dem.tif to Google Drive folder.
# Copied 23228_dem.tif to Google Drive folder.
# Copied 23552_dem.tif to Google Drive folder.
# Copied 23196_dem.tif to Google Drive folder.
# Copied 23508_dem.tif to Google Drive folder.
# Copied 23316_dem.tif to Google Drive folder.
# Copied 22331_dem.tif to Google Drive folder.
# Copied 22477_dem.tif to Google Drive folder.
# Copied 23116_dem.tif to Google Drive folder.
# Copied 22402_dem.tif to Google Drive folder.
# Copied 22966_dem.tif to Google Drive folder.
# Copied 22693_dem.tif to Google Drive folder.
# Copied 22881_dem.tif to Google Drive folder.
# Copied 22894_dem.tif to Google Drive folder.
# Copied 23815_dem.tif to Google Drive folder.
# Copied 23792_dem.tif to Google Drive folder.
# Copied 23015_dem.tif to Google Drive folder.
# Copied 23135_dem.tif to Google Drive folder.
# Copied 22706_dem.tif to Google Drive folder.
# Copied 22750_dem.tif to Google Drive folder.
# Copied 23412_dem.tif to Google Drive folder.
# Copied 23852_dem.tif to Google Drive folder.
# Copied 23208_dem.tif to Google Drive folder.
# Copied 22473_dem.tif to Google Drive folder.
# Copied 23938_dem.tif to Google Drive folder.
# Copied 23586_dem.tif to Google Drive folder.
# Copied 23190_dem.tif to Google Drive folder.
# Copied 22643_dem.tif to Google Drive folder.
# Copied 23398_dem.tif to Google Drive folder.
# Copied 22358_dem.tif to Google Drive folder.
# Copied 23614_dem.tif to Google Drive folder.
# Copied 22528_dem.tif to Google Drive folder.
# Copied 23036_dem.tif to Google Drive folder.
# Copied 22337_dem.tif to Google Drive folder.
# Copied 22674_dem.tif to Google Drive folder.
# Copied 23635_dem.tif to Google Drive folder.
# Copied 22956_dem.tif to Google Drive folder.
# Copied 23481_dem.tif to Google Drive folder.
# Copied 22976_dem.tif to Google Drive folder.
# Copied 22901_dem.tif to Google Drive folder.
# Copied 23960_dem.tif to Google Drive folder.
# Copied 23512_dem.tif to Google Drive folder.
# Copied 22423_dem.tif to Google Drive folder.
# Copied 22314_dem.tif to Google Drive folder.
# Copied 23060_dem.tif to Google Drive folder.
# Copied 23171_dem.tif to Google Drive folder.
# Copied 23842_dem.tif to Google Drive folder.
# Copied 22816_dem.tif to Google Drive folder.
# Copied 22491_dem.tif to Google Drive folder.
# Copied 23781_dem.tif to Google Drive folder.
# Copied 23250_dem.tif to Google Drive folder.
# Copied 23172_dem.tif to Google Drive folder.
# Copied 22717_dem.tif to Google Drive folder.
# Copied 23471_dem.tif to Google Drive folder.
# Copied 23747_dem.tif to Google Drive folder.
# Copied 22571_dem.tif to Google Drive folder.
# Copied 23775_dem.tif to Google Drive folder.
# Copied 22935_dem.tif to Google Drive folder.
# Copied 23574_dem.tif to Google Drive folder.
# Copied 23274_dem.tif to Google Drive folder.
# Copied 22560_dem.tif to Google Drive folder.
# Copied 23194_dem.tif to Google Drive folder.
# Copied 23875_dem.tif to Google Drive folder.
# Copied 22561_dem.tif to Google Drive folder.
# Copied 22807_dem.tif to Google Drive folder.
# Copied 22525_dem.tif to Google Drive folder.
# Copied 22372_dem.tif to Google Drive folder.
# Copied 22971_dem.tif to Google Drive folder.
# Copied 23806_dem.tif to Google Drive folder.
# Copied 22857_dem.tif to Google Drive folder.
# Copied 22484_dem.tif to Google Drive folder.
# Copied 22723_dem.tif to Google Drive folder.
# Copied 23706_dem.tif to Google Drive folder.
# Copied 23669_dem.tif to Google Drive folder.
# Copied 23907_dem.tif to Google Drive folder.
# Copied 23102_dem.tif to Google Drive folder.
# Copied 23633_dem.tif to Google Drive folder.
# Copied 23704_dem.tif to Google Drive folder.
# Copied 23557_dem.tif to Google Drive folder.
# Copied 23615_dem.tif to Google Drive folder.
# Copied 23425_dem.tif to Google Drive folder.
# Copied 22770_dem.tif to Google Drive folder.
# Copied 23682_dem.tif to Google Drive folder.
# Copied 22915_dem.tif to Google Drive folder.
# Copied 23679_dem.tif to Google Drive folder.
# Copied 23484_dem.tif to Google Drive folder.
# Copied 22789_dem.tif to Google Drive folder.
# Copied 23773_dem.tif to Google Drive folder.
# Copied 23641_dem.tif to Google Drive folder.
# Copied 23656_dem.tif to Google Drive folder.
# Copied 22356_dem.tif to Google Drive folder.
# Copied 23314_dem.tif to Google Drive folder.
# Copied 22610_dem.tif to Google Drive folder.
# Copied 23427_dem.tif to Google Drive folder.
# Copied 22713_dem.tif to Google Drive folder.
# Copied 22796_dem.tif to Google Drive folder.
# Copied 23913_dem.tif to Google Drive folder.
# Copied 23175_dem.tif to Google Drive folder.
# Copied 23347_dem.tif to Google Drive folder.
# Copied 23765_dem.tif to Google Drive folder.
# Copied 22734_dem.tif to Google Drive folder.
# Copied 22954_dem.tif to Google Drive folder.
# Copied 22853_dem.tif to Google Drive folder.
# Copied 23961_dem.tif to Google Drive folder.
# Copied 23944_dem.tif to Google Drive folder.
# Copied 23903_dem.tif to Google Drive folder.
# Copied 22507_dem.tif to Google Drive folder.
# Copied 22369_dem.tif to Google Drive folder.
# Copied 23546_dem.tif to Google Drive folder.
# Copied 22689_dem.tif to Google Drive folder.
# Copied 23187_dem.tif to Google Drive folder.
# Copied 23230_dem.tif to Google Drive folder.
# Copied 23702_dem.tif to Google Drive folder.
# Copied 23541_dem.tif to Google Drive folder.
# Copied 23530_dem.tif to Google Drive folder.
# Copied 22480_dem.tif to Google Drive folder.
# Copied 22651_dem.tif to Google Drive folder.
# Copied 22325_dem.tif to Google Drive folder.
# Copied 23393_dem.tif to Google Drive folder.
# Copied 22780_dem.tif to Google Drive folder.
# Copied 22586_dem.tif to Google Drive folder.
# Copied 23610_dem.tif to Google Drive folder.
# Copied 22373_dem.tif to Google Drive folder.
# Copied 22774_dem.tif to Google Drive folder.
# Copied 23927_dem.tif to Google Drive folder.
# Copied 23624_dem.tif to Google Drive folder.
# Copied 23547_dem.tif to Google Drive folder.
# Copied 23024_dem.tif to Google Drive folder.
# Copied 22321_dem.tif to Google Drive folder.
# Copied 23075_dem.tif to Google Drive folder.
# Copied 23111_dem.tif to Google Drive folder.
# Copied 23737_dem.tif to Google Drive folder.
# Copied 23561_dem.tif to Google Drive folder.
# Copied 23399_dem.tif to Google Drive folder.
# Copied 23764_dem.tif to Google Drive folder.
# Copied 22918_dem.tif to Google Drive folder.
# Copied 22628_dem.tif to Google Drive folder.
# Copied 23317_dem.tif to Google Drive folder.
# Copied 23951_dem.tif to Google Drive folder.
# Copied 23643_dem.tif to Google Drive folder.
# Copied 23337_dem.tif to Google Drive folder.
# Copied 22589_dem.tif to Google Drive folder.
# Copied 23943_dem.tif to Google Drive folder.
# Copied 23136_dem.tif to Google Drive folder.
# Copied 22944_dem.tif to Google Drive folder.
# Copied 23729_dem.tif to Google Drive folder.
# Copied 23174_dem.tif to Google Drive folder.
# Copied 23658_dem.tif to Google Drive folder.
# Copied 22862_dem.tif to Google Drive folder.
# Copied 22495_dem.tif to Google Drive folder.
# Copied 23370_dem.tif to Google Drive folder.
# Copied 23070_dem.tif to Google Drive folder.
# Copied 23758_dem.tif to Google Drive folder.
# Copied 22912_dem.tif to Google Drive folder.
# Copied 22398_dem.tif to Google Drive folder.
# Copied 23708_dem.tif to Google Drive folder.
# Copied 22847_dem.tif to Google Drive folder.
# Copied 23776_dem.tif to Google Drive folder.
# Copied 23478_dem.tif to Google Drive folder.
# Copied 22841_dem.tif to Google Drive folder.
# Copied 23058_dem.tif to Google Drive folder.
# Copied 22848_dem.tif to Google Drive folder.
# Copied 23311_dem.tif to Google Drive folder.
# Copied 23120_dem.tif to Google Drive folder.
# Copied 22949_dem.tif to Google Drive folder.
# Copied 23328_dem.tif to Google Drive folder.
# Copied 22964_dem.tif to Google Drive folder.
# Copied 23516_dem.tif to Google Drive folder.
# Copied 22886_dem.tif to Google Drive folder.
# Copied 23661_dem.tif to Google Drive folder.
# Copied 22497_dem.tif to Google Drive folder.
# Copied 23497_dem.tif to Google Drive folder.
# Copied 23808_dem.tif to Google Drive folder.
# Copied 22361_dem.tif to Google Drive folder.
# Copied 22865_dem.tif to Google Drive folder.
# Copied 22947_dem.tif to Google Drive folder.
# Copied 23676_dem.tif to Google Drive folder.
# Copied 23429_dem.tif to Google Drive folder.
# Copied 23064_dem.tif to Google Drive folder.
# Copied 22451_dem.tif to Google Drive folder.
# Copied 22635_dem.tif to Google Drive folder.
# Copied 22324_dem.tif to Google Drive folder.
# Copied 23728_dem.tif to Google Drive folder.
# Copied 22313_dem.tif to Google Drive folder.
# Copied 23491_dem.tif to Google Drive folder.
# Copied 22899_dem.tif to Google Drive folder.
# Copied 23732_dem.tif to Google Drive folder.
# Copied 22413_dem.tif to Google Drive folder.
# Copied 22465_dem.tif to Google Drive folder.
# Copied 22503_dem.tif to Google Drive folder.
# Copied 23254_dem.tif to Google Drive folder.
# Copied 23019_dem.tif to Google Drive folder.
# Copied 23689_dem.tif to Google Drive folder.
# Copied 22943_dem.tif to Google Drive folder.
# Copied 23363_dem.tif to Google Drive folder.
# Copied 23306_dem.tif to Google Drive folder.
# Copied 22536_dem.tif to Google Drive folder.
# Copied 23255_dem.tif to Google Drive folder.
# Copied 22360_dem.tif to Google Drive folder.
# Copied 22747_dem.tif to Google Drive folder.
# Copied 22468_dem.tif to Google Drive folder.
# Copied 23122_dem.tif to Google Drive folder.
# Copied 23467_dem.tif to Google Drive folder.
# Copied 22566_dem.tif to Google Drive folder.
# Copied 23833_dem.tif to Google Drive folder.
# Copied 23168_dem.tif to Google Drive folder.
# Copied 23366_dem.tif to Google Drive folder.
# Copied 23887_dem.tif to Google Drive folder.
# Copied 23617_dem.tif to Google Drive folder.
# Copied 23570_dem.tif to Google Drive folder.
# Copied 22592_dem.tif to Google Drive folder.
# Copied 23267_dem.tif to Google Drive folder.
# Copied 23009_dem.tif to Google Drive folder.
# Copied 23225_dem.tif to Google Drive folder.
# Copied 23335_dem.tif to Google Drive folder.
# Copied 22351_dem.tif to Google Drive folder.
# Copied 22442_dem.tif to Google Drive folder.
# Copied 22924_dem.tif to Google Drive folder.
# Copied 23526_dem.tif to Google Drive folder.
# Copied 23025_dem.tif to Google Drive folder.
# Copied 23596_dem.tif to Google Drive folder.
# Copied 23916_dem.tif to Google Drive folder.
# Copied 22927_dem.tif to Google Drive folder.
# Copied 23324_dem.tif to Google Drive folder.
# Copied 22790_dem.tif to Google Drive folder.
# Copied 22312_dem.tif to Google Drive folder.
# Copied 23914_dem.tif to Google Drive folder.
# Copied 23048_dem.tif to Google Drive folder.
# Copied 23717_dem.tif to Google Drive folder.
# Copied 23713_dem.tif to Google Drive folder.
# Copied 23421_dem.tif to Google Drive folder.
# Copied 23264_dem.tif to Google Drive folder.
# Copied 23496_dem.tif to Google Drive folder.
# Copied 23247_dem.tif to Google Drive folder.
# Copied 23606_dem.tif to Google Drive folder.
# Copied 23835_dem.tif to Google Drive folder.
# Copied 23855_dem.tif to Google Drive folder.
# Copied 23540_dem.tif to Google Drive folder.
# Copied 23623_dem.tif to Google Drive folder.
# Copied 23822_dem.tif to Google Drive folder.
# Copied 23503_dem.tif to Google Drive folder.
# Copied 22647_dem.tif to Google Drive folder.
# Copied 22452_dem.tif to Google Drive folder.
# Copied 23973_dem.tif to Google Drive folder.
# Copied 23231_dem.tif to Google Drive folder.
# Copied 22850_dem.tif to Google Drive folder.
# Copied 23409_dem.tif to Google Drive folder.
# Copied 23285_dem.tif to Google Drive folder.
# Copied 22744_dem.tif to Google Drive folder.
# Copied 22801_dem.tif to Google Drive folder.
# Copied 23707_dem.tif to Google Drive folder.
# Copied 23506_dem.tif to Google Drive folder.
# Copied 23016_dem.tif to Google Drive folder.
# Copied 23678_dem.tif to Google Drive folder.
# Copied 23578_dem.tif to Google Drive folder.
# Copied 23101_dem.tif to Google Drive folder.
# Copied 23559_dem.tif to Google Drive folder.
# Copied 23837_dem.tif to Google Drive folder.
# Copied 22817_dem.tif to Google Drive folder.
# Copied 23031_dem.tif to Google Drive folder.
# Copied 23585_dem.tif to Google Drive folder.
# Copied 23071_dem.tif to Google Drive folder.
# Copied 23777_dem.tif to Google Drive folder.
# Copied 22378_dem.tif to Google Drive folder.
# Copied 23309_dem.tif to Google Drive folder.
# Copied 22732_dem.tif to Google Drive folder.
# Copied 23786_dem.tif to Google Drive folder.
# Copied 23315_dem.tif to Google Drive folder.
# Copied 23035_dem.tif to Google Drive folder.
# Copied 23290_dem.tif to Google Drive folder.
# Copied 22911_dem.tif to Google Drive folder.
# Copied 23323_dem.tif to Google Drive folder.
# Copied 22556_dem.tif to Google Drive folder.
# Copied 23256_dem.tif to Google Drive folder.
# Copied 23162_dem.tif to Google Drive folder.
# Copied 22513_dem.tif to Google Drive folder.
# Copied 23180_dem.tif to Google Drive folder.
# Copied 23039_dem.tif to Google Drive folder.
# Copied 23959_dem.tif to Google Drive folder.
# Copied 23654_dem.tif to Google Drive folder.
# Copied 22754_dem.tif to Google Drive folder.
# Copied 23378_dem.tif to Google Drive folder.
# Copied 22753_dem.tif to Google Drive folder.
# Copied 23400_dem.tif to Google Drive folder.
# Copied 22666_dem.tif to Google Drive folder.
# Copied 22877_dem.tif to Google Drive folder.
# Copied 22773_dem.tif to Google Drive folder.
# Copied 23371_dem.tif to Google Drive folder.
# Copied 23809_dem.tif to Google Drive folder.
# Copied 23153_dem.tif to Google Drive folder.
# Copied 23451_dem.tif to Google Drive folder.
# Copied 23863_dem.tif to Google Drive folder.
# Copied 23280_dem.tif to Google Drive folder.
# Copied 22380_dem.tif to Google Drive folder.
# Copied 22498_dem.tif to Google Drive folder.
# Copied 23443_dem.tif to Google Drive folder.
# Copied 23772_dem.tif to Google Drive folder.
# Copied 23215_dem.tif to Google Drive folder.
# Copied 23237_dem.tif to Google Drive folder.
# Copied 22489_dem.tif to Google Drive folder.
# Copied 23054_dem.tif to Google Drive folder.
# Copied 23802_dem.tif to Google Drive folder.
# Copied 22980_dem.tif to Google Drive folder.
# Copied 22745_dem.tif to Google Drive folder.
# Copied 22659_dem.tif to Google Drive folder.
# Copied 23860_dem.tif to Google Drive folder.
# Copied 22668_dem.tif to Google Drive folder.
# Copied 23859_dem.tif to Google Drive folder.
# Copied 23672_dem.tif to Google Drive folder.
# Copied 22406_dem.tif to Google Drive folder.
# Copied 23080_dem.tif to Google Drive folder.
# Copied 23100_dem.tif to Google Drive folder.
# Copied 23890_dem.tif to Google Drive folder.
# Copied 23883_dem.tif to Google Drive folder.
# Copied 23477_dem.tif to Google Drive folder.
# Copied 23825_dem.tif to Google Drive folder.
# Copied 23533_dem.tif to Google Drive folder.
# Copied 22998_dem.tif to Google Drive folder.
# Copied 23169_dem.tif to Google Drive folder.
# Copied 22371_dem.tif to Google Drive folder.
# Copied 22522_dem.tif to Google Drive folder.
# Copied 23023_dem.tif to Google Drive folder.
# Copied 23861_dem.tif to Google Drive folder.
# Copied 22614_dem.tif to Google Drive folder.
# Copied 23404_dem.tif to Google Drive folder.
# Copied 22832_dem.tif to Google Drive folder.
# Copied 23312_dem.tif to Google Drive folder.
# Copied 23905_dem.tif to Google Drive folder.
# Copied 22355_dem.tif to Google Drive folder.
# Copied 23458_dem.tif to Google Drive folder.
# Copied 23932_dem.tif to Google Drive folder.
# Copied 23857_dem.tif to Google Drive folder.
# Copied 23410_dem.tif to Google Drive folder.
# Copied 23909_dem.tif to Google Drive folder.
# Copied 23368_dem.tif to Google Drive folder.
# Copied 22963_dem.tif to Google Drive folder.
# Copied 23657_dem.tif to Google Drive folder.
# Copied 22433_dem.tif to Google Drive folder.
# Copied 23038_dem.tif to Google Drive folder.
# Copied 22384_dem.tif to Google Drive folder.
# Copied 23232_dem.tif to Google Drive folder.
# Copied 22960_dem.tif to Google Drive folder.
# Copied 23217_dem.tif to Google Drive folder.
# Copied 23646_dem.tif to Google Drive folder.
# Copied 23441_dem.tif to Google Drive folder.
# Copied 23386_dem.tif to Google Drive folder.
# Copied 22444_dem.tif to Google Drive folder.
# Copied 23602_dem.tif to Google Drive folder.
# Copied 23665_dem.tif to Google Drive folder.
# Copied 22389_dem.tif to Google Drive folder.
# Copied 23042_dem.tif to Google Drive folder.
# Copied 23794_dem.tif to Google Drive folder.
# Copied 22557_dem.tif to Google Drive folder.
# Copied 22771_dem.tif to Google Drive folder.
# Copied 22867_dem.tif to Google Drive folder.
# Copied 22392_dem.tif to Google Drive folder.
# Copied 23866_dem.tif to Google Drive folder.
# Copied 22367_dem.tif to Google Drive folder.
# Copied 23693_dem.tif to Google Drive folder.
# Copied 22520_dem.tif to Google Drive folder.
# Copied 23302_dem.tif to Google Drive folder.
# Copied 23245_dem.tif to Google Drive folder.
# Copied 23912_dem.tif to Google Drive folder.
# Copied 22860_dem.tif to Google Drive folder.
# Copied 23374_dem.tif to Google Drive folder.
# Copied 23011_dem.tif to Google Drive folder.
# Copied 22972_dem.tif to Google Drive folder.
# Copied 22836_dem.tif to Google Drive folder.
# Copied 22587_dem.tif to Google Drive folder.
# Copied 23573_dem.tif to Google Drive folder.
# Copied 22565_dem.tif to Google Drive folder.
# Copied 22982_dem.tif to Google Drive folder.
# Copied 23361_dem.tif to Google Drive folder.
# Copied 23273_dem.tif to Google Drive folder.
# Copied 22543_dem.tif to Google Drive folder.
# Copied 23940_dem.tif to Google Drive folder.
# Copied 23079_dem.tif to Google Drive folder.
# Copied 22830_dem.tif to Google Drive folder.
# Copied 22652_dem.tif to Google Drive folder.
# Copied 23367_dem.tif to Google Drive folder.
# Copied 22631_dem.tif to Google Drive folder.
# Copied 23298_dem.tif to Google Drive folder.
# Copied 23677_dem.tif to Google Drive folder.
# Copied 22835_dem.tif to Google Drive folder.
# Copied 22921_dem.tif to Google Drive folder.
# Copied 22827_dem.tif to Google Drive folder.
# Copied 22955_dem.tif to Google Drive folder.
# Copied 23277_dem.tif to Google Drive folder.
# Copied 23755_dem.tif to Google Drive folder.
# Copied 22580_dem.tif to Google Drive folder.
# Copied 23681_dem.tif to Google Drive folder.
# Copied 23631_dem.tif to Google Drive folder.
# Copied 23923_dem.tif to Google Drive folder.
# Copied 22845_dem.tif to Google Drive folder.
# Copied 22833_dem.tif to Google Drive folder.
# Copied 22812_dem.tif to Google Drive folder.
# Copied 22970_dem.tif to Google Drive folder.
# Copied 23647_dem.tif to Google Drive folder.
# Copied 23523_dem.tif to Google Drive folder.
# Copied 23667_dem.tif to Google Drive folder.
# Copied 22514_dem.tif to Google Drive folder.
# Copied 23558_dem.tif to Google Drive folder.
# Copied 23112_dem.tif to Google Drive folder.
# Copied 23867_dem.tif to Google Drive folder.
# Copied 23358_dem.tif to Google Drive folder.
# Copied 22985_dem.tif to Google Drive folder.
# Copied 22486_dem.tif to Google Drive folder.
# Copied 22661_dem.tif to Google Drive folder.
# Copied 23133_dem.tif to Google Drive folder.
# Copied 22765_dem.tif to Google Drive folder.
# Copied 22920_dem.tif to Google Drive folder.
# Copied 22965_dem.tif to Google Drive folder.
# Copied 23341_dem.tif to Google Drive folder.
# Copied 22898_dem.tif to Google Drive folder.
# Copied 22849_dem.tif to Google Drive folder.
# Copied 23376_dem.tif to Google Drive folder.
# Copied 23457_dem.tif to Google Drive folder.
# Copied 22781_dem.tif to Google Drive folder.
# Copied 22880_dem.tif to Google Drive folder.
# Copied 23572_dem.tif to Google Drive folder.
# Copied 23906_dem.tif to Google Drive folder.
# Copied 22425_dem.tif to Google Drive folder.
# Copied 22742_dem.tif to Google Drive folder.
# Copied 23028_dem.tif to Google Drive folder.
# Copied 22893_dem.tif to Google Drive folder.
# Copied 23423_dem.tif to Google Drive folder.
# Copied 23761_dem.tif to Google Drive folder.
# Copied 22488_dem.tif to Google Drive folder.
# Copied 22615_dem.tif to Google Drive folder.
# Copied 23556_dem.tif to Google Drive folder.
# Copied 22875_dem.tif to Google Drive folder.
# Copied 23193_dem.tif to Google Drive folder.
# Copied 22838_dem.tif to Google Drive folder.
# Copied 22803_dem.tif to Google Drive folder.
# Copied 22348_dem.tif to Google Drive folder.
# Copied 23839_dem.tif to Google Drive folder.
# Copied 22403_dem.tif to Google Drive folder.
# Copied 23746_dem.tif to Google Drive folder.
# Copied 22554_dem.tif to Google Drive folder.
# Copied 23408_dem.tif to Google Drive folder.
# Copied 23033_dem.tif to Google Drive folder.
# Copied 22831_dem.tif to Google Drive folder.
# Copied 23117_dem.tif to Google Drive folder.
# Copied 23218_dem.tif to Google Drive folder.
# Copied 22864_dem.tif to Google Drive folder.
# Copied 23841_dem.tif to Google Drive folder.
# Copied 23603_dem.tif to Google Drive folder.
# Copied 22328_dem.tif to Google Drive folder.
# Copied 23743_dem.tif to Google Drive folder.
# Copied 22767_dem.tif to Google Drive folder.
# Copied 23246_dem.tif to Google Drive folder.
# Copied 22892_dem.tif to Google Drive folder.
# Copied 23141_dem.tif to Google Drive folder.
# Copied 23846_dem.tif to Google Drive folder.
# Copied 23900_dem.tif to Google Drive folder.
# Copied 22978_dem.tif to Google Drive folder.
# Copied 22760_dem.tif to Google Drive folder.
# Copied 22335_dem.tif to Google Drive folder.
# Copied 22575_dem.tif to Google Drive folder.
# Copied 23021_dem.tif to Google Drive folder.
# Copied 22981_dem.tif to Google Drive folder.
# Copied 23115_dem.tif to Google Drive folder.
# Copied 23357_dem.tif to Google Drive folder.
# Copied 23348_dem.tif to Google Drive folder.
# Copied 22997_dem.tif to Google Drive folder.
# Copied 23074_dem.tif to Google Drive folder.
# Copied 23027_dem.tif to Google Drive folder.
# Copied 23787_dem.tif to Google Drive folder.
# Copied 22512_dem.tif to Google Drive folder.
# Copied 23303_dem.tif to Google Drive folder.
# Copied 22756_dem.tif to Google Drive folder.
# Copied 22563_dem.tif to Google Drive folder.
# Copied 23522_dem.tif to Google Drive folder.
# Copied 23221_dem.tif to Google Drive folder.
# Copied 23052_dem.tif to Google Drive folder.
# Copied 22441_dem.tif to Google Drive folder.
# Copied 22443_dem.tif to Google Drive folder.
# Copied 22928_dem.tif to Google Drive folder.
# Copied 23831_dem.tif to Google Drive folder.
# Copied 22786_dem.tif to Google Drive folder.
# Copied 23489_dem.tif to Google Drive folder.
# Copied 23627_dem.tif to Google Drive folder.
# Copied 22345_dem.tif to Google Drive folder.
# Copied 22792_dem.tif to Google Drive folder.
# Copied 23106_dem.tif to Google Drive folder.
# Copied 23087_dem.tif to Google Drive folder.
# Copied 23045_dem.tif to Google Drive folder.
# Copied 22593_dem.tif to Google Drive folder.
# Copied 22636_dem.tif to Google Drive folder.
# Copied 22670_dem.tif to Google Drive folder.
# Copied 23686_dem.tif to Google Drive folder.
# Copied 23219_dem.tif to Google Drive folder.
# Copied 23714_dem.tif to Google Drive folder.
# Copied 22682_dem.tif to Google Drive folder.
# Copied 23005_dem.tif to Google Drive folder.
# Copied 23868_dem.tif to Google Drive folder.
# Copied 22542_dem.tif to Google Drive folder.
# Copied 22729_dem.tif to Google Drive folder.
# Copied 22504_dem.tif to Google Drive folder.
# Copied 23130_dem.tif to Google Drive folder.
# Copied 23076_dem.tif to Google Drive folder.
# Copied 22942_dem.tif to Google Drive folder.
# Copied 23103_dem.tif to Google Drive folder.
# Copied 22702_dem.tif to Google Drive folder.
# Copied 23238_dem.tif to Google Drive folder.
# Copied 22793_dem.tif to Google Drive folder.
# Copied 23962_dem.tif to Google Drive folder.
# Copied 23485_dem.tif to Google Drive folder.
# Copied 22612_dem.tif to Google Drive folder.
# Copied 22768_dem.tif to Google Drive folder.
# Copied 23632_dem.tif to Google Drive folder.
# Copied 23611_dem.tif to Google Drive folder.
# Copied 23881_dem.tif to Google Drive folder.
# Copied 23124_dem.tif to Google Drive folder.
# Copied 23126_dem.tif to Google Drive folder.
# Copied 23466_dem.tif to Google Drive folder.
# Copied 22330_dem.tif to Google Drive folder.
# Copied 22952_dem.tif to Google Drive folder.
# Copied 22725_dem.tif to Google Drive folder.
# Copied 23583_dem.tif to Google Drive folder.
# Copied 22460_dem.tif to Google Drive folder.
# Copied 23010_dem.tif to Google Drive folder.
# Copied 22887_dem.tif to Google Drive folder.
# Copied 22567_dem.tif to Google Drive folder.
# Copied 23109_dem.tif to Google Drive folder.
# Copied 23734_dem.tif to Google Drive folder.
# Copied 22763_dem.tif to Google Drive folder.
# Copied 23299_dem.tif to Google Drive folder.
# Copied 22540_dem.tif to Google Drive folder.
# Copied 23756_dem.tif to Google Drive folder.
# Copied 23026_dem.tif to Google Drive folder.
# Copied 22555_dem.tif to Google Drive folder.
# Copied 22806_dem.tif to Google Drive folder.
# Copied 23544_dem.tif to Google Drive folder.
# Copied 23261_dem.tif to Google Drive folder.
# Copied 22600_dem.tif to Google Drive folder.
# Copied 23759_dem.tif to Google Drive folder.
# Copied 23620_dem.tif to Google Drive folder.
# Copied 23223_dem.tif to Google Drive folder.
# Copied 22544_dem.tif to Google Drive folder.
# Copied 22354_dem.tif to Google Drive folder.
# Copied 23801_dem.tif to Google Drive folder.
# Copied 23107_dem.tif to Google Drive folder.
# Copied 23963_dem.tif to Google Drive folder.
# Copied 22821_dem.tif to Google Drive folder.
# Copied 23551_dem.tif to Google Drive folder.
# Copied 22323_dem.tif to Google Drive folder.
# Copied 23618_dem.tif to Google Drive folder.
# Copied 23364_dem.tif to Google Drive folder.
# Copied 23002_dem.tif to Google Drive folder.
# Copied 23818_dem.tif to Google Drive folder.
# Copied 23268_dem.tif to Google Drive folder.
# Copied 23593_dem.tif to Google Drive folder.
# Copied 23601_dem.tif to Google Drive folder.
# Copied 22851_dem.tif to Google Drive folder.
# Copied 23482_dem.tif to Google Drive folder.
# Copied 23014_dem.tif to Google Drive folder.
# Copied 23849_dem.tif to Google Drive folder.
# Copied 22986_dem.tif to Google Drive folder.
# Copied 23252_dem.tif to Google Drive folder.
# Copied 23125_dem.tif to Google Drive folder.
# Copied 22633_dem.tif to Google Drive folder.
# Copied 23893_dem.tif to Google Drive folder.
# Copied 23183_dem.tif to Google Drive folder.
# Copied 23049_dem.tif to Google Drive folder.
# Copied 22629_dem.tif to Google Drive folder.
# Copied 23326_dem.tif to Google Drive folder.
# Copied 23235_dem.tif to Google Drive folder.
# Copied 23824_dem.tif to Google Drive folder.
# Copied 23318_dem.tif to Google Drive folder.
# Copied 22453_dem.tif to Google Drive folder.
# Copied 23710_dem.tif to Google Drive folder.
# Copied 22936_dem.tif to Google Drive folder.
# Copied 23455_dem.tif to Google Drive folder.
# Copied 23352_dem.tif to Google Drive folder.
# Copied 22968_dem.tif to Google Drive folder.
# Copied 23287_dem.tif to Google Drive folder.
# Copied 23501_dem.tif to Google Drive folder.
# Copied 23817_dem.tif to Google Drive folder.
# Copied 23920_dem.tif to Google Drive folder.
# Copied 22515_dem.tif to Google Drive folder.
# Copied 23770_dem.tif to Google Drive folder.
# Copied 23453_dem.tif to Google Drive folder.
# Copied 22527_dem.tif to Google Drive folder.
# Copied 23084_dem.tif to Google Drive folder.
# Copied 22619_dem.tif to Google Drive folder.
# Copied 23856_dem.tif to Google Drive folder.
# Copied 23639_dem.tif to Google Drive folder.
# Copied 23279_dem.tif to Google Drive folder.
# Copied 22518_dem.tif to Google Drive folder.
# Copied 22618_dem.tif to Google Drive folder.
# Copied 23454_dem.tif to Google Drive folder.
# Copied 23181_dem.tif to Google Drive folder.
# Copied 23186_dem.tif to Google Drive folder.
# Copied 22395_dem.tif to Google Drive folder.
# Copied 23343_dem.tif to Google Drive folder.
# Copied 23709_dem.tif to Google Drive folder.
# Copied 23850_dem.tif to Google Drive folder.
# Copied 23684_dem.tif to Google Drive folder.
# Copied 23282_dem.tif to Google Drive folder.
# Copied 22363_dem.tif to Google Drive folder.
# Copied 23472_dem.tif to Google Drive folder.
# Copied 22940_dem.tif to Google Drive folder.
# Copied 23630_dem.tif to Google Drive folder.
# Copied 23524_dem.tif to Google Drive folder.
# Copied 23289_dem.tif to Google Drive folder.
# Copied 23037_dem.tif to Google Drive folder.
# Copied 23924_dem.tif to Google Drive folder.
# Copied 23265_dem.tif to Google Drive folder.
# Copied 23276_dem.tif to Google Drive folder.
# Copied 22694_dem.tif to Google Drive folder.
# Copied 22991_dem.tif to Google Drive folder.
# Copied 23375_dem.tif to Google Drive folder.
# Copied 23127_dem.tif to Google Drive folder.
# Copied 23845_dem.tif to Google Drive folder.
# Copied 23763_dem.tif to Google Drive folder.
# Copied 23760_dem.tif to Google Drive folder.
# Copied 23046_dem.tif to Google Drive folder.
# Copied 22418_dem.tif to Google Drive folder.
# Copied 22650_dem.tif to Google Drive folder.
# Copied 22431_dem.tif to Google Drive folder.
# Copied 22478_dem.tif to Google Drive folder.
# Copied 23055_dem.tif to Google Drive folder.
# Copied 23750_dem.tif to Google Drive folder.
# Copied 22532_dem.tif to Google Drive folder.
# Copied 23748_dem.tif to Google Drive folder.
# Copied 22385_dem.tif to Google Drive folder.
# Copied 23937_dem.tif to Google Drive folder.
# Copied 22639_dem.tif to Google Drive folder.
# Copied 23359_dem.tif to Google Drive folder.
# Copied 23140_dem.tif to Google Drive folder.
# Copied 23525_dem.tif to Google Drive folder.
# Copied 22852_dem.tif to Google Drive folder.
# Copied 23884_dem.tif to Google Drive folder.
# Copied 22604_dem.tif to Google Drive folder.
# Copied 23730_dem.tif to Google Drive folder.
# Copied 23338_dem.tif to Google Drive folder.
# Copied 23836_dem.tif to Google Drive folder.
# Copied 22409_dem.tif to Google Drive folder.
# Copied 22800_dem.tif to Google Drive folder.
# Copied 23057_dem.tif to Google Drive folder.
# Copied 23739_dem.tif to Google Drive folder.
# Copied 23397_dem.tif to Google Drive folder.
# Copied 22552_dem.tif to Google Drive folder.
# Copied 22925_dem.tif to Google Drive folder.
# Copied 22375_dem.tif to Google Drive folder.
# Copied 22562_dem.tif to Google Drive folder.
# Copied 23568_dem.tif to Google Drive folder.
# Copied 23952_dem.tif to Google Drive folder.
# Copied 23595_dem.tif to Google Drive folder.
# Copied 22590_dem.tif to Google Drive folder.
# Copied 23094_dem.tif to Google Drive folder.
# Copied 23933_dem.tif to Google Drive folder.
# Copied 22687_dem.tif to Google Drive folder.
# Copied 23864_dem.tif to Google Drive folder.
# Copied 23701_dem.tif to Google Drive folder.
# Copied 23203_dem.tif to Google Drive folder.
# Copied 23007_dem.tif to Google Drive folder.
# Copied 23308_dem.tif to Google Drive folder.
# Copied 23528_dem.tif to Google Drive folder.
# Copied 23013_dem.tif to Google Drive folder.
# Copied 23269_dem.tif to Google Drive folder.
# Copied 22500_dem.tif to Google Drive folder.
# Copied 23735_dem.tif to Google Drive folder.
# Copied 23599_dem.tif to Google Drive folder.
# Copied 23718_dem.tif to Google Drive folder.
# Copied 23166_dem.tif to Google Drive folder.
# Copied 23214_dem.tif to Google Drive folder.
# Copied 22698_dem.tif to Google Drive folder.
# Copied 23233_dem.tif to Google Drive folder.
# Copied 22676_dem.tif to Google Drive folder.
# Copied 22782_dem.tif to Google Drive folder.
# Copied 22669_dem.tif to Google Drive folder.
# Copied 23188_dem.tif to Google Drive folder.
# Copied 23146_dem.tif to Google Drive folder.
# Copied 23580_dem.tif to Google Drive folder.
# Copied 22697_dem.tif to Google Drive folder.
# Copied 22735_dem.tif to Google Drive folder.
# Copied 22379_dem.tif to Google Drive folder.
# Copied 23476_dem.tif to Google Drive folder.
# Copied 23683_dem.tif to Google Drive folder.
# Copied 23448_dem.tif to Google Drive folder.
# Copied 23782_dem.tif to Google Drive folder.
# Copied 22878_dem.tif to Google Drive folder.
# Copied 23637_dem.tif to Google Drive folder.
# Copied 22662_dem.tif to Google Drive folder.
# Copied 23719_dem.tif to Google Drive folder.
# Copied 22772_dem.tif to Google Drive folder.
# Copied 22364_dem.tif to Google Drive folder.
# Copied 22953_dem.tif to Google Drive folder.
# Copied 22690_dem.tif to Google Drive folder.
# Copied 22686_dem.tif to Google Drive folder.
# Copied 22679_dem.tif to Google Drive folder.
# Copied 23733_dem.tif to Google Drive folder.
# Copied 23876_dem.tif to Google Drive folder.
# Copied 23935_dem.tif to Google Drive folder.
# Copied 22506_dem.tif to Google Drive folder.
# Copied 22446_dem.tif to Google Drive folder.
# Copied 22946_dem.tif to Google Drive folder.
# Copied 23333_dem.tif to Google Drive folder.
# Copied 23827_dem.tif to Google Drive folder.
# Copied 23212_dem.tif to Google Drive folder.
# Copied 23950_dem.tif to Google Drive folder.
# Copied 22842_dem.tif to Google Drive folder.
# Copied 23720_dem.tif to Google Drive folder.
# Copied 22743_dem.tif to Google Drive folder.
# Copied 23067_dem.tif to Google Drive folder.
# Copied 23487_dem.tif to Google Drive folder.
# Copied 22624_dem.tif to Google Drive folder.
# Copied 22530_dem.tif to Google Drive folder.
# Copied 23766_dem.tif to Google Drive folder.
# Copied 22296_dem.tif to Google Drive folder.
# Copied 23878_dem.tif to Google Drive folder.
# Copied 22607_dem.tif to Google Drive folder.
# Copied 22622_dem.tif to Google Drive folder.
# Copied 23621_dem.tif to Google Drive folder.
# Copied 22411_dem.tif to Google Drive folder.
# Copied 23406_dem.tif to Google Drive folder.
# Copied 22410_dem.tif to Google Drive folder.
# Copied 23138_dem.tif to Google Drive folder.
# Copied 22720_dem.tif to Google Drive folder.
# Copied 23663_dem.tif to Google Drive folder.
# Copied 22705_dem.tif to Google Drive folder.
# Copied 22684_dem.tif to Google Drive folder.
# Copied 22549_dem.tif to Google Drive folder.
# Copied 23248_dem.tif to Google Drive folder.
# Copied 22318_dem.tif to Google Drive folder.
# Copied 23199_dem.tif to Google Drive folder.
# Copied 23475_dem.tif to Google Drive folder.
# Copied 22349_dem.tif to Google Drive folder.
# Copied 23056_dem.tif to Google Drive folder.
# Copied 22462_dem.tif to Google Drive folder.
# Copied 22776_dem.tif to Google Drive folder.
# Copied 23446_dem.tif to Google Drive folder.
# Copied 22632_dem.tif to Google Drive folder.
# Copied 23793_dem.tif to Google Drive folder.
# Copied 22455_dem.tif to Google Drive folder.
# Copied 22471_dem.tif to Google Drive folder.
# Copied 22665_dem.tif to Google Drive folder.
# Copied 23659_dem.tif to Google Drive folder.
# Copied 22879_dem.tif to Google Drive folder.
# Copied 22815_dem.tif to Google Drive folder.
# Copied 22396_dem.tif to Google Drive folder.
# Copied 22934_dem.tif to Google Drive folder.
# Copied 22620_dem.tif to Google Drive folder.
# Copied 22599_dem.tif to Google Drive folder.
# Copied 23149_dem.tif to Google Drive folder.
# Copied 22677_dem.tif to Google Drive folder.
# Copied 22641_dem.tif to Google Drive folder.
# Copied 23392_dem.tif to Google Drive folder.
# Copied 23695_dem.tif to Google Drive folder.
# Copied 22482_dem.tif to Google Drive folder.
# Copied 23384_dem.tif to Google Drive folder.
# Copied 23059_dem.tif to Google Drive folder.
# Copied 23407_dem.tif to Google Drive folder.
# Copied 23898_dem.tif to Google Drive folder.
# Copied 23519_dem.tif to Google Drive folder.
# Copied 23431_dem.tif to Google Drive folder.
# Copied 22606_dem.tif to Google Drive folder.
# Copied 22426_dem.tif to Google Drive folder.
# Copied 23006_dem.tif to Google Drive folder.
# Copied 23137_dem.tif to Google Drive folder.
# Copied 22726_dem.tif to Google Drive folder.
# Copied 23520_dem.tif to Google Drive folder.
# Copied 23945_dem.tif to Google Drive folder.
# Copied 23910_dem.tif to Google Drive folder.
# Copied 22440_dem.tif to Google Drive folder.
# Copied 22496_dem.tif to Google Drive folder.
# Copied 22368_dem.tif to Google Drive folder.
# Copied 22737_dem.tif to Google Drive folder.
# Copied 22644_dem.tif to Google Drive folder.
# Copied 23535_dem.tif to Google Drive folder.
# Copied 22785_dem.tif to Google Drive folder.
# Copied 23853_dem.tif to Google Drive folder.
# Copied 22709_dem.tif to Google Drive folder.
# Copied 23156_dem.tif to Google Drive folder.
# Copied 23660_dem.tif to Google Drive folder.
# Copied 22714_dem.tif to Google Drive folder.
# Copied 23514_dem.tif to Google Drive folder.
# Copied 22485_dem.tif to Google Drive folder.
# Copied 22722_dem.tif to Google Drive folder.
# Copied 22969_dem.tif to Google Drive folder.
# Copied 23941_dem.tif to Google Drive folder.
# Copied 23132_dem.tif to Google Drive folder.
# Copied 23081_dem.tif to Google Drive folder.
# Copied 22637_dem.tif to Google Drive folder.
# Copied 23543_dem.tif to Google Drive folder.
# Copied 23597_dem.tif to Google Drive folder.
# Copied 23675_dem.tif to Google Drive folder.
# Copied 22843_dem.tif to Google Drive folder.
# Copied 23511_dem.tif to Google Drive folder.
# Copied 23113_dem.tif to Google Drive folder.
# Copied 22559_dem.tif to Google Drive folder.
# Copied 23437_dem.tif to Google Drive folder.
# Copied 23762_dem.tif to Google Drive folder.
# Copied 23129_dem.tif to Google Drive folder.
# Copied 22775_dem.tif to Google Drive folder.
# Copied 23362_dem.tif to Google Drive folder.
# Copied 22546_dem.tif to Google Drive folder.
# Copied 22353_dem.tif to Google Drive folder.
# Copied 22529_dem.tif to Google Drive folder.
# Copied 23295_dem.tif to Google Drive folder.
# Copied 22941_dem.tif to Google Drive folder.
# Copied 23114_dem.tif to Google Drive folder.
# Copied 22295_dem.tif to Google Drive folder.
# Copied 23350_dem.tif to Google Drive folder.
# Copied 22510_dem.tif to Google Drive folder.
# Copied 23436_dem.tif to Google Drive folder.
# Copied 23731_dem.tif to Google Drive folder.
# Copied 22487_dem.tif to Google Drive folder.
# Copied 23700_dem.tif to Google Drive folder.
# Copied 23150_dem.tif to Google Drive folder.
# Copied 22715_dem.tif to Google Drive folder.
# Copied 22962_dem.tif to Google Drive folder.
# Copied 22741_dem.tif to Google Drive folder.
# Copied 23210_dem.tif to Google Drive folder.
# Copied 23239_dem.tif to Google Drive folder.
# Copied 23588_dem.tif to Google Drive folder.
# Copied 23564_dem.tif to Google Drive folder.
# Copied 22429_dem.tif to Google Drive folder.
# Copied 22739_dem.tif to Google Drive folder.
# Copied 23434_dem.tif to Google Drive folder.
# Copied 22695_dem.tif to Google Drive folder.
# Copied 23432_dem.tif to Google Drive folder.
# Copied 22791_dem.tif to Google Drive folder.
# Copied 22957_dem.tif to Google Drive folder.
# Copied 22492_dem.tif to Google Drive folder.
# Copied 22938_dem.tif to Google Drive folder.
# Copied 22511_dem.tif to Google Drive folder.
# Copied 22547_dem.tif to Google Drive folder.
# Copied 23346_dem.tif to Google Drive folder.
# Copied 22605_dem.tif to Google Drive folder.
# Copied 23439_dem.tif to Google Drive folder.
# Copied 23554_dem.tif to Google Drive folder.
# Copied 23493_dem.tif to Google Drive folder.
# Copied 23435_dem.tif to Google Drive folder.
# Copied 23205_dem.tif to Google Drive folder.
# Copied 22568_dem.tif to Google Drive folder.
# Copied 23360_dem.tif to Google Drive folder.
# Copied 22450_dem.tif to Google Drive folder.
# Copied 23416_dem.tif to Google Drive folder.
# Copied 23957_dem.tif to Google Drive folder.
# Copied 22347_dem.tif to Google Drive folder.
# Copied 23502_dem.tif to Google Drive folder.
# Copied 23877_dem.tif to Google Drive folder.
# Copied 23380_dem.tif to Google Drive folder.
# Copied 23727_dem.tif to Google Drive folder.
# Copied 23001_dem.tif to Google Drive folder.
# Copied 22311_dem.tif to Google Drive folder.
# Copied 22420_dem.tif to Google Drive folder.
# Copied 23804_dem.tif to Google Drive folder.
# Copied 23858_dem.tif to Google Drive folder.
# Copied 23372_dem.tif to Google Drive folder.
# Copied 23086_dem.tif to Google Drive folder.
# Copied 23691_dem.tif to Google Drive folder.
# Copied 22656_dem.tif to Google Drive folder.
# Copied 23096_dem.tif to Google Drive folder.
# Copied 22748_dem.tif to Google Drive folder.
# Copied 22437_dem.tif to Google Drive folder.
# Copied 23668_dem.tif to Google Drive folder.
# Copied 22574_dem.tif to Google Drive folder.
# Copied 22895_dem.tif to Google Drive folder.
# Copied 23331_dem.tif to Google Drive folder.
# Copied 23284_dem.tif to Google Drive folder.
# Copied 23598_dem.tif to Google Drive folder.
# Copied 23224_dem.tif to Google Drive folder.
# Copied 23099_dem.tif to Google Drive folder.
# Copied 23494_dem.tif to Google Drive folder.
# Copied 23030_dem.tif to Google Drive folder.
# Copied 23726_dem.tif to Google Drive folder.
# Copied 23724_dem.tif to Google Drive folder.
# Copied 23819_dem.tif to Google Drive folder.
# Copied 23862_dem.tif to Google Drive folder.
# Copied 23812_dem.tif to Google Drive folder.
# Copied 22362_dem.tif to Google Drive folder.
# Copied 23424_dem.tif to Google Drive folder.
# Copied 22342_dem.tif to Google Drive folder.
# Copied 22917_dem.tif to Google Drive folder.
# Copied 23464_dem.tif to Google Drive folder.
# Copied 23687_dem.tif to Google Drive folder.
# Copied 23197_dem.tif to Google Drive folder.
# Copied 23391_dem.tif to Google Drive folder.
# Copied 23931_dem.tif to Google Drive folder.
# Copied 23452_dem.tif to Google Drive folder.
# Copied 22974_dem.tif to Google Drive folder.
# Copied 22757_dem.tif to Google Drive folder.
# Copied 23334_dem.tif to Google Drive folder.
# Copied 23811_dem.tif to Google Drive folder.
# Copied 22404_dem.tif to Google Drive folder.
# Copied 23286_dem.tif to Google Drive folder.
# Copied 23784_dem.tif to Google Drive folder.
# Copied 23921_dem.tif to Google Drive folder.
# Copied 22783_dem.tif to Google Drive folder.
# Copied 22359_dem.tif to Google Drive folder.
# Copied 23542_dem.tif to Google Drive folder.
# Copied 23148_dem.tif to Google Drive folder.
# Copied 23340_dem.tif to Google Drive folder.
# Copied 22979_dem.tif to Google Drive folder.
# Copied 22391_dem.tif to Google Drive folder.
# Copied 23017_dem.tif to Google Drive folder.
# Copied 22308_dem.tif to Google Drive folder.
# Copied 22517_dem.tif to Google Drive folder.
# Copied 23680_dem.tif to Google Drive folder.
# Copied 23322_dem.tif to Google Drive folder.
# Copied 23715_dem.tif to Google Drive folder.
# Copied 23785_dem.tif to Google Drive folder.
# Copied 23699_dem.tif to Google Drive folder.
# Copied 23648_dem.tif to Google Drive folder.
# Copied 22521_dem.tif to Google Drive folder.
# Copied 23381_dem.tif to Google Drive folder.
# Copied 22930_dem.tif to Google Drive folder.
# Copied 22464_dem.tif to Google Drive folder.
# Copied 23041_dem.tif to Google Drive folder.
# Copied 22405_dem.tif to Google Drive folder.
# Copied 22309_dem.tif to Google Drive folder.
# Copied 23953_dem.tif to Google Drive folder.
# Copied 23433_dem.tif to Google Drive folder.
# Copied 23609_dem.tif to Google Drive folder.
# Copied 22794_dem.tif to Google Drive folder.
# Copied 23753_dem.tif to Google Drive folder.
# ...
# Copied 22904_dem.tif to Google Drive folder.
# Copied 22640_dem.tif to Google Drive folder.
# Copied 22601_dem.tif to Google Drive folder.
# Copied 23293_dem.tif to Google Drive folder.
# Copied 23534_dem.tif to Google Drive folder.
# Copied 22572_dem.tif to Google Drive folder.
# Copied 22733_dem.tif to Google Drive folder.
# Copied 22675_dem.tif to Google Drive folder.
# Copied 23604_dem.tif to Google Drive folder.
# Copied 23721_dem.tif to Google Drive folder.
# Copied 23240_dem.tif to Google Drive folder.
# Copied 22401_dem.tif to Google Drive folder.
# Copied 22993_dem.tif to Google Drive folder.
# Copied 22876_dem.tif to Google Drive folder.
# Copied 23500_dem.tif to Google Drive folder.
# Copied 22707_dem.tif to Google Drive folder.
# Copied 23465_dem.tif to Google Drive folder.
# Copied 22297_dem.tif to Google Drive folder.
# Copied 22366_dem.tif to Google Drive folder.
# Copied 22945_dem.tif to Google Drive folder.
# Copied 22407_dem.tif to Google Drive folder.
# Copied 23229_dem.tif to Google Drive folder.
# Copied 23847_dem.tif to Google Drive folder.
# Copied 22888_dem.tif to Google Drive folder.
# Copied 22787_dem.tif to Google Drive folder.
# Copied 23385_dem.tif to Google Drive folder.
# Copied 23088_dem.tif to Google Drive folder.
# Copied 22463_dem.tif to Google Drive folder.
# Copied 23050_dem.tif to Google Drive folder.
# Copied 22299_dem.tif to Google Drive folder.
# Copied 23626_dem.tif to Google Drive folder.
# Copied 22493_dem.tif to Google Drive folder.
# Copied 23575_dem.tif to Google Drive folder.
# Copied 23418_dem.tif to Google Drive folder.
# Copied 22719_dem.tif to Google Drive folder.
# Copied 23139_dem.tif to Google Drive folder.
# Copied 23003_dem.tif to Google Drive folder.
# Copied 23339_dem.tif to Google Drive folder.
# Copied 23411_dem.tif to Google Drive folder.
# Copied 23444_dem.tif to Google Drive folder.
# Copied 22799_dem.tif to Google Drive folder.
# Copied 22591_dem.tif to Google Drive folder.
# Copied 23965_dem.tif to Google Drive folder.
# Copied 22692_dem.tif to Google Drive folder.
# Copied 22564_dem.tif to Google Drive folder.
# Copied 23797_dem.tif to Google Drive folder.
# Copied 22678_dem.tif to Google Drive folder.
# Copied 23790_dem.tif to Google Drive folder.
# Copied 22424_dem.tif to Google Drive folder.
# Copied 22740_dem.tif to Google Drive folder.
# Copied 23110_dem.tif to Google Drive folder.
# Copied 23275_dem.tif to Google Drive folder.
# Copied 22387_dem.tif to Google Drive folder.
# Copied 22623_dem.tif to Google Drive folder.
# Copied 22683_dem.tif to Google Drive folder.
# Copied 23537_dem.tif to Google Drive folder.
# Copied 23536_dem.tif to Google Drive folder.
# Copied 22454_dem.tif to Google Drive folder.
# Copied 22937_dem.tif to Google Drive folder.
# Copied 23553_dem.tif to Google Drive folder.
# Copied 23922_dem.tif to Google Drive folder.
# Copied 23826_dem.tif to Google Drive folder.
# Copied 23300_dem.tif to Google Drive folder.
# Copied 23698_dem.tif to Google Drive folder.
# Copied 23344_dem.tif to Google Drive folder.
# Copied 22916_dem.tif to Google Drive folder.
# Copied 23159_dem.tif to Google Drive folder.
# Copied 23292_dem.tif to Google Drive folder.
# Copied 22919_dem.tif to Google Drive folder.
# Copied 22534_dem.tif to Google Drive folder.
# Copied 23470_dem.tif to Google Drive folder.
# Copied 23008_dem.tif to Google Drive folder.
# Copied 22897_dem.tif to Google Drive folder.
# Copied 22673_dem.tif to Google Drive folder.
# Copied 23131_dem.tif to Google Drive folder.
# Copied 23480_dem.tif to Google Drive folder.
# Copied 23555_dem.tif to Google Drive folder.
# Copied 23674_dem.tif to Google Drive folder.
# Copied 22481_dem.tif to Google Drive folder.
# Copied 23249_dem.tif to Google Drive folder.
# Copied 22447_dem.tif to Google Drive folder.
# Copied 22338_dem.tif to Google Drive folder.
# Copied 22346_dem.tif to Google Drive folder.
# Copied 22467_dem.tif to Google Drive folder.
# Copied 22902_dem.tif to Google Drive folder.
# Copied 23445_dem.tif to Google Drive folder.
# Copied 23291_dem.tif to Google Drive folder.
# Copied 22839_dem.tif to Google Drive folder.
# Copied 23820_dem.tif to Google Drive folder.
# Copied 23751_dem.tif to Google Drive folder.
# Copied 22502_dem.tif to Google Drive folder.
# Copied 22869_dem.tif to Google Drive folder.
# Copied 22445_dem.tif to Google Drive folder.
# Copied 23872_dem.tif to Google Drive folder.
# Copied 23548_dem.tif to Google Drive folder.
# Copied 22923_dem.tif to Google Drive folder.
# Copied 22466_dem.tif to Google Drive folder.
# Copied 23886_dem.tif to Google Drive folder.
# Copied 22805_dem.tif to Google Drive folder.
# Copied 22319_dem.tif to Google Drive folder.
# Copied 22434_dem.tif to Google Drive folder.
# Copied 23531_dem.tif to Google Drive folder.
# Copied 22626_dem.tif to Google Drive folder.
# Copied 22551_dem.tif to Google Drive folder.
# Copied 23771_dem.tif to Google Drive folder.
# Copied 22778_dem.tif to Google Drive folder.
# Copied 23394_dem.tif to Google Drive folder.
# Copied 23483_dem.tif to Google Drive folder.
# Copied 22476_dem.tif to Google Drive folder.
# Copied 23068_dem.tif to Google Drive folder.
# Copied 23325_dem.tif to Google Drive folder.
# Copied 23200_dem.tif to Google Drive folder.
# Copied 23176_dem.tif to Google Drive folder.
# Copied 22334_dem.tif to Google Drive folder.
# Copied 22519_dem.tif to Google Drive folder.
# Copied 22648_dem.tif to Google Drive folder.
# Copied 23821_dem.tif to Google Drive folder.
# Copied 22310_dem.tif to Google Drive folder.
# Copied 23688_dem.tif to Google Drive folder.
# Copied 23211_dem.tif to Google Drive folder.
# Copied 23043_dem.tif to Google Drive folder.
# Copied 22846_dem.tif to Google Drive folder.
# Copied 23608_dem.tif to Google Drive folder.
# Copied 22889_dem.tif to Google Drive folder.
# Copied 22868_dem.tif to Google Drive folder.
# Copied 23741_dem.tif to Google Drive folder.
# Copied 23894_dem.tif to Google Drive folder.
# Copied 22837_dem.tif to Google Drive folder.
# Copied 22907_dem.tif to Google Drive folder.
# Copied 22570_dem.tif to Google Drive folder.
# Copied 22871_dem.tif to Google Drive folder.
# Copied 22896_dem.tif to Google Drive folder.
# Copied 23257_dem.tif to Google Drive folder.
# Copied 22550_dem.tif to Google Drive folder.
# Copied 23167_dem.tif to Google Drive folder.
# Copied 23474_dem.tif to Google Drive folder.
# Copied 22950_dem.tif to Google Drive folder.
# Copied 23382_dem.tif to Google Drive folder.
# Copied 23438_dem.tif to Google Drive folder.
# Copied 22340_dem.tif to Google Drive folder.
# Copied 23402_dem.tif to Google Drive folder.
# Copied 22393_dem.tif to Google Drive folder.
# Copied 23179_dem.tif to Google Drive folder.
# Copied 22456_dem.tif to Google Drive folder.
# Copied 22721_dem.tif to Google Drive folder.
# Copied 23652_dem.tif to Google Drive folder.
# Copied 23664_dem.tif to Google Drive folder.
# Copied 23740_dem.tif to Google Drive folder.
# Copied 23749_dem.tif to Google Drive folder.
# Copied 22810_dem.tif to Google Drive folder.
# Copied 23355_dem.tif to Google Drive folder.
# Copied 22873_dem.tif to Google Drive folder.
# Copied 22977_dem.tif to Google Drive folder.
# Copied 23304_dem.tif to Google Drive folder.
# Copied 23600_dem.tif to Google Drive folder.
# Copied 23154_dem.tif to Google Drive folder.
# Copied 22301_dem.tif to Google Drive folder.
# Copied 23389_dem.tif to Google Drive folder.
# Copied 23270_dem.tif to Google Drive folder.
# Copied 23865_dem.tif to Google Drive folder.
# Copied 22436_dem.tif to Google Drive folder.
# Copied 23327_dem.tif to Google Drive folder.
# Copied 23170_dem.tif to Google Drive folder.
# Copied 22469_dem.tif to Google Drive folder.
# Copied 22922_dem.tif to Google Drive folder.
# Copied 22995_dem.tif to Google Drive folder.
# Copied 22617_dem.tif to Google Drive folder.
# Copied 22914_dem.tif to Google Drive folder.
# Copied 23745_dem.tif to Google Drive folder.
# Copied 22621_dem.tif to Google Drive folder.
# Copied 23204_dem.tif to Google Drive folder.
# Copied 22967_dem.tif to Google Drive folder.
# Copied 22333_dem.tif to Google Drive folder.
# Copied 22582_dem.tif to Google Drive folder.
# Copied 22428_dem.tif to Google Drive folder.
# Copied 22779_dem.tif to Google Drive folder.
# Copied 23390_dem.tif to Google Drive folder.
# Copied 22751_dem.tif to Google Drive folder.
# Copied 22992_dem.tif to Google Drive folder.
# Copied 23034_dem.tif to Google Drive folder.
# Copied 23091_dem.tif to Google Drive folder.
# Copied 23563_dem.tif to Google Drive folder.
# Copied 22727_dem.tif to Google Drive folder.
# Copied 23584_dem.tif to Google Drive folder.
# Copied 23449_dem.tif to Google Drive folder.
# Copied 23778_dem.tif to Google Drive folder.
# Copied 23430_dem.tif to Google Drive folder.
# Copied 22646_dem.tif to Google Drive folder.
# Copied 22573_dem.tif to Google Drive folder.
# Copied 23301_dem.tif to Google Drive folder.
# Copied 22569_dem.tif to Google Drive folder.
# Copied 22300_dem.tif to Google Drive folder.
# Copied 22825_dem.tif to Google Drive folder.
# Copied 23582_dem.tif to Google Drive folder.
# Copied 22332_dem.tif to Google Drive folder.
# Copied 23353_dem.tif to Google Drive folder.
# Copied 23744_dem.tif to Google Drive folder.
# Copied 23216_dem.tif to Google Drive folder.
# Copied 22448_dem.tif to Google Drive folder.
# Copied 22680_dem.tif to Google Drive folder.
# Copied 23636_dem.tif to Google Drive folder.
# Copied 22505_dem.tif to Google Drive folder.
# Copied 23629_dem.tif to Google Drive folder.
# Copied 22416_dem.tif to Google Drive folder.
# Copied 23072_dem.tif to Google Drive folder.
# Copied 22859_dem.tif to Google Drive folder.
# Copied 22645_dem.tif to Google Drive folder.
# Copied 23191_dem.tif to Google Drive folder.
# Copied 22701_dem.tif to Google Drive folder.
# Copied 22988_dem.tif to Google Drive folder.
# Copied 23703_dem.tif to Google Drive folder.
# Copied 23579_dem.tif to Google Drive folder.
# Copied 23281_dem.tif to Google Drive folder.
# Copied 23971_dem.tif to Google Drive folder.
# Copied 23173_dem.tif to Google Drive folder.
# Copied 22929_dem.tif to Google Drive folder.
# Copied 23486_dem.tif to Google Drive folder.
# Copied 22685_dem.tif to Google Drive folder.
# Copied 22959_dem.tif to Google Drive folder.
# Copied 23201_dem.tif to Google Drive folder.
# Copied 23456_dem.tif to Google Drive folder.
# Copied 23871_dem.tif to Google Drive folder.
# Copied 22872_dem.tif to Google Drive folder.
# Copied 22834_dem.tif to Google Drive folder.
# Copied 22824_dem.tif to Google Drive folder.
# Copied 22415_dem.tif to Google Drive folder.
# Copied 22630_dem.tif to Google Drive folder.
# Copied 23143_dem.tif to Google Drive folder.
# Copied 22320_dem.tif to Google Drive folder.
# Copied 22724_dem.tif to Google Drive folder.
# Copied 23420_dem.tif to Google Drive folder.
# Copied 22533_dem.tif to Google Drive folder.
# Copied 23813_dem.tif to Google Drive folder.
# Copied 23202_dem.tif to Google Drive folder.
# Copied 23262_dem.tif to Google Drive folder.
# Copied 22642_dem.tif to Google Drive folder.
# Copied 23142_dem.tif to Google Drive folder.
# Copied 22681_dem.tif to Google Drive folder.
# Copied 23018_dem.tif to Google Drive folder.
# Copied 22736_dem.tif to Google Drive folder.
# Copied 22905_dem.tif to Google Drive folder.
# Copied 23655_dem.tif to Google Drive folder.
# Copied 23379_dem.tif to Google Drive folder.
# Copied 23206_dem.tif to Google Drive folder.
# Copied 23090_dem.tif to Google Drive folder.
# Copied 23195_dem.tif to Google Drive folder.
# Copied 23619_dem.tif to Google Drive folder.
# Copied 23063_dem.tif to Google Drive folder.
# Copied 22377_dem.tif to Google Drive folder.
# Copied 23783_dem.tif to Google Drive folder.
# Copied 23118_dem.tif to Google Drive folder.
# Copied 22394_dem.tif to Google Drive folder.
# Copied 22814_dem.tif to Google Drive folder.
# Copied 23320_dem.tif to Google Drive folder.
# Copied 22828_dem.tif to Google Drive folder.
# Copied 23591_dem.tif to Google Drive folder.
# Copied 23000_dem.tif to Google Drive folder.
# Copied 22863_dem.tif to Google Drive folder.
# Copied 23093_dem.tif to Google Drive folder.
# Copied 23891_dem.tif to Google Drive folder.
# Copied 22523_dem.tif to Google Drive folder.
# Copied 23160_dem.tif to Google Drive folder.
# Copied 23105_dem.tif to Google Drive folder.
# Copied 22625_dem.tif to Google Drive folder.
# Copied 23151_dem.tif to Google Drive folder.
# Copied 23560_dem.tif to Google Drive folder.
# Copied 23307_dem.tif to Google Drive folder.
# Copied 22509_dem.tif to Google Drive folder.
# Copied 23082_dem.tif to Google Drive folder.
# Copied 22537_dem.tif to Google Drive folder.
# Copied 23083_dem.tif to Google Drive folder.
# Copied 22638_dem.tif to Google Drive folder.
# Copied 23242_dem.tif to Google Drive folder.
# Copied 23625_dem.tif to Google Drive folder.
# Copied 23144_dem.tif to Google Drive folder.
# Copied 22994_dem.tif to Google Drive folder.
# Copied 22931_dem.tif to Google Drive folder.
# Copied 23460_dem.tif to Google Drive folder.
# Copied 23387_dem.tif to Google Drive folder.
# Copied 23157_dem.tif to Google Drive folder.
# Copied 23004_dem.tif to Google Drive folder.
# Copied 22823_dem.tif to Google Drive folder.
# Copied 22381_dem.tif to Google Drive folder.
# Copied 22654_dem.tif to Google Drive folder.
# Copied 23155_dem.tif to Google Drive folder.
# Copied 23805_dem.tif to Google Drive folder.
# Copied 23549_dem.tif to Google Drive folder.
# Copied 23297_dem.tif to Google Drive folder.
# Copied 23095_dem.tif to Google Drive folder.
# Copied 23097_dem.tif to Google Drive folder.
# Copied 22951_dem.tif to Google Drive folder.
# Copied 22558_dem.tif to Google Drive folder.
# Copied 23873_dem.tif to Google Drive folder.
# Copied 23278_dem.tif to Google Drive folder.
# Copied 22749_dem.tif to Google Drive folder.
# Copied 23319_dem.tif to Google Drive folder.
# Copied 23696_dem.tif to Google Drive folder.
# Copied 22357_dem.tif to Google Drive folder.
# Copied 23349_dem.tif to Google Drive folder.
# Copied 23705_dem.tif to Google Drive folder.
# Copied 23121_dem.tif to Google Drive folder.
# Copied 23192_dem.tif to Google Drive folder.
# Copied 23089_dem.tif to Google Drive folder.
# Copied 23642_dem.tif to Google Drive folder.
# Copied 23428_dem.tif to Google Drive folder.
# Copied 23222_dem.tif to Google Drive folder.
# Copied 22983_dem.tif to Google Drive folder.
# Copied 22516_dem.tif to Google Drive folder.
# Copied 23032_dem.tif to Google Drive folder.
# Copied 22339_dem.tif to Google Drive folder.
# Copied 22535_dem.tif to Google Drive folder.
# Copied 23332_dem.tif to Google Drive folder.
# Copied 23259_dem.tif to Google Drive folder.
# Copied 22350_dem.tif to Google Drive folder.
# Copied 23948_dem.tif to Google Drive folder.
# Copied 22663_dem.tif to Google Drive folder.
# Copied 23123_dem.tif to Google Drive folder.
# Copied 23085_dem.tif to Google Drive folder.
# Copied 23529_dem.tif to Google Drive folder.
# Copied 23182_dem.tif to Google Drive folder.
# Copied 23800_dem.tif to Google Drive folder.
# Copied 22671_dem.tif to Google Drive folder.
# Copied 22913_dem.tif to Google Drive folder.
# Copied 23356_dem.tif to Google Drive folder.
# Copied 22809_dem.tif to Google Drive folder.
# Copied 23736_dem.tif to Google Drive folder.
# Copied 22908_dem.tif to Google Drive folder.
# Copied 22716_dem.tif to Google Drive folder.
# Copied 22595_dem.tif to Google Drive folder.
# Copied 22700_dem.tif to Google Drive folder.
# Copied 23189_dem.tif to Google Drive folder.
# Copied 23942_dem.tif to Google Drive folder.
# Copied 23505_dem.tif to Google Drive folder.
# Copied 22414_dem.tif to Google Drive folder.
# Copied 23051_dem.tif to Google Drive folder.
# Copied 23671_dem.tif to Google Drive folder.
# Copied 23185_dem.tif to Google Drive folder.
# Copied 23895_dem.tif to Google Drive folder.
# Copied 22691_dem.tif to Google Drive folder.
# Copied 22933_dem.tif to Google Drive folder.
# Copied 22948_dem.tif to Google Drive folder.
# Copied 23029_dem.tif to Google Drive folder.
# Copied 23365_dem.tif to Google Drive folder.
# Copied 23510_dem.tif to Google Drive folder.
# Copied 23518_dem.tif to Google Drive folder.
# Copied 23928_dem.tif to Google Drive folder.
# Copied 22608_dem.tif to Google Drive folder.
# Copied 23351_dem.tif to Google Drive folder.
# Copied 23899_dem.tif to Google Drive folder.
# Copied 23645_dem.tif to Google Drive folder.
# Copied 23415_dem.tif to Google Drive folder.
# Copied 23220_dem.tif to Google Drive folder.
# Copied 22900_dem.tif to Google Drive folder.
# Copied 22374_dem.tif to Google Drive folder.
# Copied 22819_dem.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/naip_128x128data/utm4/ccap_filled/"
tif_source = "/content/data/content/exports/ccap_filled/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 22851_ccap_filled.tif to Google Drive folder.
# Copied 23525_ccap_filled.tif to Google Drive folder.
# Copied 23193_ccap_filled.tif to Google Drive folder.
# Copied 23140_ccap_filled.tif to Google Drive folder.
# Copied 23154_ccap_filled.tif to Google Drive folder.
# Copied 22674_ccap_filled.tif to Google Drive folder.
# Copied 22499_ccap_filled.tif to Google Drive folder.
# Copied 22396_ccap_filled.tif to Google Drive folder.
# Copied 22801_ccap_filled.tif to Google Drive folder.
# Copied 23418_ccap_filled.tif to Google Drive folder.
# Copied 23614_ccap_filled.tif to Google Drive folder.
# Copied 22473_ccap_filled.tif to Google Drive folder.
# Copied 23637_ccap_filled.tif to Google Drive folder.
# Copied 22490_ccap_filled.tif to Google Drive folder.
# Copied 23232_ccap_filled.tif to Google Drive folder.
# Copied 22849_ccap_filled.tif to Google Drive folder.
# Copied 23046_ccap_filled.tif to Google Drive folder.
# Copied 22773_ccap_filled.tif to Google Drive folder.
# Copied 22807_ccap_filled.tif to Google Drive folder.
# Copied 22484_ccap_filled.tif to Google Drive folder.
# Copied 23033_ccap_filled.tif to Google Drive folder.
# Copied 23918_ccap_filled.tif to Google Drive folder.
# Copied 23798_ccap_filled.tif to Google Drive folder.
# Copied 23971_ccap_filled.tif to Google Drive folder.
# Copied 23489_ccap_filled.tif to Google Drive folder.
# Copied 22465_ccap_filled.tif to Google Drive folder.
# Copied 22900_ccap_filled.tif to Google Drive folder.
# Copied 22990_ccap_filled.tif to Google Drive folder.
# Copied 23206_ccap_filled.tif to Google Drive folder.
# Copied 22932_ccap_filled.tif to Google Drive folder.
# Copied 22953_ccap_filled.tif to Google Drive folder.
# Copied 23412_ccap_filled.tif to Google Drive folder.
# Copied 23640_ccap_filled.tif to Google Drive folder.
# Copied 23850_ccap_filled.tif to Google Drive folder.
# Copied 23804_ccap_filled.tif to Google Drive folder.
# Copied 23429_ccap_filled.tif to Google Drive folder.
# Copied 23576_ccap_filled.tif to Google Drive folder.
# Copied 23957_ccap_filled.tif to Google Drive folder.
# Copied 23003_ccap_filled.tif to Google Drive folder.
# Copied 22951_ccap_filled.tif to Google Drive folder.
# Copied 23595_ccap_filled.tif to Google Drive folder.
# Copied 23858_ccap_filled.tif to Google Drive folder.
# Copied 23310_ccap_filled.tif to Google Drive folder.
# Copied 23273_ccap_filled.tif to Google Drive folder.
# Copied 23326_ccap_filled.tif to Google Drive folder.
# Copied 22741_ccap_filled.tif to Google Drive folder.
# Copied 22813_ccap_filled.tif to Google Drive folder.
# Copied 23743_ccap_filled.tif to Google Drive folder.
# Copied 22943_ccap_filled.tif to Google Drive folder.
# Copied 23709_ccap_filled.tif to Google Drive folder.
# Copied 23533_ccap_filled.tif to Google Drive folder.
# Copied 23912_ccap_filled.tif to Google Drive folder.
# Copied 22620_ccap_filled.tif to Google Drive folder.
# Copied 22705_ccap_filled.tif to Google Drive folder.
# Copied 22767_ccap_filled.tif to Google Drive folder.
# Copied 22690_ccap_filled.tif to Google Drive folder.
# Copied 23735_ccap_filled.tif to Google Drive folder.
# Copied 23277_ccap_filled.tif to Google Drive folder.
# Copied 22330_ccap_filled.tif to Google Drive folder.
# Copied 23817_ccap_filled.tif to Google Drive folder.
# Copied 23274_ccap_filled.tif to Google Drive folder.
# Copied 23264_ccap_filled.tif to Google Drive folder.
# Copied 22634_ccap_filled.tif to Google Drive folder.
# Copied 22732_ccap_filled.tif to Google Drive folder.
# Copied 23558_ccap_filled.tif to Google Drive folder.
# Copied 23471_ccap_filled.tif to Google Drive folder.
# Copied 22610_ccap_filled.tif to Google Drive folder.
# Copied 22885_ccap_filled.tif to Google Drive folder.
# Copied 23954_ccap_filled.tif to Google Drive folder.
# Copied 23725_ccap_filled.tif to Google Drive folder.
# Copied 23853_ccap_filled.tif to Google Drive folder.
# Copied 22664_ccap_filled.tif to Google Drive folder.
# Copied 23173_ccap_filled.tif to Google Drive folder.
# Copied 23222_ccap_filled.tif to Google Drive folder.
# Copied 23861_ccap_filled.tif to Google Drive folder.
# Copied 23442_ccap_filled.tif to Google Drive folder.
# Copied 23748_ccap_filled.tif to Google Drive folder.
# Copied 22578_ccap_filled.tif to Google Drive folder.
# Copied 22873_ccap_filled.tif to Google Drive folder.
# Copied 23451_ccap_filled.tif to Google Drive folder.
# Copied 23936_ccap_filled.tif to Google Drive folder.
# Copied 23698_ccap_filled.tif to Google Drive folder.
# Copied 22436_ccap_filled.tif to Google Drive folder.
# Copied 22797_ccap_filled.tif to Google Drive folder.
# Copied 23339_ccap_filled.tif to Google Drive folder.
# Copied 22327_ccap_filled.tif to Google Drive folder.
# Copied 22431_ccap_filled.tif to Google Drive folder.
# Copied 22861_ccap_filled.tif to Google Drive folder.
# Copied 22877_ccap_filled.tif to Google Drive folder.
# Copied 23717_ccap_filled.tif to Google Drive folder.
# Copied 23259_ccap_filled.tif to Google Drive folder.
# Copied 23488_ccap_filled.tif to Google Drive folder.
# Copied 22612_ccap_filled.tif to Google Drive folder.
# Copied 23610_ccap_filled.tif to Google Drive folder.
# Copied 23780_ccap_filled.tif to Google Drive folder.
# Copied 23027_ccap_filled.tif to Google Drive folder.
# Copied 23838_ccap_filled.tif to Google Drive folder.
# Copied 22845_ccap_filled.tif to Google Drive folder.
# Copied 22963_ccap_filled.tif to Google Drive folder.
# Copied 22469_ccap_filled.tif to Google Drive folder.
# Copied 22631_ccap_filled.tif to Google Drive folder.
# Copied 22306_ccap_filled.tif to Google Drive folder.
# Copied 22331_ccap_filled.tif to Google Drive folder.
# Copied 22479_ccap_filled.tif to Google Drive folder.
# Copied 22575_ccap_filled.tif to Google Drive folder.
# Copied 22665_ccap_filled.tif to Google Drive folder.
# Copied 22670_ccap_filled.tif to Google Drive folder.
# Copied 22748_ccap_filled.tif to Google Drive folder.
# Copied 23771_ccap_filled.tif to Google Drive folder.
# Copied 23239_ccap_filled.tif to Google Drive folder.
# Copied 23238_ccap_filled.tif to Google Drive folder.
# Copied 22667_ccap_filled.tif to Google Drive folder.
# Copied 23476_ccap_filled.tif to Google Drive folder.
# Copied 22698_ccap_filled.tif to Google Drive folder.
# Copied 23898_ccap_filled.tif to Google Drive folder.
# Copied 23920_ccap_filled.tif to Google Drive folder.
# Copied 23390_ccap_filled.tif to Google Drive folder.
# Copied 22321_ccap_filled.tif to Google Drive folder.
# Copied 23841_ccap_filled.tif to Google Drive folder.
# Copied 23231_ccap_filled.tif to Google Drive folder.
# Copied 23420_ccap_filled.tif to Google Drive folder.
# Copied 22449_ccap_filled.tif to Google Drive folder.
# Copied 22901_ccap_filled.tif to Google Drive folder.
# Copied 23011_ccap_filled.tif to Google Drive folder.
# Copied 23369_ccap_filled.tif to Google Drive folder.
# Copied 22668_ccap_filled.tif to Google Drive folder.
# Copied 22318_ccap_filled.tif to Google Drive folder.
# Copied 23200_ccap_filled.tif to Google Drive folder.
# Copied 22779_ccap_filled.tif to Google Drive folder.
# Copied 22653_ccap_filled.tif to Google Drive folder.
# Copied 23097_ccap_filled.tif to Google Drive folder.
# Copied 22409_ccap_filled.tif to Google Drive folder.
# Copied 23784_ccap_filled.tif to Google Drive folder.
# Copied 23435_ccap_filled.tif to Google Drive folder.
# Copied 23503_ccap_filled.tif to Google Drive folder.
# Copied 23030_ccap_filled.tif to Google Drive folder.
# Copied 22383_ccap_filled.tif to Google Drive folder.
# Copied 22346_ccap_filled.tif to Google Drive folder.
# Copied 22576_ccap_filled.tif to Google Drive folder.
# Copied 23963_ccap_filled.tif to Google Drive folder.
# Copied 23930_ccap_filled.tif to Google Drive folder.
# Copied 22429_ccap_filled.tif to Google Drive folder.
# Copied 23854_ccap_filled.tif to Google Drive folder.
# Copied 22850_ccap_filled.tif to Google Drive folder.
# Copied 23250_ccap_filled.tif to Google Drive folder.
# Copied 22939_ccap_filled.tif to Google Drive folder.
# Copied 23814_ccap_filled.tif to Google Drive folder.
# Copied 22912_ccap_filled.tif to Google Drive folder.
# Copied 23644_ccap_filled.tif to Google Drive folder.
# Copied 23722_ccap_filled.tif to Google Drive folder.
# Copied 23864_ccap_filled.tif to Google Drive folder.
# Copied 22401_ccap_filled.tif to Google Drive folder.
# Copied 22503_ccap_filled.tif to Google Drive folder.
# Copied 23246_ccap_filled.tif to Google Drive folder.
# Copied 22817_ccap_filled.tif to Google Drive folder.
# Copied 22416_ccap_filled.tif to Google Drive folder.
# Copied 22392_ccap_filled.tif to Google Drive folder.
# Copied 22378_ccap_filled.tif to Google Drive folder.
# Copied 23125_ccap_filled.tif to Google Drive folder.
# Copied 22644_ccap_filled.tif to Google Drive folder.
# Copied 22386_ccap_filled.tif to Google Drive folder.
# Copied 23084_ccap_filled.tif to Google Drive folder.
# Copied 23739_ccap_filled.tif to Google Drive folder.
# Copied 23049_ccap_filled.tif to Google Drive folder.
# Copied 23959_ccap_filled.tif to Google Drive folder.
# Copied 23164_ccap_filled.tif to Google Drive folder.
# Copied 22353_ccap_filled.tif to Google Drive folder.
# Copied 23347_ccap_filled.tif to Google Drive folder.
# Copied 23086_ccap_filled.tif to Google Drive folder.
# Copied 22987_ccap_filled.tif to Google Drive folder.
# Copied 23559_ccap_filled.tif to Google Drive folder.
# Copied 23417_ccap_filled.tif to Google Drive folder.
# Copied 23895_ccap_filled.tif to Google Drive folder.
# Copied 22848_ccap_filled.tif to Google Drive folder.
# Copied 23785_ccap_filled.tif to Google Drive folder.
# Copied 22724_ccap_filled.tif to Google Drive folder.
# Copied 23689_ccap_filled.tif to Google Drive folder.
# Copied 23630_ccap_filled.tif to Google Drive folder.
# Copied 23732_ccap_filled.tif to Google Drive folder.
# Copied 22618_ccap_filled.tif to Google Drive folder.
# Copied 23900_ccap_filled.tif to Google Drive folder.
# Copied 23410_ccap_filled.tif to Google Drive folder.
# Copied 22474_ccap_filled.tif to Google Drive folder.
# Copied 23648_ccap_filled.tif to Google Drive folder.
# Copied 22998_ccap_filled.tif to Google Drive folder.
# Copied 23184_ccap_filled.tif to Google Drive folder.
# Copied 23925_ccap_filled.tif to Google Drive folder.
# Copied 22419_ccap_filled.tif to Google Drive folder.
# Copied 22826_ccap_filled.tif to Google Drive folder.
# Copied 22336_ccap_filled.tif to Google Drive folder.
# Copied 23359_ccap_filled.tif to Google Drive folder.
# Copied 23597_ccap_filled.tif to Google Drive folder.
# Copied 23786_ccap_filled.tif to Google Drive folder.
# Copied 23845_ccap_filled.tif to Google Drive folder.
# Copied 22925_ccap_filled.tif to Google Drive folder.
# Copied 23490_ccap_filled.tif to Google Drive folder.
# Copied 23117_ccap_filled.tif to Google Drive folder.
# Copied 23166_ccap_filled.tif to Google Drive folder.
# Copied 23541_ccap_filled.tif to Google Drive folder.
# Copied 22906_ccap_filled.tif to Google Drive folder.
# Copied 22404_ccap_filled.tif to Google Drive folder.
# Copied 22931_ccap_filled.tif to Google Drive folder.
# Copied 23651_ccap_filled.tif to Google Drive folder.
# Copied 22961_ccap_filled.tif to Google Drive folder.
# Copied 23254_ccap_filled.tif to Google Drive folder.
# Copied 23008_ccap_filled.tif to Google Drive folder.
# Copied 23765_ccap_filled.tif to Google Drive folder.
# Copied 23455_ccap_filled.tif to Google Drive folder.
# Copied 23939_ccap_filled.tif to Google Drive folder.
# Copied 22686_ccap_filled.tif to Google Drive folder.
# Copied 23018_ccap_filled.tif to Google Drive folder.
# Copied 23010_ccap_filled.tif to Google Drive folder.
# Copied 23462_ccap_filled.tif to Google Drive folder.
# Copied 23016_ccap_filled.tif to Google Drive folder.
# Copied 22300_ccap_filled.tif to Google Drive folder.
# Copied 22949_ccap_filled.tif to Google Drive folder.
# Copied 23908_ccap_filled.tif to Google Drive folder.
# Copied 23075_ccap_filled.tif to Google Drive folder.
# Copied 23383_ccap_filled.tif to Google Drive folder.
# Copied 22508_ccap_filled.tif to Google Drive folder.
# Copied 22444_ccap_filled.tif to Google Drive folder.
# Copied 22476_ccap_filled.tif to Google Drive folder.
# Copied 23935_ccap_filled.tif to Google Drive folder.
# Copied 22842_ccap_filled.tif to Google Drive folder.
# Copied 23116_ccap_filled.tif to Google Drive folder.
# Copied 23618_ccap_filled.tif to Google Drive folder.
# Copied 22494_ccap_filled.tif to Google Drive folder.
# Copied 23081_ccap_filled.tif to Google Drive folder.
# Copied 22487_ccap_filled.tif to Google Drive folder.
# Copied 23029_ccap_filled.tif to Google Drive folder.
# Copied 23296_ccap_filled.tif to Google Drive folder.
# Copied 23054_ccap_filled.tif to Google Drive folder.
# Copied 23403_ccap_filled.tif to Google Drive folder.
# Copied 23119_ccap_filled.tif to Google Drive folder.
# Copied 22568_ccap_filled.tif to Google Drive folder.
# Copied 23297_ccap_filled.tif to Google Drive folder.
# Copied 23260_ccap_filled.tif to Google Drive folder.
# Copied 22882_ccap_filled.tif to Google Drive folder.
# Copied 23210_ccap_filled.tif to Google Drive folder.
# Copied 22928_ccap_filled.tif to Google Drive folder.
# Copied 22722_ccap_filled.tif to Google Drive folder.
# Copied 23312_ccap_filled.tif to Google Drive folder.
# Copied 22786_ccap_filled.tif to Google Drive folder.
# Copied 22410_ccap_filled.tif to Google Drive folder.
# Copied 23964_ccap_filled.tif to Google Drive folder.
# Copied 22562_ccap_filled.tif to Google Drive folder.
# Copied 23253_ccap_filled.tif to Google Drive folder.
# Copied 23247_ccap_filled.tif to Google Drive folder.
# Copied 23304_ccap_filled.tif to Google Drive folder.
# Copied 22941_ccap_filled.tif to Google Drive folder.
# Copied 23251_ccap_filled.tif to Google Drive folder.
# Copied 23496_ccap_filled.tif to Google Drive folder.
# Copied 23112_ccap_filled.tif to Google Drive folder.
# Copied 22557_ccap_filled.tif to Google Drive folder.
# Copied 23816_ccap_filled.tif to Google Drive folder.
# Copied 23744_ccap_filled.tif to Google Drive folder.
# Copied 23879_ccap_filled.tif to Google Drive folder.
# Copied 22475_ccap_filled.tif to Google Drive folder.
# Copied 22916_ccap_filled.tif to Google Drive folder.
# Copied 23331_ccap_filled.tif to Google Drive folder.
# Copied 23764_ccap_filled.tif to Google Drive folder.
# Copied 22558_ccap_filled.tif to Google Drive folder.
# Copied 23821_ccap_filled.tif to Google Drive folder.
# Copied 22854_ccap_filled.tif to Google Drive folder.
# Copied 23677_ccap_filled.tif to Google Drive folder.
# Copied 23682_ccap_filled.tif to Google Drive folder.
# Copied 22640_ccap_filled.tif to Google Drive folder.
# Copied 22841_ccap_filled.tif to Google Drive folder.
# Copied 23598_ccap_filled.tif to Google Drive folder.
# Copied 23685_ccap_filled.tif to Google Drive folder.
# Copied 22527_ccap_filled.tif to Google Drive folder.
# Copied 22536_ccap_filled.tif to Google Drive folder.
# Copied 23083_ccap_filled.tif to Google Drive folder.
# Copied 23040_ccap_filled.tif to Google Drive folder.
# Copied 23505_ccap_filled.tif to Google Drive folder.
# Copied 22295_ccap_filled.tif to Google Drive folder.
# Copied 23638_ccap_filled.tif to Google Drive folder.
# Copied 22601_ccap_filled.tif to Google Drive folder.
# Copied 23960_ccap_filled.tif to Google Drive folder.
# Copied 22316_ccap_filled.tif to Google Drive folder.
# Copied 23675_ccap_filled.tif to Google Drive folder.
# Copied 23350_ccap_filled.tif to Google Drive folder.
# Copied 22587_ccap_filled.tif to Google Drive folder.
# Copied 23733_ccap_filled.tif to Google Drive folder.
# Copied 23352_ccap_filled.tif to Google Drive folder.
# Copied 23615_ccap_filled.tif to Google Drive folder.
# Copied 23071_ccap_filled.tif to Google Drive folder.
# Copied 22714_ccap_filled.tif to Google Drive folder.
# Copied 22448_ccap_filled.tif to Google Drive folder.
# Copied 22733_ccap_filled.tif to Google Drive folder.
# Copied 22337_ccap_filled.tif to Google Drive folder.
# Copied 22455_ccap_filled.tif to Google Drive folder.
# Copied 23830_ccap_filled.tif to Google Drive folder.
# Copied 23402_ccap_filled.tif to Google Drive folder.
# Copied 23852_ccap_filled.tif to Google Drive folder.
# Copied 23371_ccap_filled.tif to Google Drive folder.
# Copied 22385_ccap_filled.tif to Google Drive folder.
# Copied 23160_ccap_filled.tif to Google Drive folder.
# Copied 23079_ccap_filled.tif to Google Drive folder.
# Copied 23230_ccap_filled.tif to Google Drive folder.
# Copied 23479_ccap_filled.tif to Google Drive folder.
# Copied 23923_ccap_filled.tif to Google Drive folder.
# Copied 23684_ccap_filled.tif to Google Drive folder.
# Copied 23643_ccap_filled.tif to Google Drive folder.
# Copied 23592_ccap_filled.tif to Google Drive folder.
# Copied 23179_ccap_filled.tif to Google Drive folder.
# Copied 23672_ccap_filled.tif to Google Drive folder.
# Copied 22359_ccap_filled.tif to Google Drive folder.
# Copied 23443_ccap_filled.tif to Google Drive folder.
# Copied 22978_ccap_filled.tif to Google Drive folder.
# Copied 23454_ccap_filled.tif to Google Drive folder.
# Copied 23189_ccap_filled.tif to Google Drive folder.
# Copied 23777_ccap_filled.tif to Google Drive folder.
# Copied 23323_ccap_filled.tif to Google Drive folder.
# Copied 22328_ccap_filled.tif to Google Drive folder.
# Copied 23057_ccap_filled.tif to Google Drive folder.
# Copied 23789_ccap_filled.tif to Google Drive folder.
# Copied 23863_ccap_filled.tif to Google Drive folder.
# Copied 22486_ccap_filled.tif to Google Drive folder.
# Copied 23519_ccap_filled.tif to Google Drive folder.
# Copied 23070_ccap_filled.tif to Google Drive folder.
# Copied 23042_ccap_filled.tif to Google Drive folder.
# Copied 22590_ccap_filled.tif to Google Drive folder.
# Copied 22875_ccap_filled.tif to Google Drive folder.
# Copied 23398_ccap_filled.tif to Google Drive folder.
# Copied 23408_ccap_filled.tif to Google Drive folder.
# Copied 23512_ccap_filled.tif to Google Drive folder.
# Copied 23190_ccap_filled.tif to Google Drive folder.
# Copied 23211_ccap_filled.tif to Google Drive folder.
# Copied 22538_ccap_filled.tif to Google Drive folder.
# Copied 23934_ccap_filled.tif to Google Drive folder.
# Copied 23586_ccap_filled.tif to Google Drive folder.
# Copied 22894_ccap_filled.tif to Google Drive folder.
# Copied 22952_ccap_filled.tif to Google Drive folder.
# Copied 22529_ccap_filled.tif to Google Drive folder.
# Copied 23069_ccap_filled.tif to Google Drive folder.
# Copied 22962_ccap_filled.tif to Google Drive folder.
# Copied 22433_ccap_filled.tif to Google Drive folder.
# Copied 23531_ccap_filled.tif to Google Drive folder.
# Copied 23650_ccap_filled.tif to Google Drive folder.
# Copied 22571_ccap_filled.tif to Google Drive folder.
# Copied 23233_ccap_filled.tif to Google Drive folder.
# Copied 23803_ccap_filled.tif to Google Drive folder.
# Copied 23208_ccap_filled.tif to Google Drive folder.
# Copied 22423_ccap_filled.tif to Google Drive folder.
# Copied 23148_ccap_filled.tif to Google Drive folder.
# Copied 23406_ccap_filled.tif to Google Drive folder.
# Copied 23267_ccap_filled.tif to Google Drive folder.
# Copied 23568_ccap_filled.tif to Google Drive folder.
# Copied 23697_ccap_filled.tif to Google Drive folder.
# Copied 22467_ccap_filled.tif to Google Drive folder.
# Copied 23555_ccap_filled.tif to Google Drive folder.
# Copied 23768_ccap_filled.tif to Google Drive folder.
# Copied 23436_ccap_filled.tif to Google Drive folder.
# Copied 23157_ccap_filled.tif to Google Drive folder.
# Copied 23875_ccap_filled.tif to Google Drive folder.
# Copied 23051_ccap_filled.tif to Google Drive folder.
# Copied 22883_ccap_filled.tif to Google Drive folder.
# Copied 23707_ccap_filled.tif to Google Drive folder.
# Copied 23484_ccap_filled.tif to Google Drive folder.
# Copied 23674_ccap_filled.tif to Google Drive folder.
# Copied 23395_ccap_filled.tif to Google Drive folder.
# Copied 22887_ccap_filled.tif to Google Drive folder.
# Copied 22975_ccap_filled.tif to Google Drive folder.
# Copied 23884_ccap_filled.tif to Google Drive folder.
# Copied 23642_ccap_filled.tif to Google Drive folder.
# Copied 22880_ccap_filled.tif to Google Drive folder.
# Copied 22405_ccap_filled.tif to Google Drive folder.
# Copied 23892_ccap_filled.tif to Google Drive folder.
# Copied 23711_ccap_filled.tif to Google Drive folder.
# Copied 22418_ccap_filled.tif to Google Drive folder.
# Copied 23146_ccap_filled.tif to Google Drive folder.
# Copied 22461_ccap_filled.tif to Google Drive folder.
# Copied 23511_ccap_filled.tif to Google Drive folder.
# Copied 23155_ccap_filled.tif to Google Drive folder.
# Copied 23585_ccap_filled.tif to Google Drive folder.
# Copied 22411_ccap_filled.tif to Google Drive folder.
# Copied 22579_ccap_filled.tif to Google Drive folder.
# Copied 23799_ccap_filled.tif to Google Drive folder.
# Copied 22457_ccap_filled.tif to Google Drive folder.
# Copied 23073_ccap_filled.tif to Google Drive folder.
# Copied 22645_ccap_filled.tif to Google Drive folder.
# Copied 23529_ccap_filled.tif to Google Drive folder.
# Copied 22497_ccap_filled.tif to Google Drive folder.
# Copied 23611_ccap_filled.tif to Google Drive folder.
# Copied 23563_ccap_filled.tif to Google Drive folder.
# Copied 22770_ccap_filled.tif to Google Drive folder.
# Copied 23878_ccap_filled.tif to Google Drive folder.
# Copied 22526_ccap_filled.tif to Google Drive folder.
# Copied 23885_ccap_filled.tif to Google Drive folder.
# Copied 22969_ccap_filled.tif to Google Drive folder.
# Copied 22548_ccap_filled.tif to Google Drive folder.
# Copied 23028_ccap_filled.tif to Google Drive folder.
# Copied 23721_ccap_filled.tif to Google Drive folder.
# Copied 23216_ccap_filled.tif to Google Drive folder.
# Copied 22451_ccap_filled.tif to Google Drive folder.
# Copied 22913_ccap_filled.tif to Google Drive folder.
# Copied 23712_ccap_filled.tif to Google Drive folder.
# Copied 23416_ccap_filled.tif to Google Drive folder.
# Copied 22936_ccap_filled.tif to Google Drive folder.
# Copied 22905_ccap_filled.tif to Google Drive folder.
# Copied 23158_ccap_filled.tif to Google Drive folder.
# Copied 23951_ccap_filled.tif to Google Drive folder.
# Copied 23111_ccap_filled.tif to Google Drive folder.
# Copied 23530_ccap_filled.tif to Google Drive folder.
# Copied 22412_ccap_filled.tif to Google Drive folder.
# Copied 22582_ccap_filled.tif to Google Drive folder.
# Copied 23382_ccap_filled.tif to Google Drive folder.
# Copied 23693_ccap_filled.tif to Google Drive folder.
# Copied 22480_ccap_filled.tif to Google Drive folder.
# Copied 23368_ccap_filled.tif to Google Drive folder.
# Copied 22948_ccap_filled.tif to Google Drive folder.
# Copied 22919_ccap_filled.tif to Google Drive folder.
# Copied 23933_ccap_filled.tif to Google Drive folder.
# Copied 22539_ccap_filled.tif to Google Drive folder.
# Copied 23017_ccap_filled.tif to Google Drive folder.
# Copied 23718_ccap_filled.tif to Google Drive folder.
# Copied 23646_ccap_filled.tif to Google Drive folder.
# Copied 22390_ccap_filled.tif to Google Drive folder.
# Copied 23652_ccap_filled.tif to Google Drive folder.
# Copied 23019_ccap_filled.tif to Google Drive folder.
# Copied 23090_ccap_filled.tif to Google Drive folder.
# Copied 23215_ccap_filled.tif to Google Drive folder.
# Copied 22830_ccap_filled.tif to Google Drive folder.
# Copied 23137_ccap_filled.tif to Google Drive folder.
# Copied 23949_ccap_filled.tif to Google Drive folder.
# Copied 22903_ccap_filled.tif to Google Drive folder.
# Copied 23114_ccap_filled.tif to Google Drive folder.
# Copied 22966_ccap_filled.tif to Google Drive folder.
# Copied 23433_ccap_filled.tif to Google Drive folder.
# Copied 23497_ccap_filled.tif to Google Drive folder.
# Copied 22544_ccap_filled.tif to Google Drive folder.
# Copied 23280_ccap_filled.tif to Google Drive folder.
# Copied 23629_ccap_filled.tif to Google Drive folder.
# Copied 23820_ccap_filled.tif to Google Drive folder.
# Copied 23575_ccap_filled.tif to Google Drive folder.
# Copied 22682_ccap_filled.tif to Google Drive folder.
# Copied 23356_ccap_filled.tif to Google Drive folder.
# Copied 23182_ccap_filled.tif to Google Drive folder.
# Copied 23678_ccap_filled.tif to Google Drive folder.
# Copied 22669_ccap_filled.tif to Google Drive folder.
# Copied 23561_ccap_filled.tif to Google Drive folder.
# Copied 23681_ccap_filled.tif to Google Drive folder.
# Copied 22596_ccap_filled.tif to Google Drive folder.
# Copied 22351_ccap_filled.tif to Google Drive folder.
# Copied 22968_ccap_filled.tif to Google Drive folder.
# Copied 23322_ccap_filled.tif to Google Drive folder.
# Copied 23654_ccap_filled.tif to Google Drive folder.
# Copied 23815_ccap_filled.tif to Google Drive folder.
# Copied 23474_ccap_filled.tif to Google Drive folder.
# Copied 23478_ccap_filled.tif to Google Drive folder.
# Copied 22511_ccap_filled.tif to Google Drive folder.
# Copied 23459_ccap_filled.tif to Google Drive folder.
# Copied 22840_ccap_filled.tif to Google Drive folder.
# Copied 22506_ccap_filled.tif to Google Drive folder.
# Copied 22570_ccap_filled.tif to Google Drive folder.
# Copied 23104_ccap_filled.tif to Google Drive folder.
# Copied 23052_ccap_filled.tif to Google Drive folder.
# Copied 23534_ccap_filled.tif to Google Drive folder.
# Copied 22659_ccap_filled.tif to Google Drive folder.
# Copied 23828_ccap_filled.tif to Google Drive folder.
# Copied 23122_ccap_filled.tif to Google Drive folder.
# Copied 22858_ccap_filled.tif to Google Drive folder.
# Copied 23688_ccap_filled.tif to Google Drive folder.
# Copied 22453_ccap_filled.tif to Google Drive folder.
# Copied 22706_ccap_filled.tif to Google Drive folder.
# Copied 23620_ccap_filled.tif to Google Drive folder.
# Copied 23315_ccap_filled.tif to Google Drive folder.
# Copied 23809_ccap_filled.tif to Google Drive folder.
# Copied 23329_ccap_filled.tif to Google Drive folder.
# Copied 23802_ccap_filled.tif to Google Drive folder.
# Copied 23604_ccap_filled.tif to Google Drive folder.
# Copied 22365_ccap_filled.tif to Google Drive folder.
# Copied 22922_ccap_filled.tif to Google Drive folder.
# Copied 22361_ccap_filled.tif to Google Drive folder.
# Copied 23453_ccap_filled.tif to Google Drive folder.
# Copied 23472_ccap_filled.tif to Google Drive folder.
# Copied 23342_ccap_filled.tif to Google Drive folder.
# Copied 22464_ccap_filled.tif to Google Drive folder.
# Copied 23573_ccap_filled.tif to Google Drive folder.
# Copied 23795_ccap_filled.tif to Google Drive folder.
# Copied 22483_ccap_filled.tif to Google Drive folder.
# Copied 23394_ccap_filled.tif to Google Drive folder.
# Copied 22309_ccap_filled.tif to Google Drive folder.
# Copied 23271_ccap_filled.tif to Google Drive folder.
# Copied 22876_ccap_filled.tif to Google Drive folder.
# Copied 22426_ccap_filled.tif to Google Drive folder.
# Copied 23606_ccap_filled.tif to Google Drive folder.
# Copied 23634_ccap_filled.tif to Google Drive folder.
# Copied 22753_ccap_filled.tif to Google Drive folder.
# Copied 23438_ccap_filled.tif to Google Drive folder.
# Copied 23579_ccap_filled.tif to Google Drive folder.
# Copied 23599_ccap_filled.tif to Google Drive folder.
# Copied 22957_ccap_filled.tif to Google Drive folder.
# Copied 23399_ccap_filled.tif to Google Drive folder.
# Copied 23947_ccap_filled.tif to Google Drive folder.
# Copied 23299_ccap_filled.tif to Google Drive folder.
# Copied 23076_ccap_filled.tif to Google Drive folder.
# Copied 22326_ccap_filled.tif to Google Drive folder.
# Copied 23663_ccap_filled.tif to Google Drive folder.
# Copied 23207_ccap_filled.tif to Google Drive folder.
# Copied 23759_ccap_filled.tif to Google Drive folder.
# Copied 22958_ccap_filled.tif to Google Drive folder.
# Copied 22357_ccap_filled.tif to Google Drive folder.
# Copied 22388_ccap_filled.tif to Google Drive folder.
# Copied 23118_ccap_filled.tif to Google Drive folder.
# Copied 23099_ccap_filled.tif to Google Drive folder.
# Copied 22869_ccap_filled.tif to Google Drive folder.
# Copied 23370_ccap_filled.tif to Google Drive folder.
# Copied 22408_ccap_filled.tif to Google Drive folder.
# Copied 23796_ccap_filled.tif to Google Drive folder.
# Copied 23973_ccap_filled.tif to Google Drive folder.
# Copied 22781_ccap_filled.tif to Google Drive folder.
# Copied 22540_ccap_filled.tif to Google Drive folder.
# Copied 22760_ccap_filled.tif to Google Drive folder.
# Copied 23872_ccap_filled.tif to Google Drive folder.
# Copied 23341_ccap_filled.tif to Google Drive folder.
# Copied 22803_ccap_filled.tif to Google Drive folder.
# Copied 23944_ccap_filled.tif to Google Drive folder.
# Copied 23188_ccap_filled.tif to Google Drive folder.
# Copied 22731_ccap_filled.tif to Google Drive folder.
# Copied 23639_ccap_filled.tif to Google Drive folder.
# Copied 22723_ccap_filled.tif to Google Drive folder.
# Copied 22920_ccap_filled.tif to Google Drive folder.
# Copied 22938_ccap_filled.tif to Google Drive folder.
# Copied 23336_ccap_filled.tif to Google Drive folder.
# Copied 23467_ccap_filled.tif to Google Drive folder.
# Copied 22428_ccap_filled.tif to Google Drive folder.
# Copied 23463_ccap_filled.tif to Google Drive folder.
# Copied 22635_ccap_filled.tif to Google Drive folder.
# Copied 22862_ccap_filled.tif to Google Drive folder.
# Copied 23338_ccap_filled.tif to Google Drive folder.
# Copied 23842_ccap_filled.tif to Google Drive folder.
# Copied 22565_ccap_filled.tif to Google Drive folder.
# Copied 22940_ccap_filled.tif to Google Drive folder.
# Copied 23066_ccap_filled.tif to Google Drive folder.
# Copied 23135_ccap_filled.tif to Google Drive folder.
# Copied 23397_ccap_filled.tif to Google Drive folder.
# Copied 22675_ccap_filled.tif to Google Drive folder.
# Copied 23063_ccap_filled.tif to Google Drive folder.
# Copied 23491_ccap_filled.tif to Google Drive folder.
# Copied 23632_ccap_filled.tif to Google Drive folder.
# Copied 23522_ccap_filled.tif to Google Drive folder.
# Copied 22820_ccap_filled.tif to Google Drive folder.
# Copied 23055_ccap_filled.tif to Google Drive folder.
# Copied 22502_ccap_filled.tif to Google Drive folder.
# Copied 23498_ccap_filled.tif to Google Drive folder.
# Copied 23307_ccap_filled.tif to Google Drive folder.
# Copied 23907_ccap_filled.tif to Google Drive folder.
# Copied 22362_ccap_filled.tif to Google Drive folder.
# Copied 22477_ccap_filled.tif to Google Drive folder.
# Copied 22646_ccap_filled.tif to Google Drive folder.
# Copied 22824_ccap_filled.tif to Google Drive folder.
# Copied 23832_ccap_filled.tif to Google Drive folder.
# Copied 23844_ccap_filled.tif to Google Drive folder.
# Copied 22445_ccap_filled.tif to Google Drive folder.
# Copied 22679_ccap_filled.tif to Google Drive folder.
# Copied 22633_ccap_filled.tif to Google Drive folder.
# Copied 22463_ccap_filled.tif to Google Drive folder.
# Copied 23856_ccap_filled.tif to Google Drive folder.
# Copied 23692_ccap_filled.tif to Google Drive folder.
# Copied 23899_ccap_filled.tif to Google Drive folder.
# Copied 22744_ccap_filled.tif to Google Drive folder.
# Copied 22608_ccap_filled.tif to Google Drive folder.
# Copied 22438_ccap_filled.tif to Google Drive folder.
# Copied 23330_ccap_filled.tif to Google Drive folder.
# Copied 23392_ccap_filled.tif to Google Drive folder.
# Copied 22311_ccap_filled.tif to Google Drive folder.
# Copied 22684_ccap_filled.tif to Google Drive folder.
# Copied 22591_ccap_filled.tif to Google Drive folder.
# Copied 22399_ccap_filled.tif to Google Drive folder.
# Copied 23694_ccap_filled.tif to Google Drive folder.
# Copied 22889_ccap_filled.tif to Google Drive folder.
# Copied 22823_ccap_filled.tif to Google Drive folder.
# Copied 22734_ccap_filled.tif to Google Drive folder.
# Copied 23500_ccap_filled.tif to Google Drive folder.
# Copied 23241_ccap_filled.tif to Google Drive folder.
# Copied 22776_ccap_filled.tif to Google Drive folder.
# Copied 23726_ccap_filled.tif to Google Drive folder.
# Copied 23741_ccap_filled.tif to Google Drive folder.
# Copied 23169_ccap_filled.tif to Google Drive folder.
# Copied 22614_ccap_filled.tif to Google Drive folder.
# Copied 23236_ccap_filled.tif to Google Drive folder.
# Copied 23334_ccap_filled.tif to Google Drive folder.
# Copied 23794_ccap_filled.tif to Google Drive folder.
# Copied 22641_ccap_filled.tif to Google Drive folder.
# Copied 23318_ccap_filled.tif to Google Drive folder.
# Copied 23762_ccap_filled.tif to Google Drive folder.
# Copied 22793_ccap_filled.tif to Google Drive folder.
# Copied 22765_ccap_filled.tif to Google Drive folder.
# Copied 23129_ccap_filled.tif to Google Drive folder.
# Copied 23671_ccap_filled.tif to Google Drive folder.
# Copied 22917_ccap_filled.tif to Google Drive folder.
# Copied 23458_ccap_filled.tif to Google Drive folder.
# Copied 22552_ccap_filled.tif to Google Drive folder.
# Copied 23175_ccap_filled.tif to Google Drive folder.
# Copied 22699_ccap_filled.tif to Google Drive folder.
# Copied 23891_ccap_filled.tif to Google Drive folder.
# Copied 22443_ccap_filled.tif to Google Drive folder.
# Copied 23107_ccap_filled.tif to Google Drive folder.
# Copied 23494_ccap_filled.tif to Google Drive folder.
# Copied 23581_ccap_filled.tif to Google Drive folder.
# Copied 22822_ccap_filled.tif to Google Drive folder.
# Copied 23178_ccap_filled.tif to Google Drive folder.
# Copied 23729_ccap_filled.tif to Google Drive folder.
# Copied 23354_ccap_filled.tif to Google Drive folder.
# Copied 22369_ccap_filled.tif to Google Drive folder.
# Copied 23716_ccap_filled.tif to Google Drive folder.
# Copied 23911_ccap_filled.tif to Google Drive folder.
# Copied 23387_ccap_filled.tif to Google Drive folder.
# Copied 22368_ccap_filled.tif to Google Drive folder.
# Copied 23506_ccap_filled.tif to Google Drive folder.
# Copied 23686_ccap_filled.tif to Google Drive folder.
# Copied 23386_ccap_filled.tif to Google Drive folder.
# Copied 22924_ccap_filled.tif to Google Drive folder.
# Copied 22970_ccap_filled.tif to Google Drive folder.
# Copied 22382_ccap_filled.tif to Google Drive folder.
# Copied 23931_ccap_filled.tif to Google Drive folder.
# Copied 23024_ccap_filled.tif to Google Drive folder.
# Copied 22749_ccap_filled.tif to Google Drive folder.
# Copied 23328_ccap_filled.tif to Google Drive folder.
# Copied 22730_ccap_filled.tif to Google Drive folder.
# Copied 23566_ccap_filled.tif to Google Drive folder.
# Copied 22303_ccap_filled.tif to Google Drive folder.
# Copied 23426_ccap_filled.tif to Google Drive folder.
# Copied 22737_ccap_filled.tif to Google Drive folder.
# Copied 23225_ccap_filled.tif to Google Drive folder.
# Copied 23812_ccap_filled.tif to Google Drive folder.
# Copied 23198_ccap_filled.tif to Google Drive folder.
# Copied 22736_ccap_filled.tif to Google Drive folder.
# Copied 22866_ccap_filled.tif to Google Drive folder.
# Copied 22711_ccap_filled.tif to Google Drive folder.
# Copied 22709_ccap_filled.tif to Google Drive folder.
# Copied 23701_ccap_filled.tif to Google Drive folder.
# Copied 22937_ccap_filled.tif to Google Drive folder.
# Copied 22717_ccap_filled.tif to Google Drive folder.
# Copied 23186_ccap_filled.tif to Google Drive folder.
# Copied 23401_ccap_filled.tif to Google Drive folder.
# Copied 23876_ccap_filled.tif to Google Drive folder.
# Copied 22769_ccap_filled.tif to Google Drive folder.
# Copied 22545_ccap_filled.tif to Google Drive folder.
# Copied 23153_ccap_filled.tif to Google Drive folder.
# Copied 22708_ccap_filled.tif to Google Drive folder.
# Copied 23673_ccap_filled.tif to Google Drive folder.
# Copied 22301_ccap_filled.tif to Google Drive folder.
# Copied 22946_ccap_filled.tif to Google Drive folder.
# Copied 22310_ccap_filled.tif to Google Drive folder.
# Copied 23915_ccap_filled.tif to Google Drive folder.
# Copied 22468_ccap_filled.tif to Google Drive folder.
# Copied 23192_ccap_filled.tif to Google Drive folder.
# Copied 23205_ccap_filled.tif to Google Drive folder.
# Copied 23481_ccap_filled.tif to Google Drive folder.
# Copied 23751_ccap_filled.tif to Google Drive folder.
# Copied 22563_ccap_filled.tif to Google Drive folder.
# Copied 23608_ccap_filled.tif to Google Drive folder.
# Copied 23819_ccap_filled.tif to Google Drive folder.
# Copied 22304_ccap_filled.tif to Google Drive folder.
# Copied 22504_ccap_filled.tif to Google Drive folder.
# Copied 23552_ccap_filled.tif to Google Drive folder.
# Copied 22890_ccap_filled.tif to Google Drive folder.
# Copied 22846_ccap_filled.tif to Google Drive folder.
# Copied 23547_ccap_filled.tif to Google Drive folder.
# Copied 23754_ccap_filled.tif to Google Drive folder.
# Copied 23385_ccap_filled.tif to Google Drive folder.
# Copied 22348_ccap_filled.tif to Google Drive folder.
# Copied 23492_ccap_filled.tif to Google Drive folder.
# Copied 23703_ccap_filled.tif to Google Drive folder.
# Copied 22857_ccap_filled.tif to Google Drive folder.
# Copied 22898_ccap_filled.tif to Google Drive folder.
# Copied 22585_ccap_filled.tif to Google Drive folder.
# Copied 23229_ccap_filled.tif to Google Drive folder.
# Copied 23270_ccap_filled.tif to Google Drive folder.
# Copied 23034_ccap_filled.tif to Google Drive folder.
# Copied 22955_ccap_filled.tif to Google Drive folder.
# Copied 23068_ccap_filled.tif to Google Drive folder.
# Copied 23696_ccap_filled.tif to Google Drive folder.
# Copied 22472_ccap_filled.tif to Google Drive folder.
# Copied 22742_ccap_filled.tif to Google Drive folder.
# Copied 23961_ccap_filled.tif to Google Drive folder.
# Copied 22947_ccap_filled.tif to Google Drive folder.
# Copied 22791_ccap_filled.tif to Google Drive folder.
# Copied 22688_ccap_filled.tif to Google Drive folder.
# Copied 22804_ccap_filled.tif to Google Drive folder.
# Copied 23138_ccap_filled.tif to Google Drive folder.
# Copied 23223_ccap_filled.tif to Google Drive folder.
# Copied 22335_ccap_filled.tif to Google Drive folder.
# Copied 22573_ccap_filled.tif to Google Drive folder.
# Copied 23026_ccap_filled.tif to Google Drive folder.
# Copied 23032_ccap_filled.tif to Google Drive folder.
# Copied 22671_ccap_filled.tif to Google Drive folder.
# Copied 22911_ccap_filled.tif to Google Drive folder.
# Copied 22420_ccap_filled.tif to Google Drive folder.
# Copied 22622_ccap_filled.tif to Google Drive folder.
# Copied 23187_ccap_filled.tif to Google Drive folder.
# Copied 23132_ccap_filled.tif to Google Drive folder.
# Copied 23275_ccap_filled.tif to Google Drive folder.
# Copied 23546_ccap_filled.tif to Google Drive folder.
# Copied 23409_ccap_filled.tif to Google Drive folder.
# Copied 23932_ccap_filled.tif to Google Drive folder.
# Copied 22649_ccap_filled.tif to Google Drive folder.
# Copied 22980_ccap_filled.tif to Google Drive folder.
# Copied 23039_ccap_filled.tif to Google Drive folder.
# Copied 22662_ccap_filled.tif to Google Drive folder.
# Copied 23012_ccap_filled.tif to Google Drive folder.
# Copied 23655_ccap_filled.tif to Google Drive folder.
# Copied 23631_ccap_filled.tif to Google Drive folder.
# Copied 23333_ccap_filled.tif to Google Drive folder.
# Copied 22313_ccap_filled.tif to Google Drive folder.
# Copied 23680_ccap_filled.tif to Google Drive folder.
# Copied 23227_ccap_filled.tif to Google Drive folder.
# Copied 23893_ccap_filled.tif to Google Drive folder.
# Copied 23906_ccap_filled.tif to Google Drive folder.
# Copied 23324_ccap_filled.tif to Google Drive folder.
# Copied 23101_ccap_filled.tif to Google Drive folder.
# Copied 22333_ccap_filled.tif to Google Drive folder.
# Copied 23294_ccap_filled.tif to Google Drive folder.
# Copied 23683_ccap_filled.tif to Google Drive folder.
# Copied 22535_ccap_filled.tif to Google Drive folder.
# Copied 23865_ccap_filled.tif to Google Drive folder.
# Copied 22521_ccap_filled.tif to Google Drive folder.
# Copied 23966_ccap_filled.tif to Google Drive folder.
# Copied 23020_ccap_filled.tif to Google Drive folder.
# Copied 23659_ccap_filled.tif to Google Drive folder.
# Copied 23835_ccap_filled.tif to Google Drive folder.
# Copied 23332_ccap_filled.tif to Google Drive folder.
# Copied 22421_ccap_filled.tif to Google Drive folder.
# Copied 22712_ccap_filled.tif to Google Drive folder.
# Copied 23896_ccap_filled.tif to Google Drive folder.
# Copied 23877_ccap_filled.tif to Google Drive folder.
# Copied 22507_ccap_filled.tif to Google Drive folder.
# Copied 23913_ccap_filled.tif to Google Drive folder.
# Copied 23843_ccap_filled.tif to Google Drive folder.
# Copied 22425_ccap_filled.tif to Google Drive folder.
# Copied 23123_ccap_filled.tif to Google Drive folder.
# Copied 23373_ccap_filled.tif to Google Drive folder.
# Copied 23393_ccap_filled.tif to Google Drive folder.
# Copied 23261_ccap_filled.tif to Google Drive folder.
# Copied 22757_ccap_filled.tif to Google Drive folder.
# Copied 23710_ccap_filled.tif to Google Drive folder.
# Copied 22910_ccap_filled.tif to Google Drive folder.
# Copied 23142_ccap_filled.tif to Google Drive folder.
# Copied 23540_ccap_filled.tif to Google Drive folder.
# Copied 23047_ccap_filled.tif to Google Drive folder.
# Copied 22434_ccap_filled.tif to Google Drive folder.
# Copied 23501_ccap_filled.tif to Google Drive folder.
# Copied 22763_ccap_filled.tif to Google Drive folder.
# Copied 23790_ccap_filled.tif to Google Drive folder.
# Copied 23314_ccap_filled.tif to Google Drive folder.
# Copied 23967_ccap_filled.tif to Google Drive folder.
# Copied 23760_ccap_filled.tif to Google Drive folder.
# Copied 23162_ccap_filled.tif to Google Drive folder.
# Copied 22785_ccap_filled.tif to Google Drive folder.
# Copied 23257_ccap_filled.tif to Google Drive folder.
# Copied 22720_ccap_filled.tif to Google Drive folder.
# Copied 22456_ccap_filled.tif to Google Drive folder.
# Copied 23219_ccap_filled.tif to Google Drive folder.
# Copied 23588_ccap_filled.tif to Google Drive folder.
# Copied 22481_ccap_filled.tif to Google Drive folder.
# Copied 23521_ccap_filled.tif to Google Drive folder.
# Copied 23956_ccap_filled.tif to Google Drive folder.
# Copied 23549_ccap_filled.tif to Google Drive folder.
# Copied 23130_ccap_filled.tif to Google Drive folder.
# Copied 22500_ccap_filled.tif to Google Drive folder.
# Copied 23335_ccap_filled.tif to Google Drive folder.
# Copied 22607_ccap_filled.tif to Google Drive folder.
# Copied 23623_ccap_filled.tif to Google Drive folder.
# Copied 23237_ccap_filled.tif to Google Drive folder.
# Copied 23868_ccap_filled.tif to Google Drive folder.
# Copied 23953_ccap_filled.tif to Google Drive folder.
# Copied 22657_ccap_filled.tif to Google Drive folder.
# Copied 23869_ccap_filled.tif to Google Drive folder.
# Copied 22750_ccap_filled.tif to Google Drive folder.
# Copied 22611_ccap_filled.tif to Google Drive folder.
# Copied 23320_ccap_filled.tif to Google Drive folder.
# Copied 23800_ccap_filled.tif to Google Drive folder.
# Copied 22516_ccap_filled.tif to Google Drive folder.
# Copied 23974_ccap_filled.tif to Google Drive folder.
# Copied 23874_ccap_filled.tif to Google Drive folder.
# Copied 22598_ccap_filled.tif to Google Drive folder.
# Copied 23539_ccap_filled.tif to Google Drive folder.
# Copied 23147_ccap_filled.tif to Google Drive folder.
# Copied 22606_ccap_filled.tif to Google Drive folder.
# Copied 23464_ccap_filled.tif to Google Drive folder.
# Copied 23806_ccap_filled.tif to Google Drive folder.
# Copied 22520_ccap_filled.tif to Google Drive folder.
# Copied 23706_ccap_filled.tif to Google Drive folder.
# Copied 22827_ccap_filled.tif to Google Drive folder.
# Copied 23351_ccap_filled.tif to Google Drive folder.
# Copied 23036_ccap_filled.tif to Google Drive folder.
# Copied 23133_ccap_filled.tif to Google Drive folder.
# Copied 22363_ccap_filled.tif to Google Drive folder.
# Copied 23840_ccap_filled.tif to Google Drive folder.
# Copied 22458_ccap_filled.tif to Google Drive folder.
# Copied 23437_ccap_filled.tif to Google Drive folder.
# Copied 22325_ccap_filled.tif to Google Drive folder.
# Copied 23965_ccap_filled.tif to Google Drive folder.
# Copied 23317_ccap_filled.tif to Google Drive folder.
# Copied 22524_ccap_filled.tif to Google Drive folder.
# Copied 22501_ccap_filled.tif to Google Drive folder.
# Copied 23941_ccap_filled.tif to Google Drive folder.
# Copied 23516_ccap_filled.tif to Google Drive folder.
# Copied 23756_ccap_filled.tif to Google Drive folder.
# Copied 23272_ccap_filled.tif to Google Drive folder.
# Copied 22755_ccap_filled.tif to Google Drive folder.
# Copied 23775_ccap_filled.tif to Google Drive folder.
# Copied 23591_ccap_filled.tif to Google Drive folder.
# Copied 23657_ccap_filled.tif to Google Drive folder.
# Copied 23968_ccap_filled.tif to Google Drive folder.
# Copied 22747_ccap_filled.tif to Google Drive folder.
# Copied 22402_ccap_filled.tif to Google Drive folder.
# Copied 22312_ccap_filled.tif to Google Drive folder.
# Copied 22588_ccap_filled.tif to Google Drive folder.
# Copied 23825_ccap_filled.tif to Google Drive folder.
# Copied 22766_ccap_filled.tif to Google Drive folder.
# Copied 22976_ccap_filled.tif to Google Drive folder.
# Copied 23641_ccap_filled.tif to Google Drive folder.
# Copied 22837_ccap_filled.tif to Google Drive folder.
# Copied 23258_ccap_filled.tif to Google Drive folder.
# Copied 23499_ccap_filled.tif to Google Drive folder.
# Copied 23580_ccap_filled.tif to Google Drive folder.
# Copied 23773_ccap_filled.tif to Google Drive folder.
# Copied 23092_ccap_filled.tif to Google Drive folder.
# Copied 23355_ccap_filled.tif to Google Drive folder.
# Copied 22799_ccap_filled.tif to Google Drive folder.
# Copied 22703_ccap_filled.tif to Google Drive folder.
# Copied 23446_ccap_filled.tif to Google Drive folder.
# Copied 22738_ccap_filled.tif to Google Drive folder.
# Copied 23013_ccap_filled.tif to Google Drive folder.
# Copied 23601_ccap_filled.tif to Google Drive folder.
# Copied 22986_ccap_filled.tif to Google Drive folder.
# Copied 23415_ccap_filled.tif to Google Drive folder.
# Copied 23050_ccap_filled.tif to Google Drive folder.
# Copied 22518_ccap_filled.tif to Google Drive folder.
# Copied 22672_ccap_filled.tif to Google Drive folder.
# Copied 22700_ccap_filled.tif to Google Drive folder.
# Copied 23736_ccap_filled.tif to Google Drive folder.
# Copied 22979_ccap_filled.tif to Google Drive folder.
# Copied 23379_ccap_filled.tif to Google Drive folder.
# Copied 22721_ccap_filled.tif to Google Drive folder.
# Copied 22743_ccap_filled.tif to Google Drive folder.
# Copied 22852_ccap_filled.tif to Google Drive folder.
# Copied 22935_ccap_filled.tif to Google Drive folder.
# Copied 22792_ccap_filled.tif to Google Drive folder.
# Copied 23757_ccap_filled.tif to Google Drive folder.
# Copied 22762_ccap_filled.tif to Google Drive folder.
# Copied 22774_ccap_filled.tif to Google Drive folder.
# Copied 23635_ccap_filled.tif to Google Drive folder.
# Copied 22713_ccap_filled.tif to Google Drive folder.
# Copied 23473_ccap_filled.tif to Google Drive folder.
# Copied 22519_ccap_filled.tif to Google Drive folder.
# Copied 23808_ccap_filled.tif to Google Drive folder.
# Copied 23149_ccap_filled.tif to Google Drive folder.
# Copied 23727_ccap_filled.tif to Google Drive folder.
# Copied 23769_ccap_filled.tif to Google Drive folder.
# Copied 22689_ccap_filled.tif to Google Drive folder.
# Copied 22547_ccap_filled.tif to Google Drive folder.
# Copied 22934_ccap_filled.tif to Google Drive folder.
# Copied 23827_ccap_filled.tif to Google Drive folder.
# Copied 22806_ccap_filled.tif to Google Drive folder.
# Copied 23781_ccap_filled.tif to Google Drive folder.
# Copied 23217_ccap_filled.tif to Google Drive folder.
# Copied 22546_ccap_filled.tif to Google Drive folder.
# Copied 23905_ccap_filled.tif to Google Drive folder.
# Copied 23349_ccap_filled.tif to Google Drive folder.
# Copied 22796_ccap_filled.tif to Google Drive folder.
# Copied 22427_ccap_filled.tif to Google Drive folder.
# Copied 22973_ccap_filled.tif to Google Drive folder.
# Copied 22541_ccap_filled.tif to Google Drive folder.
# Copied 23423_ccap_filled.tif to Google Drive folder.
# Copied 22893_ccap_filled.tif to Google Drive folder.
# Copied 23617_ccap_filled.tif to Google Drive folder.
# Copied 22551_ccap_filled.tif to Google Drive folder.
# Copied 22393_ccap_filled.tif to Google Drive folder.
# Copied 22441_ccap_filled.tif to Google Drive folder.
# Copied 22446_ccap_filled.tif to Google Drive folder.
# Copied 23882_ccap_filled.tif to Google Drive folder.
# Copied 23281_ccap_filled.tif to Google Drive folder.
# Copied 23468_ccap_filled.tif to Google Drive folder.
# Copied 23285_ccap_filled.tif to Google Drive folder.
# Copied 23889_ccap_filled.tif to Google Drive folder.
# Copied 23810_ccap_filled.tif to Google Drive folder.
# Copied 23441_ccap_filled.tif to Google Drive folder.
# Copied 23708_ccap_filled.tif to Google Drive folder.
# Copied 23871_ccap_filled.tif to Google Drive folder.
# Copied 23292_ccap_filled.tif to Google Drive folder.
# Copied 23656_ccap_filled.tif to Google Drive folder.
# Copied 23746_ccap_filled.tif to Google Drive folder.
# Copied 23136_ccap_filled.tif to Google Drive folder.
# Copied 22422_ccap_filled.tif to Google Drive folder.
# Copied 23284_ccap_filled.tif to Google Drive folder.
# Copied 22534_ccap_filled.tif to Google Drive folder.
# Copied 23836_ccap_filled.tif to Google Drive folder.
# Copied 22605_ccap_filled.tif to Google Drive folder.
# Copied 22355_ccap_filled.tif to Google Drive folder.
# Copied 23787_ccap_filled.tif to Google Drive folder.
# Copied 22908_ccap_filled.tif to Google Drive folder.
# Copied 23537_ccap_filled.tif to Google Drive folder.
# Copied 22810_ccap_filled.tif to Google Drive folder.
# Copied 22509_ccap_filled.tif to Google Drive folder.
# Copied 23495_ccap_filled.tif to Google Drive folder.
# Copied 22440_ccap_filled.tif to Google Drive folder.
# Copied 22778_ccap_filled.tif to Google Drive folder.
# Copied 22907_ccap_filled.tif to Google Drive folder.
# Copied 22777_ccap_filled.tif to Google Drive folder.
# Copied 23587_ccap_filled.tif to Google Drive folder.
# ...
# Copied 22341_ccap_filled.tif to Google Drive folder.
# Copied 23676_ccap_filled.tif to Google Drive folder.
# Copied 22488_ccap_filled.tif to Google Drive folder.
# Copied 23167_ccap_filled.tif to Google Drive folder.
# Copied 22993_ccap_filled.tif to Google Drive folder.
# Copied 22835_ccap_filled.tif to Google Drive folder.
# Copied 22982_ccap_filled.tif to Google Drive folder.
# Copied 23170_ccap_filled.tif to Google Drive folder.
# Copied 22406_ccap_filled.tif to Google Drive folder.
# Copied 22603_ccap_filled.tif to Google Drive folder.
# Copied 23098_ccap_filled.tif to Google Drive folder.
# Copied 23288_ccap_filled.tif to Google Drive folder.
# Copied 22923_ccap_filled.tif to Google Drive folder.
# Copied 23400_ccap_filled.tif to Google Drive folder.
# Copied 22897_ccap_filled.tif to Google Drive folder.
# Copied 23360_ccap_filled.tif to Google Drive folder.
# Copied 22676_ccap_filled.tif to Google Drive folder.
# Copied 22533_ccap_filled.tif to Google Drive folder.
# Copied 23619_ccap_filled.tif to Google Drive folder.
# Copied 23165_ccap_filled.tif to Google Drive folder.
# Copied 23199_ccap_filled.tif to Google Drive folder.
# Copied 22450_ccap_filled.tif to Google Drive folder.
# Copied 23035_ccap_filled.tif to Google Drive folder.
# Copied 23445_ccap_filled.tif to Google Drive folder.
# Copied 22296_ccap_filled.tif to Google Drive folder.
# Copied 22756_ccap_filled.tif to Google Drive folder.
# Copied 23141_ccap_filled.tif to Google Drive folder.
# Copied 22593_ccap_filled.tif to Google Drive folder.
# Copied 23089_ccap_filled.tif to Google Drive folder.
# Copied 22693_ccap_filled.tif to Google Drive folder.
# Copied 22299_ccap_filled.tif to Google Drive folder.
# Copied 23120_ccap_filled.tif to Google Drive folder.
# Copied 23831_ccap_filled.tif to Google Drive folder.
# Copied 23121_ccap_filled.tif to Google Drive folder.
# Copied 22460_ccap_filled.tif to Google Drive folder.
# Copied 22868_ccap_filled.tif to Google Drive folder.
# Copied 23572_ccap_filled.tif to Google Drive folder.
# Copied 23801_ccap_filled.tif to Google Drive folder.
# Copied 23851_ccap_filled.tif to Google Drive folder.
# Copied 23180_ccap_filled.tif to Google Drive folder.
# Copied 22999_ccap_filled.tif to Google Drive folder.
# Copied 23301_ccap_filled.tif to Google Drive folder.
# Copied 22626_ccap_filled.tif to Google Drive folder.
# Copied 23536_ccap_filled.tif to Google Drive folder.
# Copied 22872_ccap_filled.tif to Google Drive folder.
# Copied 23805_ccap_filled.tif to Google Drive folder.
# Copied 22329_ccap_filled.tif to Google Drive folder.
# Copied 23365_ccap_filled.tif to Google Drive folder.
# Copied 23690_ccap_filled.tif to Google Drive folder.
# Copied 23556_ccap_filled.tif to Google Drive folder.
# Copied 23486_ccap_filled.tif to Google Drive folder.
# Copied 23670_ccap_filled.tif to Google Drive folder.
# Copied 23543_ccap_filled.tif to Google Drive folder.
# Copied 22795_ccap_filled.tif to Google Drive folder.
# Copied 23389_ccap_filled.tif to Google Drive folder.
# Copied 23747_ccap_filled.tif to Google Drive folder.
# Copied 23551_ccap_filled.tif to Google Drive folder.
# Copied 23509_ccap_filled.tif to Google Drive folder.
# Copied 23753_ccap_filled.tif to Google Drive folder.
# Copied 22397_ccap_filled.tif to Google Drive folder.
# Copied 23067_ccap_filled.tif to Google Drive folder.
# Copied 23204_ccap_filled.tif to Google Drive folder.
# Copied 23616_ccap_filled.tif to Google Drive folder.
# Copied 23766_ccap_filled.tif to Google Drive folder.
# Copied 23763_ccap_filled.tif to Google Drive folder.
# Copied 22314_ccap_filled.tif to Google Drive folder.
# Copied 22972_ccap_filled.tif to Google Drive folder.
# Copied 22681_ccap_filled.tif to Google Drive folder.
# Copied 22493_ccap_filled.tif to Google Drive folder.
# Copied 23792_ccap_filled.tif to Google Drive folder.
# Copied 22356_ccap_filled.tif to Google Drive folder.
# Copied 22829_ccap_filled.tif to Google Drive folder.
# Copied 23343_ccap_filled.tif to Google Drive folder.
# Copied 23553_ccap_filled.tif to Google Drive folder.
# Copied 23005_ccap_filled.tif to Google Drive folder.
# Copied 22373_ccap_filled.tif to Google Drive folder.
# Copied 23263_ccap_filled.tif to Google Drive folder.
# Copied 23038_ccap_filled.tif to Google Drive folder.
# Copied 23955_ccap_filled.tif to Google Drive folder.
# Copied 23427_ccap_filled.tif to Google Drive folder.
# Copied 23074_ccap_filled.tif to Google Drive folder.
# Copied 23938_ccap_filled.tif to Google Drive folder.
# Copied 23633_ccap_filled.tif to Google Drive folder.
# Copied 22945_ccap_filled.tif to Google Drive folder.
# Copied 23242_ccap_filled.tif to Google Drive folder.
# Copied 23658_ccap_filled.tif to Google Drive folder.
# Copied 23022_ccap_filled.tif to Google Drive folder.
# Copied 23103_ccap_filled.tif to Google Drive folder.
# Copied 22974_ccap_filled.tif to Google Drive folder.
# Copied 23487_ccap_filled.tif to Google Drive folder.
# Copied 22338_ccap_filled.tif to Google Drive folder.
# Copied 23053_ccap_filled.tif to Google Drive folder.
# Copied 22867_ccap_filled.tif to Google Drive folder.
# Copied 23202_ccap_filled.tif to Google Drive folder.
# Copied 23316_ccap_filled.tif to Google Drive folder.
# Copied 22381_ccap_filled.tif to Google Drive folder.
# Copied 22956_ccap_filled.tif to Google Drive folder.
# Copied 23502_ccap_filled.tif to Google Drive folder.
# Copied 22881_ccap_filled.tif to Google Drive folder.
# Copied 23139_ccap_filled.tif to Google Drive folder.
# Copied 22625_ccap_filled.tif to Google Drive folder.
# Copied 22512_ccap_filled.tif to Google Drive folder.
# Copied 23105_ccap_filled.tif to Google Drive folder.
# Copied 22678_ccap_filled.tif to Google Drive folder.
# Copied 22754_ccap_filled.tif to Google Drive folder.
# Copied 23001_ccap_filled.tif to Google Drive folder.
# Copied 22589_ccap_filled.tif to Google Drive folder.
# Copied 22694_ccap_filled.tif to Google Drive folder.
# Copied 22323_ccap_filled.tif to Google Drive folder.
# Copied 22814_ccap_filled.tif to Google Drive folder.
# Copied 22808_ccap_filled.tif to Google Drive folder.
# Copied 23545_ccap_filled.tif to Google Drive folder.
# Copied 23661_ccap_filled.tif to Google Drive folder.
# Copied 22391_ccap_filled.tif to Google Drive folder.
# Copied 23470_ccap_filled.tif to Google Drive folder.
# Copied 23857_ccap_filled.tif to Google Drive folder.
# Copied 23755_ccap_filled.tif to Google Drive folder.
# Copied 23621_ccap_filled.tif to Google Drive folder.
# Copied 23108_ccap_filled.tif to Google Drive folder.
# Copied 23867_ccap_filled.tif to Google Drive folder.
# Copied 23106_ccap_filled.tif to Google Drive folder.
# Copied 23849_ccap_filled.tif to Google Drive folder.
# Copied 23244_ccap_filled.tif to Google Drive folder.
# Copied 22652_ccap_filled.tif to Google Drive folder.
# Copied 22566_ccap_filled.tif to Google Drive folder.
# Copied 22298_ccap_filled.tif to Google Drive folder.
# Copied 23037_ccap_filled.tif to Google Drive folder.
# Copied 22454_ccap_filled.tif to Google Drive folder.
# Copied 22398_ccap_filled.tif to Google Drive folder.
# Copied 23452_ccap_filled.tif to Google Drive folder.
# Copied 23738_ccap_filled.tif to Google Drive folder.
# Copied 22638_ccap_filled.tif to Google Drive folder.
# Copied 23535_ccap_filled.tif to Google Drive folder.
# Copied 23196_ccap_filled.tif to Google Drive folder.
# Copied 23937_ccap_filled.tif to Google Drive folder.
# Copied 22967_ccap_filled.tif to Google Drive folder.
# Copied 23220_ccap_filled.tif to Google Drive folder.
# Copied 22400_ccap_filled.tif to Google Drive folder.
# Copied 22556_ccap_filled.tif to Google Drive folder.
# Copied 23268_ccap_filled.tif to Google Drive folder.
# Copied 23603_ccap_filled.tif to Google Drive folder.
# Copied 23916_ccap_filled.tif to Google Drive folder.
# Copied 23161_ccap_filled.tif to Google Drive folder.
# Copied 23058_ccap_filled.tif to Google Drive folder.
# Copied 23096_ccap_filled.tif to Google Drive folder.
# Copied 22921_ccap_filled.tif to Google Drive folder.
# Copied 22643_ccap_filled.tif to Google Drive folder.
# Copied 23209_ccap_filled.tif to Google Drive folder.
# Copied 23883_ccap_filled.tif to Google Drive folder.
# Copied 22929_ccap_filled.tif to Google Drive folder.
# Copied 23749_ccap_filled.tif to Google Drive folder.
# Copied 23583_ccap_filled.tif to Google Drive folder.
# Copied 22981_ccap_filled.tif to Google Drive folder.
# Copied 22485_ccap_filled.tif to Google Drive folder.
# Copied 23298_ccap_filled.tif to Google Drive folder.
# Copied 22865_ccap_filled.tif to Google Drive folder.
# Copied 22513_ccap_filled.tif to Google Drive folder.
# Copied 22574_ccap_filled.tif to Google Drive folder.
# Copied 23578_ccap_filled.tif to Google Drive folder.
# Copied 23970_ccap_filled.tif to Google Drive folder.
# Copied 23325_ccap_filled.tif to Google Drive folder.
# Copied 23560_ccap_filled.tif to Google Drive folder.
# Copied 22677_ccap_filled.tif to Google Drive folder.
# Copied 23163_ccap_filled.tif to Google Drive folder.
# Copied 23302_ccap_filled.tif to Google Drive folder.
# Copied 22442_ccap_filled.tif to Google Drive folder.
# Copied 23636_ccap_filled.tif to Google Drive folder.
# Copied 23405_ccap_filled.tif to Google Drive folder.
# Copied 23917_ccap_filled.tif to Google Drive folder.
# Copied 22339_ccap_filled.tif to Google Drive folder.
# Copied 23372_ccap_filled.tif to Google Drive folder.
# Copied 22630_ccap_filled.tif to Google Drive folder.
# Copied 23201_ccap_filled.tif to Google Drive folder.
# Copied 23528_ccap_filled.tif to Google Drive folder.
# Copied 23859_ccap_filled.tif to Google Drive folder.
# Copied 22370_ccap_filled.tif to Google Drive folder.
# Copied 23113_ccap_filled.tif to Google Drive folder.
# Copied 23240_ccap_filled.tif to Google Drive folder.
# Copied 23168_ccap_filled.tif to Google Drive folder.
# Copied 22838_ccap_filled.tif to Google Drive folder.
# Copied 23313_ccap_filled.tif to Google Drive folder.
# Copied 22379_ccap_filled.tif to Google Drive folder.
# Copied 23431_ccap_filled.tif to Google Drive folder.
# Copied 23945_ccap_filled.tif to Google Drive folder.
# Copied 22992_ccap_filled.tif to Google Drive folder.
# Copied 23724_ccap_filled.tif to Google Drive folder.
# Copied 22595_ccap_filled.tif to Google Drive folder.
# Copied 22542_ccap_filled.tif to Google Drive folder.
# Copied 23194_ccap_filled.tif to Google Drive folder.
# Copied 22387_ccap_filled.tif to Google Drive folder.
# Copied 23752_ccap_filled.tif to Google Drive folder.
# Copied 22656_ccap_filled.tif to Google Drive folder.
# Copied 23855_ccap_filled.tif to Google Drive folder.
# Copied 23407_ccap_filled.tif to Google Drive folder.
# Copied 23627_ccap_filled.tif to Google Drive folder.
# Copied 22489_ccap_filled.tif to Google Drive folder.
# Copied 22988_ccap_filled.tif to Google Drive folder.
# Copied 23245_ccap_filled.tif to Google Drive folder.
# Copied 22942_ccap_filled.tif to Google Drive folder.
# Copied 22307_ccap_filled.tif to Google Drive folder.
# Copied 23567_ccap_filled.tif to Google Drive folder.
# Copied 23866_ccap_filled.tif to Google Drive folder.
# Copied 22788_ccap_filled.tif to Google Drive folder.
# Copied 22833_ccap_filled.tif to Google Drive folder.
# Copied 23818_ccap_filled.tif to Google Drive folder.
# Copied 22577_ccap_filled.tif to Google Drive folder.
# Copied 23715_ccap_filled.tif to Google Drive folder.
# Copied 22360_ccap_filled.tif to Google Drive folder.
# Copied 23235_ccap_filled.tif to Google Drive folder.
# Copied 22613_ccap_filled.tif to Google Drive folder.
# Copied 23532_ccap_filled.tif to Google Drive folder.
# Copied 22297_ccap_filled.tif to Google Drive folder.
# Copied 23704_ccap_filled.tif to Google Drive folder.
# Copied 23357_ccap_filled.tif to Google Drive folder.
# Copied 23094_ccap_filled.tif to Google Drive folder.
# Copied 23072_ccap_filled.tif to Google Drive folder.
# Copied 22324_ccap_filled.tif to Google Drive folder.
# Copied 23649_ccap_filled.tif to Google Drive folder.
# Copied 22660_ccap_filled.tif to Google Drive folder.
# Copied 22639_ccap_filled.tif to Google Drive folder.
# Copied 23422_ccap_filled.tif to Google Drive folder.
# Copied 23596_ccap_filled.tif to Google Drive folder.
# Copied 22466_ccap_filled.tif to Google Drive folder.
# Copied 22828_ccap_filled.tif to Google Drive folder.
# Copied 22782_ccap_filled.tif to Google Drive folder.
# Copied 23091_ccap_filled.tif to Google Drive folder.
# Copied 22632_ccap_filled.tif to Google Drive folder.
# Copied 23191_ccap_filled.tif to Google Drive folder.
# Copied 22735_ccap_filled.tif to Google Drive folder.
# Copied 22654_ccap_filled.tif to Google Drive folder.
# Copied 23419_ccap_filled.tif to Google Drive folder.
# Copied 22602_ccap_filled.tif to Google Drive folder.
# Copied 23942_ccap_filled.tif to Google Drive folder.
# Copied 23723_ccap_filled.tif to Google Drive folder.
# Copied 23308_ccap_filled.tif to Google Drive folder.
# Copied 22994_ccap_filled.tif to Google Drive folder.
# Copied 23126_ccap_filled.tif to Google Drive folder.
# Copied 22710_ccap_filled.tif to Google Drive folder.
# Copied 23887_ccap_filled.tif to Google Drive folder.
# Copied 22915_ccap_filled.tif to Google Drive folder.
# Copied 22505_ccap_filled.tif to Google Drive folder.
# Copied 22342_ccap_filled.tif to Google Drive folder.
# Copied 23124_ccap_filled.tif to Google Drive folder.
# Copied 23625_ccap_filled.tif to Google Drive folder.
# Copied 23014_ccap_filled.tif to Google Drive folder.
# Copied 23950_ccap_filled.tif to Google Drive folder.
# Copied 23628_ccap_filled.tif to Google Drive folder.
# Copied 22715_ccap_filled.tif to Google Drive folder.
# Copied 23228_ccap_filled.tif to Google Drive folder.
# Copied 23811_ccap_filled.tif to Google Drive folder.
# Copied 23622_ccap_filled.tif to Google Drive folder.
# Copied 23061_ccap_filled.tif to Google Drive folder.
# Copied 22583_ccap_filled.tif to Google Drive folder.
# Copied 23278_ccap_filled.tif to Google Drive folder.
# Copied 22996_ccap_filled.tif to Google Drive folder.
# Copied 23791_ccap_filled.tif to Google Drive folder.
# Copied 22403_ccap_filled.tif to Google Drive folder.
# Copied 22886_ccap_filled.tif to Google Drive folder.
# Copied 23256_ccap_filled.tif to Google Drive folder.
# Copied 22439_ccap_filled.tif to Google Drive folder.
# Copied 22320_ccap_filled.tif to Google Drive folder.
# Copied 22514_ccap_filled.tif to Google Drive folder.
# Copied 23482_ccap_filled.tif to Google Drive folder.
# Copied 23888_ccap_filled.tif to Google Drive folder.
# Copied 23000_ccap_filled.tif to Google Drive folder.
# Copied 22812_ccap_filled.tif to Google Drive folder.
# Copied 23728_ccap_filled.tif to Google Drive folder.
# Copied 23159_ccap_filled.tif to Google Drive folder.
# Copied 23480_ccap_filled.tif to Google Drive folder.
# Copied 23829_ccap_filled.tif to Google Drive folder.
# Copied 22697_ccap_filled.tif to Google Drive folder.
# Copied 23064_ccap_filled.tif to Google Drive folder.
# Copied 22879_ccap_filled.tif to Google Drive folder.
# Copied 22498_ccap_filled.tif to Google Drive folder.
# Copied 22394_ccap_filled.tif to Google Drive folder.
# Copied 22594_ccap_filled.tif to Google Drive folder.
# Copied 22549_ccap_filled.tif to Google Drive folder.
# Copied 23554_ccap_filled.tif to Google Drive folder.
# Copied 22496_ccap_filled.tif to Google Drive folder.
# Copied 23873_ccap_filled.tif to Google Drive folder.
# Copied 22965_ccap_filled.tif to Google Drive folder.
# Copied 23902_ccap_filled.tif to Google Drive folder.
# Copied 23171_ccap_filled.tif to Google Drive folder.
# Copied 23156_ccap_filled.tif to Google Drive folder.
# Copied 22567_ccap_filled.tif to Google Drive folder.
# Copied 23391_ccap_filled.tif to Google Drive folder.
# Copied 23300_ccap_filled.tif to Google Drive folder.
# Copied 23144_ccap_filled.tif to Google Drive folder.
# Copied 22892_ccap_filled.tif to Google Drive folder.
# Copied 22340_ccap_filled.tif to Google Drive folder.
# Copied 23460_ccap_filled.tif to Google Drive folder.
# Copied 22950_ccap_filled.tif to Google Drive folder.
# Copied 23023_ccap_filled.tif to Google Drive folder.
# Copied 23737_ccap_filled.tif to Google Drive folder.
# Copied 23380_ccap_filled.tif to Google Drive folder.
# Copied 22836_ccap_filled.tif to Google Drive folder.
# Copied 23289_ccap_filled.tif to Google Drive folder.
# Copied 23523_ccap_filled.tif to Google Drive folder.
# Copied 23295_ccap_filled.tif to Google Drive folder.
# Copied 22528_ccap_filled.tif to Google Drive folder.
# Copied 22629_ccap_filled.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/naip_128x128data/utm4/nwi_ccap_filled/"
tif_source = "/content/data/content/exports/nwi_ccap_filled/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 22479_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22382_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23460_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23371_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23710_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23321_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23408_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23412_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22540_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22343_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23537_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23318_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22741_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22768_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23352_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22571_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23149_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22406_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23249_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23701_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23756_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23363_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23045_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22829_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22432_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22522_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23121_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22494_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23239_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23503_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23087_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22971_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23066_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22740_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22363_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23806_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22892_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23523_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23880_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23631_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23208_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23665_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23432_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22575_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22622_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22537_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23515_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23925_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22639_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23351_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23421_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23285_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22352_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23619_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23568_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23470_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23685_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22567_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22828_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23435_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22302_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23181_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23757_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22980_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23907_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22504_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23514_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23300_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23843_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22401_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23775_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23852_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23169_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23531_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22523_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23689_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23865_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23771_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23936_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22799_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22927_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22506_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23055_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23403_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23248_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23252_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23263_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23743_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23353_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23161_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23938_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23393_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23654_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22967_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22850_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23397_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23851_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23079_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23552_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22350_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22417_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22488_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23773_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23233_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23546_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22600_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23386_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23268_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23327_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22484_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23231_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22543_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22628_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22447_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23236_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23855_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23530_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22901_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23532_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22367_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22349_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23159_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23957_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23651_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23719_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22581_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22790_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22368_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22346_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23739_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23557_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23642_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22935_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22764_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22338_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22666_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23288_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23385_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23405_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23049_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23146_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23111_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22296_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23781_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23209_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23966_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22413_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22770_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22514_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23316_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22339_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22876_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22442_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23597_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22771_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22398_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22590_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22730_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22306_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23952_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22326_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23816_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23188_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23407_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22703_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23326_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22956_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23072_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23916_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22340_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22665_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23118_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22365_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22526_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23626_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23518_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23317_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23010_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23053_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22946_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22728_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22420_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22315_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23911_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23883_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23899_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22746_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23517_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23709_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23228_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22826_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23033_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22732_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22776_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23056_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22427_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23920_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22643_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22737_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22860_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23656_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23225_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23257_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23287_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23874_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23021_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23148_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23063_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23741_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23956_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22992_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23790_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22656_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23653_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23624_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23745_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23508_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22583_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23141_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22641_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22872_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22702_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23818_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23097_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23172_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22623_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23889_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23246_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23696_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22304_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23032_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22723_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23929_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22832_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23039_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22311_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23167_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22820_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23245_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23080_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22439_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23622_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22475_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23596_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22563_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22468_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23115_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23594_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23173_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23635_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23864_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23534_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23829_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22369_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22922_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23377_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23932_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23569_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22618_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23958_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22993_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23878_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23904_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23640_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22307_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22788_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23960_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23043_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23147_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23380_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22410_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23599_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23922_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22689_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23944_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23539_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23394_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23673_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22722_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22297_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23179_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23480_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23347_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22749_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23182_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22466_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23065_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22409_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22842_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22520_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22589_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23483_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23264_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23890_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22572_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23135_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22375_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23331_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22766_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22928_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23939_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23332_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22868_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23897_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23735_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23881_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23682_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23649_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22377_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22986_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22932_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22782_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23547_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23325_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22390_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22384_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23140_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23645_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22661_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23091_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23437_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23489_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23312_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23298_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22851_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22576_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22480_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23559_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22529_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22533_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22481_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22674_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23766_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22316_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23187_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23536_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23675_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22325_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22744_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22462_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23061_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23185_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22701_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22635_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23217_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23396_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23466_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23334_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22303_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23876_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23041_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22985_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22412_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22379_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22920_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22646_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22507_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23030_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23601_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23687_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23144_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22726_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23381_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23549_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23923_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23155_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23274_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23277_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22822_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23492_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22444_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22662_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23447_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22919_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22849_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23255_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23451_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22403_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23262_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22739_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22456_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22755_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22834_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22474_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22411_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23868_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23629_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23814_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22711_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23373_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23825_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22823_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22664_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22645_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23908_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23902_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23456_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22750_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22704_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22613_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23369_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23943_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23004_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22625_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22846_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22452_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23341_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22877_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23128_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23361_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23272_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23548_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22508_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23633_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23750_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23101_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22839_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22687_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23110_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23002_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23770_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22753_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22530_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23495_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23948_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22897_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23314_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23791_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23928_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22415_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23544_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23543_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23641_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22364_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23504_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23893_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23477_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23424_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23286_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22898_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23926_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22779_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22344_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22978_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22699_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22333_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22318_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22483_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22640_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23258_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22911_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23714_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23784_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22463_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22754_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22814_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22798_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22949_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23301_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23782_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23200_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23909_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23945_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23413_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23527_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23136_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22433_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23275_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23677_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23472_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23970_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22404_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23151_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23207_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23674_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23297_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23798_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23446_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23222_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22738_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23705_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22642_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23499_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22809_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23869_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23820_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23452_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23900_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23813_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22969_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22383_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23416_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23595_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22521_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22471_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23607_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23302_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22818_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22496_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23887_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23858_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23204_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22908_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23663_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23464_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23259_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23676_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22925_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22419_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22489_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22988_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22342_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22865_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22469_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22336_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22821_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22658_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23015_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22777_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23563_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23577_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22866_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23708_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22387_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22337_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22614_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23089_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22902_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23639_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23859_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22678_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22827_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23933_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22756_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23921_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23913_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23630_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22599_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23242_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23521_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23020_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23280_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22995_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22680_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22961_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22700_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23971_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22886_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23342_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23847_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23100_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23107_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23157_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23400_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22663_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23827_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23044_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22408_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22517_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23540_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22778_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22323_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22331_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22918_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23662_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23949_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22714_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22816_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22347_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22968_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23419_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22931_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22717_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23484_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23333_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23338_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22706_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23409_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23196_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23035_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22441_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22579_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22944_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23150_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22553_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23646_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23013_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23894_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22859_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22319_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22525_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22705_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23276_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22963_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23026_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22431_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23942_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23453_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23586_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23009_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22758_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23882_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23243_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23924_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23235_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23912_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23917_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23349_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23764_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23755_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22465_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22495_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23459_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23722_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22550_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22982_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23292_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23713_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23191_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22693_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22487_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23572_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23968_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22817_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23969_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23700_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23052_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22335_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23742_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22429_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23494_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22668_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23964_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23194_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22545_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23014_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22554_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23123_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23822_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23183_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23203_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22334_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22629_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23592_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22569_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23529_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23165_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23440_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23550_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23886_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23590_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23835_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23454_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23455_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23497_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22796_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23355_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23786_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23178_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23660_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22402_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22493_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22713_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23768_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22329_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23139_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22675_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23702_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22785_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22825_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23542_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22801_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22502_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23388_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23841_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23022_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23106_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23892_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22745_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23019_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22405_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23684_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22534_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23796_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23738_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23404_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23634_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22997_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23358_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23941_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22996_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23398_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23058_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23695_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22688_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23707_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23391_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23551_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23506_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23670_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23105_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23133_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23535_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23465_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22923_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23845_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23434_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23593_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22861_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23831_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22389_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23368_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22873_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22472_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22560_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22630_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23085_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22915_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23711_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23463_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22893_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22760_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22792_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22819_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22909_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23888_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23078_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22551_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23507_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23120_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22659_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22438_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23658_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22313_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23062_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22443_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23946_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23114_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23927_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22715_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23561_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23417_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22330_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22953_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23279_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23585_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23652_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23189_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23223_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23482_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23251_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23109_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23215_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22320_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23541_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23730_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23006_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22773_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23284_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22871_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22562_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22445_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23732_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22621_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22547_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22644_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23513_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23237_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22939_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22356_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23234_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23060_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23450_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23322_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23620_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22582_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23844_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22874_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23849_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22497_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22460_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23047_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22841_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23666_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22584_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22626_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22862_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23636_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23426_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23777_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22806_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23282_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23533_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22811_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22458_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23627_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22724_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23553_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23354_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22470_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23746_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22633_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22516_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22870_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22573_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23016_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22854_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22651_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23863_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22783_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23406_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22906_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23153_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23479_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23671_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23024_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23951_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23054_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22312_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22314_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23304_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23232_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23584_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22957_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22549_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22592_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23365_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23448_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23810_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23703_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23379_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22891_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23389_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22989_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23068_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22794_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22616_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23623_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22857_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23357_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23214_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22477_nwi_ccap_filled.tif to Google Drive folder.
# ...
# Copied 23648_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22615_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22461_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23856_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22602_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22885_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23329_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22830_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23323_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23850_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23919_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22883_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23873_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22972_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23082_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22667_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22686_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22729_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22518_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22926_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22485_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23098_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22610_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22880_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23241_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23598_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23706_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23436_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23414_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23260_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23099_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22869_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23328_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22448_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23545_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23356_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23575_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22965_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22309_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23313_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22603_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23872_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23556_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22638_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23340_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23350_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23643_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22587_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22852_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23940_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23587_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22762_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23803_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22328_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23836_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23095_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23615_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23526_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22457_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23362_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23050_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22803_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23688_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22836_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22955_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22370_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22929_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22454_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22774_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23000_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23963_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23915_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22962_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23142_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22940_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22802_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23610_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22498_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23031_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22388_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22421_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23269_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23299_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23974_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23581_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23519_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23103_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23819_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22595_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22345_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22769_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23754_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23430_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23505_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23037_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23962_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23306_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23972_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22840_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23372_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23669_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23498_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22761_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22476_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23374_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22804_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23094_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22591_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23734_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23048_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23603_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23554_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22879_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22736_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22505_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23227_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23736_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23697_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22358_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22934_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23570_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23867_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22515_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23788_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23267_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22459_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23618_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22436_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22848_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22910_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23278_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22586_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23589_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23692_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23667_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23433_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23632_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22682_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22900_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23367_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23583_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23752_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23025_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22396_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23955_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23793_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22657_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23011_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22805_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23392_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23609_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23737_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22975_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23266_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22426_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22696_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23375_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23444_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22548_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22936_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23256_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23826_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23778_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22896_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23715_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22565_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23512_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22414_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23659_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22709_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22867_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22937_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22719_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23202_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23134_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23823_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22948_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22708_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22636_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23866_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23779_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23345_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23765_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22631_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23438_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22676_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23162_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23330_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22890_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22649_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23580_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23731_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23861_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22855_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23875_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22735_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23127_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22959_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23800_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23471_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23224_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23728_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22793_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23661_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23681_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23074_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23315_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23693_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23378_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23339_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23935_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22397_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22655_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23740_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23611_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22580_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23018_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23335_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22887_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23410_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22391_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23364_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22973_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23759_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23809_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22559_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23384_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23422_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22742_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22407_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22653_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23158_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23132_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23152_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22555_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23166_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22966_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23821_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23064_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22566_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22904_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23877_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23846_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23769_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23220_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23244_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22373_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22492_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23192_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23910_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22707_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22437_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22608_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23824_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22698_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23744_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22863_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22455_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23871_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22482_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22632_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22824_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22542_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23473_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23348_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23571_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23815_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22385_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22800_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23240_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23833_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23029_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23271_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22691_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23218_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22791_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22351_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22527_nwi_ccap_filled.tif to Google Drive folder.
# Copied 23698_nwi_ccap_filled.tif to Google Drive folder.
# Copied 22425_nwi_ccap_filled.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/naip_128x128data/utm4/nwi_nlcd_filled/"
tif_source = "/content/data/content/exports/nwi_nlcd_filled/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 22690_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22950_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23307_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22692_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22802_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22390_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23865_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23169_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22809_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23312_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22961_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22589_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22718_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22413_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23315_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23760_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23541_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22758_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23736_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22488_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22922_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23953_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23043_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23559_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23328_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23482_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23101_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22352_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22823_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23562_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23754_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23080_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23090_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23814_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23150_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23540_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22810_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22622_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23637_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22579_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23872_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22434_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23201_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23394_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22366_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23168_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23106_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22307_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23943_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23885_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22469_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23965_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22993_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23670_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23027_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23551_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23442_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22852_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22474_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22429_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23879_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23052_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23531_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23439_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23137_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22355_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23215_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22361_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22990_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23224_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22913_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22550_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23647_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22323_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22774_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23210_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23227_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23652_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23172_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23696_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23085_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23935_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22858_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23841_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23330_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23855_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22736_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22315_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23100_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22529_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22364_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23870_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23042_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22918_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22948_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23657_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23388_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22613_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22320_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23679_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23171_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22781_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22656_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23572_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23383_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23410_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22811_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23002_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23772_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22944_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23803_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23782_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23272_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23800_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23587_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22461_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22920_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22768_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23689_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23003_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23008_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23039_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23931_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22618_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23240_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23858_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23189_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22295_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23273_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23297_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23630_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23508_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23934_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22410_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23821_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23138_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23578_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23871_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22498_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22587_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22698_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22658_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23892_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22397_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22634_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22445_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22350_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23829_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23274_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23098_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23132_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23253_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23056_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23074_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22441_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23247_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23289_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23640_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22621_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22530_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22572_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23802_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22399_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23279_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22446_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23746_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23907_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23636_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22447_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23721_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22346_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23774_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22332_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23287_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22819_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23204_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23464_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23294_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23671_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23873_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23717_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23324_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22761_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23595_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23404_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22734_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22803_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23851_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22848_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23503_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23863_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23318_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22596_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23856_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22588_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22941_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22710_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23924_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23269_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23755_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23769_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22425_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23761_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23906_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22845_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23710_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23798_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23064_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23223_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23547_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23443_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23104_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23765_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22342_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23164_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23927_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22886_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23018_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22591_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22296_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22902_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23730_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23357_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22683_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23968_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23643_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23400_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23375_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23874_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23895_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22586_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22454_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22299_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23242_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23179_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22401_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23429_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22767_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23058_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22724_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23396_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23695_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23651_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23070_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23105_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22793_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23379_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23747_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22574_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23842_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22620_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23622_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23206_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23248_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22636_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23903_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23125_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22716_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23701_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23952_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23819_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23615_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23471_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22890_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23277_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23067_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22403_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22779_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23893_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23309_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23674_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23884_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23786_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23602_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23382_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22385_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23010_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22788_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23826_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22304_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23145_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22641_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22623_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22818_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22870_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23886_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22792_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22942_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23193_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22847_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23236_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23405_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23778_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22387_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22730_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23706_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23788_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23539_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23940_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23026_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23557_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22722_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23037_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23416_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23327_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22871_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22697_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23662_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23340_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23787_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23389_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23936_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22547_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23195_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22805_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22492_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22676_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22787_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22367_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23153_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23468_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22568_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23231_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22862_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22600_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23068_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23061_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23898_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22885_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23177_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23373_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23181_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23569_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22808_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22524_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23688_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22762_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23795_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23757_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22931_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22543_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23846_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23535_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23264_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23109_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23516_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23001_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22652_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23955_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23837_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23564_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23303_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23941_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22727_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23825_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23921_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23523_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23262_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22444_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22557_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22415_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22482_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22873_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22305_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22974_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23694_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22519_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22725_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23212_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23536_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23583_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22512_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23645_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22490_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22854_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22664_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22353_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22326_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23631_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23553_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23306_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23718_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23928_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22324_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23660_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23775_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23415_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22316_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22837_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23278_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22564_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23332_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22916_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23217_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22616_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23059_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23684_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23513_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22551_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23496_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22439_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22504_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22735_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22883_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22649_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22669_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22689_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22684_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22340_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22580_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22563_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23603_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23197_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22654_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23917_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22442_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22666_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23914_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23285_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22704_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23093_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23623_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23950_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23116_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23362_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23816_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23120_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22522_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22321_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22932_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23127_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23501_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23422_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23036_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23902_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23693_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23488_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23030_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23715_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22368_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23453_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23727_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22705_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23655_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22795_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22500_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23022_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23412_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22906_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23081_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22926_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23617_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23593_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23862_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22766_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22421_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22631_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23960_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22450_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23966_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23957_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23349_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23733_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23094_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22552_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22484_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22428_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23853_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23668_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23832_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23013_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23467_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23801_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22956_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23428_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23823_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22394_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23089_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23459_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23805_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23942_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23737_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23051_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22300_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22508_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22559_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22396_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22741_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23751_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22821_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23066_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23143_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22354_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22696_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23218_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22908_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23310_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22865_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22687_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23592_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23086_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23764_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23653_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23843_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23211_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23305_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22456_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23336_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22655_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22703_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22371_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23228_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23110_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23160_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23213_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22569_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22714_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23097_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23449_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23713_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22602_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23487_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22833_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23493_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23260_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22657_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23198_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22935_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22314_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23762_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23947_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23561_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22806_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23275_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22775_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22328_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23425_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22877_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23565_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23749_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23173_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22746_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22448_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23225_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22565_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22327_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22786_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22627_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22784_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22878_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23184_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23601_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23616_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23609_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23207_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22982_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23773_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23500_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23261_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22599_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22989_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22939_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23669_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22721_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23681_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23122_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23421_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23530_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23783_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23166_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22455_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23417_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22466_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22770_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23568_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23276_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23845_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23599_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23742_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22595_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23161_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23741_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23451_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22891_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23558_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22671_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23675_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22626_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23518_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23019_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23882_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22764_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22302_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22668_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22335_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22831_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23317_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22402_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23507_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22874_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23729_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23331_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22468_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22329_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22834_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23833_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22876_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23690_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22866_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23165_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23386_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23708_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23545_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22797_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23811_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22528_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23186_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23915_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23423_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23719_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23854_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23176_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22776_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23625_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22611_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23588_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23175_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22431_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23808_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22978_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22554_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22581_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23182_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23820_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23346_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22737_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23418_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22503_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22483_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22499_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23431_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22897_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22635_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23296_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22356_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23196_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23484_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23465_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23174_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23251_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22965_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22801_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23446_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22825_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22983_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22419_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22359_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23099_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23969_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22816_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23848_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23131_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22640_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23723_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22867_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23511_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23226_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22745_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23091_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22333_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23876_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22814_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22416_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23905_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22879_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23470_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23167_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23626_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23313_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22369_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22438_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22644_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23384_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23387_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23494_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22544_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22382_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23367_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22729_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22830_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23827_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23144_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23789_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23686_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23480_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23060_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23323_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23455_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22943_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23878_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23129_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23850_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22471_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23334_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23239_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22842_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22507_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22540_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22930_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22642_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23589_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22357_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23329_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22744_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23447_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22995_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23750_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23624_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23702_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23385_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23178_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23946_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22453_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23824_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23062_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23548_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23256_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22828_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23258_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23533_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22662_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23596_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22869_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23620_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23779_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22994_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23644_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23281_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23124_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23812_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22457_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23566_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23544_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23350_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23301_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23209_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22773_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22898_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22987_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23014_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22493_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22912_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22472_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22938_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22907_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23913_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23378_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22336_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23680_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23509_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22999_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22955_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22748_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23912_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23020_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23732_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23123_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23528_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22812_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23961_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23537_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23767_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23117_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22629_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22972_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23023_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22573_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23191_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23235_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23259_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23214_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23407_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22968_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22380_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23347_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23597_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23918_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23817_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23293_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22516_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23752_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23887_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22659_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22496_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23514_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23300_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23141_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23025_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22910_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22763_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23380_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22538_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23904_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23822_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23185_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23133_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22991_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23560_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23552_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22527_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23348_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23806_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22567_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22849_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23759_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23096_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22584_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23868_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22449_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22475_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23919_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23639_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22562_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23929_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22476_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23372_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22345_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23065_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22996_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23612_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23527_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22719_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23000_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22881_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23267_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23082_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23951_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23462_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22645_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23634_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22826_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22979_nwi_nlcd_filled.tif to Google Drive folder.
# ...
# Copied 22384_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22610_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23891_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22678_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22383_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22347_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22341_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22675_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22556_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23461_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22857_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23363_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23525_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22772_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23546_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22577_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23205_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23498_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22712_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22370_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23152_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22598_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23112_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22829_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23577_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22435_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22344_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23753_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23512_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23678_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22884_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23777_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22929_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23079_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23399_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23607_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23370_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22940_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22928_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23698_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23119_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22747_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23299_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22960_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23517_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22856_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23619_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22521_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23314_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23543_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22400_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23890_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23716_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22373_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23522_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23479_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23497_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22672_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23280_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22297_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22436_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23374_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23371_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23828_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22976_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22859_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23571_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23883_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22651_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22717_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22914_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22732_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23731_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23486_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23910_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23600_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23392_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22905_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22667_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22303_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23633_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23598_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23618_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23291_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23836_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23033_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22909_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22868_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22771_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23157_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22992_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23949_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22486_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23857_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23685_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22975_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23408_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23047_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22325_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22661_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22951_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23202_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23398_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22733_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23194_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22643_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23155_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23250_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23012_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22674_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23252_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23974_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22986_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23298_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23839_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23580_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23028_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23341_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22358_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22949_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22363_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23343_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22467_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22738_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22487_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22796_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22418_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23646_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23549_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23088_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22608_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22489_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23069_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23308_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23575_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23709_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22406_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23102_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23115_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23376_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23111_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22536_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22700_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23944_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23608_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23401_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23869_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22726_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22984_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22407_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23220_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22306_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23414_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22597_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22376_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23354_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22962_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23574_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23534_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22708_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23926_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23450_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23880_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23333_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23326_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23419_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23967_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23475_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23044_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22702_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23433_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22392_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22647_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22534_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23200_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23962_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22706_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23083_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22520_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22537_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22510_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22952_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22807_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23576_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23148_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22533_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22558_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22783_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23810_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22404_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23103_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23813_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23440_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22420_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22485_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22720_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22911_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22789_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23784_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23325_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23489_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22701_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22804_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22424_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23393_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23793_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23524_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22430_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22966_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23180_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23232_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22838_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22546_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23700_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23136_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22603_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22827_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22606_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23938_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23864_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23034_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23594_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23031_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22414_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22840_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22832_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22900_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22365_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23118_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23901_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23897_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22980_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23473_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22440_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23704_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22301_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22541_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22680_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23526_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23402_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23785_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22740_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23377_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22959_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22571_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23791_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22481_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23768_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23230_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23076_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23048_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22887_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22681_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22677_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23257_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23483_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23707_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22936_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22310_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22639_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22889_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22855_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23345_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23448_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22334_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22875_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23794_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22853_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22578_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23563_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22398_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23658_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23113_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23188_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22755_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23444_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22947_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22517_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 22953_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 23029_nwi_nlcd_filled.tif to Google Drive folder.

# %%
# original images and labels folder: how many files are there?
iamges = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/naip_128x128data/utm4/nwi_nlcd_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 23206

# %% [markdown]
# end

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export001_ccap_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export002_ccap_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export003_ccap_filled.zip -d /content/data/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/data/content/exports/ccap_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export001_dem.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export002_dem.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export003_dem.zip -d /content/data/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/data/content/exports/dem'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 2630

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat_exports/utm5/landsat_utm5_2016.zip -d /content/data/

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat_exports/utm5/landsat_utm5_2017.zip -d /content/data/

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat_exports/utm5/landsat_utm5_2018.zip -d /content/data/

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat_exports/utm5/landsat_utm5_2019.zip -d /content/data/
# Out:
# Archive:  /content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat_exports/utm5/landsat_utm5_2019.zip
# replace /content/data/content/exports/nwi_ccap_filled/2_nwi_ccap_filled.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
#    creating: /content/data/content/exports/image/
#   inflating: /content/data/content/exports/image/1_landsat.tif
#   inflating: /content/data/content/exports/image/2_landsat.tif
#   inflating: /content/data/content/exports/image/3_landsat.tif
#   inflating: /content/data/content/exports/image/4_landsat.tif
#   inflating: /content/data/content/exports/image/5_landsat.tif

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat_exports/utm5/landsat_utm5_2020.zip -d /content/data/
# Out:
# Archive:  /content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat_exports/utm5/landsat_utm5_2020.zip
# replace /content/data/content/exports/nwi_ccap_filled/2_nwi_ccap_filled.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
#    creating: /content/data/content/exports/image/
#   inflating: /content/data/content/exports/image/1_landsat.tif
#   inflating: /content/data/content/exports/image/2_landsat.tif
#   inflating: /content/data/content/exports/image/3_landsat.tif
#   inflating: /content/data/content/exports/image/4_landsat.tif
#   inflating: /content/data/content/exports/image/5_landsat.tif

# %%
# original images and labels folder: how many files are there?
iamges = '/content/data/content/exports/dem'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 42

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export001_nwi_ccap_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export002_nwi_ccap_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export003_nwi_ccap_filled.zip -d /content/data/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/data/content/exports/nwi_ccap_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 2630

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export001_ccap_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export002_ccap_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export003_ccap_filled.zip -d /content/data/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/data/content/exports/ccap_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 229

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export001_dem.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export002_dem.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export003_dem.zip -d /content/data/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/data/content/exports/dem'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 229

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export001_nwi_ccap_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export002_nwi_ccap_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export003_nwi_ccap_filled.zip -d /content/data/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/data/content/exports/nwi_ccap_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 229

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export001_nwi_nlcd_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export002_nwi_nlcd_filled.zip -d /content/data/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export003_nwi_nlcd_filled.zip -d /content/data/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/data/content/exports/nwi_nlcd_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 194

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2020_export001_nwi_nlcd_filled.zip -d /content/data/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/data/content/exports/nwi_nlcd_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 229

# %%
# utm5 metadata csv writing

ccap_folder_path = "/content/data/content/exports/nwi_nlcd_filled"

ccap_metadata_list = []

for filename in os.listdir(ccap_folder_path):
  if filename.endswith(".tif"):
    filepath = os.path.join(ccap_folder_path, filename)

    with rasterio.open(filepath) as src:
      metadata = src.meta

      metadata_info = {
          'filename': filename,
          'width': src.width,
          'height': src.height,
          'crs': src.crs
      }
      ccap_metadata_list.append(metadata_info)

ccap_metadata_df = pd.DataFrame(ccap_metadata_list)

print(ccap_metadata_df)
# Out:
#                 filename  width  height     crs
# 0  5_nwi_nlcd_filled.tif   3840    3840  (init)
# 1  4_nwi_nlcd_filled.tif   3840    3840  (init)
# 2  2_nwi_nlcd_filled.tif   3840    3840  (init)
# 3  3_nwi_nlcd_filled.tif   3840    3840  (init)
# 4  1_nwi_nlcd_filled.tif   3840    3840  (init)

# %%
# !mkdir "/content/csvfiles"

# %%
csv_path_file = "/content/csvfiles/utm5_ccap_metadata.csv"

ccap_metadata_df.to_csv(csv_path_file, index=False)

# %% [markdown]
# write all data to single folder so its together and unziped in google drive.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/nwi_ccap_filled/"
tif_source = "/content/data/content/exports/nwi_ccap_filled/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 2_nwi_ccap_filled.tif to Google Drive folder.
# Copied 4_nwi_ccap_filled.tif to Google Drive folder.
# Copied 1_nwi_ccap_filled.tif to Google Drive folder.
# Copied 5_nwi_ccap_filled.tif to Google Drive folder.
# Copied 3_nwi_ccap_filled.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/nwi_nlcd_filled/"
tif_source = "/content/data/content/exports/nwi_nlcd_filled/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 5_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 4_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 2_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 3_nwi_nlcd_filled.tif to Google Drive folder.
# Copied 1_nwi_nlcd_filled.tif to Google Drive folder.

# %% [markdown]
# utm4 files

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/landsat_2016"
tif_source = "/content/data/content/exports/landsat_2016/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 2_landsat.tif to Google Drive folder.
# Copied 4_landsat.tif to Google Drive folder.
# Copied 5_landsat.tif to Google Drive folder.
# Copied 1_landsat.tif to Google Drive folder.
# Copied 3_landsat.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/landsat_2017"
tif_source = "/content/data/content/exports/landsat_2017/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 2_landsat.tif to Google Drive folder.
# Copied 4_landsat.tif to Google Drive folder.
# Copied 5_landsat.tif to Google Drive folder.
# Copied 1_landsat.tif to Google Drive folder.
# Copied 3_landsat.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/landsat_2018"
tif_source = "/content/data/content/exports/landsat_2018/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 2_landsat.tif to Google Drive folder.
# Copied 4_landsat.tif to Google Drive folder.
# Copied 5_landsat.tif to Google Drive folder.
# Copied 1_landsat.tif to Google Drive folder.
# Copied 3_landsat.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/landsat_2019"
tif_source = "/content/data/content/exports/landsat_2019/"
# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 2_landsat.tif to Google Drive folder.
# Copied 4_landsat.tif to Google Drive folder.
# Copied 5_landsat.tif to Google Drive folder.
# Copied 1_landsat.tif to Google Drive folder.
# Copied 3_landsat.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm5/landsat_2020"
tif_source = "/content/data/content/exports/landsat_2020/"
# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 2_landsat.tif to Google Drive folder.
# Copied 4_landsat.tif to Google Drive folder.
# Copied 5_landsat.tif to Google Drive folder.
# Copied 1_landsat.tif to Google Drive folder.
# Copied 3_landsat.tif to Google Drive folder.

# %%
# original images and labels folder: how many files are there?
iamges = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/landsat128x128data/utm4/ccap_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 42

# %% [markdown]
# # images

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export001_image.zip -d /content/image/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export002_image.zip -d /content/image/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2018_export003_image.zip -d /content/image/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/image/content/exports/image'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 2630

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2019_export001_image.zip -d /content/image/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2019_export002_image.zip -d /content/image/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/image/content/exports/image'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 2648

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2020_export001_image.zip -d /content/image/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm4_2020_export002_image.zip -d /content/image/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/image/content/exports/image'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 2648

# %% [markdown]
# so far I've unzipped all the training data (ccap, nwi/ccap, nwi/nlcd) and dem, as well as the imagery data for 2018, 2019, 2020.

# %% [markdown]
# Next, I need to think about how I want to organize all of this so its in the correct //trainingdata//images, //trainindata//lables set up

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export001_image.zip -d /content/image/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export002_image.zip -d /content/image/
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2018_export003_image.zip -d /content/image/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/image/content/exports/image'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 229

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2019_export001_image.zip -d /content/image/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/image/content/exports/image'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 229

# %%
# !unzip /content/drive/MyDrive/DeepLearning_Project/trainingdata/feb27_exports/Planet_utm5_2020_export001_image.zip -d /content/image/

# %%
# original images and labels folder: how many files are there?
iamges = '/content/image/content/exports/image'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')
# Out:
# The number of files in the folder is: 229

# %% [markdown]
# check the number of files in image folders and data folders

# %% [markdown]
# *   UTM 5 data and image count match.
# *   UTM 4 data and image count DO NOT match.

# %%
import re

# %%
folder = '/content/image/content/exports/planet_utm4_2018'
files = os.listdir(folder)


# Function to extract the numerical part of a filename
def extract_number(filename):
    match = re.search(r'\d+', filename)
    return int(match.group()) if match else 0

# Sort the files using the extract_number function as key
files_sorted = sorted(files, key=extract_number)

for file in files_sorted:
    print(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-59-2727760ff44e> in <cell line: 2>()
#       1 folder = '/content/image/content/exports/planet_utm4_2018'
# ----> 2 files = os.listdir(folder)
#       3
#       4
#       5 # Function to extract the numerical part of a filename
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/image/content/exports/planet_utm4_2018'

# %%
folder = '/content/image/content/exports/planet_utm4_2019'
files = os.listdir(folder)


# Function to extract the numerical part of a filename
def extract_number(filename):
    match = re.search(r'\d+', filename)
    return int(match.group()) if match else 0

# Sort the files using the extract_number function as key
files_sorted = sorted(files, key=extract_number)

for file in files_sorted:
    print(file)

# %%
# Function to extract the numerical part of a filename
def extract_number(filename):
    match = re.search(r'\d+', filename)
    return int(match.group()) if match else 0

def list_and_sort_files(folder_path):
    files = os.listdir(folder_path)
    return sorted(files, key=extract_number)


folder_path_1 = '/content/image/content/exports/utm4_2018'
folder_path_2 = '/content/image/content/exports/utm4_2020'


files_folder_1 = list_and_sort_files(folder_path_1)
files_folder_2 = list_and_sort_files(folder_path_2)

# Find files in folder 1 not in folder 2
missing_in_folder_2 = set(files_folder_1) - set(files_folder_2)

# Find files in folder 2 not in folder 1
missing_in_folder_1 = set(files_folder_2) - set(files_folder_1)

# Print the results
if missing_in_folder_2:
    print("Files in folder 1 missing in folder 2:", missing_in_folder_2)
else:
    print("No files in folder 1 are missing in folder 2.")

if missing_in_folder_1:
    print("Files in folder 2 missing in folder 1:", missing_in_folder_1)
else:
    print("No files in folder 2 are missing in folder 1.")

# for file_1, file_2 in zip(files_folder_1, files_folder_2):
#     if file_1 != file_2:
#         print(f"File mismatch: {file_1} in folder 1 and {file_2} in folder 2")
# Out:
# Files in folder 1 missing in folder 2: {'.ipynb_checkpoints'}
# Files in folder 2 missing in folder 1: {'627_planet.tif'}

# %%
# !mkdir /content/extra/planet_utm4_2019
# !mkdir /content/extra/planet_utm4_2020
# !mkdir /content/other
# !mkdir /content/other/utm4_2019
# !mkdir /content/other/utm4_2020

# %%
filetomove = "/content/image/content/exports/utm4_2020/627_planet.tif"

destination = "/content/other/utm4_2020"

shutil.move(filetomove, destination)
# Out:
# '/content/other/utm4_2020/627_planet.tif'

# %%
# original images and labels folder: how many files are there?
iamges = '/content/image/content/exports/utm4_2018'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')


iamges_two = '/content/image/content/exports/utm4_2019'
image_folder_two = os.listdir(iamges_two)
image_folder_two_count = len(image_folder_two)
print(f'The number of files in the folder is: {image_folder_two_count}')


iamges_three = '/content/image/content/exports/utm4_2020'
image_folder_three = os.listdir(iamges_three)
image_folder_three_count = len(image_folder_three)
print(f'The number of files in the folder is: {image_folder_three_count}')
# Out:
# The number of files in the folder is: 2630
# The number of files in the folder is: 2629
# The number of files in the folder is: 2629

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/images_2018/"
tif_source = "/content/image/content/exports/utm5_2018/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/images_2019/"
tif_source = "/content/image/content/exports/utm5_2019/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/images_2020/"
tif_source = "/content/image/content/exports/utm5_2020/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/images_2018/"
tif_source = "/content/image/content/exports/utm4_2018/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 1792_planet.tif to Google Drive folder.
# Copied 2208_planet.tif to Google Drive folder.
# Copied 559_planet.tif to Google Drive folder.
# Copied 2022_planet.tif to Google Drive folder.
# Copied 2578_planet.tif to Google Drive folder.
# Copied 995_planet.tif to Google Drive folder.
# Copied 2060_planet.tif to Google Drive folder.
# Copied 1612_planet.tif to Google Drive folder.
# Copied 895_planet.tif to Google Drive folder.
# Copied 475_planet.tif to Google Drive folder.
# Copied 1618_planet.tif to Google Drive folder.
# Copied 100_planet.tif to Google Drive folder.
# Copied 1004_planet.tif to Google Drive folder.
# Copied 2570_planet.tif to Google Drive folder.
# Copied 1978_planet.tif to Google Drive folder.
# Copied 362_planet.tif to Google Drive folder.
# Copied 2364_planet.tif to Google Drive folder.
# Copied 1191_planet.tif to Google Drive folder.
# Copied 1001_planet.tif to Google Drive folder.
# Copied 1976_planet.tif to Google Drive folder.
# Copied 1398_planet.tif to Google Drive folder.
# Copied 193_planet.tif to Google Drive folder.
# Copied 515_planet.tif to Google Drive folder.
# Copied 2340_planet.tif to Google Drive folder.
# Copied 55_planet.tif to Google Drive folder.
# Copied 1114_planet.tif to Google Drive folder.
# Copied 2607_planet.tif to Google Drive folder.
# Copied 2068_planet.tif to Google Drive folder.
# Copied 1652_planet.tif to Google Drive folder.
# Copied 2201_planet.tif to Google Drive folder.
# Copied 2138_planet.tif to Google Drive folder.
# Copied 1812_planet.tif to Google Drive folder.
# Copied 1414_planet.tif to Google Drive folder.
# Copied 1906_planet.tif to Google Drive folder.
# Copied 35_planet.tif to Google Drive folder.
# Copied 2025_planet.tif to Google Drive folder.
# Copied 1303_planet.tif to Google Drive folder.
# Copied 2658_planet.tif to Google Drive folder.
# Copied 435_planet.tif to Google Drive folder.
# Copied 1029_planet.tif to Google Drive folder.
# Copied 1979_planet.tif to Google Drive folder.
# Copied 851_planet.tif to Google Drive folder.
# Copied 505_planet.tif to Google Drive folder.
# Copied 1333_planet.tif to Google Drive folder.
# Copied 349_planet.tif to Google Drive folder.
# Copied 727_planet.tif to Google Drive folder.
# Copied 2223_planet.tif to Google Drive folder.
# Copied 50_planet.tif to Google Drive folder.
# Copied 11_planet.tif to Google Drive folder.
# Copied 2346_planet.tif to Google Drive folder.
# Copied 1296_planet.tif to Google Drive folder.
# Copied 512_planet.tif to Google Drive folder.
# Copied 882_planet.tif to Google Drive folder.
# Copied 2056_planet.tif to Google Drive folder.
# Copied 1998_planet.tif to Google Drive folder.
# Copied 1128_planet.tif to Google Drive folder.
# Copied 2189_planet.tif to Google Drive folder.
# Copied 2664_planet.tif to Google Drive folder.
# Copied 544_planet.tif to Google Drive folder.
# Copied 613_planet.tif to Google Drive folder.
# Copied 2567_planet.tif to Google Drive folder.
# Copied 2131_planet.tif to Google Drive folder.
# Copied 699_planet.tif to Google Drive folder.
# Copied 1164_planet.tif to Google Drive folder.
# Copied 638_planet.tif to Google Drive folder.
# Copied 2620_planet.tif to Google Drive folder.
# Copied 538_planet.tif to Google Drive folder.
# Copied 2525_planet.tif to Google Drive folder.
# Copied 99_planet.tif to Google Drive folder.
# Copied 1860_planet.tif to Google Drive folder.
# Copied 1819_planet.tif to Google Drive folder.
# Copied 1325_planet.tif to Google Drive folder.
# Copied 403_planet.tif to Google Drive folder.
# Copied 2392_planet.tif to Google Drive folder.
# Copied 22_planet.tif to Google Drive folder.
# Copied 1653_planet.tif to Google Drive folder.
# Copied 1901_planet.tif to Google Drive folder.
# Copied 439_planet.tif to Google Drive folder.
# Copied 129_planet.tif to Google Drive folder.
# Copied 989_planet.tif to Google Drive folder.
# Copied 489_planet.tif to Google Drive folder.
# Copied 2028_planet.tif to Google Drive folder.
# Copied 1574_planet.tif to Google Drive folder.
# Copied 510_planet.tif to Google Drive folder.
# Copied 977_planet.tif to Google Drive folder.
# Copied 119_planet.tif to Google Drive folder.
# Copied 2608_planet.tif to Google Drive folder.
# Copied 1855_planet.tif to Google Drive folder.
# Copied 1625_planet.tif to Google Drive folder.
# Copied 1649_planet.tif to Google Drive folder.
# Copied 445_planet.tif to Google Drive folder.
# Copied 1336_planet.tif to Google Drive folder.
# Copied 108_planet.tif to Google Drive folder.
# Copied 1729_planet.tif to Google Drive folder.
# Copied 726_planet.tif to Google Drive folder.
# Copied 2244_planet.tif to Google Drive folder.
# Copied 988_planet.tif to Google Drive folder.
# Copied 2263_planet.tif to Google Drive folder.
# Copied 1895_planet.tif to Google Drive folder.
# Copied 585_planet.tif to Google Drive folder.
# Copied 2547_planet.tif to Google Drive folder.
# Copied 324_planet.tif to Google Drive folder.
# Copied 1165_planet.tif to Google Drive folder.
# Copied 1702_planet.tif to Google Drive folder.
# Copied 803_planet.tif to Google Drive folder.
# Copied 791_planet.tif to Google Drive folder.
# Copied 998_planet.tif to Google Drive folder.
# Copied 472_planet.tif to Google Drive folder.
# Copied 68_planet.tif to Google Drive folder.
# Copied 1891_planet.tif to Google Drive folder.
# Copied 610_planet.tif to Google Drive folder.
# Copied 2104_planet.tif to Google Drive folder.
# Copied 756_planet.tif to Google Drive folder.
# Copied 2348_planet.tif to Google Drive folder.
# Copied 89_planet.tif to Google Drive folder.
# Copied 1230_planet.tif to Google Drive folder.
# Copied 1368_planet.tif to Google Drive folder.
# Copied 1651_planet.tif to Google Drive folder.
# Copied 956_planet.tif to Google Drive folder.
# Copied 327_planet.tif to Google Drive folder.
# Copied 1776_planet.tif to Google Drive folder.
# Copied 2326_planet.tif to Google Drive folder.
# Copied 476_planet.tif to Google Drive folder.
# Copied 587_planet.tif to Google Drive folder.
# Copied 2579_planet.tif to Google Drive folder.
# Copied 885_planet.tif to Google Drive folder.
# Copied 793_planet.tif to Google Drive folder.
# Copied 1313_planet.tif to Google Drive folder.
# Copied 2085_planet.tif to Google Drive folder.
# Copied 1269_planet.tif to Google Drive folder.
# Copied 848_planet.tif to Google Drive folder.
# Copied 335_planet.tif to Google Drive folder.
# Copied 1501_planet.tif to Google Drive folder.
# Copied 1424_planet.tif to Google Drive folder.
# Copied 1298_planet.tif to Google Drive folder.
# Copied 1223_planet.tif to Google Drive folder.
# Copied 2118_planet.tif to Google Drive folder.
# Copied 601_planet.tif to Google Drive folder.
# Copied 2588_planet.tif to Google Drive folder.
# Copied 389_planet.tif to Google Drive folder.
# Copied 1116_planet.tif to Google Drive folder.
# Copied 469_planet.tif to Google Drive folder.
# Copied 2196_planet.tif to Google Drive folder.
# Copied 1282_planet.tif to Google Drive folder.
# Copied 2182_planet.tif to Google Drive folder.
# Copied 2380_planet.tif to Google Drive folder.
# Copied 1816_planet.tif to Google Drive folder.
# Copied 2295_planet.tif to Google Drive folder.
# Copied 2652_planet.tif to Google Drive folder.
# Copied 1412_planet.tif to Google Drive folder.
# Copied 318_planet.tif to Google Drive folder.
# Copied 1179_planet.tif to Google Drive folder.
# Copied 496_planet.tif to Google Drive folder.
# Copied 2038_planet.tif to Google Drive folder.
# Copied 2071_planet.tif to Google Drive folder.
# Copied 2335_planet.tif to Google Drive folder.
# Copied 1143_planet.tif to Google Drive folder.
# Copied 2541_planet.tif to Google Drive folder.
# Copied 687_planet.tif to Google Drive folder.
# Copied 2081_planet.tif to Google Drive folder.
# Copied 2612_planet.tif to Google Drive folder.
# Copied 869_planet.tif to Google Drive folder.
# Copied 892_planet.tif to Google Drive folder.
# Copied 2119_planet.tif to Google Drive folder.
# Copied 330_planet.tif to Google Drive folder.
# Copied 1145_planet.tif to Google Drive folder.
# Copied 2441_planet.tif to Google Drive folder.
# Copied 819_planet.tif to Google Drive folder.
# Copied 657_planet.tif to Google Drive folder.
# Copied 715_planet.tif to Google Drive folder.
# Copied 1220_planet.tif to Google Drive folder.
# Copied 767_planet.tif to Google Drive folder.
# Copied 1119_planet.tif to Google Drive folder.
# Copied 1121_planet.tif to Google Drive folder.
# Copied 46_planet.tif to Google Drive folder.
# Copied 405_planet.tif to Google Drive folder.
# Copied 51_planet.tif to Google Drive folder.
# Copied 543_planet.tif to Google Drive folder.
# Copied 1835_planet.tif to Google Drive folder.
# Copied 2472_planet.tif to Google Drive folder.
# Copied 436_planet.tif to Google Drive folder.
# Copied 2014_planet.tif to Google Drive folder.
# Copied 596_planet.tif to Google Drive folder.
# Copied 1579_planet.tif to Google Drive folder.
# Copied 1291_planet.tif to Google Drive folder.
# Copied 570_planet.tif to Google Drive folder.
# Copied 1163_planet.tif to Google Drive folder.
# Copied 986_planet.tif to Google Drive folder.
# Copied 1448_planet.tif to Google Drive folder.
# Copied 2618_planet.tif to Google Drive folder.
# Copied 1775_planet.tif to Google Drive folder.
# Copied 189_planet.tif to Google Drive folder.
# Copied 567_planet.tif to Google Drive folder.
# Copied 311_planet.tif to Google Drive folder.
# Copied 1331_planet.tif to Google Drive folder.
# Copied 1632_planet.tif to Google Drive folder.
# Copied 1036_planet.tif to Google Drive folder.
# Copied 2149_planet.tif to Google Drive folder.
# Copied 2035_planet.tif to Google Drive folder.
# Copied 116_planet.tif to Google Drive folder.
# Copied 1493_planet.tif to Google Drive folder.
# Copied 2483_planet.tif to Google Drive folder.
# Copied 493_planet.tif to Google Drive folder.
# Copied 823_planet.tif to Google Drive folder.
# Copied 47_planet.tif to Google Drive folder.
# Copied 351_planet.tif to Google Drive folder.
# Copied 45_planet.tif to Google Drive folder.
# Copied 1184_planet.tif to Google Drive folder.
# Copied 2301_planet.tif to Google Drive folder.
# Copied 2453_planet.tif to Google Drive folder.
# Copied 886_planet.tif to Google Drive folder.
# Copied 586_planet.tif to Google Drive folder.
# Copied 2544_planet.tif to Google Drive folder.
# Copied 1034_planet.tif to Google Drive folder.
# Copied 2552_planet.tif to Google Drive folder.
# Copied 1616_planet.tif to Google Drive folder.
# Copied 1945_planet.tif to Google Drive folder.
# Copied 2466_planet.tif to Google Drive folder.
# Copied 1684_planet.tif to Google Drive folder.
# Copied 2628_planet.tif to Google Drive folder.
# Copied 2108_planet.tif to Google Drive folder.
# Copied 1772_planet.tif to Google Drive folder.
# Copied 246_planet.tif to Google Drive folder.
# Copied 866_planet.tif to Google Drive folder.
# Copied 1293_planet.tif to Google Drive folder.
# Copied 1457_planet.tif to Google Drive folder.
# Copied 1817_planet.tif to Google Drive folder.
# Copied 2350_planet.tif to Google Drive folder.
# Copied 217_planet.tif to Google Drive folder.
# Copied 2112_planet.tif to Google Drive folder.
# Copied 1512_planet.tif to Google Drive folder.
# Copied 2128_planet.tif to Google Drive folder.
# Copied 2566_planet.tif to Google Drive folder.
# Copied 1808_planet.tif to Google Drive folder.
# Copied 1390_planet.tif to Google Drive folder.
# Copied 1747_planet.tif to Google Drive folder.
# Copied 1765_planet.tif to Google Drive folder.
# Copied 1300_planet.tif to Google Drive folder.
# Copied 2152_planet.tif to Google Drive folder.
# Copied 1312_planet.tif to Google Drive folder.
# Copied 1281_planet.tif to Google Drive folder.
# Copied 1454_planet.tif to Google Drive folder.
# Copied 1531_planet.tif to Google Drive folder.
# Copied 2436_planet.tif to Google Drive folder.
# Copied 1883_planet.tif to Google Drive folder.
# Copied 828_planet.tif to Google Drive folder.
# Copied 230_planet.tif to Google Drive folder.
# Copied 990_planet.tif to Google Drive folder.
# Copied 2010_planet.tif to Google Drive folder.
# Copied 231_planet.tif to Google Drive folder.
# Copied 82_planet.tif to Google Drive folder.
# Copied 2275_planet.tif to Google Drive folder.
# Copied 1405_planet.tif to Google Drive folder.
# Copied 1363_planet.tif to Google Drive folder.
# Copied 2514_planet.tif to Google Drive folder.
# Copied 1437_planet.tif to Google Drive folder.
# Copied 1857_planet.tif to Google Drive folder.
# Copied 748_planet.tif to Google Drive folder.
# Copied 839_planet.tif to Google Drive folder.
# Copied 1067_planet.tif to Google Drive folder.
# Copied 1340_planet.tif to Google Drive folder.
# Copied 741_planet.tif to Google Drive folder.
# Copied 1709_planet.tif to Google Drive folder.
# Copied 1206_planet.tif to Google Drive folder.
# Copied 136_planet.tif to Google Drive folder.
# Copied 179_planet.tif to Google Drive folder.
# Copied 460_planet.tif to Google Drive folder.
# Copied 713_planet.tif to Google Drive folder.
# Copied 675_planet.tif to Google Drive folder.
# Copied 1941_planet.tif to Google Drive folder.
# Copied 1192_planet.tif to Google Drive folder.
# Copied 2533_planet.tif to Google Drive folder.
# Copied 2319_planet.tif to Google Drive folder.
# Copied 1487_planet.tif to Google Drive folder.
# Copied 266_planet.tif to Google Drive folder.
# Copied 1439_planet.tif to Google Drive folder.
# Copied 528_planet.tif to Google Drive folder.
# Copied 273_planet.tif to Google Drive folder.
# Copied 1274_planet.tif to Google Drive folder.
# Copied 2471_planet.tif to Google Drive folder.
# Copied 1662_planet.tif to Google Drive folder.
# Copied 1549_planet.tif to Google Drive folder.
# Copied 749_planet.tif to Google Drive folder.
# Copied 1240_planet.tif to Google Drive folder.
# Copied 1851_planet.tif to Google Drive folder.
# Copied 1594_planet.tif to Google Drive folder.
# Copied 690_planet.tif to Google Drive folder.
# Copied 145_planet.tif to Google Drive folder.
# Copied 575_planet.tif to Google Drive folder.
# Copied 2212_planet.tif to Google Drive folder.
# Copied 1727_planet.tif to Google Drive folder.
# Copied 1791_planet.tif to Google Drive folder.
# Copied 903_planet.tif to Google Drive folder.
# Copied 1435_planet.tif to Google Drive folder.
# Copied 752_planet.tif to Google Drive folder.
# Copied 1867_planet.tif to Google Drive folder.
# Copied 513_planet.tif to Google Drive folder.
# Copied 276_planet.tif to Google Drive folder.
# Copied 244_planet.tif to Google Drive folder.
# Copied 245_planet.tif to Google Drive folder.
# Copied 419_planet.tif to Google Drive folder.
# Copied 2164_planet.tif to Google Drive folder.
# Copied 2169_planet.tif to Google Drive folder.
# Copied 1131_planet.tif to Google Drive folder.
# Copied 2332_planet.tif to Google Drive folder.
# Copied 2174_planet.tif to Google Drive folder.
# Copied 1380_planet.tif to Google Drive folder.
# Copied 714_planet.tif to Google Drive folder.
# Copied 306_planet.tif to Google Drive folder.
# Copied 1309_planet.tif to Google Drive folder.
# Copied 2458_planet.tif to Google Drive folder.
# Copied 760_planet.tif to Google Drive folder.
# Copied 1242_planet.tif to Google Drive folder.
# Copied 79_planet.tif to Google Drive folder.
# Copied 1449_planet.tif to Google Drive folder.
# Copied 1346_planet.tif to Google Drive folder.
# Copied 2007_planet.tif to Google Drive folder.
# Copied 1295_planet.tif to Google Drive folder.
# Copied 1527_planet.tif to Google Drive folder.
# Copied 1035_planet.tif to Google Drive folder.
# Copied 1619_planet.tif to Google Drive folder.
# Copied 702_planet.tif to Google Drive folder.
# Copied 2114_planet.tif to Google Drive folder.
# Copied 1063_planet.tif to Google Drive folder.
# Copied 312_planet.tif to Google Drive folder.
# Copied 2307_planet.tif to Google Drive folder.
# Copied 722_planet.tif to Google Drive folder.
# Copied 416_planet.tif to Google Drive folder.
# Copied 987_planet.tif to Google Drive folder.
# Copied 2125_planet.tif to Google Drive folder.
# Copied 2032_planet.tif to Google Drive folder.
# Copied 366_planet.tif to Google Drive folder.
# Copied 2141_planet.tif to Google Drive folder.
# Copied 1319_planet.tif to Google Drive folder.
# Copied 2478_planet.tif to Google Drive folder.
# Copied 1074_planet.tif to Google Drive folder.
# Copied 109_planet.tif to Google Drive folder.
# Copied 1021_planet.tif to Google Drive folder.
# Copied 2059_planet.tif to Google Drive folder.
# Copied 258_planet.tif to Google Drive folder.
# Copied 1689_planet.tif to Google Drive folder.
# Copied 502_planet.tif to Google Drive folder.
# Copied 1529_planet.tif to Google Drive folder.
# Copied 1195_planet.tif to Google Drive folder.
# Copied 1751_planet.tif to Google Drive folder.
# Copied 27_planet.tif to Google Drive folder.
# Copied 319_planet.tif to Google Drive folder.
# Copied 1434_planet.tif to Google Drive folder.
# Copied 491_planet.tif to Google Drive folder.
# Copied 1567_planet.tif to Google Drive folder.
# Copied 1924_planet.tif to Google Drive folder.
# Copied 1664_planet.tif to Google Drive folder.
# Copied 28_planet.tif to Google Drive folder.
# Copied 781_planet.tif to Google Drive folder.
# Copied 2498_planet.tif to Google Drive folder.
# Copied 2379_planet.tif to Google Drive folder.
# Copied 1358_planet.tif to Google Drive folder.
# Copied 1551_planet.tif to Google Drive folder.
# Copied 2274_planet.tif to Google Drive folder.
# Copied 1418_planet.tif to Google Drive folder.
# Copied 1790_planet.tif to Google Drive folder.
# Copied 2214_planet.tif to Google Drive folder.
# Copied 370_planet.tif to Google Drive folder.
# Copied 1912_planet.tif to Google Drive folder.
# Copied 1494_planet.tif to Google Drive folder.
# Copied 274_planet.tif to Google Drive folder.
# Copied 1083_planet.tif to Google Drive folder.
# Copied 529_planet.tif to Google Drive folder.
# Copied 1002_planet.tif to Google Drive folder.
# Copied 2197_planet.tif to Google Drive folder.
# Copied 1989_planet.tif to Google Drive folder.
# Copied 1560_planet.tif to Google Drive folder.
# Copied 156_planet.tif to Google Drive folder.
# Copied 533_planet.tif to Google Drive folder.
# Copied 1157_planet.tif to Google Drive folder.
# Copied 646_planet.tif to Google Drive folder.
# Copied 1371_planet.tif to Google Drive folder.
# Copied 447_planet.tif to Google Drive folder.
# Copied 1048_planet.tif to Google Drive folder.
# Copied 888_planet.tif to Google Drive folder.
# Copied 2501_planet.tif to Google Drive folder.
# Copied 2304_planet.tif to Google Drive folder.
# Copied 1000_planet.tif to Google Drive folder.
# Copied 1008_planet.tif to Google Drive folder.
# Copied 1722_planet.tif to Google Drive folder.
# Copied 2508_planet.tif to Google Drive folder.
# Copied 1492_planet.tif to Google Drive folder.
# Copied 1972_planet.tif to Google Drive folder.
# Copied 2356_planet.tif to Google Drive folder.
# Copied 192_planet.tif to Google Drive folder.
# Copied 717_planet.tif to Google Drive folder.
# Copied 328_planet.tif to Google Drive folder.
# Copied 2497_planet.tif to Google Drive folder.
# Copied 2455_planet.tif to Google Drive folder.
# Copied 2241_planet.tif to Google Drive folder.
# Copied 114_planet.tif to Google Drive folder.
# Copied 2218_planet.tif to Google Drive folder.
# Copied 1585_planet.tif to Google Drive folder.
# Copied 2538_planet.tif to Google Drive folder.
# Copied 2284_planet.tif to Google Drive folder.
# Copied 808_planet.tif to Google Drive folder.
# Copied 359_planet.tif to Google Drive folder.
# Copied 1896_planet.tif to Google Drive folder.
# Copied 1142_planet.tif to Google Drive folder.
# Copied 1198_planet.tif to Google Drive folder.
# Copied 2583_planet.tif to Google Drive folder.
# Copied 295_planet.tif to Google Drive folder.
# Copied 1033_planet.tif to Google Drive folder.
# Copied 2420_planet.tif to Google Drive folder.
# Copied 1013_planet.tif to Google Drive folder.
# Copied 968_planet.tif to Google Drive folder.
# Copied 1401_planet.tif to Google Drive folder.
# Copied 1252_planet.tif to Google Drive folder.
# Copied 981_planet.tif to Google Drive folder.
# Copied 898_planet.tif to Google Drive folder.
# Copied 2485_planet.tif to Google Drive folder.
# Copied 647_planet.tif to Google Drive folder.
# Copied 2200_planet.tif to Google Drive folder.
# Copied 1849_planet.tif to Google Drive folder.
# Copied 211_planet.tif to Google Drive folder.
# Copied 1838_planet.tif to Google Drive folder.
# Copied 1951_planet.tif to Google Drive folder.
# Copied 1541_planet.tif to Google Drive folder.
# Copied 1606_planet.tif to Google Drive folder.
# Copied 2345_planet.tif to Google Drive folder.
# Copied 1914_planet.tif to Google Drive folder.
# Copied 143_planet.tif to Google Drive folder.
# Copied 458_planet.tif to Google Drive folder.
# Copied 2058_planet.tif to Google Drive folder.
# Copied 2491_planet.tif to Google Drive folder.
# Copied 2373_planet.tif to Google Drive folder.
# Copied 1757_planet.tif to Google Drive folder.
# Copied 1261_planet.tif to Google Drive folder.
# Copied 1982_planet.tif to Google Drive folder.
# Copied 667_planet.tif to Google Drive folder.
# Copied 1260_planet.tif to Google Drive folder.
# Copied 718_planet.tif to Google Drive folder.
# Copied 1759_planet.tif to Google Drive folder.
# Copied 92_planet.tif to Google Drive folder.
# Copied 1674_planet.tif to Google Drive folder.
# Copied 1075_planet.tif to Google Drive folder.
# Copied 2161_planet.tif to Google Drive folder.
# Copied 2639_planet.tif to Google Drive folder.
# Copied 190_planet.tif to Google Drive folder.
# Copied 1604_planet.tif to Google Drive folder.
# Copied 1853_planet.tif to Google Drive folder.
# Copied 2153_planet.tif to Google Drive folder.
# Copied 152_planet.tif to Google Drive folder.
# Copied 826_planet.tif to Google Drive folder.
# Copied 2020_planet.tif to Google Drive folder.
# Copied 2322_planet.tif to Google Drive folder.
# Copied 2329_planet.tif to Google Drive folder.
# Copied 2631_planet.tif to Google Drive folder.
# Copied 1939_planet.tif to Google Drive folder.
# Copied 1406_planet.tif to Google Drive folder.
# Copied 1151_planet.tif to Google Drive folder.
# Copied 2352_planet.tif to Google Drive folder.
# Copied 385_planet.tif to Google Drive folder.
# Copied 2581_planet.tif to Google Drive folder.
# Copied 1779_planet.tif to Google Drive folder.
# Copied 216_planet.tif to Google Drive folder.
# Copied 1091_planet.tif to Google Drive folder.
# Copied 2324_planet.tif to Google Drive folder.
# Copied 484_planet.tif to Google Drive folder.
# Copied 481_planet.tif to Google Drive folder.
# Copied 1249_planet.tif to Google Drive folder.
# Copied 2107_planet.tif to Google Drive folder.
# Copied 1129_planet.tif to Google Drive folder.
# Copied 137_planet.tif to Google Drive folder.
# Copied 2635_planet.tif to Google Drive folder.
# Copied 26_planet.tif to Google Drive folder.
# Copied 1569_planet.tif to Google Drive folder.
# Copied 194_planet.tif to Google Drive folder.
# Copied 151_planet.tif to Google Drive folder.
# Copied 1793_planet.tif to Google Drive folder.
# Copied 1216_planet.tif to Google Drive folder.
# Copied 215_planet.tif to Google Drive folder.
# Copied 852_planet.tif to Google Drive folder.
# Copied 249_planet.tif to Google Drive folder.
# Copied 2073_planet.tif to Google Drive folder.
# Copied 1968_planet.tif to Google Drive folder.
# Copied 2454_planet.tif to Google Drive folder.
# Copied 1030_planet.tif to Google Drive folder.
# Copied 1524_planet.tif to Google Drive folder.
# Copied 1411_planet.tif to Google Drive folder.
# Copied 605_planet.tif to Google Drive folder.
# Copied 1600_planet.tif to Google Drive folder.
# Copied 789_planet.tif to Google Drive folder.
# Copied 205_planet.tif to Google Drive folder.
# Copied 1888_planet.tif to Google Drive folder.
# Copied 1272_planet.tif to Google Drive folder.
# Copied 425_planet.tif to Google Drive folder.
# Copied 696_planet.tif to Google Drive folder.
# Copied 1690_planet.tif to Google Drive folder.
# Copied 1596_planet.tif to Google Drive folder.
# Copied 771_planet.tif to Google Drive folder.
# Copied 20_planet.tif to Google Drive folder.
# Copied 877_planet.tif to Google Drive folder.
# Copied 1766_planet.tif to Google Drive folder.
# Copied 589_planet.tif to Google Drive folder.
# Copied 2273_planet.tif to Google Drive folder.
# Copied 779_planet.tif to Google Drive folder.
# Copied 1691_planet.tif to Google Drive folder.
# Copied 1837_planet.tif to Google Drive folder.
# Copied 168_planet.tif to Google Drive folder.
# Copied 1679_planet.tif to Google Drive folder.
# Copied 1467_planet.tif to Google Drive folder.
# Copied 1536_planet.tif to Google Drive folder.
# Copied 320_planet.tif to Google Drive folder.
# Copied 2126_planet.tif to Google Drive folder.
# Copied 2622_planet.tif to Google Drive folder.
# Copied 2253_planet.tif to Google Drive folder.
# Copied 1305_planet.tif to Google Drive folder.
# Copied 1996_planet.tif to Google Drive folder.
# Copied 2260_planet.tif to Google Drive folder.
# Copied 1038_planet.tif to Google Drive folder.
# Copied 867_planet.tif to Google Drive folder.
# Copied 2575_planet.tif to Google Drive folder.
# Copied 1373_planet.tif to Google Drive folder.
# Copied 1172_planet.tif to Google Drive folder.
# Copied 1009_planet.tif to Google Drive folder.
# Copied 1410_planet.tif to Google Drive folder.
# Copied 1200_planet.tif to Google Drive folder.
# Copied 2097_planet.tif to Google Drive folder.
# Copied 53_planet.tif to Google Drive folder.
# Copied 1693_planet.tif to Google Drive folder.
# Copied 1207_planet.tif to Google Drive folder.
# Copied 2385_planet.tif to Google Drive folder.
# Copied 120_planet.tif to Google Drive folder.
# Copied 577_planet.tif to Google Drive folder.
# Copied 1015_planet.tif to Google Drive folder.
# Copied 1992_planet.tif to Google Drive folder.
# Copied 1603_planet.tif to Google Drive folder.
# Copied 478_planet.tif to Google Drive folder.
# Copied 1841_planet.tif to Google Drive folder.
# Copied 2100_planet.tif to Google Drive folder.
# Copied 800_planet.tif to Google Drive folder.
# Copied 1307_planet.tif to Google Drive folder.
# Copied 2136_planet.tif to Google Drive folder.
# Copied 1918_planet.tif to Google Drive folder.
# Copied 431_planet.tif to Google Drive folder.
# Copied 1712_planet.tif to Google Drive folder.
# Copied 1511_planet.tif to Google Drive folder.
# Copied 1085_planet.tif to Google Drive folder.
# Copied 225_planet.tif to Google Drive folder.
# Copied 2333_planet.tif to Google Drive folder.
# Copied 1953_planet.tif to Google Drive folder.
# Copied 1591_planet.tif to Google Drive folder.
# Copied 112_planet.tif to Google Drive folder.
# Copied 653_planet.tif to Google Drive folder.
# Copied 786_planet.tif to Google Drive folder.
# Copied 1270_planet.tif to Google Drive folder.
# Copied 1897_planet.tif to Google Drive folder.
# Copied 1140_planet.tif to Google Drive folder.
# Copied 1535_planet.tif to Google Drive folder.
# Copied 2041_planet.tif to Google Drive folder.
# Copied 257_planet.tif to Google Drive folder.
# Copied 933_planet.tif to Google Drive folder.
# Copied 18_planet.tif to Google Drive folder.
# Copied 2595_planet.tif to Google Drive folder.
# Copied 1466_planet.tif to Google Drive folder.
# Copied 2036_planet.tif to Google Drive folder.
# Copied 2154_planet.tif to Google Drive folder.
# Copied 1330_planet.tif to Google Drive folder.
# Copied 1221_planet.tif to Google Drive folder.
# Copied 993_planet.tif to Google Drive folder.
# Copied 1463_planet.tif to Google Drive folder.
# Copied 2521_planet.tif to Google Drive folder.
# Copied 557_planet.tif to Google Drive folder.
# Copied 2660_planet.tif to Google Drive folder.
# Copied 201_planet.tif to Google Drive folder.
# Copied 200_planet.tif to Google Drive folder.
# Copied 891_planet.tif to Google Drive folder.
# Copied 1654_planet.tif to Google Drive folder.
# Copied 1136_planet.tif to Google Drive folder.
# Copied 2109_planet.tif to Google Drive folder.
# Copied 547_planet.tif to Google Drive folder.
# Copied 2470_planet.tif to Google Drive folder.
# Copied 396_planet.tif to Google Drive folder.
# Copied 1226_planet.tif to Google Drive folder.
# Copied 2550_planet.tif to Google Drive folder.
# Copied 942_planet.tif to Google Drive folder.
# Copied 1859_planet.tif to Google Drive folder.
# Copied 642_planet.tif to Google Drive folder.
# Copied 74_planet.tif to Google Drive folder.
# Copied 2404_planet.tif to Google Drive folder.
# Copied 1993_planet.tif to Google Drive folder.
# Copied 378_planet.tif to Google Drive folder.
# Copied 1758_planet.tif to Google Drive folder.
# Copied 165_planet.tif to Google Drive folder.
# Copied 1419_planet.tif to Google Drive folder.
# Copied 571_planet.tif to Google Drive folder.
# Copied 162_planet.tif to Google Drive folder.
# Copied 1525_planet.tif to Google Drive folder.
# Copied 569_planet.tif to Google Drive folder.
# Copied 2536_planet.tif to Google Drive folder.
# Copied 2532_planet.tif to Google Drive folder.
# Copied 153_planet.tif to Google Drive folder.
# Copied 2449_planet.tif to Google Drive folder.
# Copied 1432_planet.tif to Google Drive folder.
# Copied 422_planet.tif to Google Drive folder.
# Copied 411_planet.tif to Google Drive folder.
# Copied 669_planet.tif to Google Drive folder.
# Copied 1263_planet.tif to Google Drive folder.
# Copied 1922_planet.tif to Google Drive folder.
# Copied 1588_planet.tif to Google Drive folder.
# Copied 929_planet.tif to Google Drive folder.
# Copied 2662_planet.tif to Google Drive folder.
# Copied 1497_planet.tif to Google Drive folder.
# Copied 1299_planet.tif to Google Drive folder.
# Copied 896_planet.tif to Google Drive folder.
# Copied 1446_planet.tif to Google Drive folder.
# Copied 963_planet.tif to Google Drive folder.
# Copied 360_planet.tif to Google Drive folder.
# Copied 552_planet.tif to Google Drive folder.
# Copied 1287_planet.tif to Google Drive folder.
# Copied 2170_planet.tif to Google Drive folder.
# Copied 1103_planet.tif to Google Drive folder.
# Copied 1761_planet.tif to Google Drive folder.
# Copied 1364_planet.tif to Google Drive folder.
# Copied 2009_planet.tif to Google Drive folder.
# Copied 1217_planet.tif to Google Drive folder.
# Copied 1728_planet.tif to Google Drive folder.
# Copied 897_planet.tif to Google Drive folder.
# Copied 2247_planet.tif to Google Drive folder.
# Copied 878_planet.tif to Google Drive folder.
# Copied 1665_planet.tif to Google Drive folder.
# Copied 1676_planet.tif to Google Drive folder.
# Copied 820_planet.tif to Google Drive folder.
# Copied 2371_planet.tif to Google Drive folder.
# Copied 492_planet.tif to Google Drive folder.
# Copied 1749_planet.tif to Google Drive folder.
# Copied 2224_planet.tif to Google Drive folder.
# Copied 609_planet.tif to Google Drive folder.
# Copied 2604_planet.tif to Google Drive folder.
# Copied 1994_planet.tif to Google Drive folder.
# Copied 2482_planet.tif to Google Drive folder.
# Copied 379_planet.tif to Google Drive folder.
# Copied 1633_planet.tif to Google Drive folder.
# Copied 2046_planet.tif to Google Drive folder.
# Copied 2051_planet.tif to Google Drive folder.
# Copied 1770_planet.tif to Google Drive folder.
# Copied 1182_planet.tif to Google Drive folder.
# Copied 19_planet.tif to Google Drive folder.
# Copied 2088_planet.tif to Google Drive folder.
# Copied 2496_planet.tif to Google Drive folder.
# Copied 332_planet.tif to Google Drive folder.
# Copied 641_planet.tif to Google Drive folder.
# Copied 1936_planet.tif to Google Drive folder.
# Copied 661_planet.tif to Google Drive folder.
# Copied 2246_planet.tif to Google Drive folder.
# Copied 698_planet.tif to Google Drive folder.
# Copied 1590_planet.tif to Google Drive folder.
# Copied 32_planet.tif to Google Drive folder.
# Copied 1711_planet.tif to Google Drive folder.
# Copied 2124_planet.tif to Google Drive folder.
# Copied 251_planet.tif to Google Drive folder.
# Copied 709_planet.tif to Google Drive folder.
# Copied 1807_planet.tif to Google Drive folder.
# Copied 1943_planet.tif to Google Drive folder.
# Copied 1636_planet.tif to Google Drive folder.
# Copied 1219_planet.tif to Google Drive folder.
# Copied 381_planet.tif to Google Drive folder.
# Copied 539_planet.tif to Google Drive folder.
# Copied 2278_planet.tif to Google Drive folder.
# Copied 2186_planet.tif to Google Drive folder.
# Copied 520_planet.tif to Google Drive folder.
# Copied 1944_planet.tif to Google Drive folder.
# Copied 2145_planet.tif to Google Drive folder.
# Copied 1856_planet.tif to Google Drive folder.
# Copied 725_planet.tif to Google Drive folder.
# Copied 2065_planet.tif to Google Drive folder.
# Copied 1503_planet.tif to Google Drive folder.
# Copied 881_planet.tif to Google Drive folder.
# Copied 1187_planet.tif to Google Drive folder.
# Copied 81_planet.tif to Google Drive folder.
# Copied 1959_planet.tif to Google Drive folder.
# Copied 2210_planet.tif to Google Drive folder.
# Copied 1400_planet.tif to Google Drive folder.
# Copied 1956_planet.tif to Google Drive folder.
# Copied 2018_planet.tif to Google Drive folder.
# Copied 104_planet.tif to Google Drive folder.
# Copied 1094_planet.tif to Google Drive folder.
# Copied 1311_planet.tif to Google Drive folder.
# Copied 2327_planet.tif to Google Drive folder.
# Copied 1697_planet.tif to Google Drive folder.
# Copied 862_planet.tif to Google Drive folder.
# Copied 2159_planet.tif to Google Drive folder.
# Copied 207_planet.tif to Google Drive folder.
# Copied 1668_planet.tif to Google Drive folder.
# Copied 939_planet.tif to Google Drive folder.
# Copied 2245_planet.tif to Google Drive folder.
# Copied 2232_planet.tif to Google Drive folder.
# Copied 755_planet.tif to Google Drive folder.
# Copied 2487_planet.tif to Google Drive folder.
# Copied 1534_planet.tif to Google Drive folder.
# Copied 313_planet.tif to Google Drive folder.
# Copied 1213_planet.tif to Google Drive folder.
# Copied 2621_planet.tif to Google Drive folder.
# Copied 1117_planet.tif to Google Drive folder.
# Copied 2560_planet.tif to Google Drive folder.
# Copied 1583_planet.tif to Google Drive folder.
# Copied 554_planet.tif to Google Drive folder.
# Copied 1639_planet.tif to Google Drive folder.
# Copied 353_planet.tif to Google Drive folder.
# Copied 1530_planet.tif to Google Drive folder.
# Copied 732_planet.tif to Google Drive folder.
# Copied 218_planet.tif to Google Drive folder.
# Copied 2383_planet.tif to Google Drive folder.
# Copied 73_planet.tif to Google Drive folder.
# Copied 1617_planet.tif to Google Drive folder.
# Copied 2271_planet.tif to Google Drive folder.
# Copied 2055_planet.tif to Google Drive folder.
# Copied 1986_planet.tif to Google Drive folder.
# Copied 388_planet.tif to Google Drive folder.
# Copied 2187_planet.tif to Google Drive folder.
# Copied 1137_planet.tif to Google Drive folder.
# Copied 736_planet.tif to Google Drive folder.
# Copied 765_planet.tif to Google Drive folder.
# Copied 712_planet.tif to Google Drive folder.
# Copied 2070_planet.tif to Google Drive folder.
# Copied 976_planet.tif to Google Drive folder.
# Copied 2225_planet.tif to Google Drive folder.
# Copied 1280_planet.tif to Google Drive folder.
# Copied 1593_planet.tif to Google Drive folder.
# Copied 1011_planet.tif to Google Drive folder.
# Copied 1279_planet.tif to Google Drive folder.
# Copied 1451_planet.tif to Google Drive folder.
# Copied 2398_planet.tif to Google Drive folder.
# Copied 1105_planet.tif to Google Drive folder.
# Copied 1784_planet.tif to Google Drive folder.
# Copied 1378_planet.tif to Google Drive folder.
# Copied 437_planet.tif to Google Drive folder.
# Copied 221_planet.tif to Google Drive folder.
# Copied 545_planet.tif to Google Drive folder.
# Copied 38_planet.tif to Google Drive folder.
# Copied 603_planet.tif to Google Drive folder.
# Copied 1962_planet.tif to Google Drive folder.
# Copied 2459_planet.tif to Google Drive folder.
# Copied 1683_planet.tif to Google Drive folder.
# Copied 2450_planet.tif to Google Drive folder.
# Copied 204_planet.tif to Google Drive folder.
# Copied 681_planet.tif to Google Drive folder.
# Copied 2477_planet.tif to Google Drive folder.
# Copied 597_planet.tif to Google Drive folder.
# Copied 1304_planet.tif to Google Drive folder.
# Copied 907_planet.tif to Google Drive folder.
# Copied 180_planet.tif to Google Drive folder.
# Copied 1351_planet.tif to Google Drive folder.
# Copied 140_planet.tif to Google Drive folder.
# Copied 2240_planet.tif to Google Drive folder.
# Copied 957_planet.tif to Google Drive folder.
# Copied 2096_planet.tif to Google Drive folder.
# Copied 1480_planet.tif to Google Drive folder.
# Copied 37_planet.tif to Google Drive folder.
# Copied 1542_planet.tif to Google Drive folder.
# Copied 1630_planet.tif to Google Drive folder.
# Copied 2561_planet.tif to Google Drive folder.
# Copied 44_planet.tif to Google Drive folder.
# Copied 2489_planet.tif to Google Drive folder.
# Copied 1893_planet.tif to Google Drive folder.
# Copied 2269_planet.tif to Google Drive folder.
# Copied 2343_planet.tif to Google Drive folder.
# Copied 1258_planet.tif to Google Drive folder.
# Copied 1848_planet.tif to Google Drive folder.
# Copied 2262_planet.tif to Google Drive folder.
# Copied 2103_planet.tif to Google Drive folder.
# Copied 1563_planet.tif to Google Drive folder.
# Copied 815_planet.tif to Google Drive folder.
# Copied 1554_planet.tif to Google Drive folder.
# Copied 775_planet.tif to Google Drive folder.
# Copied 1044_planet.tif to Google Drive folder.
# Copied 49_planet.tif to Google Drive folder.
# Copied 456_planet.tif to Google Drive folder.
# Copied 2004_planet.tif to Google Drive folder.
# Copied 2395_planet.tif to Google Drive folder.
# Copied 434_planet.tif to Google Drive folder.
# Copied 671_planet.tif to Google Drive folder.
# Copied 85_planet.tif to Google Drive folder.
# Copied 2317_planet.tif to Google Drive folder.
# Copied 391_planet.tif to Google Drive folder.
# Copied 1468_planet.tif to Google Drive folder.
# Copied 1043_planet.tif to Google Drive folder.
# Copied 1743_planet.tif to Google Drive folder.
# Copied 818_planet.tif to Google Drive folder.
# Copied 1548_planet.tif to Google Drive folder.
# Copied 1478_planet.tif to Google Drive folder.
# Copied 139_planet.tif to Google Drive folder.
# Copied 1455_planet.tif to Google Drive folder.
# Copied 1809_planet.tif to Google Drive folder.
# Copied 1985_planet.tif to Google Drive folder.
# Copied 2517_planet.tif to Google Drive folder.
# Copied 1886_planet.tif to Google Drive folder.
# Copied 2026_planet.tif to Google Drive folder.
# Copied 309_planet.tif to Google Drive folder.
# Copied 962_planet.tif to Google Drive folder.
# Copied 1950_planet.tif to Google Drive folder.
# Copied 2655_planet.tif to Google Drive folder.
# Copied 2415_planet.tif to Google Drive folder.
# Copied 2293_planet.tif to Google Drive folder.
# Copied 1065_planet.tif to Google Drive folder.
# Copied 1106_planet.tif to Google Drive folder.
# Copied 1472_planet.tif to Google Drive folder.
# Copied 1803_planet.tif to Google Drive folder.
# Copied 1930_planet.tif to Google Drive folder.
# Copied 787_planet.tif to Google Drive folder.
# Copied 198_planet.tif to Google Drive folder.
# Copied 1161_planet.tif to Google Drive folder.
# Copied 1475_planet.tif to Google Drive folder.
# Copied 191_planet.tif to Google Drive folder.
# Copied 2586_planet.tif to Google Drive folder.
# Copied 2215_planet.tif to Google Drive folder.
# Copied 2234_planet.tif to Google Drive folder.
# Copied 834_planet.tif to Google Drive folder.
# Copied 2584_planet.tif to Google Drive folder.
# Copied 2233_planet.tif to Google Drive folder.
# Copied 305_planet.tif to Google Drive folder.
# Copied 1614_planet.tif to Google Drive folder.
# Copied 2430_planet.tif to Google Drive folder.
# Copied 1052_planet.tif to Google Drive folder.
# Copied 172_planet.tif to Google Drive folder.
# Copied 706_planet.tif to Google Drive folder.
# Copied 1017_planet.tif to Google Drive folder.
# Copied 692_planet.tif to Google Drive folder.
# Copied 41_planet.tif to Google Drive folder.
# Copied 894_planet.tif to Google Drive folder.
# Copied 2589_planet.tif to Google Drive folder.
# Copied 1474_planet.tif to Google Drive folder.
# Copied 1937_planet.tif to Google Drive folder.
# Copied 1498_planet.tif to Google Drive folder.
# Copied 2377_planet.tif to Google Drive folder.
# Copied 958_planet.tif to Google Drive folder.
# Copied 2099_planet.tif to Google Drive folder.
# Copied 1183_planet.tif to Google Drive folder.
# Copied 1349_planet.tif to Google Drive folder.
# Copied 1447_planet.tif to Google Drive folder.
# Copied 2447_planet.tif to Google Drive folder.
# Copied 2202_planet.tif to Google Drive folder.
# Copied 2461_planet.tif to Google Drive folder.
# Copied 1024_planet.tif to Google Drive folder.
# Copied 286_planet.tif to Google Drive folder.
# Copied 296_planet.tif to Google Drive folder.
# Copied 960_planet.tif to Google Drive folder.
# Copied 2179_planet.tif to Google Drive folder.
# Copied 2653_planet.tif to Google Drive folder.
# Copied 486_planet.tif to Google Drive folder.
# Copied 812_planet.tif to Google Drive folder.
# Copied 1425_planet.tif to Google Drive folder.
# Copied 1705_planet.tif to Google Drive folder.
# Copied 870_planet.tif to Google Drive folder.
# Copied 357_planet.tif to Google Drive folder.
# Copied 2424_planet.tif to Google Drive folder.
# Copied 1545_planet.tif to Google Drive folder.
# Copied 2562_planet.tif to Google Drive folder.
# Copied 1294_planet.tif to Google Drive folder.
# Copied 1558_planet.tif to Google Drive folder.
# Copied 2462_planet.tif to Google Drive folder.
# Copied 598_planet.tif to Google Drive folder.
# Copied 1156_planet.tif to Google Drive folder.
# Copied 1335_planet.tif to Google Drive folder.
# Copied 1194_planet.tif to Google Drive folder.
# Copied 2222_planet.tif to Google Drive folder.
# Copied 634_planet.tif to Google Drive folder.
# Copied 1031_planet.tif to Google Drive folder.
# Copied 2523_planet.tif to Google Drive folder.
# Copied 1514_planet.tif to Google Drive folder.
# Copied 860_planet.tif to Google Drive folder.
# Copied 2393_planet.tif to Google Drive folder.
# Copied 1787_planet.tif to Google Drive folder.
# Copied 1607_planet.tif to Google Drive folder.
# Copied 173_planet.tif to Google Drive folder.
# Copied 372_planet.tif to Google Drive folder.
# Copied 1_planet.tif to Google Drive folder.
# Copied 535_planet.tif to Google Drive folder.
# Copied 1970_planet.tif to Google Drive folder.
# Copied 95_planet.tif to Google Drive folder.
# Copied 971_planet.tif to Google Drive folder.
# Copied 1931_planet.tif to Google Drive folder.
# Copied 738_planet.tif to Google Drive folder.
# Copied 1347_planet.tif to Google Drive folder.
# Copied 2601_planet.tif to Google Drive folder.
# Copied 2031_planet.tif to Google Drive folder.
# Copied 1623_planet.tif to Google Drive folder.
# Copied 1485_planet.tif to Google Drive folder.
# Copied 1479_planet.tif to Google Drive folder.
# Copied 2091_planet.tif to Google Drive folder.
# Copied 531_planet.tif to Google Drive folder.
# Copied 441_planet.tif to Google Drive folder.
# Copied 2341_planet.tif to Google Drive folder.
# Copied 212_planet.tif to Google Drive folder.
# Copied 555_planet.tif to Google Drive folder.
# Copied 2543_planet.tif to Google Drive folder.
# Copied 1620_planet.tif to Google Drive folder.
# Copied 375_planet.tif to Google Drive folder.
# Copied 470_planet.tif to Google Drive folder.
# Copied 303_planet.tif to Google Drive folder.
# Copied 2217_planet.tif to Google Drive folder.
# Copied 2053_planet.tif to Google Drive folder.
# Copied 443_planet.tif to Google Drive folder.
# Copied 1051_planet.tif to Google Drive folder.
# Copied 2574_planet.tif to Google Drive folder.
# Copied 69_planet.tif to Google Drive folder.
# Copied 730_planet.tif to Google Drive folder.
# Copied 1203_planet.tif to Google Drive folder.
# Copied 1821_planet.tif to Google Drive folder.
# Copied 36_planet.tif to Google Drive folder.
# Copied 2624_planet.tif to Google Drive folder.
# Copied 1721_planet.tif to Google Drive folder.
# Copied 1436_planet.tif to Google Drive folder.
# Copied 1046_planet.tif to Google Drive folder.
# Copied 2598_planet.tif to Google Drive folder.
# Copied 940_planet.tif to Google Drive folder.
# Copied 804_planet.tif to Google Drive folder.
# Copied 1570_planet.tif to Google Drive folder.
# Copied 2193_planet.tif to Google Drive folder.
# Copied 1836_planet.tif to Google Drive folder.
# Copied 2479_planet.tif to Google Drive folder.
# Copied 247_planet.tif to Google Drive folder.
# Copied 2251_planet.tif to Google Drive folder.
# Copied 2663_planet.tif to Google Drive folder.
# Copied 1096_planet.tif to Google Drive folder.
# Copied 264_planet.tif to Google Drive folder.
# Copied 1905_planet.tif to Google Drive folder.
# Copied 2524_planet.tif to Google Drive folder.
# Copied 1773_planet.tif to Google Drive folder.
# Copied 2400_planet.tif to Google Drive folder.
# Copied 1737_planet.tif to Google Drive folder.
# Copied 292_planet.tif to Google Drive folder.
# Copied 1829_planet.tif to Google Drive folder.
# Copied 337_planet.tif to Google Drive folder.
# Copied 1150_planet.tif to Google Drive folder.
# Copied 840_planet.tif to Google Drive folder.
# Copied 401_planet.tif to Google Drive folder.
# Copied 2000_planet.tif to Google Drive folder.
# Copied 1306_planet.tif to Google Drive folder.
# Copied 124_planet.tif to Google Drive folder.
# Copied 2158_planet.tif to Google Drive folder.
# Copied 1948_planet.tif to Google Drive folder.
# Copied 583_planet.tif to Google Drive folder.
# Copied 1012_planet.tif to Google Drive folder.
# Copied 2358_planet.tif to Google Drive folder.
# Copied 719_planet.tif to Google Drive folder.
# Copied 1908_planet.tif to Google Drive folder.
# Copied 2286_planet.tif to Google Drive folder.
# Copied 824_planet.tif to Google Drive folder.
# Copied 950_planet.tif to Google Drive folder.
# Copied 997_planet.tif to Google Drive folder.
# Copied 184_planet.tif to Google Drive folder.
# Copied 1643_planet.tif to Google Drive folder.
# Copied 984_planet.tif to Google Drive folder.
# Copied 766_planet.tif to Google Drive folder.
# Copied 855_planet.tif to Google Drive folder.
# Copied 1324_planet.tif to Google Drive folder.
# Copied 1581_planet.tif to Google Drive folder.
# Copied 2500_planet.tif to Google Drive folder.
# Copied 1961_planet.tif to Google Drive folder.
# Copied 34_planet.tif to Google Drive folder.
# Copied 1874_planet.tif to Google Drive folder.
# Copied 234_planet.tif to Google Drive folder.
# Copied 1178_planet.tif to Google Drive folder.
# Copied 591_planet.tif to Google Drive folder.
# Copied 2105_planet.tif to Google Drive folder.
# Copied 697_planet.tif to Google Drive folder.
# Copied 1080_planet.tif to Google Drive folder.
# Copied 1122_planet.tif to Google Drive folder.
# Copied 2137_planet.tif to Google Drive folder.
# Copied 420_planet.tif to Google Drive folder.
# Copied 1719_planet.tif to Google Drive folder.
# Copied 1801_planet.tif to Google Drive folder.
# Copied 117_planet.tif to Google Drive folder.
# Copied 361_planet.tif to Google Drive folder.
# Copied 2310_planet.tif to Google Drive folder.
# Copied 2221_planet.tif to Google Drive folder.
# Copied 785_planet.tif to Google Drive folder.
# Copied 183_planet.tif to Google Drive folder.
# Copied 2199_planet.tif to Google Drive folder.
# Copied 2650_planet.tif to Google Drive folder.
# Copied 1019_planet.tif to Google Drive folder.
# Copied 1290_planet.tif to Google Drive folder.
# Copied 1880_planet.tif to Google Drive folder.
# Copied 2314_planet.tif to Google Drive folder.
# Copied 747_planet.tif to Google Drive folder.
# Copied 612_planet.tif to Google Drive folder.
# Copied 776_planet.tif to Google Drive folder.
# Copied 2248_planet.tif to Google Drive folder.
# Copied 1635_planet.tif to Google Drive folder.
# Copied 992_planet.tif to Google Drive folder.
# Copied 333_planet.tif to Google Drive folder.
# Copied 291_planet.tif to Google Drive folder.
# Copied 1445_planet.tif to Google Drive folder.
# Copied 2391_planet.tif to Google Drive folder.
# Copied 1438_planet.tif to Google Drive folder.
# Copied 2211_planet.tif to Google Drive folder.
# Copied 2522_planet.tif to Google Drive folder.
# Copied 1699_planet.tif to Google Drive folder.
# Copied 2042_planet.tif to Google Drive folder.
# Copied 508_planet.tif to Google Drive folder.
# Copied 2192_planet.tif to Google Drive folder.
# Copied 1477_planet.tif to Google Drive folder.
# Copied 2646_planet.tif to Google Drive folder.
# Copied 600_planet.tif to Google Drive folder.
# Copied 2359_planet.tif to Google Drive folder.
# Copied 219_planet.tif to Google Drive folder.
# Copied 1452_planet.tif to Google Drive folder.
# Copied 2290_planet.tif to Google Drive folder.
# Copied 115_planet.tif to Google Drive folder.
# Copied 2408_planet.tif to Google Drive folder.
# Copied 2204_planet.tif to Google Drive folder.
# Copied 1850_planet.tif to Google Drive folder.
# Copied 1316_planet.tif to Google Drive folder.
# Copied 2287_planet.tif to Google Drive folder.
# Copied 2309_planet.tif to Google Drive folder.
# Copied 991_planet.tif to Google Drive folder.
# Copied 80_planet.tif to Google Drive folder.
# Copied 2095_planet.tif to Google Drive folder.
# Copied 1255_planet.tif to Google Drive folder.
# Copied 1228_planet.tif to Google Drive folder.
# Copied 1344_planet.tif to Google Drive folder.
# Copied 2325_planet.tif to Google Drive folder.
# Copied 1040_planet.tif to Google Drive folder.
# Copied 1988_planet.tif to Google Drive folder.
# Copied 1093_planet.tif to Google Drive folder.
# Copied 978_planet.tif to Google Drive folder.
# Copied 1420_planet.tif to Google Drive folder.
# Copied 873_planet.tif to Google Drive folder.
# Copied 1337_planet.tif to Google Drive folder.
# Copied 1788_planet.tif to Google Drive folder.
# Copied 1927_planet.tif to Google Drive folder.
# Copied 2167_planet.tif to Google Drive folder.
# ...
# Copied 1685_planet.tif to Google Drive folder.
# Copied 444_planet.tif to Google Drive folder.
# Copied 817_planet.tif to Google Drive folder.
# Copied 2438_planet.tif to Google Drive folder.
# Copied 1887_planet.tif to Google Drive folder.
# Copied 208_planet.tif to Google Drive folder.
# Copied 751_planet.tif to Google Drive folder.
# Copied 534_planet.tif to Google Drive folder.
# Copied 463_planet.tif to Google Drive folder.
# Copied 2593_planet.tif to Google Drive folder.
# Copied 652_planet.tif to Google Drive folder.
# Copied 1253_planet.tif to Google Drive folder.
# Copied 1694_planet.tif to Google Drive folder.
# Copied 2599_planet.tif to Google Drive folder.
# Copied 2023_planet.tif to Google Drive folder.
# Copied 1341_planet.tif to Google Drive folder.
# Copied 564_planet.tif to Google Drive folder.
# Copied 935_planet.tif to Google Drive folder.
# Copied 2399_planet.tif to Google Drive folder.
# Copied 307_planet.tif to Google Drive folder.
# Copied 954_planet.tif to Google Drive folder.
# Copied 2565_planet.tif to Google Drive folder.
# Copied 2666_planet.tif to Google Drive folder.
# Copied 1055_planet.tif to Google Drive folder.
# Copied 2344_planet.tif to Google Drive folder.
# Copied 777_planet.tif to Google Drive folder.
# Copied 158_planet.tif to Google Drive folder.
# Copied 1470_planet.tif to Google Drive folder.
# Copied 648_planet.tif to Google Drive folder.
# Copied 2084_planet.tif to Google Drive folder.
# Copied 277_planet.tif to Google Drive folder.
# Copied 1827_planet.tif to Google Drive folder.
# Copied 2339_planet.tif to Google Drive folder.
# Copied 94_planet.tif to Google Drive folder.
# Copied 2645_planet.tif to Google Drive folder.
# Copied 2629_planet.tif to Google Drive folder.
# Copied 905_planet.tif to Google Drive folder.
# Copied 1687_planet.tif to Google Drive folder.
# Copied 1385_planet.tif to Google Drive folder.
# Copied 967_planet.tif to Google Drive folder.
# Copied 1609_planet.tif to Google Drive folder.
# Copied 1744_planet.tif to Google Drive folder.
# Copied 2129_planet.tif to Google Drive folder.
# Copied 2388_planet.tif to Google Drive folder.
# Copied 565_planet.tif to Google Drive folder.
# Copied 637_planet.tif to Google Drive folder.
# Copied 883_planet.tif to Google Drive folder.
# Copied 1489_planet.tif to Google Drive folder.
# Copied 341_planet.tif to Google Drive folder.
# Copied 854_planet.tif to Google Drive folder.
# Copied 407_planet.tif to Google Drive folder.
# Copied 1752_planet.tif to Google Drive folder.
# Copied 1174_planet.tif to Google Drive folder.
# Copied 2649_planet.tif to Google Drive folder.
# Copied 1571_planet.tif to Google Drive folder.
# Copied 778_planet.tif to Google Drive folder.
# Copied 9_planet.tif to Google Drive folder.
# Copied 2594_planet.tif to Google Drive folder.
# Copied 1357_planet.tif to Google Drive folder.
# Copied 2362_planet.tif to Google Drive folder.
# Copied 149_planet.tif to Google Drive folder.
# Copied 1139_planet.tif to Google Drive folder.
# Copied 2603_planet.tif to Google Drive folder.
# Copied 584_planet.tif to Google Drive folder.
# Copied 769_planet.tif to Google Drive folder.
# Copied 1155_planet.tif to Google Drive folder.
# Copied 397_planet.tif to Google Drive folder.
# Copied 969_planet.tif to Google Drive folder.
# Copied 1746_planet.tif to Google Drive folder.
# Copied 2518_planet.tif to Google Drive folder.
# Copied 1125_planet.tif to Google Drive folder.
# Copied 2115_planet.tif to Google Drive folder.
# Copied 1042_planet.tif to Google Drive folder.
# Copied 656_planet.tif to Google Drive folder.
# Copied 329_planet.tif to Google Drive folder.
# Copied 259_planet.tif to Google Drive folder.
# Copied 2177_planet.tif to Google Drive folder.
# Copied 1884_planet.tif to Google Drive folder.
# Copied 574_planet.tif to Google Drive folder.
# Copied 374_planet.tif to Google Drive folder.
# Copied 1899_planet.tif to Google Drive folder.
# Copied 1102_planet.tif to Google Drive folder.
# Copied 285_planet.tif to Google Drive folder.
# Copied 938_planet.tif to Google Drive folder.
# Copied 1935_planet.tif to Google Drive folder.
# Copied 10_planet.tif to Google Drive folder.
# Copied 1921_planet.tif to Google Drive folder.
# Copied 2080_planet.tif to Google Drive folder.
# Copied 446_planet.tif to Google Drive folder.
# Copied 1321_planet.tif to Google Drive folder.
# Copied 792_planet.tif to Google Drive folder.
# Copied 1429_planet.tif to Google Drive folder.
# Copied 1863_planet.tif to Google Drive folder.
# Copied 1382_planet.tif to Google Drive folder.
# Copied 525_planet.tif to Google Drive folder.
# Copied 2001_planet.tif to Google Drive folder.
# Copied 511_planet.tif to Google Drive folder.
# Copied 287_planet.tif to Google Drive folder.
# Copied 226_planet.tif to Google Drive folder.
# Copied 964_planet.tif to Google Drive folder.
# Copied 1068_planet.tif to Google Drive folder.
# Copied 2468_planet.tif to Google Drive folder.
# Copied 98_planet.tif to Google Drive folder.
# Copied 1130_planet.tif to Google Drive folder.
# Copied 214_planet.tif to Google Drive folder.
# Copied 7_planet.tif to Google Drive folder.
# Copied 673_planet.tif to Google Drive folder.
# Copied 507_planet.tif to Google Drive folder.
# Copied 96_planet.tif to Google Drive folder.
# Copied 1834_planet.tif to Google Drive folder.
# Copied 1229_planet.tif to Google Drive folder.
# Copied 2504_planet.tif to Google Drive folder.
# Copied 701_planet.tif to Google Drive folder.
# Copied 2394_planet.tif to Google Drive folder.
# Copied 758_planet.tif to Google Drive folder.
# Copied 890_planet.tif to Google Drive folder.
# Copied 1232_planet.tif to Google Drive folder.
# Copied 1403_planet.tif to Google Drive folder.
# Copied 639_planet.tif to Google Drive folder.
# Copied 1799_planet.tif to Google Drive folder.
# Copied 1247_planet.tif to Google Drive folder.
# Copied 1077_planet.tif to Google Drive folder.
# Copied 2259_planet.tif to Google Drive folder.
# Copied 2425_planet.tif to Google Drive folder.
# Copied 2405_planet.tif to Google Drive folder.
# Copied 2376_planet.tif to Google Drive folder.
# Copied 1543_planet.tif to Google Drive folder.
# Copied 2426_planet.tif to Google Drive folder.
# Copied 1890_planet.tif to Google Drive folder.
# Copied 260_planet.tif to Google Drive folder.
# Copied 1715_planet.tif to Google Drive folder.
# Copied 402_planet.tif to Google Drive folder.
# Copied 2328_planet.tif to Google Drive folder.
# Copied 636_planet.tif to Google Drive folder.
# Copied 966_planet.tif to Google Drive folder.
# Copied 1598_planet.tif to Google Drive folder.
# Copied 607_planet.tif to Google Drive folder.
# Copied 1519_planet.tif to Google Drive folder.
# Copied 1879_planet.tif to Google Drive folder.
# Copied 269_planet.tif to Google Drive folder.
# Copied 1132_planet.tif to Google Drive folder.
# Copied 1367_planet.tif to Google Drive folder.
# Copied 2265_planet.tif to Google Drive folder.
# Copied 1061_planet.tif to Google Drive folder.
# Copied 822_planet.tif to Google Drive folder.
# Copied 660_planet.tif to Google Drive folder.
# Copied 290_planet.tif to Google Drive folder.
# Copied 2165_planet.tif to Google Drive folder.
# Copied 181_planet.tif to Google Drive folder.
# Copied 590_planet.tif to Google Drive folder.
# Copied 2519_planet.tif to Google Drive folder.
# Copied 202_planet.tif to Google Drive folder.
# Copied 644_planet.tif to Google Drive folder.
# Copied 23_planet.tif to Google Drive folder.
# Copied 2549_planet.tif to Google Drive folder.
# Copied 342_planet.tif to Google Drive folder.
# Copied 1073_planet.tif to Google Drive folder.
# Copied 57_planet.tif to Google Drive folder.
# Copied 742_planet.tif to Google Drive folder.
# Copied 2216_planet.tif to Google Drive folder.
# Copied 1873_planet.tif to Google Drive folder.
# Copied 782_planet.tif to Google Drive folder.
# Copied 1271_planet.tif to Google Drive folder.
# Copied 750_planet.tif to Google Drive folder.
# Copied 1777_planet.tif to Google Drive folder.
# Copied 2534_planet.tif to Google Drive folder.
# Copied 1688_planet.tif to Google Drive folder.
# Copied 2542_planet.tif to Google Drive folder.
# Copied 857_planet.tif to Google Drive folder.
# Copied 2492_planet.tif to Google Drive folder.
# Copied 494_planet.tif to Google Drive folder.
# Copied 604_planet.tif to Google Drive folder.
# Copied 1506_planet.tif to Google Drive folder.
# Copied 188_planet.tif to Google Drive folder.
# Copied 240_planet.tif to Google Drive folder.
# Copied 2429_planet.tif to Google Drive folder.
# Copied 1647_planet.tif to Google Drive folder.
# Copied 308_planet.tif to Google Drive folder.
# Copied 2374_planet.tif to Google Drive folder.
# Copied 236_planet.tif to Google Drive folder.
# Copied 825_planet.tif to Google Drive folder.
# Copied 676_planet.tif to Google Drive folder.
# Copied 1667_planet.tif to Google Drive folder.
# Copied 1196_planet.tif to Google Drive folder.
# Copied 807_planet.tif to Google Drive folder.
# Copied 932_planet.tif to Google Drive folder.
# Copied 224_planet.tif to Google Drive folder.
# Copied 279_planet.tif to Google Drive folder.
# Copied 1515_planet.tif to Google Drive folder.
# Copied 52_planet.tif to Google Drive folder.
# Copied 2338_planet.tif to Google Drive folder.
# Copied 1762_planet.tif to Google Drive folder.
# Copied 716_planet.tif to Google Drive folder.
# Copied 2609_planet.tif to Google Drive folder.
# Copied 844_planet.tif to Google Drive folder.
# Copied 1016_planet.tif to Google Drive folder.
# Copied 813_planet.tif to Google Drive folder.
# Copied 733_planet.tif to Google Drive folder.
# Copied 2623_planet.tif to Google Drive folder.
# Copied 2600_planet.tif to Google Drive folder.
# Copied 2546_planet.tif to Google Drive folder.
# Copied 2268_planet.tif to Google Drive folder.
# Copied 1507_planet.tif to Google Drive folder.
# Copied 2074_planet.tif to Google Drive folder.
# Copied 532_planet.tif to Google Drive folder.
# Copied 2509_planet.tif to Google Drive folder.
# Copied 1824_planet.tif to Google Drive folder.
# Copied 1724_planet.tif to Google Drive folder.
# Copied 459_planet.tif to Google Drive folder.
# Copied 1090_planet.tif to Google Drive folder.
# Copied 901_planet.tif to Google Drive folder.
# Copied 1441_planet.tif to Google Drive folder.
# Copied 2175_planet.tif to Google Drive folder.
# Copied 144_planet.tif to Google Drive folder.
# Copied 2282_planet.tif to Google Drive folder.
# Copied 1288_planet.tif to Google Drive folder.
# Copied 197_planet.tif to Google Drive folder.
# Copied 1521_planet.tif to Google Drive folder.
# Copied 2236_planet.tif to Google Drive folder.
# Copied 432_planet.tif to Google Drive folder.
# Copied 2219_planet.tif to Google Drive folder.
# Copied 105_planet.tif to Google Drive folder.
# Copied 457_planet.tif to Google Drive folder.
# Copied 578_planet.tif to Google Drive folder.
# Copied 1706_planet.tif to Google Drive folder.
# Copied 1987_planet.tif to Google Drive folder.
# Copied 1929_planet.tif to Google Drive folder.
# Copied 2559_planet.tif to Google Drive folder.
# Copied 2146_planet.tif to Google Drive folder.
# Copied 1696_planet.tif to Google Drive folder.
# Copied 868_planet.tif to Google Drive folder.
# Copied 2582_planet.tif to Google Drive folder.
# Copied 2163_planet.tif to Google Drive folder.
# Copied 2657_planet.tif to Google Drive folder.
# Copied 275_planet.tif to Google Drive folder.
# Copied 1110_planet.tif to Google Drive folder.
# Copied 558_planet.tif to Google Drive folder.
# Copied 832_planet.tif to Google Drive folder.
# Copied 2554_planet.tif to Google Drive folder.
# Copied 71_planet.tif to Google Drive folder.
# Copied 504_planet.tif to Google Drive folder.
# Copied 1160_planet.tif to Google Drive folder.
# Copied 1878_planet.tif to Google Drive folder.
# Copied 708_planet.tif to Google Drive folder.
# Copied 1334_planet.tif to Google Drive folder.
# Copied 893_planet.tif to Google Drive folder.
# Copied 1081_planet.tif to Google Drive folder.
# Copied 1900_planet.tif to Google Drive folder.
# Copied 177_planet.tif to Google Drive folder.
# Copied 2557_planet.tif to Google Drive folder.
# Copied 761_planet.tif to Google Drive folder.
# Copied 78_planet.tif to Google Drive folder.
# Copied 2292_planet.tif to Google Drive folder.
# Copied 668_planet.tif to Google Drive folder.
# Copied 141_planet.tif to Google Drive folder.
# Copied 1621_planet.tif to Google Drive folder.
# Copied 1089_planet.tif to Google Drive folder.
# Copied 2372_planet.tif to Google Drive folder.
# Copied 2610_planet.tif to Google Drive folder.
# Copied 2008_planet.tif to Google Drive folder.
# Copied 1214_planet.tif to Google Drive folder.
# Copied 2264_planet.tif to Google Drive folder.
# Copied 1408_planet.tif to Google Drive folder.
# Copied 772_planet.tif to Google Drive folder.
# Copied 1372_planet.tif to Google Drive folder.
# Copied 363_planet.tif to Google Drive folder.
# Copied 842_planet.tif to Google Drive folder.
# Copied 1796_planet.tif to Google Drive folder.
# Copied 1870_planet.tif to Google Drive folder.
# Copied 1010_planet.tif to Google Drive folder.
# Copied 462_planet.tif to Google Drive folder.
# Copied 352_planet.tif to Google Drive folder.
# Copied 783_planet.tif to Google Drive folder.
# Copied 206_planet.tif to Google Drive folder.
# Copied 2181_planet.tif to Google Drive folder.
# Copied 2511_planet.tif to Google Drive folder.
# Copied 2488_planet.tif to Google Drive folder.
# Copied 248_planet.tif to Google Drive folder.
# Copied 1218_planet.tif to Google Drive folder.
# Copied 1672_planet.tif to Google Drive folder.
# Copied 2092_planet.tif to Google Drive folder.
# Copied 1885_planet.tif to Google Drive folder.
# Copied 1658_planet.tif to Google Drive folder.
# Copied 1965_planet.tif to Google Drive folder.
# Copied 1638_planet.tif to Google Drive folder.
# Copied 2384_planet.tif to Google Drive folder.
# Copied 975_planet.tif to Google Drive folder.
# Copied 464_planet.tif to Google Drive folder.
# Copied 1734_planet.tif to Google Drive folder.
# Copied 1339_planet.tif to Google Drive folder.
# Copied 1473_planet.tif to Google Drive folder.
# Copied 5_planet.tif to Google Drive folder.
# Copied 2308_planet.tif to Google Drive folder.
# Copied 289_planet.tif to Google Drive folder.
# Copied 2606_planet.tif to Google Drive folder.
# Copied 1862_planet.tif to Google Drive folder.
# Copied 1135_planet.tif to Google Drive folder.
# Copied 1350_planet.tif to Google Drive folder.
# Copied 1275_planet.tif to Google Drive folder.
# Copied 1225_planet.tif to Google Drive folder.
# Copied 1725_planet.tif to Google Drive folder.
# Copied 1427_planet.tif to Google Drive folder.
# Copied 146_planet.tif to Google Drive folder.
# Copied 753_planet.tif to Google Drive folder.
# Copied 683_planet.tif to Google Drive folder.
# Copied 284_planet.tif to Google Drive folder.
# Copied 2075_planet.tif to Google Drive folder.
# Copied 1259_planet.tif to Google Drive folder.
# Copied 1402_planet.tif to Google Drive folder.
# Copied 841_planet.tif to Google Drive folder.
# Copied 1909_planet.tif to Google Drive folder.
# Copied 2427_planet.tif to Google Drive folder.
# Copied 2577_planet.tif to Google Drive folder.
# Copied 694_planet.tif to Google Drive folder.
# Copied 133_planet.tif to Google Drive folder.
# Copied 1864_planet.tif to Google Drive folder.
# Copied 2401_planet.tif to Google Drive folder.
# Copied 2298_planet.tif to Google Drive folder.
# Copied 1781_planet.tif to Google Drive folder.
# Copied 1825_planet.tif to Google Drive folder.
# Copied 339_planet.tif to Google Drive folder.
# Copied 693_planet.tif to Google Drive folder.
# Copied 400_planet.tif to Google Drive folder.
# Copied 1610_planet.tif to Google Drive folder.
# Copied 999_planet.tif to Google Drive folder.
# Copied 906_planet.tif to Google Drive folder.
# Copied 1713_planet.tif to Google Drive folder.
# Copied 2270_planet.tif to Google Drive folder.
# Copied 835_planet.tif to Google Drive folder.
# Copied 2150_planet.tif to Google Drive folder.
# Copied 1526_planet.tif to Google Drive folder.
# Copied 1582_planet.tif to Google Drive folder.
# Copied 1276_planet.tif to Google Drive folder.
# Copied 2558_planet.tif to Google Drive folder.
# Copied 2367_planet.tif to Google Drive folder.
# Copied 210_planet.tif to Google Drive folder.
# Copied 2139_planet.tif to Google Drive folder.
# Copied 282_planet.tif to Google Drive folder.
# Copied 740_planet.tif to Google Drive folder.
# Copied 468_planet.tif to Google Drive folder.
# Copied 522_planet.tif to Google Drive folder.
# Copied 1086_planet.tif to Google Drive folder.
# Copied 88_planet.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/images_2019/"
tif_source = "/content/image/content/exports/utm4_2019/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 1792_planet.tif to Google Drive folder.
# Copied 2208_planet.tif to Google Drive folder.
# Copied 559_planet.tif to Google Drive folder.
# Copied 2022_planet.tif to Google Drive folder.
# Copied 2578_planet.tif to Google Drive folder.
# Copied 995_planet.tif to Google Drive folder.
# Copied 2060_planet.tif to Google Drive folder.
# Copied 1612_planet.tif to Google Drive folder.
# Copied 895_planet.tif to Google Drive folder.
# Copied 475_planet.tif to Google Drive folder.
# Copied 1618_planet.tif to Google Drive folder.
# Copied 100_planet.tif to Google Drive folder.
# Copied 1004_planet.tif to Google Drive folder.
# Copied 2570_planet.tif to Google Drive folder.
# Copied 1978_planet.tif to Google Drive folder.
# Copied 362_planet.tif to Google Drive folder.
# Copied 2364_planet.tif to Google Drive folder.
# Copied 1191_planet.tif to Google Drive folder.
# Copied 1001_planet.tif to Google Drive folder.
# Copied 1976_planet.tif to Google Drive folder.
# Copied 1398_planet.tif to Google Drive folder.
# Copied 193_planet.tif to Google Drive folder.
# Copied 515_planet.tif to Google Drive folder.
# Copied 2340_planet.tif to Google Drive folder.
# Copied 55_planet.tif to Google Drive folder.
# Copied 1114_planet.tif to Google Drive folder.
# Copied 2607_planet.tif to Google Drive folder.
# Copied 2068_planet.tif to Google Drive folder.
# Copied 1652_planet.tif to Google Drive folder.
# Copied 2201_planet.tif to Google Drive folder.
# Copied 2138_planet.tif to Google Drive folder.
# Copied 1812_planet.tif to Google Drive folder.
# Copied 1414_planet.tif to Google Drive folder.
# Copied 1906_planet.tif to Google Drive folder.
# Copied 35_planet.tif to Google Drive folder.
# Copied 2025_planet.tif to Google Drive folder.
# Copied 1303_planet.tif to Google Drive folder.
# Copied 2658_planet.tif to Google Drive folder.
# Copied 435_planet.tif to Google Drive folder.
# Copied 1029_planet.tif to Google Drive folder.
# Copied 1979_planet.tif to Google Drive folder.
# Copied 851_planet.tif to Google Drive folder.
# Copied 505_planet.tif to Google Drive folder.
# Copied 1333_planet.tif to Google Drive folder.
# Copied 349_planet.tif to Google Drive folder.
# Copied 727_planet.tif to Google Drive folder.
# Copied 2223_planet.tif to Google Drive folder.
# Copied 50_planet.tif to Google Drive folder.
# Copied 11_planet.tif to Google Drive folder.
# Copied 2346_planet.tif to Google Drive folder.
# Copied 1296_planet.tif to Google Drive folder.
# Copied 512_planet.tif to Google Drive folder.
# Copied 882_planet.tif to Google Drive folder.
# Copied 2056_planet.tif to Google Drive folder.
# Copied 1998_planet.tif to Google Drive folder.
# Copied 1128_planet.tif to Google Drive folder.
# Copied 2189_planet.tif to Google Drive folder.
# Copied 2664_planet.tif to Google Drive folder.
# Copied 544_planet.tif to Google Drive folder.
# Copied 613_planet.tif to Google Drive folder.
# Copied 2567_planet.tif to Google Drive folder.
# Copied 2131_planet.tif to Google Drive folder.
# Copied 699_planet.tif to Google Drive folder.
# Copied 1164_planet.tif to Google Drive folder.
# Copied 638_planet.tif to Google Drive folder.
# Copied 2620_planet.tif to Google Drive folder.
# Copied 538_planet.tif to Google Drive folder.
# Copied 2525_planet.tif to Google Drive folder.
# Copied 99_planet.tif to Google Drive folder.
# Copied 1860_planet.tif to Google Drive folder.
# Copied 1819_planet.tif to Google Drive folder.
# Copied 1325_planet.tif to Google Drive folder.
# Copied 403_planet.tif to Google Drive folder.
# Copied 2392_planet.tif to Google Drive folder.
# Copied 22_planet.tif to Google Drive folder.
# Copied 1653_planet.tif to Google Drive folder.
# Copied 1901_planet.tif to Google Drive folder.
# Copied 439_planet.tif to Google Drive folder.
# Copied 129_planet.tif to Google Drive folder.
# Copied 989_planet.tif to Google Drive folder.
# Copied 489_planet.tif to Google Drive folder.
# Copied 2028_planet.tif to Google Drive folder.
# Copied 1574_planet.tif to Google Drive folder.
# Copied 510_planet.tif to Google Drive folder.
# Copied 977_planet.tif to Google Drive folder.
# Copied 119_planet.tif to Google Drive folder.
# Copied 2608_planet.tif to Google Drive folder.
# Copied 1855_planet.tif to Google Drive folder.
# Copied 1625_planet.tif to Google Drive folder.
# Copied 1649_planet.tif to Google Drive folder.
# Copied 445_planet.tif to Google Drive folder.
# Copied 1336_planet.tif to Google Drive folder.
# Copied 108_planet.tif to Google Drive folder.
# Copied 1729_planet.tif to Google Drive folder.
# Copied 726_planet.tif to Google Drive folder.
# Copied 2244_planet.tif to Google Drive folder.
# Copied 988_planet.tif to Google Drive folder.
# Copied 2263_planet.tif to Google Drive folder.
# Copied 1895_planet.tif to Google Drive folder.
# Copied 585_planet.tif to Google Drive folder.
# Copied 2547_planet.tif to Google Drive folder.
# Copied 324_planet.tif to Google Drive folder.
# Copied 1165_planet.tif to Google Drive folder.
# Copied 1702_planet.tif to Google Drive folder.
# Copied 803_planet.tif to Google Drive folder.
# Copied 791_planet.tif to Google Drive folder.
# Copied 998_planet.tif to Google Drive folder.
# Copied 472_planet.tif to Google Drive folder.
# Copied 68_planet.tif to Google Drive folder.
# Copied 1891_planet.tif to Google Drive folder.
# Copied 610_planet.tif to Google Drive folder.
# Copied 2104_planet.tif to Google Drive folder.
# Copied 756_planet.tif to Google Drive folder.
# Copied 2348_planet.tif to Google Drive folder.
# Copied 89_planet.tif to Google Drive folder.
# Copied 1230_planet.tif to Google Drive folder.
# Copied 1368_planet.tif to Google Drive folder.
# Copied 1651_planet.tif to Google Drive folder.
# Copied 956_planet.tif to Google Drive folder.
# Copied 327_planet.tif to Google Drive folder.
# Copied 1776_planet.tif to Google Drive folder.
# Copied 2326_planet.tif to Google Drive folder.
# Copied 476_planet.tif to Google Drive folder.
# Copied 587_planet.tif to Google Drive folder.
# Copied 2579_planet.tif to Google Drive folder.
# Copied 885_planet.tif to Google Drive folder.
# Copied 793_planet.tif to Google Drive folder.
# Copied 1313_planet.tif to Google Drive folder.
# Copied 2085_planet.tif to Google Drive folder.
# Copied 1269_planet.tif to Google Drive folder.
# Copied 848_planet.tif to Google Drive folder.
# Copied 335_planet.tif to Google Drive folder.
# Copied 1501_planet.tif to Google Drive folder.
# Copied 1424_planet.tif to Google Drive folder.
# Copied 1298_planet.tif to Google Drive folder.
# Copied 1223_planet.tif to Google Drive folder.
# Copied 2118_planet.tif to Google Drive folder.
# Copied 601_planet.tif to Google Drive folder.
# Copied 2588_planet.tif to Google Drive folder.
# Copied 389_planet.tif to Google Drive folder.
# Copied 1116_planet.tif to Google Drive folder.
# Copied 469_planet.tif to Google Drive folder.
# Copied 2196_planet.tif to Google Drive folder.
# Copied 1282_planet.tif to Google Drive folder.
# Copied 2182_planet.tif to Google Drive folder.
# Copied 2380_planet.tif to Google Drive folder.
# Copied 1816_planet.tif to Google Drive folder.
# Copied 2295_planet.tif to Google Drive folder.
# Copied 2652_planet.tif to Google Drive folder.
# Copied 1412_planet.tif to Google Drive folder.
# Copied 318_planet.tif to Google Drive folder.
# Copied 1179_planet.tif to Google Drive folder.
# Copied 496_planet.tif to Google Drive folder.
# Copied 2038_planet.tif to Google Drive folder.
# Copied 2071_planet.tif to Google Drive folder.
# Copied 2335_planet.tif to Google Drive folder.
# Copied 1143_planet.tif to Google Drive folder.
# Copied 2541_planet.tif to Google Drive folder.
# Copied 687_planet.tif to Google Drive folder.
# Copied 2081_planet.tif to Google Drive folder.
# Copied 2612_planet.tif to Google Drive folder.
# Copied 869_planet.tif to Google Drive folder.
# Copied 892_planet.tif to Google Drive folder.
# Copied 2119_planet.tif to Google Drive folder.
# Copied 330_planet.tif to Google Drive folder.
# Copied 1145_planet.tif to Google Drive folder.
# Copied 2441_planet.tif to Google Drive folder.
# Copied 819_planet.tif to Google Drive folder.
# Copied 657_planet.tif to Google Drive folder.
# Copied 715_planet.tif to Google Drive folder.
# Copied 1220_planet.tif to Google Drive folder.
# Copied 767_planet.tif to Google Drive folder.
# Copied 1119_planet.tif to Google Drive folder.
# Copied 1121_planet.tif to Google Drive folder.
# Copied 46_planet.tif to Google Drive folder.
# Copied 405_planet.tif to Google Drive folder.
# Copied 51_planet.tif to Google Drive folder.
# Copied 543_planet.tif to Google Drive folder.
# Copied 1835_planet.tif to Google Drive folder.
# Copied 2472_planet.tif to Google Drive folder.
# Copied 436_planet.tif to Google Drive folder.
# Copied 2014_planet.tif to Google Drive folder.
# Copied 596_planet.tif to Google Drive folder.
# Copied 1579_planet.tif to Google Drive folder.
# Copied 1291_planet.tif to Google Drive folder.
# Copied 570_planet.tif to Google Drive folder.
# Copied 1163_planet.tif to Google Drive folder.
# Copied 986_planet.tif to Google Drive folder.
# Copied 1448_planet.tif to Google Drive folder.
# Copied 2618_planet.tif to Google Drive folder.
# Copied 1775_planet.tif to Google Drive folder.
# Copied 189_planet.tif to Google Drive folder.
# Copied 567_planet.tif to Google Drive folder.
# Copied 311_planet.tif to Google Drive folder.
# Copied 1331_planet.tif to Google Drive folder.
# Copied 1632_planet.tif to Google Drive folder.
# Copied 1036_planet.tif to Google Drive folder.
# Copied 2149_planet.tif to Google Drive folder.
# Copied 2035_planet.tif to Google Drive folder.
# Copied 116_planet.tif to Google Drive folder.
# Copied 1493_planet.tif to Google Drive folder.
# Copied 2483_planet.tif to Google Drive folder.
# Copied 493_planet.tif to Google Drive folder.
# Copied 823_planet.tif to Google Drive folder.
# Copied 47_planet.tif to Google Drive folder.
# Copied 351_planet.tif to Google Drive folder.
# Copied 45_planet.tif to Google Drive folder.
# Copied 1184_planet.tif to Google Drive folder.
# Copied 2301_planet.tif to Google Drive folder.
# Copied 2453_planet.tif to Google Drive folder.
# Copied 886_planet.tif to Google Drive folder.
# Copied 586_planet.tif to Google Drive folder.
# Copied 2544_planet.tif to Google Drive folder.
# Copied 1034_planet.tif to Google Drive folder.
# Copied 2552_planet.tif to Google Drive folder.
# Copied 1616_planet.tif to Google Drive folder.
# Copied 1945_planet.tif to Google Drive folder.
# Copied 2466_planet.tif to Google Drive folder.
# Copied 1684_planet.tif to Google Drive folder.
# Copied 2628_planet.tif to Google Drive folder.
# Copied 2108_planet.tif to Google Drive folder.
# Copied 1772_planet.tif to Google Drive folder.
# Copied 246_planet.tif to Google Drive folder.
# Copied 866_planet.tif to Google Drive folder.
# Copied 1293_planet.tif to Google Drive folder.
# Copied 1457_planet.tif to Google Drive folder.
# Copied 1817_planet.tif to Google Drive folder.
# Copied 2350_planet.tif to Google Drive folder.
# Copied 217_planet.tif to Google Drive folder.
# Copied 2112_planet.tif to Google Drive folder.
# Copied 1512_planet.tif to Google Drive folder.
# Copied 2128_planet.tif to Google Drive folder.
# Copied 2566_planet.tif to Google Drive folder.
# Copied 1808_planet.tif to Google Drive folder.
# Copied 1390_planet.tif to Google Drive folder.
# Copied 1747_planet.tif to Google Drive folder.
# Copied 1765_planet.tif to Google Drive folder.
# Copied 1300_planet.tif to Google Drive folder.
# Copied 2152_planet.tif to Google Drive folder.
# Copied 1312_planet.tif to Google Drive folder.
# Copied 1281_planet.tif to Google Drive folder.
# Copied 1454_planet.tif to Google Drive folder.
# Copied 1531_planet.tif to Google Drive folder.
# Copied 2436_planet.tif to Google Drive folder.
# Copied 1883_planet.tif to Google Drive folder.
# Copied 828_planet.tif to Google Drive folder.
# Copied 230_planet.tif to Google Drive folder.
# Copied 990_planet.tif to Google Drive folder.
# Copied 2010_planet.tif to Google Drive folder.
# Copied 231_planet.tif to Google Drive folder.
# Copied 82_planet.tif to Google Drive folder.
# Copied 2275_planet.tif to Google Drive folder.
# Copied 1405_planet.tif to Google Drive folder.
# Copied 1363_planet.tif to Google Drive folder.
# Copied 2514_planet.tif to Google Drive folder.
# Copied 1437_planet.tif to Google Drive folder.
# Copied 1857_planet.tif to Google Drive folder.
# Copied 748_planet.tif to Google Drive folder.
# Copied 839_planet.tif to Google Drive folder.
# Copied 1067_planet.tif to Google Drive folder.
# Copied 1340_planet.tif to Google Drive folder.
# Copied 741_planet.tif to Google Drive folder.
# Copied 1709_planet.tif to Google Drive folder.
# Copied 1206_planet.tif to Google Drive folder.
# Copied 136_planet.tif to Google Drive folder.
# Copied 179_planet.tif to Google Drive folder.
# Copied 460_planet.tif to Google Drive folder.
# Copied 713_planet.tif to Google Drive folder.
# Copied 675_planet.tif to Google Drive folder.
# Copied 1941_planet.tif to Google Drive folder.
# Copied 1192_planet.tif to Google Drive folder.
# Copied 2533_planet.tif to Google Drive folder.
# Copied 2319_planet.tif to Google Drive folder.
# Copied 1487_planet.tif to Google Drive folder.
# Copied 266_planet.tif to Google Drive folder.
# Copied 1439_planet.tif to Google Drive folder.
# Copied 528_planet.tif to Google Drive folder.
# Copied 273_planet.tif to Google Drive folder.
# Copied 1274_planet.tif to Google Drive folder.
# Copied 2471_planet.tif to Google Drive folder.
# Copied 1662_planet.tif to Google Drive folder.
# Copied 1549_planet.tif to Google Drive folder.
# Copied 749_planet.tif to Google Drive folder.
# Copied 1240_planet.tif to Google Drive folder.
# Copied 1851_planet.tif to Google Drive folder.
# Copied 1594_planet.tif to Google Drive folder.
# Copied 690_planet.tif to Google Drive folder.
# Copied 145_planet.tif to Google Drive folder.
# Copied 575_planet.tif to Google Drive folder.
# Copied 2212_planet.tif to Google Drive folder.
# Copied 1727_planet.tif to Google Drive folder.
# Copied 1791_planet.tif to Google Drive folder.
# Copied 903_planet.tif to Google Drive folder.
# Copied 1435_planet.tif to Google Drive folder.
# Copied 752_planet.tif to Google Drive folder.
# Copied 1867_planet.tif to Google Drive folder.
# Copied 513_planet.tif to Google Drive folder.
# Copied 276_planet.tif to Google Drive folder.
# Copied 244_planet.tif to Google Drive folder.
# Copied 245_planet.tif to Google Drive folder.
# Copied 419_planet.tif to Google Drive folder.
# Copied 2164_planet.tif to Google Drive folder.
# Copied 2169_planet.tif to Google Drive folder.
# Copied 1131_planet.tif to Google Drive folder.
# Copied 2332_planet.tif to Google Drive folder.
# Copied 2174_planet.tif to Google Drive folder.
# Copied 1380_planet.tif to Google Drive folder.
# Copied 714_planet.tif to Google Drive folder.
# Copied 306_planet.tif to Google Drive folder.
# Copied 1309_planet.tif to Google Drive folder.
# Copied 2458_planet.tif to Google Drive folder.
# Copied 760_planet.tif to Google Drive folder.
# Copied 1242_planet.tif to Google Drive folder.
# Copied 79_planet.tif to Google Drive folder.
# Copied 1449_planet.tif to Google Drive folder.
# Copied 1346_planet.tif to Google Drive folder.
# Copied 2007_planet.tif to Google Drive folder.
# Copied 1295_planet.tif to Google Drive folder.
# Copied 1527_planet.tif to Google Drive folder.
# Copied 1035_planet.tif to Google Drive folder.
# Copied 1619_planet.tif to Google Drive folder.
# Copied 702_planet.tif to Google Drive folder.
# Copied 2114_planet.tif to Google Drive folder.
# Copied 1063_planet.tif to Google Drive folder.
# Copied 312_planet.tif to Google Drive folder.
# Copied 2307_planet.tif to Google Drive folder.
# Copied 722_planet.tif to Google Drive folder.
# Copied 416_planet.tif to Google Drive folder.
# Copied 987_planet.tif to Google Drive folder.
# Copied 2125_planet.tif to Google Drive folder.
# Copied 2032_planet.tif to Google Drive folder.
# Copied 366_planet.tif to Google Drive folder.
# Copied 2141_planet.tif to Google Drive folder.
# Copied 1319_planet.tif to Google Drive folder.
# Copied 2478_planet.tif to Google Drive folder.
# Copied 1074_planet.tif to Google Drive folder.
# Copied 109_planet.tif to Google Drive folder.
# Copied 1021_planet.tif to Google Drive folder.
# Copied 2059_planet.tif to Google Drive folder.
# Copied 258_planet.tif to Google Drive folder.
# Copied 1689_planet.tif to Google Drive folder.
# Copied 502_planet.tif to Google Drive folder.
# Copied 1529_planet.tif to Google Drive folder.
# Copied 1195_planet.tif to Google Drive folder.
# Copied 1751_planet.tif to Google Drive folder.
# Copied 27_planet.tif to Google Drive folder.
# Copied 319_planet.tif to Google Drive folder.
# Copied 1434_planet.tif to Google Drive folder.
# Copied 491_planet.tif to Google Drive folder.
# Copied 1567_planet.tif to Google Drive folder.
# Copied 1924_planet.tif to Google Drive folder.
# Copied 1664_planet.tif to Google Drive folder.
# Copied 28_planet.tif to Google Drive folder.
# Copied 781_planet.tif to Google Drive folder.
# Copied 2498_planet.tif to Google Drive folder.
# Copied 2379_planet.tif to Google Drive folder.
# Copied 1358_planet.tif to Google Drive folder.
# Copied 1551_planet.tif to Google Drive folder.
# Copied 2274_planet.tif to Google Drive folder.
# Copied 1418_planet.tif to Google Drive folder.
# Copied 1790_planet.tif to Google Drive folder.
# Copied 2214_planet.tif to Google Drive folder.
# Copied 370_planet.tif to Google Drive folder.
# Copied 1912_planet.tif to Google Drive folder.
# Copied 1494_planet.tif to Google Drive folder.
# Copied 274_planet.tif to Google Drive folder.
# Copied 1083_planet.tif to Google Drive folder.
# Copied 529_planet.tif to Google Drive folder.
# Copied 1002_planet.tif to Google Drive folder.
# Copied 2197_planet.tif to Google Drive folder.
# Copied 1989_planet.tif to Google Drive folder.
# Copied 1560_planet.tif to Google Drive folder.
# Copied 156_planet.tif to Google Drive folder.
# Copied 533_planet.tif to Google Drive folder.
# Copied 1157_planet.tif to Google Drive folder.
# Copied 646_planet.tif to Google Drive folder.
# Copied 1371_planet.tif to Google Drive folder.
# Copied 447_planet.tif to Google Drive folder.
# Copied 1048_planet.tif to Google Drive folder.
# Copied 888_planet.tif to Google Drive folder.
# Copied 2501_planet.tif to Google Drive folder.
# Copied 2304_planet.tif to Google Drive folder.
# Copied 1000_planet.tif to Google Drive folder.
# Copied 1008_planet.tif to Google Drive folder.
# Copied 1722_planet.tif to Google Drive folder.
# Copied 2508_planet.tif to Google Drive folder.
# Copied 1492_planet.tif to Google Drive folder.
# Copied 1972_planet.tif to Google Drive folder.
# Copied 2356_planet.tif to Google Drive folder.
# Copied 192_planet.tif to Google Drive folder.
# Copied 717_planet.tif to Google Drive folder.
# Copied 328_planet.tif to Google Drive folder.
# Copied 2497_planet.tif to Google Drive folder.
# Copied 2455_planet.tif to Google Drive folder.
# Copied 2241_planet.tif to Google Drive folder.
# Copied 114_planet.tif to Google Drive folder.
# Copied 2218_planet.tif to Google Drive folder.
# Copied 1585_planet.tif to Google Drive folder.
# Copied 2538_planet.tif to Google Drive folder.
# Copied 2284_planet.tif to Google Drive folder.
# Copied 808_planet.tif to Google Drive folder.
# Copied 359_planet.tif to Google Drive folder.
# Copied 1896_planet.tif to Google Drive folder.
# Copied 1142_planet.tif to Google Drive folder.
# Copied 1198_planet.tif to Google Drive folder.
# Copied 2583_planet.tif to Google Drive folder.
# Copied 295_planet.tif to Google Drive folder.
# Copied 1033_planet.tif to Google Drive folder.
# Copied 2420_planet.tif to Google Drive folder.
# Copied 1013_planet.tif to Google Drive folder.
# Copied 968_planet.tif to Google Drive folder.
# Copied 1401_planet.tif to Google Drive folder.
# Copied 1252_planet.tif to Google Drive folder.
# Copied 981_planet.tif to Google Drive folder.
# Copied 898_planet.tif to Google Drive folder.
# Copied 2485_planet.tif to Google Drive folder.
# Copied 647_planet.tif to Google Drive folder.
# Copied 2200_planet.tif to Google Drive folder.
# Copied 1849_planet.tif to Google Drive folder.
# Copied 211_planet.tif to Google Drive folder.
# Copied 1838_planet.tif to Google Drive folder.
# Copied 1951_planet.tif to Google Drive folder.
# Copied 1541_planet.tif to Google Drive folder.
# Copied 1606_planet.tif to Google Drive folder.
# Copied 2345_planet.tif to Google Drive folder.
# Copied 1914_planet.tif to Google Drive folder.
# Copied 143_planet.tif to Google Drive folder.
# Copied 458_planet.tif to Google Drive folder.
# Copied 2058_planet.tif to Google Drive folder.
# Copied 2491_planet.tif to Google Drive folder.
# Copied 2373_planet.tif to Google Drive folder.
# Copied 1757_planet.tif to Google Drive folder.
# Copied 1261_planet.tif to Google Drive folder.
# Copied 1982_planet.tif to Google Drive folder.
# Copied 667_planet.tif to Google Drive folder.
# Copied 1260_planet.tif to Google Drive folder.
# Copied 718_planet.tif to Google Drive folder.
# Copied 1759_planet.tif to Google Drive folder.
# Copied 92_planet.tif to Google Drive folder.
# Copied 1674_planet.tif to Google Drive folder.
# Copied 1075_planet.tif to Google Drive folder.
# Copied 2161_planet.tif to Google Drive folder.
# Copied 2639_planet.tif to Google Drive folder.
# Copied 190_planet.tif to Google Drive folder.
# Copied 1604_planet.tif to Google Drive folder.
# Copied 1853_planet.tif to Google Drive folder.
# Copied 2153_planet.tif to Google Drive folder.
# Copied 152_planet.tif to Google Drive folder.
# Copied 826_planet.tif to Google Drive folder.
# Copied 2020_planet.tif to Google Drive folder.
# Copied 2322_planet.tif to Google Drive folder.
# Copied 2329_planet.tif to Google Drive folder.
# Copied 2631_planet.tif to Google Drive folder.
# Copied 1939_planet.tif to Google Drive folder.
# Copied 1406_planet.tif to Google Drive folder.
# Copied 1151_planet.tif to Google Drive folder.
# Copied 2352_planet.tif to Google Drive folder.
# Copied 385_planet.tif to Google Drive folder.
# Copied 2581_planet.tif to Google Drive folder.
# Copied 1779_planet.tif to Google Drive folder.
# Copied 216_planet.tif to Google Drive folder.
# Copied 1091_planet.tif to Google Drive folder.
# Copied 2324_planet.tif to Google Drive folder.
# Copied 484_planet.tif to Google Drive folder.
# Copied 481_planet.tif to Google Drive folder.
# Copied 1249_planet.tif to Google Drive folder.
# Copied 2107_planet.tif to Google Drive folder.
# Copied 1129_planet.tif to Google Drive folder.
# Copied 137_planet.tif to Google Drive folder.
# Copied 2635_planet.tif to Google Drive folder.
# Copied 26_planet.tif to Google Drive folder.
# Copied 1569_planet.tif to Google Drive folder.
# Copied 194_planet.tif to Google Drive folder.
# Copied 151_planet.tif to Google Drive folder.
# Copied 1793_planet.tif to Google Drive folder.
# Copied 1216_planet.tif to Google Drive folder.
# Copied 215_planet.tif to Google Drive folder.
# Copied 852_planet.tif to Google Drive folder.
# Copied 249_planet.tif to Google Drive folder.
# Copied 2073_planet.tif to Google Drive folder.
# Copied 1968_planet.tif to Google Drive folder.
# Copied 2454_planet.tif to Google Drive folder.
# Copied 1030_planet.tif to Google Drive folder.
# Copied 1524_planet.tif to Google Drive folder.
# Copied 1411_planet.tif to Google Drive folder.
# Copied 605_planet.tif to Google Drive folder.
# Copied 1600_planet.tif to Google Drive folder.
# Copied 789_planet.tif to Google Drive folder.
# Copied 205_planet.tif to Google Drive folder.
# Copied 1888_planet.tif to Google Drive folder.
# Copied 1272_planet.tif to Google Drive folder.
# Copied 425_planet.tif to Google Drive folder.
# Copied 696_planet.tif to Google Drive folder.
# Copied 1690_planet.tif to Google Drive folder.
# Copied 1596_planet.tif to Google Drive folder.
# Copied 771_planet.tif to Google Drive folder.
# Copied 20_planet.tif to Google Drive folder.
# Copied 877_planet.tif to Google Drive folder.
# Copied 1766_planet.tif to Google Drive folder.
# Copied 589_planet.tif to Google Drive folder.
# Copied 2273_planet.tif to Google Drive folder.
# Copied 779_planet.tif to Google Drive folder.
# Copied 1691_planet.tif to Google Drive folder.
# Copied 1837_planet.tif to Google Drive folder.
# Copied 168_planet.tif to Google Drive folder.
# Copied 1679_planet.tif to Google Drive folder.
# Copied 1467_planet.tif to Google Drive folder.
# Copied 1536_planet.tif to Google Drive folder.
# Copied 320_planet.tif to Google Drive folder.
# Copied 2126_planet.tif to Google Drive folder.
# Copied 2622_planet.tif to Google Drive folder.
# Copied 2253_planet.tif to Google Drive folder.
# Copied 1305_planet.tif to Google Drive folder.
# Copied 1996_planet.tif to Google Drive folder.
# Copied 2260_planet.tif to Google Drive folder.
# Copied 1038_planet.tif to Google Drive folder.
# Copied 867_planet.tif to Google Drive folder.
# Copied 2575_planet.tif to Google Drive folder.
# Copied 1373_planet.tif to Google Drive folder.
# Copied 1172_planet.tif to Google Drive folder.
# Copied 1009_planet.tif to Google Drive folder.
# Copied 1410_planet.tif to Google Drive folder.
# Copied 1200_planet.tif to Google Drive folder.
# Copied 2097_planet.tif to Google Drive folder.
# Copied 53_planet.tif to Google Drive folder.
# Copied 1693_planet.tif to Google Drive folder.
# Copied 1207_planet.tif to Google Drive folder.
# Copied 2385_planet.tif to Google Drive folder.
# Copied 120_planet.tif to Google Drive folder.
# Copied 577_planet.tif to Google Drive folder.
# Copied 1015_planet.tif to Google Drive folder.
# Copied 1992_planet.tif to Google Drive folder.
# Copied 1603_planet.tif to Google Drive folder.
# Copied 478_planet.tif to Google Drive folder.
# Copied 1841_planet.tif to Google Drive folder.
# Copied 2100_planet.tif to Google Drive folder.
# Copied 800_planet.tif to Google Drive folder.
# Copied 1307_planet.tif to Google Drive folder.
# Copied 2136_planet.tif to Google Drive folder.
# Copied 1918_planet.tif to Google Drive folder.
# Copied 431_planet.tif to Google Drive folder.
# Copied 1712_planet.tif to Google Drive folder.
# Copied 1511_planet.tif to Google Drive folder.
# Copied 1085_planet.tif to Google Drive folder.
# Copied 225_planet.tif to Google Drive folder.
# Copied 2333_planet.tif to Google Drive folder.
# Copied 1953_planet.tif to Google Drive folder.
# Copied 1591_planet.tif to Google Drive folder.
# Copied 112_planet.tif to Google Drive folder.
# Copied 653_planet.tif to Google Drive folder.
# Copied 786_planet.tif to Google Drive folder.
# Copied 1270_planet.tif to Google Drive folder.
# Copied 1897_planet.tif to Google Drive folder.
# Copied 1140_planet.tif to Google Drive folder.
# Copied 1535_planet.tif to Google Drive folder.
# Copied 2041_planet.tif to Google Drive folder.
# Copied 257_planet.tif to Google Drive folder.
# Copied 933_planet.tif to Google Drive folder.
# Copied 18_planet.tif to Google Drive folder.
# Copied 2595_planet.tif to Google Drive folder.
# Copied 1466_planet.tif to Google Drive folder.
# Copied 2036_planet.tif to Google Drive folder.
# Copied 2154_planet.tif to Google Drive folder.
# Copied 1330_planet.tif to Google Drive folder.
# Copied 1221_planet.tif to Google Drive folder.
# Copied 993_planet.tif to Google Drive folder.
# Copied 1463_planet.tif to Google Drive folder.
# Copied 2521_planet.tif to Google Drive folder.
# Copied 557_planet.tif to Google Drive folder.
# Copied 2660_planet.tif to Google Drive folder.
# Copied 201_planet.tif to Google Drive folder.
# Copied 200_planet.tif to Google Drive folder.
# Copied 891_planet.tif to Google Drive folder.
# Copied 1654_planet.tif to Google Drive folder.
# Copied 1136_planet.tif to Google Drive folder.
# Copied 2109_planet.tif to Google Drive folder.
# Copied 547_planet.tif to Google Drive folder.
# Copied 2470_planet.tif to Google Drive folder.
# Copied 396_planet.tif to Google Drive folder.
# Copied 1226_planet.tif to Google Drive folder.
# Copied 2550_planet.tif to Google Drive folder.
# Copied 942_planet.tif to Google Drive folder.
# Copied 1859_planet.tif to Google Drive folder.
# Copied 642_planet.tif to Google Drive folder.
# Copied 74_planet.tif to Google Drive folder.
# Copied 2404_planet.tif to Google Drive folder.
# Copied 1993_planet.tif to Google Drive folder.
# Copied 378_planet.tif to Google Drive folder.
# Copied 1758_planet.tif to Google Drive folder.
# Copied 165_planet.tif to Google Drive folder.
# Copied 1419_planet.tif to Google Drive folder.
# Copied 571_planet.tif to Google Drive folder.
# Copied 162_planet.tif to Google Drive folder.
# Copied 1525_planet.tif to Google Drive folder.
# Copied 569_planet.tif to Google Drive folder.
# Copied 2536_planet.tif to Google Drive folder.
# Copied 2532_planet.tif to Google Drive folder.
# Copied 153_planet.tif to Google Drive folder.
# Copied 2449_planet.tif to Google Drive folder.
# Copied 1432_planet.tif to Google Drive folder.
# Copied 422_planet.tif to Google Drive folder.
# Copied 411_planet.tif to Google Drive folder.
# Copied 669_planet.tif to Google Drive folder.
# Copied 1263_planet.tif to Google Drive folder.
# Copied 1922_planet.tif to Google Drive folder.
# Copied 1588_planet.tif to Google Drive folder.
# Copied 929_planet.tif to Google Drive folder.
# Copied 2662_planet.tif to Google Drive folder.
# Copied 1497_planet.tif to Google Drive folder.
# Copied 1299_planet.tif to Google Drive folder.
# Copied 896_planet.tif to Google Drive folder.
# Copied 1446_planet.tif to Google Drive folder.
# Copied 963_planet.tif to Google Drive folder.
# Copied 360_planet.tif to Google Drive folder.
# Copied 552_planet.tif to Google Drive folder.
# Copied 1287_planet.tif to Google Drive folder.
# Copied 2170_planet.tif to Google Drive folder.
# Copied 1103_planet.tif to Google Drive folder.
# Copied 1761_planet.tif to Google Drive folder.
# Copied 1364_planet.tif to Google Drive folder.
# Copied 2009_planet.tif to Google Drive folder.
# Copied 1217_planet.tif to Google Drive folder.
# Copied 1728_planet.tif to Google Drive folder.
# Copied 897_planet.tif to Google Drive folder.
# Copied 2247_planet.tif to Google Drive folder.
# Copied 878_planet.tif to Google Drive folder.
# Copied 1665_planet.tif to Google Drive folder.
# Copied 1676_planet.tif to Google Drive folder.
# Copied 820_planet.tif to Google Drive folder.
# Copied 2371_planet.tif to Google Drive folder.
# Copied 492_planet.tif to Google Drive folder.
# Copied 1749_planet.tif to Google Drive folder.
# Copied 2224_planet.tif to Google Drive folder.
# Copied 609_planet.tif to Google Drive folder.
# Copied 2604_planet.tif to Google Drive folder.
# Copied 1994_planet.tif to Google Drive folder.
# Copied 2482_planet.tif to Google Drive folder.
# Copied 379_planet.tif to Google Drive folder.
# Copied 1633_planet.tif to Google Drive folder.
# Copied 2046_planet.tif to Google Drive folder.
# Copied 2051_planet.tif to Google Drive folder.
# Copied 1770_planet.tif to Google Drive folder.
# Copied 1182_planet.tif to Google Drive folder.
# Copied 19_planet.tif to Google Drive folder.
# Copied 2088_planet.tif to Google Drive folder.
# Copied 2496_planet.tif to Google Drive folder.
# Copied 332_planet.tif to Google Drive folder.
# Copied 641_planet.tif to Google Drive folder.
# Copied 1936_planet.tif to Google Drive folder.
# Copied 661_planet.tif to Google Drive folder.
# Copied 2246_planet.tif to Google Drive folder.
# Copied 698_planet.tif to Google Drive folder.
# Copied 1590_planet.tif to Google Drive folder.
# Copied 32_planet.tif to Google Drive folder.
# Copied 1711_planet.tif to Google Drive folder.
# Copied 2124_planet.tif to Google Drive folder.
# Copied 251_planet.tif to Google Drive folder.
# Copied 709_planet.tif to Google Drive folder.
# Copied 1807_planet.tif to Google Drive folder.
# Copied 1943_planet.tif to Google Drive folder.
# Copied 1636_planet.tif to Google Drive folder.
# Copied 1219_planet.tif to Google Drive folder.
# Copied 381_planet.tif to Google Drive folder.
# Copied 539_planet.tif to Google Drive folder.
# Copied 2278_planet.tif to Google Drive folder.
# Copied 2186_planet.tif to Google Drive folder.
# Copied 520_planet.tif to Google Drive folder.
# Copied 1944_planet.tif to Google Drive folder.
# Copied 2145_planet.tif to Google Drive folder.
# Copied 1856_planet.tif to Google Drive folder.
# Copied 725_planet.tif to Google Drive folder.
# Copied 2065_planet.tif to Google Drive folder.
# Copied 1503_planet.tif to Google Drive folder.
# Copied 881_planet.tif to Google Drive folder.
# Copied 1187_planet.tif to Google Drive folder.
# Copied 81_planet.tif to Google Drive folder.
# Copied 1959_planet.tif to Google Drive folder.
# Copied 2210_planet.tif to Google Drive folder.
# Copied 1400_planet.tif to Google Drive folder.
# Copied 1956_planet.tif to Google Drive folder.
# Copied 2018_planet.tif to Google Drive folder.
# Copied 104_planet.tif to Google Drive folder.
# Copied 1094_planet.tif to Google Drive folder.
# Copied 1311_planet.tif to Google Drive folder.
# Copied 2327_planet.tif to Google Drive folder.
# Copied 1697_planet.tif to Google Drive folder.
# Copied 862_planet.tif to Google Drive folder.
# Copied 2159_planet.tif to Google Drive folder.
# Copied 207_planet.tif to Google Drive folder.
# Copied 1668_planet.tif to Google Drive folder.
# Copied 939_planet.tif to Google Drive folder.
# Copied 2245_planet.tif to Google Drive folder.
# Copied 2232_planet.tif to Google Drive folder.
# Copied 755_planet.tif to Google Drive folder.
# Copied 2487_planet.tif to Google Drive folder.
# Copied 1534_planet.tif to Google Drive folder.
# Copied 313_planet.tif to Google Drive folder.
# Copied 1213_planet.tif to Google Drive folder.
# Copied 2621_planet.tif to Google Drive folder.
# Copied 1117_planet.tif to Google Drive folder.
# Copied 2560_planet.tif to Google Drive folder.
# Copied 1583_planet.tif to Google Drive folder.
# Copied 554_planet.tif to Google Drive folder.
# Copied 1639_planet.tif to Google Drive folder.
# Copied 353_planet.tif to Google Drive folder.
# Copied 1530_planet.tif to Google Drive folder.
# Copied 732_planet.tif to Google Drive folder.
# Copied 218_planet.tif to Google Drive folder.
# Copied 2383_planet.tif to Google Drive folder.
# Copied 73_planet.tif to Google Drive folder.
# Copied 1617_planet.tif to Google Drive folder.
# Copied 2271_planet.tif to Google Drive folder.
# Copied 2055_planet.tif to Google Drive folder.
# Copied 1986_planet.tif to Google Drive folder.
# Copied 388_planet.tif to Google Drive folder.
# Copied 2187_planet.tif to Google Drive folder.
# Copied 1137_planet.tif to Google Drive folder.
# Copied 736_planet.tif to Google Drive folder.
# Copied 765_planet.tif to Google Drive folder.
# Copied 712_planet.tif to Google Drive folder.
# Copied 2070_planet.tif to Google Drive folder.
# Copied 976_planet.tif to Google Drive folder.
# Copied 2225_planet.tif to Google Drive folder.
# Copied 1280_planet.tif to Google Drive folder.
# Copied 1593_planet.tif to Google Drive folder.
# Copied 1011_planet.tif to Google Drive folder.
# Copied 1279_planet.tif to Google Drive folder.
# Copied 1451_planet.tif to Google Drive folder.
# Copied 2398_planet.tif to Google Drive folder.
# Copied 1105_planet.tif to Google Drive folder.
# Copied 1784_planet.tif to Google Drive folder.
# Copied 1378_planet.tif to Google Drive folder.
# Copied 437_planet.tif to Google Drive folder.
# Copied 221_planet.tif to Google Drive folder.
# Copied 545_planet.tif to Google Drive folder.
# Copied 38_planet.tif to Google Drive folder.
# Copied 603_planet.tif to Google Drive folder.
# Copied 1962_planet.tif to Google Drive folder.
# Copied 2459_planet.tif to Google Drive folder.
# Copied 1683_planet.tif to Google Drive folder.
# Copied 2450_planet.tif to Google Drive folder.
# Copied 204_planet.tif to Google Drive folder.
# Copied 681_planet.tif to Google Drive folder.
# Copied 2477_planet.tif to Google Drive folder.
# Copied 597_planet.tif to Google Drive folder.
# Copied 1304_planet.tif to Google Drive folder.
# Copied 907_planet.tif to Google Drive folder.
# Copied 180_planet.tif to Google Drive folder.
# Copied 1351_planet.tif to Google Drive folder.
# Copied 140_planet.tif to Google Drive folder.
# Copied 2240_planet.tif to Google Drive folder.
# Copied 957_planet.tif to Google Drive folder.
# Copied 2096_planet.tif to Google Drive folder.
# Copied 1480_planet.tif to Google Drive folder.
# Copied 37_planet.tif to Google Drive folder.
# Copied 1542_planet.tif to Google Drive folder.
# Copied 1630_planet.tif to Google Drive folder.
# Copied 2561_planet.tif to Google Drive folder.
# Copied 44_planet.tif to Google Drive folder.
# Copied 2489_planet.tif to Google Drive folder.
# Copied 1893_planet.tif to Google Drive folder.
# Copied 2269_planet.tif to Google Drive folder.
# Copied 2343_planet.tif to Google Drive folder.
# Copied 1258_planet.tif to Google Drive folder.
# Copied 1848_planet.tif to Google Drive folder.
# Copied 2262_planet.tif to Google Drive folder.
# Copied 2103_planet.tif to Google Drive folder.
# Copied 1563_planet.tif to Google Drive folder.
# Copied 815_planet.tif to Google Drive folder.
# Copied 1554_planet.tif to Google Drive folder.
# Copied 775_planet.tif to Google Drive folder.
# Copied 1044_planet.tif to Google Drive folder.
# Copied 49_planet.tif to Google Drive folder.
# Copied 456_planet.tif to Google Drive folder.
# Copied 2004_planet.tif to Google Drive folder.
# Copied 2395_planet.tif to Google Drive folder.
# Copied 434_planet.tif to Google Drive folder.
# Copied 671_planet.tif to Google Drive folder.
# Copied 85_planet.tif to Google Drive folder.
# Copied 2317_planet.tif to Google Drive folder.
# Copied 391_planet.tif to Google Drive folder.
# Copied 1468_planet.tif to Google Drive folder.
# Copied 1043_planet.tif to Google Drive folder.
# Copied 1743_planet.tif to Google Drive folder.
# Copied 818_planet.tif to Google Drive folder.
# Copied 1548_planet.tif to Google Drive folder.
# Copied 1478_planet.tif to Google Drive folder.
# Copied 139_planet.tif to Google Drive folder.
# Copied 1455_planet.tif to Google Drive folder.
# Copied 1809_planet.tif to Google Drive folder.
# Copied 1985_planet.tif to Google Drive folder.
# Copied 2517_planet.tif to Google Drive folder.
# Copied 1886_planet.tif to Google Drive folder.
# Copied 2026_planet.tif to Google Drive folder.
# Copied 309_planet.tif to Google Drive folder.
# Copied 962_planet.tif to Google Drive folder.
# Copied 1950_planet.tif to Google Drive folder.
# Copied 2655_planet.tif to Google Drive folder.
# Copied 2415_planet.tif to Google Drive folder.
# Copied 2293_planet.tif to Google Drive folder.
# Copied 1065_planet.tif to Google Drive folder.
# Copied 1106_planet.tif to Google Drive folder.
# Copied 1472_planet.tif to Google Drive folder.
# Copied 1803_planet.tif to Google Drive folder.
# Copied 1930_planet.tif to Google Drive folder.
# Copied 787_planet.tif to Google Drive folder.
# Copied 198_planet.tif to Google Drive folder.
# Copied 1161_planet.tif to Google Drive folder.
# Copied 1475_planet.tif to Google Drive folder.
# Copied 191_planet.tif to Google Drive folder.
# Copied 2586_planet.tif to Google Drive folder.
# Copied 2215_planet.tif to Google Drive folder.
# Copied 2234_planet.tif to Google Drive folder.
# Copied 834_planet.tif to Google Drive folder.
# Copied 2584_planet.tif to Google Drive folder.
# Copied 2233_planet.tif to Google Drive folder.
# Copied 305_planet.tif to Google Drive folder.
# Copied 1614_planet.tif to Google Drive folder.
# Copied 2430_planet.tif to Google Drive folder.
# Copied 1052_planet.tif to Google Drive folder.
# Copied 172_planet.tif to Google Drive folder.
# Copied 706_planet.tif to Google Drive folder.
# Copied 1017_planet.tif to Google Drive folder.
# Copied 692_planet.tif to Google Drive folder.
# Copied 41_planet.tif to Google Drive folder.
# Copied 894_planet.tif to Google Drive folder.
# Copied 2589_planet.tif to Google Drive folder.
# Copied 1474_planet.tif to Google Drive folder.
# Copied 1937_planet.tif to Google Drive folder.
# Copied 1498_planet.tif to Google Drive folder.
# Copied 2377_planet.tif to Google Drive folder.
# Copied 958_planet.tif to Google Drive folder.
# Copied 2099_planet.tif to Google Drive folder.
# Copied 1183_planet.tif to Google Drive folder.
# Copied 1349_planet.tif to Google Drive folder.
# Copied 1447_planet.tif to Google Drive folder.
# Copied 2447_planet.tif to Google Drive folder.
# Copied 2202_planet.tif to Google Drive folder.
# Copied 2461_planet.tif to Google Drive folder.
# Copied 1024_planet.tif to Google Drive folder.
# Copied 286_planet.tif to Google Drive folder.
# Copied 296_planet.tif to Google Drive folder.
# Copied 960_planet.tif to Google Drive folder.
# Copied 2179_planet.tif to Google Drive folder.
# Copied 2653_planet.tif to Google Drive folder.
# Copied 486_planet.tif to Google Drive folder.
# Copied 812_planet.tif to Google Drive folder.
# Copied 1425_planet.tif to Google Drive folder.
# Copied 1705_planet.tif to Google Drive folder.
# Copied 870_planet.tif to Google Drive folder.
# Copied 357_planet.tif to Google Drive folder.
# Copied 2424_planet.tif to Google Drive folder.
# Copied 1545_planet.tif to Google Drive folder.
# Copied 2562_planet.tif to Google Drive folder.
# Copied 1294_planet.tif to Google Drive folder.
# Copied 1558_planet.tif to Google Drive folder.
# Copied 2462_planet.tif to Google Drive folder.
# Copied 598_planet.tif to Google Drive folder.
# Copied 1156_planet.tif to Google Drive folder.
# Copied 1335_planet.tif to Google Drive folder.
# Copied 1194_planet.tif to Google Drive folder.
# Copied 2222_planet.tif to Google Drive folder.
# Copied 634_planet.tif to Google Drive folder.
# Copied 1031_planet.tif to Google Drive folder.
# Copied 2523_planet.tif to Google Drive folder.
# Copied 1514_planet.tif to Google Drive folder.
# Copied 860_planet.tif to Google Drive folder.
# Copied 2393_planet.tif to Google Drive folder.
# Copied 1787_planet.tif to Google Drive folder.
# Copied 1607_planet.tif to Google Drive folder.
# Copied 173_planet.tif to Google Drive folder.
# Copied 372_planet.tif to Google Drive folder.
# Copied 1_planet.tif to Google Drive folder.
# Copied 535_planet.tif to Google Drive folder.
# Copied 1970_planet.tif to Google Drive folder.
# Copied 95_planet.tif to Google Drive folder.
# Copied 971_planet.tif to Google Drive folder.
# Copied 1931_planet.tif to Google Drive folder.
# Copied 738_planet.tif to Google Drive folder.
# Copied 1347_planet.tif to Google Drive folder.
# Copied 2601_planet.tif to Google Drive folder.
# Copied 2031_planet.tif to Google Drive folder.
# Copied 1623_planet.tif to Google Drive folder.
# Copied 1485_planet.tif to Google Drive folder.
# Copied 1479_planet.tif to Google Drive folder.
# Copied 2091_planet.tif to Google Drive folder.
# Copied 531_planet.tif to Google Drive folder.
# Copied 441_planet.tif to Google Drive folder.
# Copied 2341_planet.tif to Google Drive folder.
# Copied 212_planet.tif to Google Drive folder.
# Copied 555_planet.tif to Google Drive folder.
# Copied 2543_planet.tif to Google Drive folder.
# Copied 1620_planet.tif to Google Drive folder.
# Copied 375_planet.tif to Google Drive folder.
# Copied 470_planet.tif to Google Drive folder.
# Copied 303_planet.tif to Google Drive folder.
# Copied 2217_planet.tif to Google Drive folder.
# Copied 2053_planet.tif to Google Drive folder.
# Copied 443_planet.tif to Google Drive folder.
# Copied 1051_planet.tif to Google Drive folder.
# Copied 2574_planet.tif to Google Drive folder.
# Copied 69_planet.tif to Google Drive folder.
# Copied 730_planet.tif to Google Drive folder.
# Copied 1203_planet.tif to Google Drive folder.
# Copied 1821_planet.tif to Google Drive folder.
# Copied 36_planet.tif to Google Drive folder.
# Copied 2624_planet.tif to Google Drive folder.
# Copied 1721_planet.tif to Google Drive folder.
# Copied 1436_planet.tif to Google Drive folder.
# Copied 1046_planet.tif to Google Drive folder.
# Copied 2598_planet.tif to Google Drive folder.
# Copied 940_planet.tif to Google Drive folder.
# Copied 804_planet.tif to Google Drive folder.
# Copied 1570_planet.tif to Google Drive folder.
# Copied 2193_planet.tif to Google Drive folder.
# Copied 1836_planet.tif to Google Drive folder.
# Copied 2479_planet.tif to Google Drive folder.
# Copied 247_planet.tif to Google Drive folder.
# Copied 2251_planet.tif to Google Drive folder.
# Copied 2663_planet.tif to Google Drive folder.
# Copied 1096_planet.tif to Google Drive folder.
# Copied 264_planet.tif to Google Drive folder.
# Copied 1905_planet.tif to Google Drive folder.
# Copied 2524_planet.tif to Google Drive folder.
# Copied 1773_planet.tif to Google Drive folder.
# Copied 2400_planet.tif to Google Drive folder.
# Copied 1737_planet.tif to Google Drive folder.
# Copied 292_planet.tif to Google Drive folder.
# Copied 1829_planet.tif to Google Drive folder.
# Copied 337_planet.tif to Google Drive folder.
# Copied 1150_planet.tif to Google Drive folder.
# Copied 840_planet.tif to Google Drive folder.
# Copied 401_planet.tif to Google Drive folder.
# Copied 2000_planet.tif to Google Drive folder.
# Copied 1306_planet.tif to Google Drive folder.
# Copied 124_planet.tif to Google Drive folder.
# Copied 2158_planet.tif to Google Drive folder.
# Copied 1948_planet.tif to Google Drive folder.
# Copied 583_planet.tif to Google Drive folder.
# Copied 1012_planet.tif to Google Drive folder.
# Copied 2358_planet.tif to Google Drive folder.
# Copied 719_planet.tif to Google Drive folder.
# Copied 1908_planet.tif to Google Drive folder.
# Copied 2286_planet.tif to Google Drive folder.
# Copied 824_planet.tif to Google Drive folder.
# Copied 950_planet.tif to Google Drive folder.
# Copied 997_planet.tif to Google Drive folder.
# Copied 184_planet.tif to Google Drive folder.
# Copied 1643_planet.tif to Google Drive folder.
# Copied 984_planet.tif to Google Drive folder.
# Copied 766_planet.tif to Google Drive folder.
# Copied 855_planet.tif to Google Drive folder.
# Copied 1324_planet.tif to Google Drive folder.
# Copied 1581_planet.tif to Google Drive folder.
# Copied 2500_planet.tif to Google Drive folder.
# Copied 1961_planet.tif to Google Drive folder.
# Copied 34_planet.tif to Google Drive folder.
# Copied 1874_planet.tif to Google Drive folder.
# Copied 234_planet.tif to Google Drive folder.
# Copied 1178_planet.tif to Google Drive folder.
# Copied 591_planet.tif to Google Drive folder.
# Copied 2105_planet.tif to Google Drive folder.
# Copied 697_planet.tif to Google Drive folder.
# Copied 1080_planet.tif to Google Drive folder.
# Copied 1122_planet.tif to Google Drive folder.
# Copied 2137_planet.tif to Google Drive folder.
# Copied 420_planet.tif to Google Drive folder.
# Copied 1719_planet.tif to Google Drive folder.
# Copied 1801_planet.tif to Google Drive folder.
# Copied 117_planet.tif to Google Drive folder.
# Copied 361_planet.tif to Google Drive folder.
# Copied 2310_planet.tif to Google Drive folder.
# Copied 2221_planet.tif to Google Drive folder.
# Copied 785_planet.tif to Google Drive folder.
# Copied 183_planet.tif to Google Drive folder.
# Copied 2199_planet.tif to Google Drive folder.
# Copied 2650_planet.tif to Google Drive folder.
# Copied 1019_planet.tif to Google Drive folder.
# Copied 1290_planet.tif to Google Drive folder.
# Copied 1880_planet.tif to Google Drive folder.
# Copied 2314_planet.tif to Google Drive folder.
# Copied 747_planet.tif to Google Drive folder.
# Copied 612_planet.tif to Google Drive folder.
# Copied 776_planet.tif to Google Drive folder.
# Copied 2248_planet.tif to Google Drive folder.
# Copied 1635_planet.tif to Google Drive folder.
# Copied 992_planet.tif to Google Drive folder.
# Copied 333_planet.tif to Google Drive folder.
# Copied 291_planet.tif to Google Drive folder.
# Copied 1445_planet.tif to Google Drive folder.
# Copied 2391_planet.tif to Google Drive folder.
# Copied 1438_planet.tif to Google Drive folder.
# Copied 2211_planet.tif to Google Drive folder.
# Copied 2522_planet.tif to Google Drive folder.
# Copied 1699_planet.tif to Google Drive folder.
# Copied 2042_planet.tif to Google Drive folder.
# Copied 508_planet.tif to Google Drive folder.
# Copied 2192_planet.tif to Google Drive folder.
# Copied 1477_planet.tif to Google Drive folder.
# Copied 2646_planet.tif to Google Drive folder.
# Copied 600_planet.tif to Google Drive folder.
# Copied 2359_planet.tif to Google Drive folder.
# Copied 219_planet.tif to Google Drive folder.
# Copied 1452_planet.tif to Google Drive folder.
# Copied 2290_planet.tif to Google Drive folder.
# Copied 115_planet.tif to Google Drive folder.
# Copied 2408_planet.tif to Google Drive folder.
# Copied 2204_planet.tif to Google Drive folder.
# Copied 1850_planet.tif to Google Drive folder.
# Copied 1316_planet.tif to Google Drive folder.
# Copied 2287_planet.tif to Google Drive folder.
# Copied 2309_planet.tif to Google Drive folder.
# Copied 991_planet.tif to Google Drive folder.
# Copied 80_planet.tif to Google Drive folder.
# Copied 2095_planet.tif to Google Drive folder.
# Copied 1255_planet.tif to Google Drive folder.
# Copied 1228_planet.tif to Google Drive folder.
# Copied 1344_planet.tif to Google Drive folder.
# Copied 2325_planet.tif to Google Drive folder.
# Copied 1040_planet.tif to Google Drive folder.
# Copied 1988_planet.tif to Google Drive folder.
# Copied 1093_planet.tif to Google Drive folder.
# Copied 978_planet.tif to Google Drive folder.
# Copied 1420_planet.tif to Google Drive folder.
# Copied 873_planet.tif to Google Drive folder.
# Copied 1337_planet.tif to Google Drive folder.
# Copied 1788_planet.tif to Google Drive folder.
# Copied 1927_planet.tif to Google Drive folder.
# Copied 2167_planet.tif to Google Drive folder.
# ...
# Copied 1685_planet.tif to Google Drive folder.
# Copied 444_planet.tif to Google Drive folder.
# Copied 817_planet.tif to Google Drive folder.
# Copied 2438_planet.tif to Google Drive folder.
# Copied 1887_planet.tif to Google Drive folder.
# Copied 208_planet.tif to Google Drive folder.
# Copied 751_planet.tif to Google Drive folder.
# Copied 534_planet.tif to Google Drive folder.
# Copied 463_planet.tif to Google Drive folder.
# Copied 2593_planet.tif to Google Drive folder.
# Copied 652_planet.tif to Google Drive folder.
# Copied 1253_planet.tif to Google Drive folder.
# Copied 1694_planet.tif to Google Drive folder.
# Copied 2599_planet.tif to Google Drive folder.
# Copied 2023_planet.tif to Google Drive folder.
# Copied 1341_planet.tif to Google Drive folder.
# Copied 564_planet.tif to Google Drive folder.
# Copied 935_planet.tif to Google Drive folder.
# Copied 2399_planet.tif to Google Drive folder.
# Copied 307_planet.tif to Google Drive folder.
# Copied 954_planet.tif to Google Drive folder.
# Copied 2565_planet.tif to Google Drive folder.
# Copied 2666_planet.tif to Google Drive folder.
# Copied 1055_planet.tif to Google Drive folder.
# Copied 2344_planet.tif to Google Drive folder.
# Copied 777_planet.tif to Google Drive folder.
# Copied 158_planet.tif to Google Drive folder.
# Copied 1470_planet.tif to Google Drive folder.
# Copied 648_planet.tif to Google Drive folder.
# Copied 2084_planet.tif to Google Drive folder.
# Copied 277_planet.tif to Google Drive folder.
# Copied 1827_planet.tif to Google Drive folder.
# Copied 2339_planet.tif to Google Drive folder.
# Copied 94_planet.tif to Google Drive folder.
# Copied 2645_planet.tif to Google Drive folder.
# Copied 2629_planet.tif to Google Drive folder.
# Copied 905_planet.tif to Google Drive folder.
# Copied 1687_planet.tif to Google Drive folder.
# Copied 1385_planet.tif to Google Drive folder.
# Copied 967_planet.tif to Google Drive folder.
# Copied 1609_planet.tif to Google Drive folder.
# Copied 1744_planet.tif to Google Drive folder.
# Copied 2129_planet.tif to Google Drive folder.
# Copied 2388_planet.tif to Google Drive folder.
# Copied 565_planet.tif to Google Drive folder.
# Copied 637_planet.tif to Google Drive folder.
# Copied 883_planet.tif to Google Drive folder.
# Copied 1489_planet.tif to Google Drive folder.
# Copied 341_planet.tif to Google Drive folder.
# Copied 854_planet.tif to Google Drive folder.
# Copied 407_planet.tif to Google Drive folder.
# Copied 1752_planet.tif to Google Drive folder.
# Copied 1174_planet.tif to Google Drive folder.
# Copied 2649_planet.tif to Google Drive folder.
# Copied 1571_planet.tif to Google Drive folder.
# Copied 778_planet.tif to Google Drive folder.
# Copied 9_planet.tif to Google Drive folder.
# Copied 2594_planet.tif to Google Drive folder.
# Copied 1357_planet.tif to Google Drive folder.
# Copied 2362_planet.tif to Google Drive folder.
# Copied 149_planet.tif to Google Drive folder.
# Copied 1139_planet.tif to Google Drive folder.
# Copied 2603_planet.tif to Google Drive folder.
# Copied 584_planet.tif to Google Drive folder.
# Copied 769_planet.tif to Google Drive folder.
# Copied 1155_planet.tif to Google Drive folder.
# Copied 397_planet.tif to Google Drive folder.
# Copied 969_planet.tif to Google Drive folder.
# Copied 1746_planet.tif to Google Drive folder.
# Copied 2518_planet.tif to Google Drive folder.
# Copied 1125_planet.tif to Google Drive folder.
# Copied 2115_planet.tif to Google Drive folder.
# Copied 1042_planet.tif to Google Drive folder.
# Copied 656_planet.tif to Google Drive folder.
# Copied 329_planet.tif to Google Drive folder.
# Copied 259_planet.tif to Google Drive folder.
# Copied 2177_planet.tif to Google Drive folder.
# Copied 1884_planet.tif to Google Drive folder.
# Copied 574_planet.tif to Google Drive folder.
# Copied 374_planet.tif to Google Drive folder.
# Copied 1899_planet.tif to Google Drive folder.
# Copied 1102_planet.tif to Google Drive folder.
# Copied 285_planet.tif to Google Drive folder.
# Copied 938_planet.tif to Google Drive folder.
# Copied 1935_planet.tif to Google Drive folder.
# Copied 10_planet.tif to Google Drive folder.
# Copied 1921_planet.tif to Google Drive folder.
# Copied 2080_planet.tif to Google Drive folder.
# Copied 446_planet.tif to Google Drive folder.
# Copied 1321_planet.tif to Google Drive folder.
# Copied 792_planet.tif to Google Drive folder.
# Copied 1429_planet.tif to Google Drive folder.
# Copied 1863_planet.tif to Google Drive folder.
# Copied 1382_planet.tif to Google Drive folder.
# Copied 525_planet.tif to Google Drive folder.
# Copied 2001_planet.tif to Google Drive folder.
# Copied 511_planet.tif to Google Drive folder.
# Copied 287_planet.tif to Google Drive folder.
# Copied 226_planet.tif to Google Drive folder.
# Copied 964_planet.tif to Google Drive folder.
# Copied 1068_planet.tif to Google Drive folder.
# Copied 2468_planet.tif to Google Drive folder.
# Copied 98_planet.tif to Google Drive folder.
# Copied 1130_planet.tif to Google Drive folder.
# Copied 214_planet.tif to Google Drive folder.
# Copied 7_planet.tif to Google Drive folder.
# Copied 673_planet.tif to Google Drive folder.
# Copied 507_planet.tif to Google Drive folder.
# Copied 96_planet.tif to Google Drive folder.
# Copied 1834_planet.tif to Google Drive folder.
# Copied 1229_planet.tif to Google Drive folder.
# Copied 2504_planet.tif to Google Drive folder.
# Copied 701_planet.tif to Google Drive folder.
# Copied 2394_planet.tif to Google Drive folder.
# Copied 758_planet.tif to Google Drive folder.
# Copied 890_planet.tif to Google Drive folder.
# Copied 1232_planet.tif to Google Drive folder.
# Copied 1403_planet.tif to Google Drive folder.
# Copied 639_planet.tif to Google Drive folder.
# Copied 1799_planet.tif to Google Drive folder.
# Copied 1247_planet.tif to Google Drive folder.
# Copied 1077_planet.tif to Google Drive folder.
# Copied 2259_planet.tif to Google Drive folder.
# Copied 2425_planet.tif to Google Drive folder.
# Copied 2405_planet.tif to Google Drive folder.
# Copied 2376_planet.tif to Google Drive folder.
# Copied 1543_planet.tif to Google Drive folder.
# Copied 2426_planet.tif to Google Drive folder.
# Copied 1890_planet.tif to Google Drive folder.
# Copied 260_planet.tif to Google Drive folder.
# Copied 1715_planet.tif to Google Drive folder.
# Copied 402_planet.tif to Google Drive folder.
# Copied 2328_planet.tif to Google Drive folder.
# Copied 636_planet.tif to Google Drive folder.
# Copied 966_planet.tif to Google Drive folder.
# Copied 1598_planet.tif to Google Drive folder.
# Copied 607_planet.tif to Google Drive folder.
# Copied 1519_planet.tif to Google Drive folder.
# Copied 1879_planet.tif to Google Drive folder.
# Copied 269_planet.tif to Google Drive folder.
# Copied 1132_planet.tif to Google Drive folder.
# Copied 1367_planet.tif to Google Drive folder.
# Copied 2265_planet.tif to Google Drive folder.
# Copied 1061_planet.tif to Google Drive folder.
# Copied 822_planet.tif to Google Drive folder.
# Copied 660_planet.tif to Google Drive folder.
# Copied 290_planet.tif to Google Drive folder.
# Copied 2165_planet.tif to Google Drive folder.
# Copied 181_planet.tif to Google Drive folder.
# Copied 590_planet.tif to Google Drive folder.
# Copied 2519_planet.tif to Google Drive folder.
# Copied 202_planet.tif to Google Drive folder.
# Copied 644_planet.tif to Google Drive folder.
# Copied 23_planet.tif to Google Drive folder.
# Copied 2549_planet.tif to Google Drive folder.
# Copied 342_planet.tif to Google Drive folder.
# Copied 1073_planet.tif to Google Drive folder.
# Copied 57_planet.tif to Google Drive folder.
# Copied 742_planet.tif to Google Drive folder.
# Copied 2216_planet.tif to Google Drive folder.
# Copied 1873_planet.tif to Google Drive folder.
# Copied 782_planet.tif to Google Drive folder.
# Copied 1271_planet.tif to Google Drive folder.
# Copied 750_planet.tif to Google Drive folder.
# Copied 1777_planet.tif to Google Drive folder.
# Copied 2534_planet.tif to Google Drive folder.
# Copied 1688_planet.tif to Google Drive folder.
# Copied 2542_planet.tif to Google Drive folder.
# Copied 857_planet.tif to Google Drive folder.
# Copied 2492_planet.tif to Google Drive folder.
# Copied 494_planet.tif to Google Drive folder.
# Copied 604_planet.tif to Google Drive folder.
# Copied 1506_planet.tif to Google Drive folder.
# Copied 188_planet.tif to Google Drive folder.
# Copied 240_planet.tif to Google Drive folder.
# Copied 2429_planet.tif to Google Drive folder.
# Copied 1647_planet.tif to Google Drive folder.
# Copied 308_planet.tif to Google Drive folder.
# Copied 2374_planet.tif to Google Drive folder.
# Copied 236_planet.tif to Google Drive folder.
# Copied 825_planet.tif to Google Drive folder.
# Copied 676_planet.tif to Google Drive folder.
# Copied 1667_planet.tif to Google Drive folder.
# Copied 1196_planet.tif to Google Drive folder.
# Copied 807_planet.tif to Google Drive folder.
# Copied 932_planet.tif to Google Drive folder.
# Copied 224_planet.tif to Google Drive folder.
# Copied 279_planet.tif to Google Drive folder.
# Copied 1515_planet.tif to Google Drive folder.
# Copied 52_planet.tif to Google Drive folder.
# Copied 2338_planet.tif to Google Drive folder.
# Copied 1762_planet.tif to Google Drive folder.
# Copied 716_planet.tif to Google Drive folder.
# Copied 2609_planet.tif to Google Drive folder.
# Copied 844_planet.tif to Google Drive folder.
# Copied 1016_planet.tif to Google Drive folder.
# Copied 813_planet.tif to Google Drive folder.
# Copied 733_planet.tif to Google Drive folder.
# Copied 2623_planet.tif to Google Drive folder.
# Copied 2600_planet.tif to Google Drive folder.
# Copied 2546_planet.tif to Google Drive folder.
# Copied 2268_planet.tif to Google Drive folder.
# Copied 1507_planet.tif to Google Drive folder.
# Copied 2074_planet.tif to Google Drive folder.
# Copied 532_planet.tif to Google Drive folder.
# Copied 2509_planet.tif to Google Drive folder.
# Copied 1824_planet.tif to Google Drive folder.
# Copied 1724_planet.tif to Google Drive folder.
# Copied 459_planet.tif to Google Drive folder.
# Copied 1090_planet.tif to Google Drive folder.
# Copied 901_planet.tif to Google Drive folder.
# Copied 1441_planet.tif to Google Drive folder.
# Copied 2175_planet.tif to Google Drive folder.
# Copied 144_planet.tif to Google Drive folder.
# Copied 2282_planet.tif to Google Drive folder.
# Copied 1288_planet.tif to Google Drive folder.
# Copied 197_planet.tif to Google Drive folder.
# Copied 1521_planet.tif to Google Drive folder.
# Copied 2236_planet.tif to Google Drive folder.
# Copied 432_planet.tif to Google Drive folder.
# Copied 2219_planet.tif to Google Drive folder.
# Copied 105_planet.tif to Google Drive folder.
# Copied 457_planet.tif to Google Drive folder.
# Copied 578_planet.tif to Google Drive folder.
# Copied 1706_planet.tif to Google Drive folder.
# Copied 1987_planet.tif to Google Drive folder.
# Copied 1929_planet.tif to Google Drive folder.
# Copied 2559_planet.tif to Google Drive folder.
# Copied 2146_planet.tif to Google Drive folder.
# Copied 1696_planet.tif to Google Drive folder.
# Copied 868_planet.tif to Google Drive folder.
# Copied 2582_planet.tif to Google Drive folder.
# Copied 2163_planet.tif to Google Drive folder.
# Copied 2657_planet.tif to Google Drive folder.
# Copied 275_planet.tif to Google Drive folder.
# Copied 1110_planet.tif to Google Drive folder.
# Copied 558_planet.tif to Google Drive folder.
# Copied 832_planet.tif to Google Drive folder.
# Copied 2554_planet.tif to Google Drive folder.
# Copied 71_planet.tif to Google Drive folder.
# Copied 504_planet.tif to Google Drive folder.
# Copied 1160_planet.tif to Google Drive folder.
# Copied 1878_planet.tif to Google Drive folder.
# Copied 708_planet.tif to Google Drive folder.
# Copied 1334_planet.tif to Google Drive folder.
# Copied 893_planet.tif to Google Drive folder.
# Copied 1081_planet.tif to Google Drive folder.
# Copied 1900_planet.tif to Google Drive folder.
# Copied 177_planet.tif to Google Drive folder.
# Copied 2557_planet.tif to Google Drive folder.
# Copied 761_planet.tif to Google Drive folder.
# Copied 78_planet.tif to Google Drive folder.
# Copied 2292_planet.tif to Google Drive folder.
# Copied 668_planet.tif to Google Drive folder.
# Copied 141_planet.tif to Google Drive folder.
# Copied 1621_planet.tif to Google Drive folder.
# Copied 1089_planet.tif to Google Drive folder.
# Copied 2372_planet.tif to Google Drive folder.
# Copied 2610_planet.tif to Google Drive folder.
# Copied 2008_planet.tif to Google Drive folder.
# Copied 1214_planet.tif to Google Drive folder.
# Copied 2264_planet.tif to Google Drive folder.
# Copied 1408_planet.tif to Google Drive folder.
# Copied 772_planet.tif to Google Drive folder.
# Copied 1372_planet.tif to Google Drive folder.
# Copied 363_planet.tif to Google Drive folder.
# Copied 842_planet.tif to Google Drive folder.
# Copied 1796_planet.tif to Google Drive folder.
# Copied 1870_planet.tif to Google Drive folder.
# Copied 1010_planet.tif to Google Drive folder.
# Copied 462_planet.tif to Google Drive folder.
# Copied 352_planet.tif to Google Drive folder.
# Copied 783_planet.tif to Google Drive folder.
# Copied 206_planet.tif to Google Drive folder.
# Copied 2181_planet.tif to Google Drive folder.
# Copied 2511_planet.tif to Google Drive folder.
# Copied 2488_planet.tif to Google Drive folder.
# Copied 248_planet.tif to Google Drive folder.
# Copied 1218_planet.tif to Google Drive folder.
# Copied 1672_planet.tif to Google Drive folder.
# Copied 2092_planet.tif to Google Drive folder.
# Copied 1885_planet.tif to Google Drive folder.
# Copied 1658_planet.tif to Google Drive folder.
# Copied 1965_planet.tif to Google Drive folder.
# Copied 1638_planet.tif to Google Drive folder.
# Copied 2384_planet.tif to Google Drive folder.
# Copied 975_planet.tif to Google Drive folder.
# Copied 464_planet.tif to Google Drive folder.
# Copied 1734_planet.tif to Google Drive folder.
# Copied 1339_planet.tif to Google Drive folder.
# Copied 1473_planet.tif to Google Drive folder.
# Copied 5_planet.tif to Google Drive folder.
# Copied 2308_planet.tif to Google Drive folder.
# Copied 289_planet.tif to Google Drive folder.
# Copied 2606_planet.tif to Google Drive folder.
# Copied 1862_planet.tif to Google Drive folder.
# Copied 1135_planet.tif to Google Drive folder.
# Copied 1350_planet.tif to Google Drive folder.
# Copied 1275_planet.tif to Google Drive folder.
# Copied 1225_planet.tif to Google Drive folder.
# Copied 1725_planet.tif to Google Drive folder.
# Copied 1427_planet.tif to Google Drive folder.
# Copied 146_planet.tif to Google Drive folder.
# Copied 753_planet.tif to Google Drive folder.
# Copied 683_planet.tif to Google Drive folder.
# Copied 284_planet.tif to Google Drive folder.
# Copied 2075_planet.tif to Google Drive folder.
# Copied 1259_planet.tif to Google Drive folder.
# Copied 1402_planet.tif to Google Drive folder.
# Copied 841_planet.tif to Google Drive folder.
# Copied 1909_planet.tif to Google Drive folder.
# Copied 2427_planet.tif to Google Drive folder.
# Copied 2577_planet.tif to Google Drive folder.
# Copied 694_planet.tif to Google Drive folder.
# Copied 133_planet.tif to Google Drive folder.
# Copied 1864_planet.tif to Google Drive folder.
# Copied 2401_planet.tif to Google Drive folder.
# Copied 2298_planet.tif to Google Drive folder.
# Copied 1781_planet.tif to Google Drive folder.
# Copied 1825_planet.tif to Google Drive folder.
# Copied 339_planet.tif to Google Drive folder.
# Copied 693_planet.tif to Google Drive folder.
# Copied 400_planet.tif to Google Drive folder.
# Copied 1610_planet.tif to Google Drive folder.
# Copied 999_planet.tif to Google Drive folder.
# Copied 906_planet.tif to Google Drive folder.
# Copied 1713_planet.tif to Google Drive folder.
# Copied 2270_planet.tif to Google Drive folder.
# Copied 835_planet.tif to Google Drive folder.
# Copied 2150_planet.tif to Google Drive folder.
# Copied 1526_planet.tif to Google Drive folder.
# Copied 1582_planet.tif to Google Drive folder.
# Copied 1276_planet.tif to Google Drive folder.
# Copied 2558_planet.tif to Google Drive folder.
# Copied 2367_planet.tif to Google Drive folder.
# Copied 210_planet.tif to Google Drive folder.
# Copied 2139_planet.tif to Google Drive folder.
# Copied 282_planet.tif to Google Drive folder.
# Copied 740_planet.tif to Google Drive folder.
# Copied 468_planet.tif to Google Drive folder.
# Copied 522_planet.tif to Google Drive folder.
# Copied 1086_planet.tif to Google Drive folder.
# Copied 88_planet.tif to Google Drive folder.

# %%
export_path = "/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/images_2020/"
tif_source = "/content/image/content/exports/utm4_2020/"

# Ensure the destination folder exists
if not os.path.exists(export_path):
    os.makedirs(export_path)

# List all .tif files in the source directory
tif_files = [f for f in os.listdir(tif_source) if f.endswith('.tif')]

# Copy each .tif file to the Google Drive destination folder
for tif_file in tif_files:
    source_path = os.path.join(tif_source, tif_file)
    destination_path = os.path.join(export_path, tif_file)
    shutil.copy(source_path, destination_path)
    print(f"Copied {tif_file} to Google Drive folder.")
# Out:
# Copied 1792_planet.tif to Google Drive folder.
# Copied 2208_planet.tif to Google Drive folder.
# Copied 559_planet.tif to Google Drive folder.
# Copied 2022_planet.tif to Google Drive folder.
# Copied 2578_planet.tif to Google Drive folder.
# Copied 995_planet.tif to Google Drive folder.
# Copied 2060_planet.tif to Google Drive folder.
# Copied 1612_planet.tif to Google Drive folder.
# Copied 895_planet.tif to Google Drive folder.
# Copied 475_planet.tif to Google Drive folder.
# Copied 1618_planet.tif to Google Drive folder.
# Copied 100_planet.tif to Google Drive folder.
# Copied 1004_planet.tif to Google Drive folder.
# Copied 2570_planet.tif to Google Drive folder.
# Copied 1978_planet.tif to Google Drive folder.
# Copied 362_planet.tif to Google Drive folder.
# Copied 2364_planet.tif to Google Drive folder.
# Copied 1191_planet.tif to Google Drive folder.
# Copied 1001_planet.tif to Google Drive folder.
# Copied 1976_planet.tif to Google Drive folder.
# Copied 1398_planet.tif to Google Drive folder.
# Copied 193_planet.tif to Google Drive folder.
# Copied 515_planet.tif to Google Drive folder.
# Copied 2340_planet.tif to Google Drive folder.
# Copied 55_planet.tif to Google Drive folder.
# Copied 1114_planet.tif to Google Drive folder.
# Copied 2607_planet.tif to Google Drive folder.
# Copied 2068_planet.tif to Google Drive folder.
# Copied 1652_planet.tif to Google Drive folder.
# Copied 2201_planet.tif to Google Drive folder.
# Copied 2138_planet.tif to Google Drive folder.
# Copied 1812_planet.tif to Google Drive folder.
# Copied 1414_planet.tif to Google Drive folder.
# Copied 1906_planet.tif to Google Drive folder.
# Copied 35_planet.tif to Google Drive folder.
# Copied 2025_planet.tif to Google Drive folder.
# Copied 1303_planet.tif to Google Drive folder.
# Copied 2658_planet.tif to Google Drive folder.
# Copied 435_planet.tif to Google Drive folder.
# Copied 1029_planet.tif to Google Drive folder.
# Copied 1979_planet.tif to Google Drive folder.
# Copied 851_planet.tif to Google Drive folder.
# Copied 505_planet.tif to Google Drive folder.
# Copied 1333_planet.tif to Google Drive folder.
# Copied 349_planet.tif to Google Drive folder.
# Copied 727_planet.tif to Google Drive folder.
# Copied 2223_planet.tif to Google Drive folder.
# Copied 50_planet.tif to Google Drive folder.
# Copied 11_planet.tif to Google Drive folder.
# Copied 2346_planet.tif to Google Drive folder.
# Copied 1296_planet.tif to Google Drive folder.
# Copied 512_planet.tif to Google Drive folder.
# Copied 882_planet.tif to Google Drive folder.
# Copied 2056_planet.tif to Google Drive folder.
# Copied 1998_planet.tif to Google Drive folder.
# Copied 1128_planet.tif to Google Drive folder.
# Copied 2189_planet.tif to Google Drive folder.
# Copied 2664_planet.tif to Google Drive folder.
# Copied 544_planet.tif to Google Drive folder.
# Copied 613_planet.tif to Google Drive folder.
# Copied 2567_planet.tif to Google Drive folder.
# Copied 2131_planet.tif to Google Drive folder.
# Copied 699_planet.tif to Google Drive folder.
# Copied 1164_planet.tif to Google Drive folder.
# Copied 638_planet.tif to Google Drive folder.
# Copied 2620_planet.tif to Google Drive folder.
# Copied 538_planet.tif to Google Drive folder.
# Copied 2525_planet.tif to Google Drive folder.
# Copied 99_planet.tif to Google Drive folder.
# Copied 1860_planet.tif to Google Drive folder.
# Copied 1819_planet.tif to Google Drive folder.
# Copied 1325_planet.tif to Google Drive folder.
# Copied 403_planet.tif to Google Drive folder.
# Copied 2392_planet.tif to Google Drive folder.
# Copied 22_planet.tif to Google Drive folder.
# Copied 1653_planet.tif to Google Drive folder.
# Copied 1901_planet.tif to Google Drive folder.
# Copied 439_planet.tif to Google Drive folder.
# Copied 129_planet.tif to Google Drive folder.
# Copied 989_planet.tif to Google Drive folder.
# Copied 489_planet.tif to Google Drive folder.
# Copied 2028_planet.tif to Google Drive folder.
# Copied 1574_planet.tif to Google Drive folder.
# Copied 510_planet.tif to Google Drive folder.
# Copied 977_planet.tif to Google Drive folder.
# Copied 119_planet.tif to Google Drive folder.
# Copied 2608_planet.tif to Google Drive folder.
# Copied 1855_planet.tif to Google Drive folder.
# Copied 1625_planet.tif to Google Drive folder.
# Copied 1649_planet.tif to Google Drive folder.
# Copied 445_planet.tif to Google Drive folder.
# Copied 1336_planet.tif to Google Drive folder.
# Copied 108_planet.tif to Google Drive folder.
# Copied 1729_planet.tif to Google Drive folder.
# Copied 726_planet.tif to Google Drive folder.
# Copied 2244_planet.tif to Google Drive folder.
# Copied 988_planet.tif to Google Drive folder.
# Copied 2263_planet.tif to Google Drive folder.
# Copied 1895_planet.tif to Google Drive folder.
# Copied 585_planet.tif to Google Drive folder.
# Copied 2547_planet.tif to Google Drive folder.
# Copied 324_planet.tif to Google Drive folder.
# Copied 1165_planet.tif to Google Drive folder.
# Copied 1702_planet.tif to Google Drive folder.
# Copied 803_planet.tif to Google Drive folder.
# Copied 791_planet.tif to Google Drive folder.
# Copied 998_planet.tif to Google Drive folder.
# Copied 472_planet.tif to Google Drive folder.
# Copied 68_planet.tif to Google Drive folder.
# Copied 1891_planet.tif to Google Drive folder.
# Copied 610_planet.tif to Google Drive folder.
# Copied 2104_planet.tif to Google Drive folder.
# Copied 756_planet.tif to Google Drive folder.
# Copied 2348_planet.tif to Google Drive folder.
# Copied 89_planet.tif to Google Drive folder.
# Copied 1230_planet.tif to Google Drive folder.
# Copied 1368_planet.tif to Google Drive folder.
# Copied 1651_planet.tif to Google Drive folder.
# Copied 956_planet.tif to Google Drive folder.
# Copied 327_planet.tif to Google Drive folder.
# Copied 1776_planet.tif to Google Drive folder.
# Copied 2326_planet.tif to Google Drive folder.
# Copied 476_planet.tif to Google Drive folder.
# Copied 587_planet.tif to Google Drive folder.
# Copied 2579_planet.tif to Google Drive folder.
# Copied 885_planet.tif to Google Drive folder.
# Copied 793_planet.tif to Google Drive folder.
# Copied 1313_planet.tif to Google Drive folder.
# Copied 2085_planet.tif to Google Drive folder.
# Copied 1269_planet.tif to Google Drive folder.
# Copied 848_planet.tif to Google Drive folder.
# Copied 335_planet.tif to Google Drive folder.
# Copied 1501_planet.tif to Google Drive folder.
# Copied 1424_planet.tif to Google Drive folder.
# Copied 1298_planet.tif to Google Drive folder.
# Copied 1223_planet.tif to Google Drive folder.
# Copied 2118_planet.tif to Google Drive folder.
# Copied 601_planet.tif to Google Drive folder.
# Copied 2588_planet.tif to Google Drive folder.
# Copied 389_planet.tif to Google Drive folder.
# Copied 1116_planet.tif to Google Drive folder.
# Copied 469_planet.tif to Google Drive folder.
# Copied 2196_planet.tif to Google Drive folder.
# Copied 1282_planet.tif to Google Drive folder.
# Copied 2182_planet.tif to Google Drive folder.
# Copied 2380_planet.tif to Google Drive folder.
# Copied 1816_planet.tif to Google Drive folder.
# Copied 2295_planet.tif to Google Drive folder.
# Copied 2652_planet.tif to Google Drive folder.
# Copied 1412_planet.tif to Google Drive folder.
# Copied 318_planet.tif to Google Drive folder.
# Copied 1179_planet.tif to Google Drive folder.
# Copied 496_planet.tif to Google Drive folder.
# Copied 2038_planet.tif to Google Drive folder.
# Copied 2071_planet.tif to Google Drive folder.
# Copied 2335_planet.tif to Google Drive folder.
# Copied 1143_planet.tif to Google Drive folder.
# Copied 2541_planet.tif to Google Drive folder.
# Copied 687_planet.tif to Google Drive folder.
# Copied 2081_planet.tif to Google Drive folder.
# Copied 2612_planet.tif to Google Drive folder.
# Copied 869_planet.tif to Google Drive folder.
# Copied 892_planet.tif to Google Drive folder.
# Copied 2119_planet.tif to Google Drive folder.
# Copied 330_planet.tif to Google Drive folder.
# Copied 1145_planet.tif to Google Drive folder.
# Copied 2441_planet.tif to Google Drive folder.
# Copied 819_planet.tif to Google Drive folder.
# Copied 657_planet.tif to Google Drive folder.
# Copied 715_planet.tif to Google Drive folder.
# Copied 1220_planet.tif to Google Drive folder.
# Copied 767_planet.tif to Google Drive folder.
# Copied 1119_planet.tif to Google Drive folder.
# Copied 1121_planet.tif to Google Drive folder.
# Copied 46_planet.tif to Google Drive folder.
# Copied 405_planet.tif to Google Drive folder.
# Copied 51_planet.tif to Google Drive folder.
# Copied 543_planet.tif to Google Drive folder.
# Copied 1835_planet.tif to Google Drive folder.
# Copied 2472_planet.tif to Google Drive folder.
# Copied 436_planet.tif to Google Drive folder.
# Copied 2014_planet.tif to Google Drive folder.
# Copied 596_planet.tif to Google Drive folder.
# Copied 1579_planet.tif to Google Drive folder.
# Copied 1291_planet.tif to Google Drive folder.
# Copied 570_planet.tif to Google Drive folder.
# Copied 1163_planet.tif to Google Drive folder.
# Copied 986_planet.tif to Google Drive folder.
# Copied 1448_planet.tif to Google Drive folder.
# Copied 2618_planet.tif to Google Drive folder.
# Copied 1775_planet.tif to Google Drive folder.
# Copied 189_planet.tif to Google Drive folder.
# Copied 567_planet.tif to Google Drive folder.
# Copied 311_planet.tif to Google Drive folder.
# Copied 1331_planet.tif to Google Drive folder.
# Copied 1632_planet.tif to Google Drive folder.
# Copied 1036_planet.tif to Google Drive folder.
# Copied 2149_planet.tif to Google Drive folder.
# Copied 2035_planet.tif to Google Drive folder.
# Copied 116_planet.tif to Google Drive folder.
# Copied 1493_planet.tif to Google Drive folder.
# Copied 2483_planet.tif to Google Drive folder.
# Copied 493_planet.tif to Google Drive folder.
# Copied 823_planet.tif to Google Drive folder.
# Copied 47_planet.tif to Google Drive folder.
# Copied 351_planet.tif to Google Drive folder.
# Copied 45_planet.tif to Google Drive folder.
# Copied 1184_planet.tif to Google Drive folder.
# Copied 2301_planet.tif to Google Drive folder.
# Copied 2453_planet.tif to Google Drive folder.
# Copied 886_planet.tif to Google Drive folder.
# Copied 586_planet.tif to Google Drive folder.
# Copied 2544_planet.tif to Google Drive folder.
# Copied 1034_planet.tif to Google Drive folder.
# Copied 2552_planet.tif to Google Drive folder.
# Copied 1616_planet.tif to Google Drive folder.
# Copied 1945_planet.tif to Google Drive folder.
# Copied 2466_planet.tif to Google Drive folder.
# Copied 1684_planet.tif to Google Drive folder.
# Copied 2628_planet.tif to Google Drive folder.
# Copied 2108_planet.tif to Google Drive folder.
# Copied 1772_planet.tif to Google Drive folder.
# Copied 246_planet.tif to Google Drive folder.
# Copied 866_planet.tif to Google Drive folder.
# Copied 1293_planet.tif to Google Drive folder.
# Copied 1457_planet.tif to Google Drive folder.
# Copied 1817_planet.tif to Google Drive folder.
# Copied 2350_planet.tif to Google Drive folder.
# Copied 217_planet.tif to Google Drive folder.
# Copied 2112_planet.tif to Google Drive folder.
# Copied 1512_planet.tif to Google Drive folder.
# Copied 2128_planet.tif to Google Drive folder.
# Copied 2566_planet.tif to Google Drive folder.
# Copied 1808_planet.tif to Google Drive folder.
# Copied 1390_planet.tif to Google Drive folder.
# Copied 1747_planet.tif to Google Drive folder.
# Copied 1765_planet.tif to Google Drive folder.
# Copied 1300_planet.tif to Google Drive folder.
# Copied 2152_planet.tif to Google Drive folder.
# Copied 1312_planet.tif to Google Drive folder.
# Copied 1281_planet.tif to Google Drive folder.
# Copied 1454_planet.tif to Google Drive folder.
# Copied 1531_planet.tif to Google Drive folder.
# Copied 2436_planet.tif to Google Drive folder.
# Copied 1883_planet.tif to Google Drive folder.
# Copied 828_planet.tif to Google Drive folder.
# Copied 230_planet.tif to Google Drive folder.
# Copied 990_planet.tif to Google Drive folder.
# Copied 2010_planet.tif to Google Drive folder.
# Copied 231_planet.tif to Google Drive folder.
# Copied 82_planet.tif to Google Drive folder.
# Copied 2275_planet.tif to Google Drive folder.
# Copied 1405_planet.tif to Google Drive folder.
# Copied 1363_planet.tif to Google Drive folder.
# Copied 2514_planet.tif to Google Drive folder.
# Copied 1437_planet.tif to Google Drive folder.
# Copied 1857_planet.tif to Google Drive folder.
# Copied 748_planet.tif to Google Drive folder.
# Copied 839_planet.tif to Google Drive folder.
# Copied 1067_planet.tif to Google Drive folder.
# Copied 1340_planet.tif to Google Drive folder.
# Copied 741_planet.tif to Google Drive folder.
# Copied 1709_planet.tif to Google Drive folder.
# Copied 1206_planet.tif to Google Drive folder.
# Copied 136_planet.tif to Google Drive folder.
# Copied 179_planet.tif to Google Drive folder.
# Copied 460_planet.tif to Google Drive folder.
# Copied 713_planet.tif to Google Drive folder.
# Copied 675_planet.tif to Google Drive folder.
# Copied 1941_planet.tif to Google Drive folder.
# Copied 1192_planet.tif to Google Drive folder.
# Copied 2533_planet.tif to Google Drive folder.
# Copied 2319_planet.tif to Google Drive folder.
# Copied 1487_planet.tif to Google Drive folder.
# Copied 266_planet.tif to Google Drive folder.
# Copied 1439_planet.tif to Google Drive folder.
# Copied 528_planet.tif to Google Drive folder.
# Copied 273_planet.tif to Google Drive folder.
# Copied 1274_planet.tif to Google Drive folder.
# Copied 2471_planet.tif to Google Drive folder.
# Copied 1662_planet.tif to Google Drive folder.
# Copied 1549_planet.tif to Google Drive folder.
# Copied 749_planet.tif to Google Drive folder.
# Copied 1240_planet.tif to Google Drive folder.
# Copied 1851_planet.tif to Google Drive folder.
# Copied 1594_planet.tif to Google Drive folder.
# Copied 690_planet.tif to Google Drive folder.
# Copied 145_planet.tif to Google Drive folder.
# Copied 575_planet.tif to Google Drive folder.
# Copied 2212_planet.tif to Google Drive folder.
# Copied 1727_planet.tif to Google Drive folder.
# Copied 1791_planet.tif to Google Drive folder.
# Copied 903_planet.tif to Google Drive folder.
# Copied 1435_planet.tif to Google Drive folder.
# Copied 752_planet.tif to Google Drive folder.
# Copied 1867_planet.tif to Google Drive folder.
# Copied 513_planet.tif to Google Drive folder.
# Copied 276_planet.tif to Google Drive folder.
# Copied 244_planet.tif to Google Drive folder.
# Copied 245_planet.tif to Google Drive folder.
# Copied 419_planet.tif to Google Drive folder.
# Copied 2164_planet.tif to Google Drive folder.
# Copied 2169_planet.tif to Google Drive folder.
# Copied 1131_planet.tif to Google Drive folder.
# Copied 2332_planet.tif to Google Drive folder.
# Copied 2174_planet.tif to Google Drive folder.
# Copied 1380_planet.tif to Google Drive folder.
# Copied 714_planet.tif to Google Drive folder.
# Copied 306_planet.tif to Google Drive folder.
# Copied 1309_planet.tif to Google Drive folder.
# Copied 2458_planet.tif to Google Drive folder.
# Copied 760_planet.tif to Google Drive folder.
# Copied 1242_planet.tif to Google Drive folder.
# Copied 79_planet.tif to Google Drive folder.
# Copied 1449_planet.tif to Google Drive folder.
# Copied 1346_planet.tif to Google Drive folder.
# Copied 2007_planet.tif to Google Drive folder.
# Copied 1295_planet.tif to Google Drive folder.
# Copied 1527_planet.tif to Google Drive folder.
# Copied 1035_planet.tif to Google Drive folder.
# Copied 1619_planet.tif to Google Drive folder.
# Copied 702_planet.tif to Google Drive folder.
# Copied 2114_planet.tif to Google Drive folder.
# Copied 1063_planet.tif to Google Drive folder.
# Copied 312_planet.tif to Google Drive folder.
# Copied 2307_planet.tif to Google Drive folder.
# Copied 722_planet.tif to Google Drive folder.
# Copied 416_planet.tif to Google Drive folder.
# Copied 987_planet.tif to Google Drive folder.
# Copied 2125_planet.tif to Google Drive folder.
# Copied 2032_planet.tif to Google Drive folder.
# Copied 366_planet.tif to Google Drive folder.
# Copied 2141_planet.tif to Google Drive folder.
# Copied 1319_planet.tif to Google Drive folder.
# Copied 2478_planet.tif to Google Drive folder.
# Copied 1074_planet.tif to Google Drive folder.
# Copied 109_planet.tif to Google Drive folder.
# Copied 1021_planet.tif to Google Drive folder.
# Copied 2059_planet.tif to Google Drive folder.
# Copied 258_planet.tif to Google Drive folder.
# Copied 1689_planet.tif to Google Drive folder.
# Copied 502_planet.tif to Google Drive folder.
# Copied 1529_planet.tif to Google Drive folder.
# Copied 1195_planet.tif to Google Drive folder.
# Copied 1751_planet.tif to Google Drive folder.
# Copied 27_planet.tif to Google Drive folder.
# Copied 319_planet.tif to Google Drive folder.
# Copied 1434_planet.tif to Google Drive folder.
# Copied 491_planet.tif to Google Drive folder.
# Copied 1567_planet.tif to Google Drive folder.
# Copied 1924_planet.tif to Google Drive folder.
# Copied 1664_planet.tif to Google Drive folder.
# Copied 28_planet.tif to Google Drive folder.
# Copied 781_planet.tif to Google Drive folder.
# Copied 2498_planet.tif to Google Drive folder.
# Copied 2379_planet.tif to Google Drive folder.
# Copied 1358_planet.tif to Google Drive folder.
# Copied 1551_planet.tif to Google Drive folder.
# Copied 2274_planet.tif to Google Drive folder.
# Copied 1418_planet.tif to Google Drive folder.
# Copied 1790_planet.tif to Google Drive folder.
# Copied 2214_planet.tif to Google Drive folder.
# Copied 370_planet.tif to Google Drive folder.
# Copied 1912_planet.tif to Google Drive folder.
# Copied 1494_planet.tif to Google Drive folder.
# Copied 274_planet.tif to Google Drive folder.
# Copied 1083_planet.tif to Google Drive folder.
# Copied 529_planet.tif to Google Drive folder.
# Copied 1002_planet.tif to Google Drive folder.
# Copied 2197_planet.tif to Google Drive folder.
# Copied 1989_planet.tif to Google Drive folder.
# Copied 1560_planet.tif to Google Drive folder.
# Copied 156_planet.tif to Google Drive folder.
# Copied 533_planet.tif to Google Drive folder.
# Copied 1157_planet.tif to Google Drive folder.
# Copied 646_planet.tif to Google Drive folder.
# Copied 1371_planet.tif to Google Drive folder.
# Copied 447_planet.tif to Google Drive folder.
# Copied 1048_planet.tif to Google Drive folder.
# Copied 888_planet.tif to Google Drive folder.
# Copied 2501_planet.tif to Google Drive folder.
# Copied 2304_planet.tif to Google Drive folder.
# Copied 1000_planet.tif to Google Drive folder.
# Copied 1008_planet.tif to Google Drive folder.
# Copied 1722_planet.tif to Google Drive folder.
# Copied 2508_planet.tif to Google Drive folder.
# Copied 1492_planet.tif to Google Drive folder.
# Copied 1972_planet.tif to Google Drive folder.
# Copied 2356_planet.tif to Google Drive folder.
# Copied 192_planet.tif to Google Drive folder.
# Copied 717_planet.tif to Google Drive folder.
# Copied 328_planet.tif to Google Drive folder.
# Copied 2497_planet.tif to Google Drive folder.
# Copied 2455_planet.tif to Google Drive folder.
# Copied 2241_planet.tif to Google Drive folder.
# Copied 114_planet.tif to Google Drive folder.
# Copied 2218_planet.tif to Google Drive folder.
# Copied 1585_planet.tif to Google Drive folder.
# Copied 2538_planet.tif to Google Drive folder.
# Copied 2284_planet.tif to Google Drive folder.
# Copied 808_planet.tif to Google Drive folder.
# Copied 359_planet.tif to Google Drive folder.
# Copied 1896_planet.tif to Google Drive folder.
# Copied 1142_planet.tif to Google Drive folder.
# Copied 1198_planet.tif to Google Drive folder.
# Copied 2583_planet.tif to Google Drive folder.
# Copied 295_planet.tif to Google Drive folder.
# Copied 1033_planet.tif to Google Drive folder.
# Copied 2420_planet.tif to Google Drive folder.
# Copied 1013_planet.tif to Google Drive folder.
# Copied 968_planet.tif to Google Drive folder.
# Copied 1401_planet.tif to Google Drive folder.
# Copied 1252_planet.tif to Google Drive folder.
# Copied 981_planet.tif to Google Drive folder.
# Copied 898_planet.tif to Google Drive folder.
# Copied 2485_planet.tif to Google Drive folder.
# Copied 647_planet.tif to Google Drive folder.
# Copied 2200_planet.tif to Google Drive folder.
# Copied 1849_planet.tif to Google Drive folder.
# Copied 211_planet.tif to Google Drive folder.
# Copied 1838_planet.tif to Google Drive folder.
# Copied 1951_planet.tif to Google Drive folder.
# Copied 1541_planet.tif to Google Drive folder.
# Copied 1606_planet.tif to Google Drive folder.
# Copied 2345_planet.tif to Google Drive folder.
# Copied 1914_planet.tif to Google Drive folder.
# Copied 143_planet.tif to Google Drive folder.
# Copied 458_planet.tif to Google Drive folder.
# Copied 2058_planet.tif to Google Drive folder.
# Copied 2491_planet.tif to Google Drive folder.
# Copied 2373_planet.tif to Google Drive folder.
# Copied 1757_planet.tif to Google Drive folder.
# Copied 1261_planet.tif to Google Drive folder.
# Copied 1982_planet.tif to Google Drive folder.
# Copied 667_planet.tif to Google Drive folder.
# Copied 1260_planet.tif to Google Drive folder.
# Copied 718_planet.tif to Google Drive folder.
# Copied 1759_planet.tif to Google Drive folder.
# Copied 92_planet.tif to Google Drive folder.
# Copied 1674_planet.tif to Google Drive folder.
# Copied 1075_planet.tif to Google Drive folder.
# Copied 2161_planet.tif to Google Drive folder.
# Copied 2639_planet.tif to Google Drive folder.
# Copied 190_planet.tif to Google Drive folder.
# Copied 1604_planet.tif to Google Drive folder.
# Copied 1853_planet.tif to Google Drive folder.
# Copied 2153_planet.tif to Google Drive folder.
# Copied 152_planet.tif to Google Drive folder.
# Copied 826_planet.tif to Google Drive folder.
# Copied 2020_planet.tif to Google Drive folder.
# Copied 2322_planet.tif to Google Drive folder.
# Copied 2329_planet.tif to Google Drive folder.
# Copied 2631_planet.tif to Google Drive folder.
# Copied 1939_planet.tif to Google Drive folder.
# Copied 1406_planet.tif to Google Drive folder.
# Copied 1151_planet.tif to Google Drive folder.
# Copied 2352_planet.tif to Google Drive folder.
# Copied 385_planet.tif to Google Drive folder.
# Copied 2581_planet.tif to Google Drive folder.
# Copied 1779_planet.tif to Google Drive folder.
# Copied 216_planet.tif to Google Drive folder.
# Copied 1091_planet.tif to Google Drive folder.
# Copied 2324_planet.tif to Google Drive folder.
# Copied 484_planet.tif to Google Drive folder.
# Copied 481_planet.tif to Google Drive folder.
# Copied 1249_planet.tif to Google Drive folder.
# Copied 2107_planet.tif to Google Drive folder.
# Copied 1129_planet.tif to Google Drive folder.
# Copied 137_planet.tif to Google Drive folder.
# Copied 2635_planet.tif to Google Drive folder.
# Copied 26_planet.tif to Google Drive folder.
# Copied 1569_planet.tif to Google Drive folder.
# Copied 194_planet.tif to Google Drive folder.
# Copied 151_planet.tif to Google Drive folder.
# Copied 1793_planet.tif to Google Drive folder.
# Copied 1216_planet.tif to Google Drive folder.
# Copied 215_planet.tif to Google Drive folder.
# Copied 852_planet.tif to Google Drive folder.
# Copied 249_planet.tif to Google Drive folder.
# Copied 2073_planet.tif to Google Drive folder.
# Copied 1968_planet.tif to Google Drive folder.
# Copied 2454_planet.tif to Google Drive folder.
# Copied 1030_planet.tif to Google Drive folder.
# Copied 1524_planet.tif to Google Drive folder.
# Copied 1411_planet.tif to Google Drive folder.
# Copied 605_planet.tif to Google Drive folder.
# Copied 1600_planet.tif to Google Drive folder.
# Copied 789_planet.tif to Google Drive folder.
# Copied 205_planet.tif to Google Drive folder.
# Copied 1888_planet.tif to Google Drive folder.
# Copied 1272_planet.tif to Google Drive folder.
# Copied 425_planet.tif to Google Drive folder.
# Copied 696_planet.tif to Google Drive folder.
# Copied 1690_planet.tif to Google Drive folder.
# Copied 1596_planet.tif to Google Drive folder.
# Copied 771_planet.tif to Google Drive folder.
# Copied 20_planet.tif to Google Drive folder.
# Copied 877_planet.tif to Google Drive folder.
# Copied 1766_planet.tif to Google Drive folder.
# Copied 589_planet.tif to Google Drive folder.
# Copied 2273_planet.tif to Google Drive folder.
# Copied 779_planet.tif to Google Drive folder.
# Copied 1691_planet.tif to Google Drive folder.
# Copied 1837_planet.tif to Google Drive folder.
# Copied 168_planet.tif to Google Drive folder.
# Copied 1679_planet.tif to Google Drive folder.
# Copied 1467_planet.tif to Google Drive folder.
# Copied 1536_planet.tif to Google Drive folder.
# Copied 320_planet.tif to Google Drive folder.
# Copied 2126_planet.tif to Google Drive folder.
# Copied 2622_planet.tif to Google Drive folder.
# Copied 2253_planet.tif to Google Drive folder.
# Copied 1305_planet.tif to Google Drive folder.
# Copied 1996_planet.tif to Google Drive folder.
# Copied 2260_planet.tif to Google Drive folder.
# Copied 1038_planet.tif to Google Drive folder.
# Copied 867_planet.tif to Google Drive folder.
# Copied 2575_planet.tif to Google Drive folder.
# Copied 1373_planet.tif to Google Drive folder.
# Copied 1172_planet.tif to Google Drive folder.
# Copied 1009_planet.tif to Google Drive folder.
# Copied 1410_planet.tif to Google Drive folder.
# Copied 1200_planet.tif to Google Drive folder.
# Copied 2097_planet.tif to Google Drive folder.
# Copied 53_planet.tif to Google Drive folder.
# Copied 1693_planet.tif to Google Drive folder.
# Copied 1207_planet.tif to Google Drive folder.
# Copied 2385_planet.tif to Google Drive folder.
# Copied 120_planet.tif to Google Drive folder.
# Copied 577_planet.tif to Google Drive folder.
# Copied 1015_planet.tif to Google Drive folder.
# Copied 1992_planet.tif to Google Drive folder.
# Copied 1603_planet.tif to Google Drive folder.
# Copied 478_planet.tif to Google Drive folder.
# Copied 1841_planet.tif to Google Drive folder.
# Copied 2100_planet.tif to Google Drive folder.
# Copied 800_planet.tif to Google Drive folder.
# Copied 1307_planet.tif to Google Drive folder.
# Copied 2136_planet.tif to Google Drive folder.
# Copied 1918_planet.tif to Google Drive folder.
# Copied 431_planet.tif to Google Drive folder.
# Copied 1712_planet.tif to Google Drive folder.
# Copied 1511_planet.tif to Google Drive folder.
# Copied 1085_planet.tif to Google Drive folder.
# Copied 225_planet.tif to Google Drive folder.
# Copied 2333_planet.tif to Google Drive folder.
# Copied 1953_planet.tif to Google Drive folder.
# Copied 1591_planet.tif to Google Drive folder.
# Copied 112_planet.tif to Google Drive folder.
# Copied 653_planet.tif to Google Drive folder.
# Copied 786_planet.tif to Google Drive folder.
# Copied 1270_planet.tif to Google Drive folder.
# Copied 1897_planet.tif to Google Drive folder.
# Copied 1140_planet.tif to Google Drive folder.
# Copied 1535_planet.tif to Google Drive folder.
# Copied 2041_planet.tif to Google Drive folder.
# Copied 257_planet.tif to Google Drive folder.
# Copied 933_planet.tif to Google Drive folder.
# Copied 18_planet.tif to Google Drive folder.
# Copied 2595_planet.tif to Google Drive folder.
# Copied 1466_planet.tif to Google Drive folder.
# Copied 2036_planet.tif to Google Drive folder.
# Copied 2154_planet.tif to Google Drive folder.
# Copied 1330_planet.tif to Google Drive folder.
# Copied 1221_planet.tif to Google Drive folder.
# Copied 993_planet.tif to Google Drive folder.
# Copied 1463_planet.tif to Google Drive folder.
# Copied 2521_planet.tif to Google Drive folder.
# Copied 557_planet.tif to Google Drive folder.
# Copied 2660_planet.tif to Google Drive folder.
# Copied 201_planet.tif to Google Drive folder.
# Copied 200_planet.tif to Google Drive folder.
# Copied 891_planet.tif to Google Drive folder.
# Copied 1654_planet.tif to Google Drive folder.
# Copied 1136_planet.tif to Google Drive folder.
# Copied 2109_planet.tif to Google Drive folder.
# Copied 547_planet.tif to Google Drive folder.
# Copied 2470_planet.tif to Google Drive folder.
# Copied 396_planet.tif to Google Drive folder.
# Copied 1226_planet.tif to Google Drive folder.
# Copied 2550_planet.tif to Google Drive folder.
# Copied 942_planet.tif to Google Drive folder.
# Copied 1859_planet.tif to Google Drive folder.
# Copied 642_planet.tif to Google Drive folder.
# Copied 74_planet.tif to Google Drive folder.
# Copied 2404_planet.tif to Google Drive folder.
# Copied 1993_planet.tif to Google Drive folder.
# Copied 378_planet.tif to Google Drive folder.
# Copied 1758_planet.tif to Google Drive folder.
# Copied 165_planet.tif to Google Drive folder.
# Copied 1419_planet.tif to Google Drive folder.
# Copied 571_planet.tif to Google Drive folder.
# Copied 162_planet.tif to Google Drive folder.
# Copied 1525_planet.tif to Google Drive folder.
# Copied 569_planet.tif to Google Drive folder.
# Copied 2536_planet.tif to Google Drive folder.
# Copied 2532_planet.tif to Google Drive folder.
# Copied 153_planet.tif to Google Drive folder.
# Copied 2449_planet.tif to Google Drive folder.
# Copied 1432_planet.tif to Google Drive folder.
# Copied 422_planet.tif to Google Drive folder.
# Copied 411_planet.tif to Google Drive folder.
# Copied 669_planet.tif to Google Drive folder.
# Copied 1263_planet.tif to Google Drive folder.
# Copied 1922_planet.tif to Google Drive folder.
# Copied 1588_planet.tif to Google Drive folder.
# Copied 929_planet.tif to Google Drive folder.
# Copied 2662_planet.tif to Google Drive folder.
# Copied 1497_planet.tif to Google Drive folder.
# Copied 1299_planet.tif to Google Drive folder.
# Copied 896_planet.tif to Google Drive folder.
# Copied 1446_planet.tif to Google Drive folder.
# Copied 963_planet.tif to Google Drive folder.
# Copied 360_planet.tif to Google Drive folder.
# Copied 552_planet.tif to Google Drive folder.
# Copied 1287_planet.tif to Google Drive folder.
# Copied 2170_planet.tif to Google Drive folder.
# Copied 1103_planet.tif to Google Drive folder.
# Copied 1761_planet.tif to Google Drive folder.
# Copied 1364_planet.tif to Google Drive folder.
# Copied 2009_planet.tif to Google Drive folder.
# Copied 1217_planet.tif to Google Drive folder.
# Copied 1728_planet.tif to Google Drive folder.
# Copied 897_planet.tif to Google Drive folder.
# Copied 2247_planet.tif to Google Drive folder.
# Copied 878_planet.tif to Google Drive folder.
# Copied 1665_planet.tif to Google Drive folder.
# Copied 1676_planet.tif to Google Drive folder.
# Copied 820_planet.tif to Google Drive folder.
# Copied 2371_planet.tif to Google Drive folder.
# Copied 492_planet.tif to Google Drive folder.
# Copied 1749_planet.tif to Google Drive folder.
# Copied 2224_planet.tif to Google Drive folder.
# Copied 609_planet.tif to Google Drive folder.
# Copied 2604_planet.tif to Google Drive folder.
# Copied 1994_planet.tif to Google Drive folder.
# Copied 2482_planet.tif to Google Drive folder.
# Copied 379_planet.tif to Google Drive folder.
# Copied 1633_planet.tif to Google Drive folder.
# Copied 2046_planet.tif to Google Drive folder.
# Copied 2051_planet.tif to Google Drive folder.
# Copied 1770_planet.tif to Google Drive folder.
# Copied 1182_planet.tif to Google Drive folder.
# Copied 19_planet.tif to Google Drive folder.
# Copied 2088_planet.tif to Google Drive folder.
# Copied 2496_planet.tif to Google Drive folder.
# Copied 332_planet.tif to Google Drive folder.
# Copied 641_planet.tif to Google Drive folder.
# Copied 1936_planet.tif to Google Drive folder.
# Copied 661_planet.tif to Google Drive folder.
# Copied 2246_planet.tif to Google Drive folder.
# Copied 698_planet.tif to Google Drive folder.
# Copied 1590_planet.tif to Google Drive folder.
# Copied 32_planet.tif to Google Drive folder.
# Copied 1711_planet.tif to Google Drive folder.
# Copied 2124_planet.tif to Google Drive folder.
# Copied 251_planet.tif to Google Drive folder.
# Copied 709_planet.tif to Google Drive folder.
# Copied 1807_planet.tif to Google Drive folder.
# Copied 1943_planet.tif to Google Drive folder.
# Copied 1636_planet.tif to Google Drive folder.
# Copied 1219_planet.tif to Google Drive folder.
# Copied 381_planet.tif to Google Drive folder.
# Copied 539_planet.tif to Google Drive folder.
# Copied 2278_planet.tif to Google Drive folder.
# Copied 2186_planet.tif to Google Drive folder.
# Copied 520_planet.tif to Google Drive folder.
# Copied 1944_planet.tif to Google Drive folder.
# Copied 2145_planet.tif to Google Drive folder.
# Copied 1856_planet.tif to Google Drive folder.
# Copied 725_planet.tif to Google Drive folder.
# Copied 2065_planet.tif to Google Drive folder.
# Copied 1503_planet.tif to Google Drive folder.
# Copied 881_planet.tif to Google Drive folder.
# Copied 1187_planet.tif to Google Drive folder.
# Copied 81_planet.tif to Google Drive folder.
# Copied 1959_planet.tif to Google Drive folder.
# Copied 2210_planet.tif to Google Drive folder.
# Copied 1400_planet.tif to Google Drive folder.
# Copied 1956_planet.tif to Google Drive folder.
# Copied 2018_planet.tif to Google Drive folder.
# Copied 104_planet.tif to Google Drive folder.
# Copied 1094_planet.tif to Google Drive folder.
# Copied 1311_planet.tif to Google Drive folder.
# Copied 2327_planet.tif to Google Drive folder.
# Copied 1697_planet.tif to Google Drive folder.
# Copied 862_planet.tif to Google Drive folder.
# Copied 2159_planet.tif to Google Drive folder.
# Copied 207_planet.tif to Google Drive folder.
# Copied 1668_planet.tif to Google Drive folder.
# Copied 939_planet.tif to Google Drive folder.
# Copied 2245_planet.tif to Google Drive folder.
# Copied 2232_planet.tif to Google Drive folder.
# Copied 755_planet.tif to Google Drive folder.
# Copied 2487_planet.tif to Google Drive folder.
# Copied 1534_planet.tif to Google Drive folder.
# Copied 313_planet.tif to Google Drive folder.
# Copied 1213_planet.tif to Google Drive folder.
# Copied 2621_planet.tif to Google Drive folder.
# Copied 1117_planet.tif to Google Drive folder.
# Copied 2560_planet.tif to Google Drive folder.
# Copied 1583_planet.tif to Google Drive folder.
# Copied 554_planet.tif to Google Drive folder.
# Copied 1639_planet.tif to Google Drive folder.
# Copied 353_planet.tif to Google Drive folder.
# Copied 1530_planet.tif to Google Drive folder.
# Copied 732_planet.tif to Google Drive folder.
# Copied 218_planet.tif to Google Drive folder.
# Copied 2383_planet.tif to Google Drive folder.
# Copied 73_planet.tif to Google Drive folder.
# Copied 1617_planet.tif to Google Drive folder.
# Copied 2271_planet.tif to Google Drive folder.
# Copied 2055_planet.tif to Google Drive folder.
# Copied 1986_planet.tif to Google Drive folder.
# Copied 388_planet.tif to Google Drive folder.
# Copied 2187_planet.tif to Google Drive folder.
# Copied 1137_planet.tif to Google Drive folder.
# Copied 736_planet.tif to Google Drive folder.
# Copied 765_planet.tif to Google Drive folder.
# Copied 712_planet.tif to Google Drive folder.
# Copied 2070_planet.tif to Google Drive folder.
# Copied 976_planet.tif to Google Drive folder.
# Copied 2225_planet.tif to Google Drive folder.
# Copied 1280_planet.tif to Google Drive folder.
# Copied 1593_planet.tif to Google Drive folder.
# Copied 1011_planet.tif to Google Drive folder.
# Copied 1279_planet.tif to Google Drive folder.
# Copied 1451_planet.tif to Google Drive folder.
# Copied 2398_planet.tif to Google Drive folder.
# Copied 1105_planet.tif to Google Drive folder.
# Copied 1784_planet.tif to Google Drive folder.
# Copied 1378_planet.tif to Google Drive folder.
# Copied 437_planet.tif to Google Drive folder.
# Copied 221_planet.tif to Google Drive folder.
# Copied 545_planet.tif to Google Drive folder.
# Copied 38_planet.tif to Google Drive folder.
# Copied 603_planet.tif to Google Drive folder.
# Copied 1962_planet.tif to Google Drive folder.
# Copied 2459_planet.tif to Google Drive folder.
# Copied 1683_planet.tif to Google Drive folder.
# Copied 2450_planet.tif to Google Drive folder.
# Copied 204_planet.tif to Google Drive folder.
# Copied 681_planet.tif to Google Drive folder.
# Copied 2477_planet.tif to Google Drive folder.
# Copied 597_planet.tif to Google Drive folder.
# Copied 1304_planet.tif to Google Drive folder.
# Copied 907_planet.tif to Google Drive folder.
# Copied 180_planet.tif to Google Drive folder.
# Copied 1351_planet.tif to Google Drive folder.
# Copied 140_planet.tif to Google Drive folder.
# Copied 2240_planet.tif to Google Drive folder.
# Copied 957_planet.tif to Google Drive folder.
# Copied 2096_planet.tif to Google Drive folder.
# Copied 1480_planet.tif to Google Drive folder.
# Copied 37_planet.tif to Google Drive folder.
# Copied 1542_planet.tif to Google Drive folder.
# Copied 1630_planet.tif to Google Drive folder.
# Copied 2561_planet.tif to Google Drive folder.
# Copied 44_planet.tif to Google Drive folder.
# Copied 2489_planet.tif to Google Drive folder.
# Copied 1893_planet.tif to Google Drive folder.
# Copied 2269_planet.tif to Google Drive folder.
# Copied 2343_planet.tif to Google Drive folder.
# Copied 1258_planet.tif to Google Drive folder.
# Copied 1848_planet.tif to Google Drive folder.
# Copied 2262_planet.tif to Google Drive folder.
# Copied 2103_planet.tif to Google Drive folder.
# Copied 1563_planet.tif to Google Drive folder.
# Copied 815_planet.tif to Google Drive folder.
# Copied 1554_planet.tif to Google Drive folder.
# Copied 775_planet.tif to Google Drive folder.
# Copied 1044_planet.tif to Google Drive folder.
# Copied 49_planet.tif to Google Drive folder.
# Copied 456_planet.tif to Google Drive folder.
# Copied 2004_planet.tif to Google Drive folder.
# Copied 2395_planet.tif to Google Drive folder.
# Copied 434_planet.tif to Google Drive folder.
# Copied 671_planet.tif to Google Drive folder.
# Copied 85_planet.tif to Google Drive folder.
# Copied 2317_planet.tif to Google Drive folder.
# Copied 391_planet.tif to Google Drive folder.
# Copied 1468_planet.tif to Google Drive folder.
# Copied 1043_planet.tif to Google Drive folder.
# Copied 1743_planet.tif to Google Drive folder.
# Copied 818_planet.tif to Google Drive folder.
# Copied 1548_planet.tif to Google Drive folder.
# Copied 1478_planet.tif to Google Drive folder.
# Copied 139_planet.tif to Google Drive folder.
# Copied 1455_planet.tif to Google Drive folder.
# Copied 1809_planet.tif to Google Drive folder.
# Copied 1985_planet.tif to Google Drive folder.
# Copied 2517_planet.tif to Google Drive folder.
# Copied 1886_planet.tif to Google Drive folder.
# Copied 2026_planet.tif to Google Drive folder.
# Copied 309_planet.tif to Google Drive folder.
# Copied 962_planet.tif to Google Drive folder.
# Copied 1950_planet.tif to Google Drive folder.
# Copied 2655_planet.tif to Google Drive folder.
# Copied 2415_planet.tif to Google Drive folder.
# Copied 2293_planet.tif to Google Drive folder.
# Copied 1065_planet.tif to Google Drive folder.
# Copied 1106_planet.tif to Google Drive folder.
# Copied 1472_planet.tif to Google Drive folder.
# Copied 1803_planet.tif to Google Drive folder.
# Copied 1930_planet.tif to Google Drive folder.
# Copied 787_planet.tif to Google Drive folder.
# Copied 198_planet.tif to Google Drive folder.
# Copied 1161_planet.tif to Google Drive folder.
# Copied 1475_planet.tif to Google Drive folder.
# Copied 191_planet.tif to Google Drive folder.
# Copied 2586_planet.tif to Google Drive folder.
# Copied 2215_planet.tif to Google Drive folder.
# Copied 2234_planet.tif to Google Drive folder.
# Copied 834_planet.tif to Google Drive folder.
# Copied 2584_planet.tif to Google Drive folder.
# Copied 2233_planet.tif to Google Drive folder.
# Copied 305_planet.tif to Google Drive folder.
# Copied 1614_planet.tif to Google Drive folder.
# Copied 2430_planet.tif to Google Drive folder.
# Copied 1052_planet.tif to Google Drive folder.
# Copied 172_planet.tif to Google Drive folder.
# Copied 706_planet.tif to Google Drive folder.
# Copied 1017_planet.tif to Google Drive folder.
# Copied 692_planet.tif to Google Drive folder.
# Copied 41_planet.tif to Google Drive folder.
# Copied 894_planet.tif to Google Drive folder.
# Copied 2589_planet.tif to Google Drive folder.
# Copied 1474_planet.tif to Google Drive folder.
# Copied 1937_planet.tif to Google Drive folder.
# Copied 1498_planet.tif to Google Drive folder.
# Copied 2377_planet.tif to Google Drive folder.
# Copied 958_planet.tif to Google Drive folder.
# Copied 2099_planet.tif to Google Drive folder.
# Copied 1183_planet.tif to Google Drive folder.
# Copied 1349_planet.tif to Google Drive folder.
# Copied 1447_planet.tif to Google Drive folder.
# Copied 2447_planet.tif to Google Drive folder.
# Copied 2202_planet.tif to Google Drive folder.
# Copied 2461_planet.tif to Google Drive folder.
# Copied 1024_planet.tif to Google Drive folder.
# Copied 286_planet.tif to Google Drive folder.
# Copied 296_planet.tif to Google Drive folder.
# Copied 960_planet.tif to Google Drive folder.
# Copied 2179_planet.tif to Google Drive folder.
# Copied 2653_planet.tif to Google Drive folder.
# Copied 486_planet.tif to Google Drive folder.
# Copied 812_planet.tif to Google Drive folder.
# Copied 1425_planet.tif to Google Drive folder.
# Copied 1705_planet.tif to Google Drive folder.
# Copied 870_planet.tif to Google Drive folder.
# Copied 357_planet.tif to Google Drive folder.
# Copied 2424_planet.tif to Google Drive folder.
# Copied 1545_planet.tif to Google Drive folder.
# Copied 2562_planet.tif to Google Drive folder.
# Copied 1294_planet.tif to Google Drive folder.
# Copied 1558_planet.tif to Google Drive folder.
# Copied 2462_planet.tif to Google Drive folder.
# Copied 598_planet.tif to Google Drive folder.
# Copied 1156_planet.tif to Google Drive folder.
# Copied 1335_planet.tif to Google Drive folder.
# Copied 1194_planet.tif to Google Drive folder.
# Copied 2222_planet.tif to Google Drive folder.
# Copied 634_planet.tif to Google Drive folder.
# Copied 1031_planet.tif to Google Drive folder.
# Copied 2523_planet.tif to Google Drive folder.
# Copied 1514_planet.tif to Google Drive folder.
# Copied 860_planet.tif to Google Drive folder.
# Copied 2393_planet.tif to Google Drive folder.
# Copied 1787_planet.tif to Google Drive folder.
# Copied 1607_planet.tif to Google Drive folder.
# Copied 173_planet.tif to Google Drive folder.
# Copied 372_planet.tif to Google Drive folder.
# Copied 1_planet.tif to Google Drive folder.
# Copied 535_planet.tif to Google Drive folder.
# Copied 1970_planet.tif to Google Drive folder.
# Copied 95_planet.tif to Google Drive folder.
# Copied 971_planet.tif to Google Drive folder.
# Copied 1931_planet.tif to Google Drive folder.
# Copied 738_planet.tif to Google Drive folder.
# Copied 1347_planet.tif to Google Drive folder.
# Copied 2601_planet.tif to Google Drive folder.
# Copied 2031_planet.tif to Google Drive folder.
# Copied 1623_planet.tif to Google Drive folder.
# Copied 1485_planet.tif to Google Drive folder.
# Copied 1479_planet.tif to Google Drive folder.
# Copied 2091_planet.tif to Google Drive folder.
# Copied 531_planet.tif to Google Drive folder.
# Copied 441_planet.tif to Google Drive folder.
# Copied 2341_planet.tif to Google Drive folder.
# Copied 212_planet.tif to Google Drive folder.
# Copied 555_planet.tif to Google Drive folder.
# Copied 2543_planet.tif to Google Drive folder.
# Copied 1620_planet.tif to Google Drive folder.
# Copied 375_planet.tif to Google Drive folder.
# Copied 470_planet.tif to Google Drive folder.
# Copied 303_planet.tif to Google Drive folder.
# Copied 2217_planet.tif to Google Drive folder.
# Copied 2053_planet.tif to Google Drive folder.
# Copied 443_planet.tif to Google Drive folder.
# Copied 1051_planet.tif to Google Drive folder.
# Copied 2574_planet.tif to Google Drive folder.
# Copied 69_planet.tif to Google Drive folder.
# Copied 730_planet.tif to Google Drive folder.
# Copied 1203_planet.tif to Google Drive folder.
# Copied 1821_planet.tif to Google Drive folder.
# Copied 36_planet.tif to Google Drive folder.
# Copied 2624_planet.tif to Google Drive folder.
# Copied 1721_planet.tif to Google Drive folder.
# Copied 1436_planet.tif to Google Drive folder.
# Copied 1046_planet.tif to Google Drive folder.
# Copied 2598_planet.tif to Google Drive folder.
# Copied 940_planet.tif to Google Drive folder.
# Copied 804_planet.tif to Google Drive folder.
# Copied 1570_planet.tif to Google Drive folder.
# Copied 2193_planet.tif to Google Drive folder.
# Copied 1836_planet.tif to Google Drive folder.
# Copied 2479_planet.tif to Google Drive folder.
# Copied 247_planet.tif to Google Drive folder.
# Copied 2251_planet.tif to Google Drive folder.
# Copied 2663_planet.tif to Google Drive folder.
# Copied 1096_planet.tif to Google Drive folder.
# Copied 264_planet.tif to Google Drive folder.
# Copied 1905_planet.tif to Google Drive folder.
# Copied 2524_planet.tif to Google Drive folder.
# Copied 1773_planet.tif to Google Drive folder.
# Copied 2400_planet.tif to Google Drive folder.
# Copied 1737_planet.tif to Google Drive folder.
# Copied 292_planet.tif to Google Drive folder.
# Copied 1829_planet.tif to Google Drive folder.
# Copied 337_planet.tif to Google Drive folder.
# Copied 1150_planet.tif to Google Drive folder.
# Copied 840_planet.tif to Google Drive folder.
# Copied 401_planet.tif to Google Drive folder.
# Copied 2000_planet.tif to Google Drive folder.
# Copied 1306_planet.tif to Google Drive folder.
# Copied 124_planet.tif to Google Drive folder.
# Copied 2158_planet.tif to Google Drive folder.
# Copied 1948_planet.tif to Google Drive folder.
# Copied 583_planet.tif to Google Drive folder.
# Copied 1012_planet.tif to Google Drive folder.
# Copied 2358_planet.tif to Google Drive folder.
# Copied 719_planet.tif to Google Drive folder.
# Copied 1908_planet.tif to Google Drive folder.
# Copied 2286_planet.tif to Google Drive folder.
# Copied 824_planet.tif to Google Drive folder.
# Copied 950_planet.tif to Google Drive folder.
# Copied 997_planet.tif to Google Drive folder.
# Copied 184_planet.tif to Google Drive folder.
# Copied 1643_planet.tif to Google Drive folder.
# Copied 984_planet.tif to Google Drive folder.
# Copied 766_planet.tif to Google Drive folder.
# Copied 855_planet.tif to Google Drive folder.
# Copied 1324_planet.tif to Google Drive folder.
# Copied 1581_planet.tif to Google Drive folder.
# Copied 2500_planet.tif to Google Drive folder.
# Copied 1961_planet.tif to Google Drive folder.
# Copied 34_planet.tif to Google Drive folder.
# Copied 1874_planet.tif to Google Drive folder.
# Copied 234_planet.tif to Google Drive folder.
# Copied 1178_planet.tif to Google Drive folder.
# Copied 591_planet.tif to Google Drive folder.
# Copied 2105_planet.tif to Google Drive folder.
# Copied 697_planet.tif to Google Drive folder.
# Copied 1080_planet.tif to Google Drive folder.
# Copied 1122_planet.tif to Google Drive folder.
# Copied 2137_planet.tif to Google Drive folder.
# Copied 420_planet.tif to Google Drive folder.
# Copied 1719_planet.tif to Google Drive folder.
# Copied 1801_planet.tif to Google Drive folder.
# Copied 117_planet.tif to Google Drive folder.
# Copied 361_planet.tif to Google Drive folder.
# Copied 2310_planet.tif to Google Drive folder.
# Copied 2221_planet.tif to Google Drive folder.
# Copied 785_planet.tif to Google Drive folder.
# Copied 183_planet.tif to Google Drive folder.
# Copied 2199_planet.tif to Google Drive folder.
# Copied 2650_planet.tif to Google Drive folder.
# Copied 1019_planet.tif to Google Drive folder.
# Copied 1290_planet.tif to Google Drive folder.
# Copied 1880_planet.tif to Google Drive folder.
# Copied 2314_planet.tif to Google Drive folder.
# Copied 747_planet.tif to Google Drive folder.
# Copied 612_planet.tif to Google Drive folder.
# Copied 776_planet.tif to Google Drive folder.
# Copied 2248_planet.tif to Google Drive folder.
# Copied 1635_planet.tif to Google Drive folder.
# Copied 992_planet.tif to Google Drive folder.
# Copied 333_planet.tif to Google Drive folder.
# Copied 291_planet.tif to Google Drive folder.
# Copied 1445_planet.tif to Google Drive folder.
# Copied 2391_planet.tif to Google Drive folder.
# Copied 1438_planet.tif to Google Drive folder.
# Copied 2211_planet.tif to Google Drive folder.
# Copied 2522_planet.tif to Google Drive folder.
# Copied 1699_planet.tif to Google Drive folder.
# Copied 2042_planet.tif to Google Drive folder.
# Copied 508_planet.tif to Google Drive folder.
# Copied 2192_planet.tif to Google Drive folder.
# Copied 1477_planet.tif to Google Drive folder.
# Copied 2646_planet.tif to Google Drive folder.
# Copied 600_planet.tif to Google Drive folder.
# Copied 2359_planet.tif to Google Drive folder.
# Copied 219_planet.tif to Google Drive folder.
# Copied 1452_planet.tif to Google Drive folder.
# Copied 2290_planet.tif to Google Drive folder.
# Copied 115_planet.tif to Google Drive folder.
# Copied 2408_planet.tif to Google Drive folder.
# Copied 2204_planet.tif to Google Drive folder.
# Copied 1850_planet.tif to Google Drive folder.
# Copied 1316_planet.tif to Google Drive folder.
# Copied 2287_planet.tif to Google Drive folder.
# Copied 2309_planet.tif to Google Drive folder.
# Copied 991_planet.tif to Google Drive folder.
# Copied 80_planet.tif to Google Drive folder.
# Copied 2095_planet.tif to Google Drive folder.
# Copied 1255_planet.tif to Google Drive folder.
# Copied 1228_planet.tif to Google Drive folder.
# Copied 1344_planet.tif to Google Drive folder.
# Copied 2325_planet.tif to Google Drive folder.
# Copied 1040_planet.tif to Google Drive folder.
# Copied 1988_planet.tif to Google Drive folder.
# Copied 1093_planet.tif to Google Drive folder.
# Copied 978_planet.tif to Google Drive folder.
# Copied 1420_planet.tif to Google Drive folder.
# Copied 873_planet.tif to Google Drive folder.
# Copied 1337_planet.tif to Google Drive folder.
# Copied 1788_planet.tif to Google Drive folder.
# Copied 1927_planet.tif to Google Drive folder.
# Copied 2167_planet.tif to Google Drive folder.
# ...
# Copied 1685_planet.tif to Google Drive folder.
# Copied 444_planet.tif to Google Drive folder.
# Copied 817_planet.tif to Google Drive folder.
# Copied 2438_planet.tif to Google Drive folder.
# Copied 1887_planet.tif to Google Drive folder.
# Copied 208_planet.tif to Google Drive folder.
# Copied 751_planet.tif to Google Drive folder.
# Copied 534_planet.tif to Google Drive folder.
# Copied 463_planet.tif to Google Drive folder.
# Copied 2593_planet.tif to Google Drive folder.
# Copied 652_planet.tif to Google Drive folder.
# Copied 1253_planet.tif to Google Drive folder.
# Copied 1694_planet.tif to Google Drive folder.
# Copied 2599_planet.tif to Google Drive folder.
# Copied 2023_planet.tif to Google Drive folder.
# Copied 1341_planet.tif to Google Drive folder.
# Copied 564_planet.tif to Google Drive folder.
# Copied 935_planet.tif to Google Drive folder.
# Copied 2399_planet.tif to Google Drive folder.
# Copied 307_planet.tif to Google Drive folder.
# Copied 954_planet.tif to Google Drive folder.
# Copied 2565_planet.tif to Google Drive folder.
# Copied 2666_planet.tif to Google Drive folder.
# Copied 1055_planet.tif to Google Drive folder.
# Copied 2344_planet.tif to Google Drive folder.
# Copied 777_planet.tif to Google Drive folder.
# Copied 158_planet.tif to Google Drive folder.
# Copied 1470_planet.tif to Google Drive folder.
# Copied 648_planet.tif to Google Drive folder.
# Copied 2084_planet.tif to Google Drive folder.
# Copied 277_planet.tif to Google Drive folder.
# Copied 1827_planet.tif to Google Drive folder.
# Copied 2339_planet.tif to Google Drive folder.
# Copied 94_planet.tif to Google Drive folder.
# Copied 2645_planet.tif to Google Drive folder.
# Copied 2629_planet.tif to Google Drive folder.
# Copied 905_planet.tif to Google Drive folder.
# Copied 1687_planet.tif to Google Drive folder.
# Copied 1385_planet.tif to Google Drive folder.
# Copied 967_planet.tif to Google Drive folder.
# Copied 1609_planet.tif to Google Drive folder.
# Copied 1744_planet.tif to Google Drive folder.
# Copied 2129_planet.tif to Google Drive folder.
# Copied 2388_planet.tif to Google Drive folder.
# Copied 565_planet.tif to Google Drive folder.
# Copied 637_planet.tif to Google Drive folder.
# Copied 883_planet.tif to Google Drive folder.
# Copied 1489_planet.tif to Google Drive folder.
# Copied 341_planet.tif to Google Drive folder.
# Copied 854_planet.tif to Google Drive folder.
# Copied 407_planet.tif to Google Drive folder.
# Copied 1752_planet.tif to Google Drive folder.
# Copied 1174_planet.tif to Google Drive folder.
# Copied 2649_planet.tif to Google Drive folder.
# Copied 1571_planet.tif to Google Drive folder.
# Copied 778_planet.tif to Google Drive folder.
# Copied 9_planet.tif to Google Drive folder.
# Copied 2594_planet.tif to Google Drive folder.
# Copied 1357_planet.tif to Google Drive folder.
# Copied 2362_planet.tif to Google Drive folder.
# Copied 149_planet.tif to Google Drive folder.
# Copied 1139_planet.tif to Google Drive folder.
# Copied 2603_planet.tif to Google Drive folder.
# Copied 584_planet.tif to Google Drive folder.
# Copied 769_planet.tif to Google Drive folder.
# Copied 1155_planet.tif to Google Drive folder.
# Copied 397_planet.tif to Google Drive folder.
# Copied 969_planet.tif to Google Drive folder.
# Copied 1746_planet.tif to Google Drive folder.
# Copied 2518_planet.tif to Google Drive folder.
# Copied 1125_planet.tif to Google Drive folder.
# Copied 2115_planet.tif to Google Drive folder.
# Copied 1042_planet.tif to Google Drive folder.
# Copied 656_planet.tif to Google Drive folder.
# Copied 329_planet.tif to Google Drive folder.
# Copied 259_planet.tif to Google Drive folder.
# Copied 2177_planet.tif to Google Drive folder.
# Copied 1884_planet.tif to Google Drive folder.
# Copied 574_planet.tif to Google Drive folder.
# Copied 374_planet.tif to Google Drive folder.
# Copied 1899_planet.tif to Google Drive folder.
# Copied 1102_planet.tif to Google Drive folder.
# Copied 285_planet.tif to Google Drive folder.
# Copied 938_planet.tif to Google Drive folder.
# Copied 1935_planet.tif to Google Drive folder.
# Copied 10_planet.tif to Google Drive folder.
# Copied 1921_planet.tif to Google Drive folder.
# Copied 2080_planet.tif to Google Drive folder.
# Copied 446_planet.tif to Google Drive folder.
# Copied 1321_planet.tif to Google Drive folder.
# Copied 792_planet.tif to Google Drive folder.
# Copied 1429_planet.tif to Google Drive folder.
# Copied 1863_planet.tif to Google Drive folder.
# Copied 1382_planet.tif to Google Drive folder.
# Copied 525_planet.tif to Google Drive folder.
# Copied 2001_planet.tif to Google Drive folder.
# Copied 511_planet.tif to Google Drive folder.
# Copied 287_planet.tif to Google Drive folder.
# Copied 226_planet.tif to Google Drive folder.
# Copied 964_planet.tif to Google Drive folder.
# Copied 1068_planet.tif to Google Drive folder.
# Copied 2468_planet.tif to Google Drive folder.
# Copied 98_planet.tif to Google Drive folder.
# Copied 1130_planet.tif to Google Drive folder.
# Copied 214_planet.tif to Google Drive folder.
# Copied 7_planet.tif to Google Drive folder.
# Copied 673_planet.tif to Google Drive folder.
# Copied 507_planet.tif to Google Drive folder.
# Copied 96_planet.tif to Google Drive folder.
# Copied 1834_planet.tif to Google Drive folder.
# Copied 1229_planet.tif to Google Drive folder.
# Copied 2504_planet.tif to Google Drive folder.
# Copied 701_planet.tif to Google Drive folder.
# Copied 2394_planet.tif to Google Drive folder.
# Copied 758_planet.tif to Google Drive folder.
# Copied 890_planet.tif to Google Drive folder.
# Copied 1232_planet.tif to Google Drive folder.
# Copied 1403_planet.tif to Google Drive folder.
# Copied 639_planet.tif to Google Drive folder.
# Copied 1799_planet.tif to Google Drive folder.
# Copied 1247_planet.tif to Google Drive folder.
# Copied 1077_planet.tif to Google Drive folder.
# Copied 2259_planet.tif to Google Drive folder.
# Copied 2425_planet.tif to Google Drive folder.
# Copied 2405_planet.tif to Google Drive folder.
# Copied 2376_planet.tif to Google Drive folder.
# Copied 1543_planet.tif to Google Drive folder.
# Copied 2426_planet.tif to Google Drive folder.
# Copied 1890_planet.tif to Google Drive folder.
# Copied 260_planet.tif to Google Drive folder.
# Copied 1715_planet.tif to Google Drive folder.
# Copied 402_planet.tif to Google Drive folder.
# Copied 2328_planet.tif to Google Drive folder.
# Copied 636_planet.tif to Google Drive folder.
# Copied 966_planet.tif to Google Drive folder.
# Copied 1598_planet.tif to Google Drive folder.
# Copied 607_planet.tif to Google Drive folder.
# Copied 1519_planet.tif to Google Drive folder.
# Copied 1879_planet.tif to Google Drive folder.
# Copied 269_planet.tif to Google Drive folder.
# Copied 1132_planet.tif to Google Drive folder.
# Copied 1367_planet.tif to Google Drive folder.
# Copied 2265_planet.tif to Google Drive folder.
# Copied 1061_planet.tif to Google Drive folder.
# Copied 822_planet.tif to Google Drive folder.
# Copied 660_planet.tif to Google Drive folder.
# Copied 290_planet.tif to Google Drive folder.
# Copied 2165_planet.tif to Google Drive folder.
# Copied 181_planet.tif to Google Drive folder.
# Copied 590_planet.tif to Google Drive folder.
# Copied 2519_planet.tif to Google Drive folder.
# Copied 202_planet.tif to Google Drive folder.
# Copied 644_planet.tif to Google Drive folder.
# Copied 23_planet.tif to Google Drive folder.
# Copied 2549_planet.tif to Google Drive folder.
# Copied 342_planet.tif to Google Drive folder.
# Copied 1073_planet.tif to Google Drive folder.
# Copied 57_planet.tif to Google Drive folder.
# Copied 742_planet.tif to Google Drive folder.
# Copied 2216_planet.tif to Google Drive folder.
# Copied 1873_planet.tif to Google Drive folder.
# Copied 782_planet.tif to Google Drive folder.
# Copied 1271_planet.tif to Google Drive folder.
# Copied 750_planet.tif to Google Drive folder.
# Copied 1777_planet.tif to Google Drive folder.
# Copied 2534_planet.tif to Google Drive folder.
# Copied 1688_planet.tif to Google Drive folder.
# Copied 2542_planet.tif to Google Drive folder.
# Copied 857_planet.tif to Google Drive folder.
# Copied 2492_planet.tif to Google Drive folder.
# Copied 494_planet.tif to Google Drive folder.
# Copied 604_planet.tif to Google Drive folder.
# Copied 1506_planet.tif to Google Drive folder.
# Copied 188_planet.tif to Google Drive folder.
# Copied 240_planet.tif to Google Drive folder.
# Copied 2429_planet.tif to Google Drive folder.
# Copied 1647_planet.tif to Google Drive folder.
# Copied 308_planet.tif to Google Drive folder.
# Copied 2374_planet.tif to Google Drive folder.
# Copied 236_planet.tif to Google Drive folder.
# Copied 825_planet.tif to Google Drive folder.
# Copied 676_planet.tif to Google Drive folder.
# Copied 1667_planet.tif to Google Drive folder.
# Copied 1196_planet.tif to Google Drive folder.
# Copied 807_planet.tif to Google Drive folder.
# Copied 932_planet.tif to Google Drive folder.
# Copied 224_planet.tif to Google Drive folder.
# Copied 279_planet.tif to Google Drive folder.
# Copied 1515_planet.tif to Google Drive folder.
# Copied 52_planet.tif to Google Drive folder.
# Copied 2338_planet.tif to Google Drive folder.
# Copied 1762_planet.tif to Google Drive folder.
# Copied 716_planet.tif to Google Drive folder.
# Copied 2609_planet.tif to Google Drive folder.
# Copied 844_planet.tif to Google Drive folder.
# Copied 1016_planet.tif to Google Drive folder.
# Copied 813_planet.tif to Google Drive folder.
# Copied 733_planet.tif to Google Drive folder.
# Copied 2623_planet.tif to Google Drive folder.
# Copied 2600_planet.tif to Google Drive folder.
# Copied 2546_planet.tif to Google Drive folder.
# Copied 2268_planet.tif to Google Drive folder.
# Copied 1507_planet.tif to Google Drive folder.
# Copied 2074_planet.tif to Google Drive folder.
# Copied 532_planet.tif to Google Drive folder.
# Copied 2509_planet.tif to Google Drive folder.
# Copied 1824_planet.tif to Google Drive folder.
# Copied 1724_planet.tif to Google Drive folder.
# Copied 459_planet.tif to Google Drive folder.
# Copied 1090_planet.tif to Google Drive folder.
# Copied 901_planet.tif to Google Drive folder.
# Copied 1441_planet.tif to Google Drive folder.
# Copied 2175_planet.tif to Google Drive folder.
# Copied 144_planet.tif to Google Drive folder.
# Copied 2282_planet.tif to Google Drive folder.
# Copied 1288_planet.tif to Google Drive folder.
# Copied 197_planet.tif to Google Drive folder.
# Copied 1521_planet.tif to Google Drive folder.
# Copied 2236_planet.tif to Google Drive folder.
# Copied 432_planet.tif to Google Drive folder.
# Copied 2219_planet.tif to Google Drive folder.
# Copied 105_planet.tif to Google Drive folder.
# Copied 457_planet.tif to Google Drive folder.
# Copied 578_planet.tif to Google Drive folder.
# Copied 1706_planet.tif to Google Drive folder.
# Copied 1987_planet.tif to Google Drive folder.
# Copied 1929_planet.tif to Google Drive folder.
# Copied 2559_planet.tif to Google Drive folder.
# Copied 2146_planet.tif to Google Drive folder.
# Copied 1696_planet.tif to Google Drive folder.
# Copied 868_planet.tif to Google Drive folder.
# Copied 2582_planet.tif to Google Drive folder.
# Copied 2163_planet.tif to Google Drive folder.
# Copied 2657_planet.tif to Google Drive folder.
# Copied 275_planet.tif to Google Drive folder.
# Copied 1110_planet.tif to Google Drive folder.
# Copied 558_planet.tif to Google Drive folder.
# Copied 832_planet.tif to Google Drive folder.
# Copied 2554_planet.tif to Google Drive folder.
# Copied 71_planet.tif to Google Drive folder.
# Copied 504_planet.tif to Google Drive folder.
# Copied 1160_planet.tif to Google Drive folder.
# Copied 1878_planet.tif to Google Drive folder.
# Copied 708_planet.tif to Google Drive folder.
# Copied 1334_planet.tif to Google Drive folder.
# Copied 893_planet.tif to Google Drive folder.
# Copied 1081_planet.tif to Google Drive folder.
# Copied 1900_planet.tif to Google Drive folder.
# Copied 177_planet.tif to Google Drive folder.
# Copied 2557_planet.tif to Google Drive folder.
# Copied 761_planet.tif to Google Drive folder.
# Copied 78_planet.tif to Google Drive folder.
# Copied 2292_planet.tif to Google Drive folder.
# Copied 668_planet.tif to Google Drive folder.
# Copied 141_planet.tif to Google Drive folder.
# Copied 1621_planet.tif to Google Drive folder.
# Copied 1089_planet.tif to Google Drive folder.
# Copied 2372_planet.tif to Google Drive folder.
# Copied 2610_planet.tif to Google Drive folder.
# Copied 2008_planet.tif to Google Drive folder.
# Copied 1214_planet.tif to Google Drive folder.
# Copied 2264_planet.tif to Google Drive folder.
# Copied 1408_planet.tif to Google Drive folder.
# Copied 772_planet.tif to Google Drive folder.
# Copied 1372_planet.tif to Google Drive folder.
# Copied 363_planet.tif to Google Drive folder.
# Copied 842_planet.tif to Google Drive folder.
# Copied 1796_planet.tif to Google Drive folder.
# Copied 1870_planet.tif to Google Drive folder.
# Copied 1010_planet.tif to Google Drive folder.
# Copied 462_planet.tif to Google Drive folder.
# Copied 352_planet.tif to Google Drive folder.
# Copied 783_planet.tif to Google Drive folder.
# Copied 206_planet.tif to Google Drive folder.
# Copied 2181_planet.tif to Google Drive folder.
# Copied 2511_planet.tif to Google Drive folder.
# Copied 2488_planet.tif to Google Drive folder.
# Copied 248_planet.tif to Google Drive folder.
# Copied 1218_planet.tif to Google Drive folder.
# Copied 1672_planet.tif to Google Drive folder.
# Copied 2092_planet.tif to Google Drive folder.
# Copied 1885_planet.tif to Google Drive folder.
# Copied 1658_planet.tif to Google Drive folder.
# Copied 1965_planet.tif to Google Drive folder.
# Copied 1638_planet.tif to Google Drive folder.
# Copied 2384_planet.tif to Google Drive folder.
# Copied 975_planet.tif to Google Drive folder.
# Copied 464_planet.tif to Google Drive folder.
# Copied 1734_planet.tif to Google Drive folder.
# Copied 1339_planet.tif to Google Drive folder.
# Copied 1473_planet.tif to Google Drive folder.
# Copied 5_planet.tif to Google Drive folder.
# Copied 2308_planet.tif to Google Drive folder.
# Copied 289_planet.tif to Google Drive folder.
# Copied 2606_planet.tif to Google Drive folder.
# Copied 1862_planet.tif to Google Drive folder.
# Copied 1135_planet.tif to Google Drive folder.
# Copied 1350_planet.tif to Google Drive folder.
# Copied 1275_planet.tif to Google Drive folder.
# Copied 1225_planet.tif to Google Drive folder.
# Copied 1725_planet.tif to Google Drive folder.
# Copied 1427_planet.tif to Google Drive folder.
# Copied 146_planet.tif to Google Drive folder.
# Copied 753_planet.tif to Google Drive folder.
# Copied 683_planet.tif to Google Drive folder.
# Copied 284_planet.tif to Google Drive folder.
# Copied 2075_planet.tif to Google Drive folder.
# Copied 1259_planet.tif to Google Drive folder.
# Copied 1402_planet.tif to Google Drive folder.
# Copied 841_planet.tif to Google Drive folder.
# Copied 1909_planet.tif to Google Drive folder.
# Copied 2427_planet.tif to Google Drive folder.
# Copied 2577_planet.tif to Google Drive folder.
# Copied 694_planet.tif to Google Drive folder.
# Copied 133_planet.tif to Google Drive folder.
# Copied 1864_planet.tif to Google Drive folder.
# Copied 2401_planet.tif to Google Drive folder.
# Copied 2298_planet.tif to Google Drive folder.
# Copied 1781_planet.tif to Google Drive folder.
# Copied 1825_planet.tif to Google Drive folder.
# Copied 339_planet.tif to Google Drive folder.
# Copied 693_planet.tif to Google Drive folder.
# Copied 400_planet.tif to Google Drive folder.
# Copied 1610_planet.tif to Google Drive folder.
# Copied 999_planet.tif to Google Drive folder.
# Copied 906_planet.tif to Google Drive folder.
# Copied 1713_planet.tif to Google Drive folder.
# Copied 2270_planet.tif to Google Drive folder.
# Copied 835_planet.tif to Google Drive folder.
# Copied 2150_planet.tif to Google Drive folder.
# Copied 1526_planet.tif to Google Drive folder.
# Copied 1582_planet.tif to Google Drive folder.
# Copied 1276_planet.tif to Google Drive folder.
# Copied 2558_planet.tif to Google Drive folder.
# Copied 2367_planet.tif to Google Drive folder.
# Copied 210_planet.tif to Google Drive folder.
# Copied 2139_planet.tif to Google Drive folder.
# Copied 282_planet.tif to Google Drive folder.
# Copied 740_planet.tif to Google Drive folder.
# Copied 468_planet.tif to Google Drive folder.
# Copied 522_planet.tif to Google Drive folder.
# Copied 1086_planet.tif to Google Drive folder.
# Copied 88_planet.tif to Google Drive folder.

# %%
# original images and labels folder: how many files are there?
iamges = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/images_2018'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')


iamges_two = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/images_2019'
image_folder_two = os.listdir(iamges_two)
image_folder_two_count = len(image_folder_two)
print(f'The number of files in the folder is: {image_folder_two_count}')


iamges_three = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/images_2020'
image_folder_three = os.listdir(iamges_three)
image_folder_three_count = len(image_folder_three)
print(f'The number of files in the folder is: {image_folder_three_count}')

iamges = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/ccap_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')


iamges_two = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/dem'
image_folder_two = os.listdir(iamges_two)
image_folder_two_count = len(image_folder_two)
print(f'The number of files in the folder is: {image_folder_two_count}')


iamges_three = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/nwi_ccap_filled'
image_folder_three = os.listdir(iamges_three)
image_folder_three_count = len(image_folder_three)
print(f'The number of files in the folder is: {image_folder_three_count}')


iamges_three = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm5/nwi_nlcd_filled'
image_folder_three = os.listdir(iamges_three)
image_folder_three_count = len(image_folder_three)
print(f'The number of files in the folder is: {image_folder_three_count}')
# Out:
# The number of files in the folder is: 229
# The number of files in the folder is: 229
# The number of files in the folder is: 229
# The number of files in the folder is: 229
# The number of files in the folder is: 229
# The number of files in the folder is: 229
# The number of files in the folder is: 229

# %%
# original images and labels folder: how many files are there?
iamges = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/images_2018'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')


iamges_two = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/images_2019'
image_folder_two = os.listdir(iamges_two)
image_folder_two_count = len(image_folder_two)
print(f'The number of files in the folder is: {image_folder_two_count}')


iamges_three = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/images_2020'
image_folder_three = os.listdir(iamges_three)
image_folder_three_count = len(image_folder_three)
print(f'The number of files in the folder is: {image_folder_three_count}')

iamges = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/ccap_filled'
image_folder_one = os.listdir(iamges)
image_folder_one_count = len(image_folder_one)
print(f'The number of files in the folder is: {image_folder_one_count}')


iamges_two = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/dem'
image_folder_two = os.listdir(iamges_two)
image_folder_two_count = len(image_folder_two)
print(f'The number of files in the folder is: {image_folder_two_count}')


iamges_three = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/nwi_ccap_filled'
image_folder_three = os.listdir(iamges_three)
image_folder_three_count = len(image_folder_three)
print(f'The number of files in the folder is: {image_folder_three_count}')


iamges_three = '/content/drive/MyDrive/DeepLearning_Project/trainingdata/planet128x128data/utm4/nwi_nlcd_filled'
image_folder_three = os.listdir(iamges_three)
image_folder_three_count = len(image_folder_three)
print(f'The number of files in the folder is: {image_folder_three_count}')
# Out:
# The number of files in the folder is: 2629
# The number of files in the folder is: 2629
# The number of files in the folder is: 2629
# The number of files in the folder is: 2629
# The number of files in the folder is: 2629
# The number of files in the folder is: 2629
# The number of files in the folder is: 2629
