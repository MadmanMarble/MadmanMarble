# %% [markdown]
# <a href="https://colab.research.google.com/github/MadmanMarble/MadmanMarble/blob/main/Copy_from_GCS_to_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
auth.authenticate_user()

# %%
project_id = 'big-passage-402400'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://datahub_bucket/

# %%
# !gsutil ls gs://datahub_bucket/subset_data/
# Out:
# gs://datahub_bucket/subset_data/HawaiI_2005_001_subset/
# gs://datahub_bucket/subset_data/Hawaii_2005_002_subset/
# gs://datahub_bucket/subset_data/Hawaii_2005_004_subset/
# gs://datahub_bucket/subset_data/Hawaii_2005_005_subset/
# gs://datahub_bucket/subset_data/Hawaii_2005_006_subset/
# gs://datahub_bucket/subset_data/Hawaii_2005_007_subset/
# gs://datahub_bucket/subset_data/Hawaii_2005_008_subset/
# gs://datahub_bucket/subset_data/Hawaii_2010_001_subset/
# gs://datahub_bucket/subset_data/Hawaii_2010_002_subset/
# gs://datahub_bucket/subset_data/Hawaii_2010_003_subset/
# gs://datahub_bucket/subset_data/Hawaii_2010_004_subset/
# gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/
# gs://datahub_bucket/subset_data/Hawaii_2010_006_subset/
# gs://datahub_bucket/subset_data/Hawaii_2010_007_subset/
# gs://datahub_bucket/subset_data/Hawaii_2010_008_subset/
# gs://datahub_bucket/subset_data/Kauai10_subset/
# gs://datahub_bucket/subset_data/Kauai_subset/
# ...

# %%
# bucket_name = 'datahub_bucket'
# !gsutil -m cp -r gs://datahub_bucket/subset_data* /content/drive/My\ Drive/unet_data/
# Out:
# Streaming output truncated to the last 5000 lines.
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/15873_513.tif...
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/15873_5633.tif...
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/16385_1.tif...
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/16385_1025.tif...
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/16385_1537.tif...
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/16385_16385.tif...
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/16385_2049.tif...
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/16385_2561.tif...
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/16385_3073.tif...
# Copying gs://datahub_bucket/subset_data/Hawaii_2010_005_subset/Labels/16385_3585.tif...
# ...

# %%
# !cp /content/drive/MyDrive/wetland_unet/UNET_Image_Chips/imagechip_trainingdata/*.csv /content/drive/My\ Drive/unet_data/csv_files
